# %%
from functions import transform_raw_data, clean_df, impute_fit_df, impute_transform_df

from imblearn.pipeline import Pipeline
from imblearn.over_sampling import SMOTE
from sklearn.base import BaseEstimator, TransformerMixin
from sklearn.dummy import DummyClassifier
from sklearn.metrics import  f1_score, make_scorer, confusion_matrix, ConfusionMatrixDisplay, roc_auc_score, precision_score, PrecisionRecallDisplay
from sklearn.model_selection import train_test_split,  StratifiedKFold, RandomizedSearchCV
from sklearn.ensemble import RandomForestClassifier
from xgboost import XGBClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC, OneClassSVM
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import GaussianNB, MultinomialNB, BernoulliNB
from hyperopt import fmin, tpe, hp, STATUS_OK

import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
from collections import Counter

# %% [markdown]
# - target = fatality
# - only considered columns with roughly <30% missing
# - removing missing values

# %%
# creating dictionary of categorical column names : corresponding one-hot encoded columns names
# this is used to make sure every X dataset in the CV has the same columns
df = transform_raw_data(path_to_csv="stats19CycleCollisions2022.csv")
cols = ['day_of_week','time','first_road_class','road_type','speed_limit','junction_detail','second_road_class',
        'light_conditions','weather_conditions','road_surface_conditions','vehicle_type','age_of_casualty','casualty_severity',
        'pedestrian_crossing_physical_facilities','vehicle_subtype','vehicle_manoeuvre','season','junction_control',
        'propulsion_code','urban_or_rural_area','first_point_of_impact']
df = df[cols]
categorical_columns = [col for col in df.select_dtypes(include='object').columns if col not in ['time','casualty_severity']] + ['speed_limit']
df = clean_df(df)
categorical_freqs, vars_to_groupby, continuous_medians_grouped, continuous_medians, scaler = impute_fit_df(df)
df = impute_transform_df(df, categorical_freqs, vars_to_groupby, continuous_medians_grouped, continuous_medians, scaler, df.columns)

encoded_cols_dict = {}

for col in categorical_columns:
    encoded_cols = [encoded_col for encoded_col in df.columns if col in encoded_col]
    if len(encoded_cols) > 0:
        encoded_cols_dict[col] = encoded_cols
# Out:
# c:\Users\danjr\Documents\Projects\cycle collisions\functions.py:6: DtypeWarning: Columns (0,2,39,72) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(path_to_csv, header=0)

# %%
# custom Transformer class for applying preprocessing in pipeline
class CustomPreprocessor(BaseEstimator, TransformerMixin):
    def __init__(self, one_hot_encoded_cols=None):
        self.categorical_freqs = None
        self.continuous_medians_grouped = None
        self.continuous_medians = None
        self.vars_to_groupby = None
        self.scaler = None
        self.features = None
        self.one_hot_encoded_cols = one_hot_encoded_cols

    # fit is only called on the train data
    def fit(self, X, y=None):
        # calculate impute values
        self.categorical_freqs, self.vars_to_groupby, self.continuous_medians_grouped, self.continuous_medians, self.scaler = impute_fit_df(X)
        return self

    # transform is called on the both the train and test data
    def transform(self, X, y=None):
        # apply the preprocessing function to the data
        df = impute_transform_df(X, self.categorical_freqs, self.vars_to_groupby, self.continuous_medians_grouped,
                                 self.continuous_medians, self.scaler, X.columns,
                                 encoded_cols_dict=encoded_cols_dict, one_hot_encoded_cols=self.one_hot_encoded_cols)
        df['log_engine_capacity_cc'] = np.log(df['engine_capacity_cc'] + 0.0000001)
        self.features = df.columns
        return df

# %%
df = transform_raw_data(path_to_csv="stats19CycleCollisions2022.csv")
cols = ['age_of_casualty','engine_capacity_cc','age_of_driver',
            'vehicle_type','vehicle_subtype','junction_detail','towing_and_articulation','vehicle_manoeuvre',
            'casualty_imd_decile','pedestrian_crossing_physical_facilities','pedestrian_crossing_human_control','driver_imd_decile',
            'day_of_week','time_period','season',
            'first_road_class','road_type','speed_limit','junction_control','second_road_class',
            'light_conditions','weather_conditions','road_surface_conditions','propulsion_code','sex_of_casualty',
            'urban_or_rural_area','casualty_home_area_type','first_point_of_impact','junction_location','casualty_severity','time'
        ]
df = clean_df(df)
df['fatality'] = np.where(df['casualty_severity'] == "Fatal", 1, 0)
target = 'fatality'
df = df[cols + [target]]
# Out:
# c:\Users\danjr\Documents\Projects\cycle collisions\functions.py:6: DtypeWarning: Columns (0,2,39,72) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(path_to_csv, header=0)

# %%
df.shape
# Out:
# (16155, 32)

# %% [markdown]
# feature engineering

# %%
df['hour'] = df.time.str.slice(start=0, stop=2).astype('int')
df['morning'] = np.where((df['hour'] >= 0) & (df['hour'] <= 12), 1, 0)
df['evening'] = np.where((df['hour'] >= 16) & (df['hour'] <= 22), 1, 0)

df['casualty_imd_decile_lessdeprived'] = np.where(df['casualty_imd_decile'].str.contains('Le'), 1, 0)
df['casualty_imd_decile_moredeprived'] = np.where(df['casualty_imd_decile'].str.contains('Mo'), 1, 0)
df['driver_imd_decile_lessdeprived'] = np.where(df['driver_imd_decile'].str.contains('Le'), 1, 0)
df['driver_imd_decile_moredeprived'] = np.where(df['driver_imd_decile'].str.contains('Mo'), 1, 0)

df['turning_left_or_right'] = np.where(df['vehicle_manoeuvre'].str.contains('Turning'), 1, 0)

df['poor_lighting'] = np.where(df['light_conditions'].str.contains('lights un|no lighting'), 1, 0)

df['raining_no_high_wind'] = np.where(df['weather_conditions'] == 'Raining no high wind', 1, 0)
df['high_wind_or_fog'] = np.where(df['weather_conditions'].str.contains('+ high winds|Fog|Other'), 1, 0)

# %% [markdown]
# experiments

# %%
features = ['age_of_casualty','engine_capacity_cc','vehicle_type','vehicle_subtype',
            'junction_detail','vehicle_manoeuvre',
            'casualty_imd_decile_lessdeprived','casualty_imd_decile_moredeprived',
            'driver_imd_decile_lessdeprived','driver_imd_decile_moredeprived',
            'morning','evening','turning_left_or_right','poor_lighting',
            'season','first_road_class','second_road_class','road_type',
            'speed_limit','junction_control','road_surface_conditions','propulsion_code',
            'urban_or_rural_area','first_point_of_impact']
one_hot_encoded_cols = [
    'vehicle_type_Car',
    'vehicle_type_Pedal cycle',
    'vehicle_subtype_1. HGV',
    'vehicle_subtype_3. Bus',
    'junction_detail_Not at junction or within 20 metres',
    'junction_detail_Roundabout',
    'vehicle_manoeuvre_Going ahead other',
    'season_winter',
    'first_road_class_A',
    'first_road_class_Unclassified',
    'road_type_Dual carriageway',
    'junction_control_Give way or uncontrolled',
    'second_road_class_Unclassified',
    'road_surface_conditions_Wet or damp',
    'propulsion_code_Heavy oil',
    'propulsion_code_Petrol',
    'propulsion_code_Undefined',
    'urban_or_rural_area_Rural',
    'first_point_of_impact_Front'
]

# %%
# baseline accuracy -> dummy classifier predicting class at random
pipeline = Pipeline([
    ('custom_preprocessor', CustomPreprocessor()),
    ('classifier', DummyClassifier(strategy="uniform"))
])
X_train, X_test, y_train, y_test = train_test_split(df[features], df[target], test_size=0.1, random_state=42)
pipeline.fit(X_train, y_train)
y_pred_dummy = pipeline.predict(X_test)
precision = f1_score(y_test, y_pred_dummy)
print(precision)
cm = confusion_matrix(y_test, y_pred_dummy)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=pipeline.classes_)
disp.plot()

PrecisionRecallDisplay.from_estimator(pipeline, X_test, y_test)
plt.show()
# Out:
# 0.007692307692307692

# %%
X_train, X_test, y_train, y_test = train_test_split(df[features], df[target], test_size=0.1, random_state=42)

# %%
counter = Counter(y_train)
print(counter)
# Out:
# Counter({0: 14454, 1: 85})

# %% [markdown]
# Random forests
#
# a. class weight balanced

# %%
def run_experiment(features, param_distributions, pipeline,
                   n_splits=4, n_iter=40, 
                   classifier=None, one_hot_encoded_cols=None, plot_param_charts=True):

    cv = StratifiedKFold(n_splits=n_splits)
    scoring = {
        "precision": make_scorer(precision_score)
    }
    random_search = RandomizedSearchCV(
        estimator=pipeline,
        param_distributions=param_distributions,
        n_iter=n_iter,  # Number of random combinations to try
        scoring=scoring,  # Choose your preferred metric
        cv=cv,  # StratifiedKFold cross-validation
        verbose=10,  # Print out progress
        n_jobs=1,  # Use all available cores
        random_state=42,  # Reproducibility
        refit="precision",
        return_train_score=True
    )
    random_search.fit(X_train, y_train)
    print(random_search.best_score_, random_search.best_params_)

    clf = random_search.best_estimator_
    clf.fit(X_train, y_train)
    y_pred = clf.predict(X_test)
    cm = confusion_matrix(y_test, y_pred)
    disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=clf.classes_)
    disp.plot()
    print(precision_score(y_test, y_pred))
    PrecisionRecallDisplay.from_estimator(clf, X_test, y_test)
    plt.show()

    # for each parameter, plot line graphs of the train auc score, test auc score, and train - test score (to identify overfitting)
    if plot_param_charts:
        cv_results_df = pd.DataFrame(random_search.cv_results_)
        params = list(cv_results_df.params[0].keys())
        cv_results_df['train_test_diff_precision'] = cv_results_df['mean_train_precision'] - cv_results_df['mean_test_precision']

        num_cols = 3
        num_rows = (3*len(param_distributions) + num_cols - 1) // num_cols
        fig, ax = plt.subplots(ncols=num_cols, nrows=num_rows, figsize=(15, 4*num_rows))
        ax = ax.flatten()

        for i, param in enumerate(params):
            sns.lineplot(cv_results_df, x='param_' + param, y='mean_test_precision', label='Test precision', ax=ax[i*3+0])
            sns.lineplot(cv_results_df, x='param_' + param, y='mean_train_precision', label='Train precision', ax=ax[i*3+1])
            sns.lineplot(cv_results_df, x='param_' + param, y='train_test_diff_precision', label='Train-Test precision Difference', ax=ax[i*3+2])

        plt.legend()
        plt.show()
    
    return random_search

# %%
param_distributions = {
        "classifier__min_samples_split": [int(i) for i in np.linspace(2, 400, 50)],
        "classifier__max_features": [int(i) for i in np.linspace(1, 37, 30)],
        "classifier__max_depth": [int(i) for i in np.linspace(10, 750, 50)] + [None]
    }
classifier = RandomForestClassifier(n_estimators=750, class_weight='balanced')
pipeline = Pipeline([
        ('custom_preprocessor', CustomPreprocessor(one_hot_encoded_cols)),
        ('classifier', classifier)
    ])
random_search = run_experiment(features, param_distributions, pipeline, 
                               n_iter=40, n_splits=4, 
                               classifier=classifier, one_hot_encoded_cols=one_hot_encoded_cols)
# Out:
# Fitting 4 folds for each of 40 candidates, totalling 160 fits
# [CV 1/4; 1/40] START classifier__max_depth=161, classifier__max_features=19, classifier__min_samples_split=367
# [CV 1/4; 1/40] END classifier__max_depth=161, classifier__max_features=19, classifier__min_samples_split=367; precision: (train=0.062, test=0.037) total time=   8.0s
# [CV 2/4; 1/40] START classifier__max_depth=161, classifier__max_features=19, classifier__min_samples_split=367
# [CV 2/4; 1/40] END classifier__max_depth=161, classifier__max_features=19, classifier__min_samples_split=367; precision: (train=0.062, test=0.032) total time=   8.1s
# [CV 3/4; 1/40] START classifier__max_depth=161, classifier__max_features=19, classifier__min_samples_split=367
# [CV 3/4; 1/40] END classifier__max_depth=161, classifier__max_features=19, classifier__min_samples_split=367; precision: (train=0.063, test=0.050) total time=   9.7s
# [CV 4/4; 1/40] START classifier__max_depth=161, classifier__max_features=19, classifier__min_samples_split=367
# [CV 4/4; 1/40] END classifier__max_depth=161, classifier__max_features=19, classifier__min_samples_split=367; precision: (train=0.064, test=0.041) total time=   9.4s
# [CV 1/4; 2/40] START classifier__max_depth=10, classifier__max_features=22, classifier__min_samples_split=83
# [CV 1/4; 2/40] END classifier__max_depth=10, classifier__max_features=22, classifier__min_samples_split=83; precision: (train=0.256, test=0.108) total time=  10.0s
# [CV 2/4; 2/40] START classifier__max_depth=10, classifier__max_features=22, classifier__min_samples_split=83
# [CV 2/4; 2/40] END classifier__max_depth=10, classifier__max_features=22, classifier__min_samples_split=83; precision: (train=0.203, test=0.057) total time=  12.6s
# [CV 3/4; 2/40] START classifier__max_depth=10, classifier__max_features=22, classifier__min_samples_split=83
# [CV 3/4; 2/40] END classifier__max_depth=10, classifier__max_features=22, classifier__min_samples_split=83; precision: (train=0.223, test=0.092) total time=  11.0s
# [CV 4/4; 2/40] START classifier__max_depth=10, classifier__max_features=22, classifier__min_samples_split=83
# [CV 4/4; 2/40] END classifier__max_depth=10, classifier__max_features=22, classifier__min_samples_split=83; precision: (train=0.198, test=0.034) total time=  10.7s
# [CV 1/4; 3/40] START classifier__max_depth=553, classifier__max_features=22, classifier__min_samples_split=294
# [CV 1/4; 3/40] END classifier__max_depth=553, classifier__max_features=22, classifier__min_samples_split=294; precision: (train=0.071, test=0.037) total time=   9.2s
# [CV 2/4; 3/40] START classifier__max_depth=553, classifier__max_features=22, classifier__min_samples_split=294
# [CV 2/4; 3/40] END classifier__max_depth=553, classifier__max_features=22, classifier__min_samples_split=294; precision: (train=0.072, test=0.035) total time=   9.3s
# [CV 3/4; 3/40] START classifier__max_depth=553, classifier__max_features=22, classifier__min_samples_split=294
# [CV 3/4; 3/40] END classifier__max_depth=553, classifier__max_features=22, classifier__min_samples_split=294; precision: (train=0.073, test=0.058) total time=   9.2s
# [CV 4/4; 3/40] START classifier__max_depth=553, classifier__max_features=22, classifier__min_samples_split=294
# [CV 4/4; 3/40] END classifier__max_depth=553, classifier__max_features=22, classifier__min_samples_split=294; precision: (train=0.074, test=0.040) total time=  10.0s
# [CV 1/4; 4/40] START classifier__max_depth=70, classifier__max_features=7, classifier__min_samples_split=123
# [CV 1/4; 4/40] END classifier__max_depth=70, classifier__max_features=7, classifier__min_samples_split=123; precision: (train=0.205, test=0.084) total time=   5.2s
# [CV 2/4; 4/40] START classifier__max_depth=70, classifier__max_features=7, classifier__min_samples_split=123
# [CV 2/4; 4/40] END classifier__max_depth=70, classifier__max_features=7, classifier__min_samples_split=123; precision: (train=0.187, test=0.040) total time=   4.8s
# [CV 3/4; 4/40] START classifier__max_depth=70, classifier__max_features=7, classifier__min_samples_split=123
# [CV 3/4; 4/40] END classifier__max_depth=70, classifier__max_features=7, classifier__min_samples_split=123; precision: (train=0.221, test=0.103) total time=   4.8s
# [CV 4/4; 4/40] START classifier__max_depth=70, classifier__max_features=7, classifier__min_samples_split=123
# [CV 4/4; 4/40] END classifier__max_depth=70, classifier__max_features=7, classifier__min_samples_split=123; precision: (train=0.163, test=0.028) total time=   4.9s
# [CV 1/4; 5/40] START classifier__max_depth=372, classifier__max_features=29, classifier__min_samples_split=359
# [CV 1/4; 5/40] END classifier__max_depth=372, classifier__max_features=29, classifier__min_samples_split=359; precision: (train=0.066, test=0.038) total time=  11.0s
# [CV 2/4; 5/40] START classifier__max_depth=372, classifier__max_features=29, classifier__min_samples_split=359
# [CV 2/4; 5/40] END classifier__max_depth=372, classifier__max_features=29, classifier__min_samples_split=359; precision: (train=0.061, test=0.031) total time=  11.3s
# [CV 3/4; 5/40] START classifier__max_depth=372, classifier__max_features=29, classifier__min_samples_split=359
# [CV 3/4; 5/40] END classifier__max_depth=372, classifier__max_features=29, classifier__min_samples_split=359; precision: (train=0.062, test=0.047) total time=  11.4s
# [CV 4/4; 5/40] START classifier__max_depth=372, classifier__max_features=29, classifier__min_samples_split=359
# [CV 4/4; 5/40] END classifier__max_depth=372, classifier__max_features=29, classifier__min_samples_split=359; precision: (train=0.065, test=0.038) total time=  11.5s
# [CV 1/4; 6/40] START classifier__max_depth=447, classifier__max_features=15, classifier__min_samples_split=253
# [CV 1/4; 6/40] END classifier__max_depth=447, classifier__max_features=15, classifier__min_samples_split=253; precision: (train=0.080, test=0.040) total time=   7.4s
# [CV 2/4; 6/40] START classifier__max_depth=447, classifier__max_features=15, classifier__min_samples_split=253
# [CV 2/4; 6/40] END classifier__max_depth=447, classifier__max_features=15, classifier__min_samples_split=253; precision: (train=0.086, test=0.037) total time=   7.2s
# [CV 3/4; 6/40] START classifier__max_depth=447, classifier__max_features=15, classifier__min_samples_split=253
# [CV 3/4; 6/40] END classifier__max_depth=447, classifier__max_features=15, classifier__min_samples_split=253; precision: (train=0.088, test=0.061) total time=   6.8s
# [CV 4/4; 6/40] START classifier__max_depth=447, classifier__max_features=15, classifier__min_samples_split=253
# [CV 4/4; 6/40] END classifier__max_depth=447, classifier__max_features=15, classifier__min_samples_split=253; precision: (train=0.086, test=0.040) total time=   6.9s
# [CV 1/4; 7/40] START classifier__max_depth=614, classifier__max_features=7, classifier__min_samples_split=107
# [CV 1/4; 7/40] END classifier__max_depth=614, classifier__max_features=7, classifier__min_samples_split=107; precision: (train=0.250, test=0.100) total time=   6.2s
# [CV 2/4; 7/40] START classifier__max_depth=614, classifier__max_features=7, classifier__min_samples_split=107
# [CV 2/4; 7/40] END classifier__max_depth=614, classifier__max_features=7, classifier__min_samples_split=107; precision: (train=0.231, test=0.055) total time=   5.6s
# [CV 3/4; 7/40] START classifier__max_depth=614, classifier__max_features=7, classifier__min_samples_split=107
# [CV 3/4; 7/40] END classifier__max_depth=614, classifier__max_features=7, classifier__min_samples_split=107; precision: (train=0.244, test=0.123) total time=   4.7s
# [CV 4/4; 7/40] START classifier__max_depth=614, classifier__max_features=7, classifier__min_samples_split=107
# [CV 4/4; 7/40] END classifier__max_depth=614, classifier__max_features=7, classifier__min_samples_split=107; precision: (train=0.186, test=0.030) total time=   4.7s
# [CV 1/4; 8/40] START classifier__max_depth=161, classifier__max_features=25, classifier__min_samples_split=188
# [CV 1/4; 8/40] END classifier__max_depth=161, classifier__max_features=25, classifier__min_samples_split=188; precision: (train=0.109, test=0.048) total time=   9.9s
# [CV 2/4; 8/40] START classifier__max_depth=161, classifier__max_features=25, classifier__min_samples_split=188
# [CV 2/4; 8/40] END classifier__max_depth=161, classifier__max_features=25, classifier__min_samples_split=188; precision: (train=0.099, test=0.050) total time=  10.2s
# [CV 3/4; 8/40] START classifier__max_depth=161, classifier__max_features=25, classifier__min_samples_split=188
# [CV 3/4; 8/40] END classifier__max_depth=161, classifier__max_features=25, classifier__min_samples_split=188; precision: (train=0.108, test=0.064) total time=  10.2s
# [CV 4/4; 8/40] START classifier__max_depth=161, classifier__max_features=25, classifier__min_samples_split=188
# [CV 4/4; 8/40] END classifier__max_depth=161, classifier__max_features=25, classifier__min_samples_split=188; precision: (train=0.103, test=0.037) total time=  10.8s
# [CV 1/4; 9/40] START classifier__max_depth=417, classifier__max_features=14, classifier__min_samples_split=326
# [CV 1/4; 9/40] END classifier__max_depth=417, classifier__max_features=14, classifier__min_samples_split=326; precision: (train=0.064, test=0.041) total time=   6.7s
# [CV 2/4; 9/40] START classifier__max_depth=417, classifier__max_features=14, classifier__min_samples_split=326
# [CV 2/4; 9/40] END classifier__max_depth=417, classifier__max_features=14, classifier__min_samples_split=326; precision: (train=0.072, test=0.034) total time=   6.8s
# [CV 3/4; 9/40] START classifier__max_depth=417, classifier__max_features=14, classifier__min_samples_split=326
# [CV 3/4; 9/40] END classifier__max_depth=417, classifier__max_features=14, classifier__min_samples_split=326; precision: (train=0.071, test=0.052) total time=   6.6s
# [CV 4/4; 9/40] START classifier__max_depth=417, classifier__max_features=14, classifier__min_samples_split=326
# [CV 4/4; 9/40] END classifier__max_depth=417, classifier__max_features=14, classifier__min_samples_split=326; precision: (train=0.069, test=0.042) total time=   6.5s
# [CV 1/4; 10/40] START classifier__max_depth=674, classifier__max_features=30, classifier__min_samples_split=172
# [CV 1/4; 10/40] END classifier__max_depth=674, classifier__max_features=30, classifier__min_samples_split=172; precision: (train=0.121, test=0.050) total time=  11.9s
# [CV 2/4; 10/40] START classifier__max_depth=674, classifier__max_features=30, classifier__min_samples_split=172
# [CV 2/4; 10/40] END classifier__max_depth=674, classifier__max_features=30, classifier__min_samples_split=172; precision: (train=0.105, test=0.045) total time=  12.5s
# [CV 3/4; 10/40] START classifier__max_depth=674, classifier__max_features=30, classifier__min_samples_split=172
# [CV 3/4; 10/40] END classifier__max_depth=674, classifier__max_features=30, classifier__min_samples_split=172; precision: (train=0.114, test=0.068) total time=  15.6s
# [CV 4/4; 10/40] START classifier__max_depth=674, classifier__max_features=30, classifier__min_samples_split=172
# [CV 4/4; 10/40] END classifier__max_depth=674, classifier__max_features=30, classifier__min_samples_split=172; precision: (train=0.111, test=0.037) total time=  14.6s
# [CV 1/4; 11/40] START classifier__max_depth=659, classifier__max_features=8, classifier__min_samples_split=164
# [CV 1/4; 11/40] END classifier__max_depth=659, classifier__max_features=8, classifier__min_samples_split=164; precision: (train=0.150, test=0.073) total time=   6.2s
# [CV 2/4; 11/40] START classifier__max_depth=659, classifier__max_features=8, classifier__min_samples_split=164
# [CV 2/4; 11/40] END classifier__max_depth=659, classifier__max_features=8, classifier__min_samples_split=164; precision: (train=0.139, test=0.036) total time=   6.2s
# [CV 3/4; 11/40] START classifier__max_depth=659, classifier__max_features=8, classifier__min_samples_split=164
# [CV 3/4; 11/40] END classifier__max_depth=659, classifier__max_features=8, classifier__min_samples_split=164; precision: (train=0.135, test=0.091) total time=   6.0s
# [CV 4/4; 11/40] START classifier__max_depth=659, classifier__max_features=8, classifier__min_samples_split=164
# [CV 4/4; 11/40] END classifier__max_depth=659, classifier__max_features=8, classifier__min_samples_split=164; precision: (train=0.118, test=0.021) total time=   6.2s
# [CV 1/4; 12/40] START classifier__max_depth=10, classifier__max_features=19, classifier__min_samples_split=156
# [CV 1/4; 12/40] END classifier__max_depth=10, classifier__max_features=19, classifier__min_samples_split=156; precision: (train=0.132, test=0.053) total time=  10.0s
# [CV 2/4; 12/40] START classifier__max_depth=10, classifier__max_features=19, classifier__min_samples_split=156
# [CV 2/4; 12/40] END classifier__max_depth=10, classifier__max_features=19, classifier__min_samples_split=156; precision: (train=0.117, test=0.050) total time=  11.2s
# [CV 3/4; 12/40] START classifier__max_depth=10, classifier__max_features=19, classifier__min_samples_split=156
# [CV 3/4; 12/40] END classifier__max_depth=10, classifier__max_features=19, classifier__min_samples_split=156; precision: (train=0.134, test=0.071) total time=  11.6s
# [CV 4/4; 12/40] START classifier__max_depth=10, classifier__max_features=19, classifier__min_samples_split=156
# [CV 4/4; 12/40] END classifier__max_depth=10, classifier__max_features=19, classifier__min_samples_split=156; precision: (train=0.126, test=0.036) total time=  10.8s
# [CV 1/4; 13/40] START classifier__max_depth=598, classifier__max_features=30, classifier__min_samples_split=286
# [CV 1/4; 13/40] END classifier__max_depth=598, classifier__max_features=30, classifier__min_samples_split=286; precision: (train=0.073, test=0.042) total time=  23.5s
# [CV 2/4; 13/40] START classifier__max_depth=598, classifier__max_features=30, classifier__min_samples_split=286
# [CV 2/4; 13/40] END classifier__max_depth=598, classifier__max_features=30, classifier__min_samples_split=286; precision: (train=0.070, test=0.034) total time=  29.5s
# [CV 3/4; 13/40] START classifier__max_depth=598, classifier__max_features=30, classifier__min_samples_split=286
# [CV 3/4; 13/40] END classifier__max_depth=598, classifier__max_features=30, classifier__min_samples_split=286; precision: (train=0.073, test=0.053) total time=  25.6s
# [CV 4/4; 13/40] START classifier__max_depth=598, classifier__max_features=30, classifier__min_samples_split=286
# [CV 4/4; 13/40] END classifier__max_depth=598, classifier__max_features=30, classifier__min_samples_split=286; precision: (train=0.075, test=0.031) total time=  35.7s
# [CV 1/4; 14/40] START classifier__max_depth=629, classifier__max_features=37, classifier__min_samples_split=42
# [CV 1/4; 14/40] END classifier__max_depth=629, classifier__max_features=37, classifier__min_samples_split=42; precision: (train=0.492, test=0.115) total time=  23.3s
# [CV 2/4; 14/40] START classifier__max_depth=629, classifier__max_features=37, classifier__min_samples_split=42
# [CV 2/4; 14/40] END classifier__max_depth=629, classifier__max_features=37, classifier__min_samples_split=42; precision: (train=0.456, test=0.118) total time=  25.1s
# [CV 3/4; 14/40] START classifier__max_depth=629, classifier__max_features=37, classifier__min_samples_split=42
# [CV 3/4; 14/40] END classifier__max_depth=629, classifier__max_features=37, classifier__min_samples_split=42; precision: (train=0.473, test=0.176) total time=  22.0s
# [CV 4/4; 14/40] START classifier__max_depth=629, classifier__max_features=37, classifier__min_samples_split=42
# [CV 4/4; 14/40] END classifier__max_depth=629, classifier__max_features=37, classifier__min_samples_split=42; precision: (train=0.365, test=0.053) total time=  16.2s
# [CV 1/4; 15/40] START classifier__max_depth=659, classifier__max_features=10, classifier__min_samples_split=205
# [CV 1/4; 15/40] END classifier__max_depth=659, classifier__max_features=10, classifier__min_samples_split=205; precision: (train=0.111, test=0.051) total time=   7.3s
# [CV 2/4; 15/40] START classifier__max_depth=659, classifier__max_features=10, classifier__min_samples_split=205
# [CV 2/4; 15/40] END classifier__max_depth=659, classifier__max_features=10, classifier__min_samples_split=205; precision: (train=0.109, test=0.044) total time=  11.0s
# [CV 3/4; 15/40] START classifier__max_depth=659, classifier__max_features=10, classifier__min_samples_split=205
# [CV 3/4; 15/40] END classifier__max_depth=659, classifier__max_features=10, classifier__min_samples_split=205; precision: (train=0.114, test=0.071) total time=  11.5s
# [CV 4/4; 15/40] START classifier__max_depth=659, classifier__max_features=10, classifier__min_samples_split=205
# [CV 4/4; 15/40] END classifier__max_depth=659, classifier__max_features=10, classifier__min_samples_split=205; precision: (train=0.108, test=0.037) total time=  11.8s
# [CV 1/4; 16/40] START classifier__max_depth=689, classifier__max_features=12, classifier__min_samples_split=156
# [CV 1/4; 16/40] END classifier__max_depth=689, classifier__max_features=12, classifier__min_samples_split=156; precision: (train=0.144, test=0.062) total time=  12.9s
# [CV 2/4; 16/40] START classifier__max_depth=689, classifier__max_features=12, classifier__min_samples_split=156
# [CV 2/4; 16/40] END classifier__max_depth=689, classifier__max_features=12, classifier__min_samples_split=156; precision: (train=0.130, test=0.038) total time=  12.2s
# [CV 3/4; 16/40] START classifier__max_depth=689, classifier__max_features=12, classifier__min_samples_split=156
# [CV 3/4; 16/40] END classifier__max_depth=689, classifier__max_features=12, classifier__min_samples_split=156; precision: (train=0.136, test=0.074) total time=  13.1s
# [CV 4/4; 16/40] START classifier__max_depth=689, classifier__max_features=12, classifier__min_samples_split=156
# [CV 4/4; 16/40] END classifier__max_depth=689, classifier__max_features=12, classifier__min_samples_split=156; precision: (train=0.138, test=0.022) total time=  13.5s
# [CV 1/4; 17/40] START classifier__max_depth=55, classifier__max_features=20, classifier__min_samples_split=91
# [CV 1/4; 17/40] END classifier__max_depth=55, classifier__max_features=20, classifier__min_samples_split=91; precision: (train=0.248, test=0.113) total time=  18.7s
# [CV 2/4; 17/40] START classifier__max_depth=55, classifier__max_features=20, classifier__min_samples_split=91
# [CV 2/4; 17/40] END classifier__max_depth=55, classifier__max_features=20, classifier__min_samples_split=91; precision: (train=0.202, test=0.056) total time=   9.9s
# [CV 3/4; 17/40] START classifier__max_depth=55, classifier__max_features=20, classifier__min_samples_split=91
# [CV 3/4; 17/40] END classifier__max_depth=55, classifier__max_features=20, classifier__min_samples_split=91; precision: (train=0.216, test=0.103) total time=  10.2s
# [CV 4/4; 17/40] START classifier__max_depth=55, classifier__max_features=20, classifier__min_samples_split=91
# [CV 4/4; 17/40] END classifier__max_depth=55, classifier__max_features=20, classifier__min_samples_split=91; precision: (train=0.185, test=0.029) total time=   9.7s
# [CV 1/4; 18/40] START classifier__max_depth=538, classifier__max_features=30, classifier__min_samples_split=58
# [CV 1/4; 18/40] END classifier__max_depth=538, classifier__max_features=30, classifier__min_samples_split=58; precision: (train=0.376, test=0.098) total time=  15.7s
# [CV 2/4; 18/40] START classifier__max_depth=538, classifier__max_features=30, classifier__min_samples_split=58
# [CV 2/4; 18/40] END classifier__max_depth=538, classifier__max_features=30, classifier__min_samples_split=58; precision: (train=0.299, test=0.070) total time=  13.6s
# [CV 3/4; 18/40] START classifier__max_depth=538, classifier__max_features=30, classifier__min_samples_split=58
# [CV 3/4; 18/40] END classifier__max_depth=538, classifier__max_features=30, classifier__min_samples_split=58; precision: (train=0.333, test=0.119) total time=  15.0s
# [CV 4/4; 18/40] START classifier__max_depth=538, classifier__max_features=30, classifier__min_samples_split=58
# [CV 4/4; 18/40] END classifier__max_depth=538, classifier__max_features=30, classifier__min_samples_split=58; precision: (train=0.273, test=0.034) total time=  14.8s
# [CV 1/4; 19/40] START classifier__max_depth=296, classifier__max_features=4, classifier__min_samples_split=351
# [CV 1/4; 19/40] END classifier__max_depth=296, classifier__max_features=4, classifier__min_samples_split=351; precision: (train=0.072, test=0.050) total time=   4.6s
# [CV 2/4; 19/40] START classifier__max_depth=296, classifier__max_features=4, classifier__min_samples_split=351
# [CV 2/4; 19/40] END classifier__max_depth=296, classifier__max_features=4, classifier__min_samples_split=351; precision: (train=0.076, test=0.031) total time=   3.7s
# [CV 3/4; 19/40] START classifier__max_depth=296, classifier__max_features=4, classifier__min_samples_split=351
# [CV 3/4; 19/40] END classifier__max_depth=296, classifier__max_features=4, classifier__min_samples_split=351; precision: (train=0.074, test=0.055) total time=   3.7s
# [CV 4/4; 19/40] START classifier__max_depth=296, classifier__max_features=4, classifier__min_samples_split=351
# [CV 4/4; 19/40] END classifier__max_depth=296, classifier__max_features=4, classifier__min_samples_split=351; precision: (train=0.072, test=0.037) total time=   3.7s
# [CV 1/4; 20/40] START classifier__max_depth=719, classifier__max_features=35, classifier__min_samples_split=261
# [CV 1/4; 20/40] END classifier__max_depth=719, classifier__max_features=35, classifier__min_samples_split=261; precision: (train=0.077, test=0.043) total time=  12.9s
# [CV 2/4; 20/40] START classifier__max_depth=719, classifier__max_features=35, classifier__min_samples_split=261
# [CV 2/4; 20/40] END classifier__max_depth=719, classifier__max_features=35, classifier__min_samples_split=261; precision: (train=0.077, test=0.037) total time=  12.2s
# [CV 3/4; 20/40] START classifier__max_depth=719, classifier__max_features=35, classifier__min_samples_split=261
# [CV 3/4; 20/40] END classifier__max_depth=719, classifier__max_features=35, classifier__min_samples_split=261; precision: (train=0.077, test=0.052) total time=  11.9s
# [CV 4/4; 20/40] START classifier__max_depth=719, classifier__max_features=35, classifier__min_samples_split=261
# [CV 4/4; 20/40] END classifier__max_depth=719, classifier__max_features=35, classifier__min_samples_split=261; precision: (train=0.078, test=0.037) total time=  12.4s
# [CV 1/4; 21/40] START classifier__max_depth=266, classifier__max_features=4, classifier__min_samples_split=66
# [CV 1/4; 21/40] END classifier__max_depth=266, classifier__max_features=4, classifier__min_samples_split=66; precision: (train=0.432, test=0.156) total time=   4.7s
# [CV 2/4; 21/40] START classifier__max_depth=266, classifier__max_features=4, classifier__min_samples_split=66
# [CV 2/4; 21/40] END classifier__max_depth=266, classifier__max_features=4, classifier__min_samples_split=66; precision: (train=0.351, test=0.083) total time=   4.5s
# [CV 3/4; 21/40] START classifier__max_depth=266, classifier__max_features=4, classifier__min_samples_split=66
# [CV 3/4; 21/40] END classifier__max_depth=266, classifier__max_features=4, classifier__min_samples_split=66; precision: (train=0.458, test=0.229) total time=   5.8s
# [CV 4/4; 21/40] START classifier__max_depth=266, classifier__max_features=4, classifier__min_samples_split=66
# [CV 4/4; 21/40] END classifier__max_depth=266, classifier__max_features=4, classifier__min_samples_split=66; precision: (train=0.300, test=0.065) total time=   8.1s
# [CV 1/4; 22/40] START classifier__max_depth=191, classifier__max_features=10, classifier__min_samples_split=253
# [CV 1/4; 22/40] END classifier__max_depth=191, classifier__max_features=10, classifier__min_samples_split=253; precision: (train=0.087, test=0.045) total time=  11.5s
# [CV 2/4; 22/40] START classifier__max_depth=191, classifier__max_features=10, classifier__min_samples_split=253
# [CV 2/4; 22/40] END classifier__max_depth=191, classifier__max_features=10, classifier__min_samples_split=253; precision: (train=0.091, test=0.040) total time=   9.6s
# [CV 3/4; 22/40] START classifier__max_depth=191, classifier__max_features=10, classifier__min_samples_split=253
# [CV 3/4; 22/40] END classifier__max_depth=191, classifier__max_features=10, classifier__min_samples_split=253; precision: (train=0.093, test=0.064) total time=   7.4s
# [CV 4/4; 22/40] START classifier__max_depth=191, classifier__max_features=10, classifier__min_samples_split=253
# [CV 4/4; 22/40] END classifier__max_depth=191, classifier__max_features=10, classifier__min_samples_split=253; precision: (train=0.090, test=0.042) total time=   6.2s
# [CV 1/4; 23/40] START classifier__max_depth=25, classifier__max_features=30, classifier__min_samples_split=383
# [CV 1/4; 23/40] END classifier__max_depth=25, classifier__max_features=30, classifier__min_samples_split=383; precision: (train=0.064, test=0.037) total time=  12.0s
# [CV 2/4; 23/40] START classifier__max_depth=25, classifier__max_features=30, classifier__min_samples_split=383
# [CV 2/4; 23/40] END classifier__max_depth=25, classifier__max_features=30, classifier__min_samples_split=383; precision: (train=0.060, test=0.030) total time=  12.6s
# [CV 3/4; 23/40] START classifier__max_depth=25, classifier__max_features=30, classifier__min_samples_split=383
# [CV 3/4; 23/40] END classifier__max_depth=25, classifier__max_features=30, classifier__min_samples_split=383; precision: (train=0.057, test=0.046) total time=  12.1s
# [CV 4/4; 23/40] START classifier__max_depth=25, classifier__max_features=30, classifier__min_samples_split=383
# [CV 4/4; 23/40] END classifier__max_depth=25, classifier__max_features=30, classifier__min_samples_split=383; precision: (train=0.061, test=0.038) total time=  12.3s
# [CV 1/4; 24/40] START classifier__max_depth=598, classifier__max_features=17, classifier__min_samples_split=2
# c:\Users\danjr\anaconda3\envs\cycleCollisions\lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# [CV 1/4; 24/40] END classifier__max_depth=598, classifier__max_features=17, classifier__min_samples_split=2; precision: (train=1.000, test=0.000) total time=  10.0s
# [CV 2/4; 24/40] START classifier__max_depth=598, classifier__max_features=17, classifier__min_samples_split=2
# [CV 2/4; 24/40] END classifier__max_depth=598, classifier__max_features=17, classifier__min_samples_split=2; precision: (train=1.000, test=0.000) total time=  10.1s
# [CV 3/4; 24/40] START classifier__max_depth=598, classifier__max_features=17, classifier__min_samples_split=2
# c:\Users\danjr\anaconda3\envs\cycleCollisions\lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# [CV 3/4; 24/40] END classifier__max_depth=598, classifier__max_features=17, classifier__min_samples_split=2; precision: (train=1.000, test=0.000) total time=  10.2s
# [CV 4/4; 24/40] START classifier__max_depth=598, classifier__max_features=17, classifier__min_samples_split=2
# c:\Users\danjr\anaconda3\envs\cycleCollisions\lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# [CV 4/4; 24/40] END classifier__max_depth=598, classifier__max_features=17, classifier__min_samples_split=2; precision: (train=1.000, test=0.000) total time=   9.9s
# [CV 1/4; 25/40] START classifier__max_depth=659, classifier__max_features=30, classifier__min_samples_split=205
# [CV 1/4; 25/40] END classifier__max_depth=659, classifier__max_features=30, classifier__min_samples_split=205; precision: (train=0.097, test=0.047) total time=  12.5s
# [CV 2/4; 25/40] START classifier__max_depth=659, classifier__max_features=30, classifier__min_samples_split=205
# [CV 2/4; 25/40] END classifier__max_depth=659, classifier__max_features=30, classifier__min_samples_split=205; precision: (train=0.090, test=0.042) total time=  12.9s
# [CV 3/4; 25/40] START classifier__max_depth=659, classifier__max_features=30, classifier__min_samples_split=205
# [CV 3/4; 25/40] END classifier__max_depth=659, classifier__max_features=30, classifier__min_samples_split=205; precision: (train=0.096, test=0.060) total time=  12.9s
# [CV 4/4; 25/40] START classifier__max_depth=659, classifier__max_features=30, classifier__min_samples_split=205
# [CV 4/4; 25/40] END classifier__max_depth=659, classifier__max_features=30, classifier__min_samples_split=205; precision: (train=0.103, test=0.040) total time=  12.5s
# [CV 1/4; 26/40] START classifier__max_depth=357, classifier__max_features=32, classifier__min_samples_split=188
# [CV 1/4; 26/40] END classifier__max_depth=357, classifier__max_features=32, classifier__min_samples_split=188; precision: (train=0.113, test=0.047) total time=  15.2s
# [CV 2/4; 26/40] START classifier__max_depth=357, classifier__max_features=32, classifier__min_samples_split=188
# [CV 2/4; 26/40] END classifier__max_depth=357, classifier__max_features=32, classifier__min_samples_split=188; precision: (train=0.092, test=0.049) total time=  20.9s
# [CV 3/4; 26/40] START classifier__max_depth=357, classifier__max_features=32, classifier__min_samples_split=188
# [CV 3/4; 26/40] END classifier__max_depth=357, classifier__max_features=32, classifier__min_samples_split=188; precision: (train=0.106, test=0.063) total time=  20.8s
# [CV 4/4; 26/40] START classifier__max_depth=357, classifier__max_features=32, classifier__min_samples_split=188
# [CV 4/4; 26/40] END classifier__max_depth=357, classifier__max_features=32, classifier__min_samples_split=188; precision: (train=0.106, test=0.030) total time=  20.7s
# [CV 1/4; 27/40] START classifier__max_depth=674, classifier__max_features=35, classifier__min_samples_split=286
# [CV 1/4; 27/40] END classifier__max_depth=674, classifier__max_features=35, classifier__min_samples_split=286; precision: (train=0.072, test=0.039) total time=  19.4s
# [CV 2/4; 27/40] START classifier__max_depth=674, classifier__max_features=35, classifier__min_samples_split=286
# [CV 2/4; 27/40] END classifier__max_depth=674, classifier__max_features=35, classifier__min_samples_split=286; precision: (train=0.069, test=0.034) total time=  19.9s
# [CV 3/4; 27/40] START classifier__max_depth=674, classifier__max_features=35, classifier__min_samples_split=286
# [CV 3/4; 27/40] END classifier__max_depth=674, classifier__max_features=35, classifier__min_samples_split=286; precision: (train=0.071, test=0.052) total time=  19.2s
# [CV 4/4; 27/40] START classifier__max_depth=674, classifier__max_features=35, classifier__min_samples_split=286
# [CV 4/4; 27/40] END classifier__max_depth=674, classifier__max_features=35, classifier__min_samples_split=286; precision: (train=0.074, test=0.039) total time=  19.3s
# [CV 1/4; 28/40] START classifier__max_depth=568, classifier__max_features=34, classifier__min_samples_split=294
# [CV 1/4; 28/40] END classifier__max_depth=568, classifier__max_features=34, classifier__min_samples_split=294; precision: (train=0.072, test=0.037) total time=  18.4s
# [CV 2/4; 28/40] START classifier__max_depth=568, classifier__max_features=34, classifier__min_samples_split=294
# [CV 2/4; 28/40] END classifier__max_depth=568, classifier__max_features=34, classifier__min_samples_split=294; precision: (train=0.072, test=0.036) total time=  20.3s
# [CV 3/4; 28/40] START classifier__max_depth=568, classifier__max_features=34, classifier__min_samples_split=294
# [CV 3/4; 28/40] END classifier__max_depth=568, classifier__max_features=34, classifier__min_samples_split=294; precision: (train=0.073, test=0.051) total time=  20.5s
# [CV 4/4; 28/40] START classifier__max_depth=568, classifier__max_features=34, classifier__min_samples_split=294
# [CV 4/4; 28/40] END classifier__max_depth=568, classifier__max_features=34, classifier__min_samples_split=294; precision: (train=0.073, test=0.035) total time=  20.1s
# [CV 1/4; 29/40] START classifier__max_depth=674, classifier__max_features=20, classifier__min_samples_split=26
# [CV 1/4; 29/40] END classifier__max_depth=674, classifier__max_features=20, classifier__min_samples_split=26; precision: (train=0.702, test=0.214) total time=  17.0s
# [CV 2/4; 29/40] START classifier__max_depth=674, classifier__max_features=20, classifier__min_samples_split=26
# [CV 2/4; 29/40] END classifier__max_depth=674, classifier__max_features=20, classifier__min_samples_split=26; precision: (train=0.705, test=0.125) total time=  17.4s
# [CV 3/4; 29/40] START classifier__max_depth=674, classifier__max_features=20, classifier__min_samples_split=26
# [CV 3/4; 29/40] END classifier__max_depth=674, classifier__max_features=20, classifier__min_samples_split=26; precision: (train=0.787, test=0.200) total time=  16.9s
# [CV 4/4; 29/40] START classifier__max_depth=674, classifier__max_features=20, classifier__min_samples_split=26
# [CV 4/4; 29/40] END classifier__max_depth=674, classifier__max_features=20, classifier__min_samples_split=26; precision: (train=0.579, test=0.067) total time=  17.1s
# [CV 1/4; 30/40] START classifier__max_depth=327, classifier__max_features=2, classifier__min_samples_split=10
# c:\Users\danjr\anaconda3\envs\cycleCollisions\lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# [CV 1/4; 30/40] END classifier__max_depth=327, classifier__max_features=2, classifier__min_samples_split=10; precision: (train=0.951, test=0.000) total time=   6.1s
# [CV 2/4; 30/40] START classifier__max_depth=327, classifier__max_features=2, classifier__min_samples_split=10
# [CV 2/4; 30/40] END classifier__max_depth=327, classifier__max_features=2, classifier__min_samples_split=10; precision: (train=0.925, test=0.000) total time=   5.9s
# [CV 3/4; 30/40] START classifier__max_depth=327, classifier__max_features=2, classifier__min_samples_split=10
# [CV 3/4; 30/40] END classifier__max_depth=327, classifier__max_features=2, classifier__min_samples_split=10; precision: (train=0.983, test=0.000) total time=   6.2s
# [CV 4/4; 30/40] START classifier__max_depth=327, classifier__max_features=2, classifier__min_samples_split=10
# [CV 4/4; 30/40] END classifier__max_depth=327, classifier__max_features=2, classifier__min_samples_split=10; precision: (train=0.937, test=0.000) total time=   6.3s
# [CV 1/4; 31/40] START classifier__max_depth=115, classifier__max_features=22, classifier__min_samples_split=359
# [CV 1/4; 31/40] END classifier__max_depth=115, classifier__max_features=22, classifier__min_samples_split=359; precision: (train=0.060, test=0.034) total time=  14.8s
# [CV 2/4; 31/40] START classifier__max_depth=115, classifier__max_features=22, classifier__min_samples_split=359
# [CV 2/4; 31/40] END classifier__max_depth=115, classifier__max_features=22, classifier__min_samples_split=359; precision: (train=0.062, test=0.032) total time=  15.8s
# [CV 3/4; 31/40] START classifier__max_depth=115, classifier__max_features=22, classifier__min_samples_split=359
# [CV 3/4; 31/40] END classifier__max_depth=115, classifier__max_features=22, classifier__min_samples_split=359; precision: (train=0.064, test=0.050) total time=  15.7s
# [CV 4/4; 31/40] START classifier__max_depth=115, classifier__max_features=22, classifier__min_samples_split=359
# [CV 4/4; 31/40] END classifier__max_depth=115, classifier__max_features=22, classifier__min_samples_split=359; precision: (train=0.067, test=0.039) total time=  15.4s
# [CV 1/4; 32/40] START classifier__max_depth=704, classifier__max_features=2, classifier__min_samples_split=343
# [CV 1/4; 32/40] END classifier__max_depth=704, classifier__max_features=2, classifier__min_samples_split=343; precision: (train=0.074, test=0.042) total time=   5.6s
# [CV 2/4; 32/40] START classifier__max_depth=704, classifier__max_features=2, classifier__min_samples_split=343
# [CV 2/4; 32/40] END classifier__max_depth=704, classifier__max_features=2, classifier__min_samples_split=343; precision: (train=0.082, test=0.041) total time=   5.0s
# [CV 3/4; 32/40] START classifier__max_depth=704, classifier__max_features=2, classifier__min_samples_split=343
# [CV 3/4; 32/40] END classifier__max_depth=704, classifier__max_features=2, classifier__min_samples_split=343; precision: (train=0.079, test=0.064) total time=   3.8s
# [CV 4/4; 32/40] START classifier__max_depth=704, classifier__max_features=2, classifier__min_samples_split=343
# [CV 4/4; 32/40] END classifier__max_depth=704, classifier__max_features=2, classifier__min_samples_split=343; precision: (train=0.076, test=0.034) total time=   3.2s
# [CV 1/4; 33/40] START classifier__max_depth=40, classifier__max_features=22, classifier__min_samples_split=326
# [CV 1/4; 33/40] END classifier__max_depth=40, classifier__max_features=22, classifier__min_samples_split=326; precision: (train=0.062, test=0.036) total time=   9.3s
# [CV 2/4; 33/40] START classifier__max_depth=40, classifier__max_features=22, classifier__min_samples_split=326
# [CV 2/4; 33/40] END classifier__max_depth=40, classifier__max_features=22, classifier__min_samples_split=326; precision: (train=0.065, test=0.034) total time=   9.5s
# [CV 3/4; 33/40] START classifier__max_depth=40, classifier__max_features=22, classifier__min_samples_split=326
# [CV 3/4; 33/40] END classifier__max_depth=40, classifier__max_features=22, classifier__min_samples_split=326; precision: (train=0.070, test=0.053) total time=   9.4s
# [CV 4/4; 33/40] START classifier__max_depth=40, classifier__max_features=22, classifier__min_samples_split=326
# [CV 4/4; 33/40] END classifier__max_depth=40, classifier__max_features=22, classifier__min_samples_split=326; precision: (train=0.071, test=0.036) total time=   9.5s
# [CV 1/4; 34/40] START classifier__max_depth=417, classifier__max_features=28, classifier__min_samples_split=50
# [CV 1/4; 34/40] END classifier__max_depth=417, classifier__max_features=28, classifier__min_samples_split=50; precision: (train=0.396, test=0.094) total time=  13.5s
# [CV 2/4; 34/40] START classifier__max_depth=417, classifier__max_features=28, classifier__min_samples_split=50
# [CV 2/4; 34/40] END classifier__max_depth=417, classifier__max_features=28, classifier__min_samples_split=50; precision: (train=0.375, test=0.093) total time=  13.0s
# [CV 3/4; 34/40] START classifier__max_depth=417, classifier__max_features=28, classifier__min_samples_split=50
# [CV 3/4; 34/40] END classifier__max_depth=417, classifier__max_features=28, classifier__min_samples_split=50; precision: (train=0.390, test=0.122) total time=  13.1s
# [CV 4/4; 34/40] START classifier__max_depth=417, classifier__max_features=28, classifier__min_samples_split=50
# [CV 4/4; 34/40] END classifier__max_depth=417, classifier__max_features=28, classifier__min_samples_split=50; precision: (train=0.313, test=0.042) total time=  13.7s
# [CV 1/4; 35/40] START classifier__max_depth=115, classifier__max_features=3, classifier__min_samples_split=221
# [CV 1/4; 35/40] END classifier__max_depth=115, classifier__max_features=3, classifier__min_samples_split=221; precision: (train=0.109, test=0.057) total time=   3.8s
# [CV 2/4; 35/40] START classifier__max_depth=115, classifier__max_features=3, classifier__min_samples_split=221
# [CV 2/4; 35/40] END classifier__max_depth=115, classifier__max_features=3, classifier__min_samples_split=221; precision: (train=0.119, test=0.027) total time=   3.5s
# [CV 3/4; 35/40] START classifier__max_depth=115, classifier__max_features=3, classifier__min_samples_split=221
# [CV 3/4; 35/40] END classifier__max_depth=115, classifier__max_features=3, classifier__min_samples_split=221; precision: (train=0.112, test=0.072) total time=   3.5s
# [CV 4/4; 35/40] START classifier__max_depth=115, classifier__max_features=3, classifier__min_samples_split=221
# [CV 4/4; 35/40] END classifier__max_depth=115, classifier__max_features=3, classifier__min_samples_split=221; precision: (train=0.105, test=0.040) total time=   3.4s
# [CV 1/4; 36/40] START classifier__max_depth=85, classifier__max_features=32, classifier__min_samples_split=343
# [CV 1/4; 36/40] END classifier__max_depth=85, classifier__max_features=32, classifier__min_samples_split=343; precision: (train=0.067, test=0.038) total time=  11.4s
# [CV 2/4; 36/40] START classifier__max_depth=85, classifier__max_features=32, classifier__min_samples_split=343
# [CV 2/4; 36/40] END classifier__max_depth=85, classifier__max_features=32, classifier__min_samples_split=343; precision: (train=0.065, test=0.031) total time=  11.9s
# [CV 3/4; 36/40] START classifier__max_depth=85, classifier__max_features=32, classifier__min_samples_split=343
# [CV 3/4; 36/40] END classifier__max_depth=85, classifier__max_features=32, classifier__min_samples_split=343; precision: (train=0.062, test=0.046) total time=  11.5s
# [CV 4/4; 36/40] START classifier__max_depth=85, classifier__max_features=32, classifier__min_samples_split=343
# [CV 4/4; 36/40] END classifier__max_depth=85, classifier__max_features=32, classifier__min_samples_split=343; precision: (train=0.067, test=0.037) total time=  11.5s
# [CV 1/4; 37/40] START classifier__max_depth=750, classifier__max_features=12, classifier__min_samples_split=156
# [CV 1/4; 37/40] END classifier__max_depth=750, classifier__max_features=12, classifier__min_samples_split=156; precision: (train=0.141, test=0.070) total time=   6.5s
# [CV 2/4; 37/40] START classifier__max_depth=750, classifier__max_features=12, classifier__min_samples_split=156
# [CV 2/4; 37/40] END classifier__max_depth=750, classifier__max_features=12, classifier__min_samples_split=156; precision: (train=0.136, test=0.034) total time=   6.3s
# [CV 3/4; 37/40] START classifier__max_depth=750, classifier__max_features=12, classifier__min_samples_split=156
# [CV 3/4; 37/40] END classifier__max_depth=750, classifier__max_features=12, classifier__min_samples_split=156; precision: (train=0.136, test=0.081) total time=   6.5s
# [CV 4/4; 37/40] START classifier__max_depth=750, classifier__max_features=12, classifier__min_samples_split=156
# [CV 4/4; 37/40] END classifier__max_depth=750, classifier__max_features=12, classifier__min_samples_split=156; precision: (train=0.136, test=0.021) total time=   6.6s
# [CV 1/4; 38/40] START classifier__max_depth=432, classifier__max_features=25, classifier__min_samples_split=10
# [CV 1/4; 38/40] END classifier__max_depth=432, classifier__max_features=25, classifier__min_samples_split=10; precision: (train=0.940, test=0.000) total time=  12.4s
# [CV 2/4; 38/40] START classifier__max_depth=432, classifier__max_features=25, classifier__min_samples_split=10
# [CV 2/4; 38/40] END classifier__max_depth=432, classifier__max_features=25, classifier__min_samples_split=10; precision: (train=0.924, test=0.333) total time=  12.3s
# [CV 3/4; 38/40] START classifier__max_depth=432, classifier__max_features=25, classifier__min_samples_split=10
# [CV 3/4; 38/40] END classifier__max_depth=432, classifier__max_features=25, classifier__min_samples_split=10; precision: (train=0.984, test=0.000) total time=  12.4s
# [CV 4/4; 38/40] START classifier__max_depth=432, classifier__max_features=25, classifier__min_samples_split=10
# [CV 4/4; 38/40] END classifier__max_depth=432, classifier__max_features=25, classifier__min_samples_split=10; precision: (train=0.921, test=0.000) total time=  12.2s
# [CV 1/4; 39/40] START classifier__max_depth=236, classifier__max_features=34, classifier__min_samples_split=383
# [CV 1/4; 39/40] END classifier__max_depth=236, classifier__max_features=34, classifier__min_samples_split=383; precision: (train=0.064, test=0.036) total time=  10.9s
# [CV 2/4; 39/40] START classifier__max_depth=236, classifier__max_features=34, classifier__min_samples_split=383
# [CV 2/4; 39/40] END classifier__max_depth=236, classifier__max_features=34, classifier__min_samples_split=383; precision: (train=0.059, test=0.030) total time=  11.6s
# [CV 3/4; 39/40] START classifier__max_depth=236, classifier__max_features=34, classifier__min_samples_split=383
# [CV 3/4; 39/40] END classifier__max_depth=236, classifier__max_features=34, classifier__min_samples_split=383; precision: (train=0.057, test=0.045) total time=  11.2s
# [CV 4/4; 39/40] START classifier__max_depth=236, classifier__max_features=34, classifier__min_samples_split=383
# [CV 4/4; 39/40] END classifier__max_depth=236, classifier__max_features=34, classifier__min_samples_split=383; precision: (train=0.063, test=0.038) total time=  11.6s
# [CV 1/4; 40/40] START classifier__max_depth=689, classifier__max_features=15, classifier__min_samples_split=391
# [CV 1/4; 40/40] END classifier__max_depth=689, classifier__max_features=15, classifier__min_samples_split=391; precision: (train=0.058, test=0.039) total time=   6.7s
# [CV 2/4; 40/40] START classifier__max_depth=689, classifier__max_features=15, classifier__min_samples_split=391
# [CV 2/4; 40/40] END classifier__max_depth=689, classifier__max_features=15, classifier__min_samples_split=391; precision: (train=0.060, test=0.031) total time=   6.9s
# [CV 3/4; 40/40] START classifier__max_depth=689, classifier__max_features=15, classifier__min_samples_split=391
# [CV 3/4; 40/40] END classifier__max_depth=689, classifier__max_features=15, classifier__min_samples_split=391; precision: (train=0.061, test=0.049) total time=   6.9s
# [CV 4/4; 40/40] START classifier__max_depth=689, classifier__max_features=15, classifier__min_samples_split=391
# [CV 4/4; 40/40] END classifier__max_depth=689, classifier__max_features=15, classifier__min_samples_split=391; precision: (train=0.063, test=0.042) total time=   7.0s
# 0.15148809523809526 {'classifier__min_samples_split': 26, 'classifier__max_features': 20, 'classifier__max_depth': 674}
# 0.125

# %% [markdown]
# b. smote

# %%
param_distributions = {
        "classifier__min_samples_split": [int(i) for i in np.linspace(2, 400, 50)],
        "classifier__max_features": [int(i) for i in np.linspace(1, 37, 30)],
        "classifier__max_depth": [int(i) for i in np.linspace(10, 750, 50)] + [None]
    }
classifier = RandomForestClassifier(n_estimators=750)
pipeline = Pipeline([
        ('custom_preprocessor', CustomPreprocessor(one_hot_encoded_cols)),
        ('over', SMOTE(sampling_strategy='not majority')),
        ('classifier', classifier)
    ])
random_search = run_experiment(features, param_distributions, pipeline, 
                               n_iter=40, n_splits=4, 
                               classifier=classifier, one_hot_encoded_cols=one_hot_encoded_cols)
# Out:
# Fitting 4 folds for each of 40 candidates, totalling 160 fits
# [CV 1/4; 1/40] START classifier__max_depth=161, classifier__max_features=19, classifier__min_samples_split=367
# [CV 1/4; 1/40] END classifier__max_depth=161, classifier__max_features=19, classifier__min_samples_split=367; precision: (train=0.122, test=0.056) total time= 1.0min
# [CV 2/4; 1/40] START classifier__max_depth=161, classifier__max_features=19, classifier__min_samples_split=367
# [CV 2/4; 1/40] END classifier__max_depth=161, classifier__max_features=19, classifier__min_samples_split=367; precision: (train=0.089, test=0.034) total time=  59.6s
# [CV 3/4; 1/40] START classifier__max_depth=161, classifier__max_features=19, classifier__min_samples_split=367
# [CV 3/4; 1/40] END classifier__max_depth=161, classifier__max_features=19, classifier__min_samples_split=367; precision: (train=0.101, test=0.044) total time= 1.0min
# [CV 4/4; 1/40] START classifier__max_depth=161, classifier__max_features=19, classifier__min_samples_split=367
# [CV 4/4; 1/40] END classifier__max_depth=161, classifier__max_features=19, classifier__min_samples_split=367; precision: (train=0.095, test=0.041) total time=  59.9s
# [CV 1/4; 2/40] START classifier__max_depth=10, classifier__max_features=22, classifier__min_samples_split=83
# [CV 1/4; 2/40] END classifier__max_depth=10, classifier__max_features=22, classifier__min_samples_split=83; precision: (train=0.184, test=0.079) total time= 1.1min
# [CV 2/4; 2/40] START classifier__max_depth=10, classifier__max_features=22, classifier__min_samples_split=83
# [CV 2/4; 2/40] END classifier__max_depth=10, classifier__max_features=22, classifier__min_samples_split=83; precision: (train=0.158, test=0.043) total time= 1.1min
# [CV 3/4; 2/40] START classifier__max_depth=10, classifier__max_features=22, classifier__min_samples_split=83
# [CV 3/4; 2/40] END classifier__max_depth=10, classifier__max_features=22, classifier__min_samples_split=83; precision: (train=0.198, test=0.115) total time= 1.1min
# [CV 4/4; 2/40] START classifier__max_depth=10, classifier__max_features=22, classifier__min_samples_split=83
# [CV 4/4; 2/40] END classifier__max_depth=10, classifier__max_features=22, classifier__min_samples_split=83; precision: (train=0.167, test=0.046) total time= 1.1min
# [CV 1/4; 3/40] START classifier__max_depth=553, classifier__max_features=22, classifier__min_samples_split=294
# [CV 1/4; 3/40] END classifier__max_depth=553, classifier__max_features=22, classifier__min_samples_split=294; precision: (train=0.129, test=0.048) total time= 1.1min
# [CV 2/4; 3/40] START classifier__max_depth=553, classifier__max_features=22, classifier__min_samples_split=294
# [CV 2/4; 3/40] END classifier__max_depth=553, classifier__max_features=22, classifier__min_samples_split=294; precision: (train=0.097, test=0.029) total time= 1.2min
# [CV 3/4; 3/40] START classifier__max_depth=553, classifier__max_features=22, classifier__min_samples_split=294
# [CV 3/4; 3/40] END classifier__max_depth=553, classifier__max_features=22, classifier__min_samples_split=294; precision: (train=0.090, test=0.047) total time= 1.2min
# [CV 4/4; 3/40] START classifier__max_depth=553, classifier__max_features=22, classifier__min_samples_split=294
# [CV 4/4; 3/40] END classifier__max_depth=553, classifier__max_features=22, classifier__min_samples_split=294; precision: (train=0.117, test=0.026) total time= 1.2min
# [CV 1/4; 4/40] START classifier__max_depth=70, classifier__max_features=7, classifier__min_samples_split=123
# [CV 1/4; 4/40] END classifier__max_depth=70, classifier__max_features=7, classifier__min_samples_split=123; precision: (train=0.538, test=0.130) total time=  26.2s
# [CV 2/4; 4/40] START classifier__max_depth=70, classifier__max_features=7, classifier__min_samples_split=123
# [CV 2/4; 4/40] END classifier__max_depth=70, classifier__max_features=7, classifier__min_samples_split=123; precision: (train=0.389, test=0.143) total time=  26.3s
# [CV 3/4; 4/40] START classifier__max_depth=70, classifier__max_features=7, classifier__min_samples_split=123
# [CV 3/4; 4/40] END classifier__max_depth=70, classifier__max_features=7, classifier__min_samples_split=123; precision: (train=0.426, test=0.135) total time=  26.0s
# [CV 4/4; 4/40] START classifier__max_depth=70, classifier__max_features=7, classifier__min_samples_split=123
# [CV 4/4; 4/40] END classifier__max_depth=70, classifier__max_features=7, classifier__min_samples_split=123; precision: (train=0.353, test=0.077) total time=  25.7s
# [CV 1/4; 5/40] START classifier__max_depth=372, classifier__max_features=29, classifier__min_samples_split=359
# [CV 1/4; 5/40] END classifier__max_depth=372, classifier__max_features=29, classifier__min_samples_split=359; precision: (train=0.049, test=0.028) total time= 1.5min
# [CV 2/4; 5/40] START classifier__max_depth=372, classifier__max_features=29, classifier__min_samples_split=359
# [CV 2/4; 5/40] END classifier__max_depth=372, classifier__max_features=29, classifier__min_samples_split=359; precision: (train=0.069, test=0.025) total time= 1.5min
# [CV 3/4; 5/40] START classifier__max_depth=372, classifier__max_features=29, classifier__min_samples_split=359
# [CV 3/4; 5/40] END classifier__max_depth=372, classifier__max_features=29, classifier__min_samples_split=359; precision: (train=0.068, test=0.046) total time= 1.5min
# [CV 4/4; 5/40] START classifier__max_depth=372, classifier__max_features=29, classifier__min_samples_split=359
# [CV 4/4; 5/40] END classifier__max_depth=372, classifier__max_features=29, classifier__min_samples_split=359; precision: (train=0.060, test=0.018) total time= 1.5min
# [CV 1/4; 6/40] START classifier__max_depth=447, classifier__max_features=15, classifier__min_samples_split=253
# [CV 1/4; 6/40] END classifier__max_depth=447, classifier__max_features=15, classifier__min_samples_split=253; precision: (train=0.167, test=0.075) total time=  50.1s
# [CV 2/4; 6/40] START classifier__max_depth=447, classifier__max_features=15, classifier__min_samples_split=253
# [CV 2/4; 6/40] END classifier__max_depth=447, classifier__max_features=15, classifier__min_samples_split=253; precision: (train=0.145, test=0.033) total time=  50.2s
# [CV 3/4; 6/40] START classifier__max_depth=447, classifier__max_features=15, classifier__min_samples_split=253
# [CV 3/4; 6/40] END classifier__max_depth=447, classifier__max_features=15, classifier__min_samples_split=253; precision: (train=0.145, test=0.076) total time=  50.3s
# [CV 4/4; 6/40] START classifier__max_depth=447, classifier__max_features=15, classifier__min_samples_split=253
# [CV 4/4; 6/40] END classifier__max_depth=447, classifier__max_features=15, classifier__min_samples_split=253; precision: (train=0.159, test=0.060) total time=  49.1s
# [CV 1/4; 7/40] START classifier__max_depth=614, classifier__max_features=7, classifier__min_samples_split=107
# [CV 1/4; 7/40] END classifier__max_depth=614, classifier__max_features=7, classifier__min_samples_split=107; precision: (train=0.507, test=0.167) total time=  43.4s
# [CV 2/4; 7/40] START classifier__max_depth=614, classifier__max_features=7, classifier__min_samples_split=107
# [CV 2/4; 7/40] END classifier__max_depth=614, classifier__max_features=7, classifier__min_samples_split=107; precision: (train=0.412, test=0.138) total time=  45.8s
# [CV 3/4; 7/40] START classifier__max_depth=614, classifier__max_features=7, classifier__min_samples_split=107
# [CV 3/4; 7/40] END classifier__max_depth=614, classifier__max_features=7, classifier__min_samples_split=107; precision: (train=0.507, test=0.160) total time=  25.9s
# [CV 4/4; 7/40] START classifier__max_depth=614, classifier__max_features=7, classifier__min_samples_split=107
# [CV 4/4; 7/40] END classifier__max_depth=614, classifier__max_features=7, classifier__min_samples_split=107; precision: (train=0.352, test=0.100) total time=  25.8s
# [CV 1/4; 8/40] START classifier__max_depth=161, classifier__max_features=25, classifier__min_samples_split=188
# [CV 1/4; 8/40] END classifier__max_depth=161, classifier__max_features=25, classifier__min_samples_split=188; precision: (train=0.147, test=0.059) total time= 1.4min
# [CV 2/4; 8/40] START classifier__max_depth=161, classifier__max_features=25, classifier__min_samples_split=188
# [CV 2/4; 8/40] END classifier__max_depth=161, classifier__max_features=25, classifier__min_samples_split=188; precision: (train=0.173, test=0.040) total time= 1.4min
# [CV 3/4; 8/40] START classifier__max_depth=161, classifier__max_features=25, classifier__min_samples_split=188
# [CV 3/4; 8/40] END classifier__max_depth=161, classifier__max_features=25, classifier__min_samples_split=188; precision: (train=0.150, test=0.055) total time= 1.4min
# [CV 4/4; 8/40] START classifier__max_depth=161, classifier__max_features=25, classifier__min_samples_split=188
# [CV 4/4; 8/40] END classifier__max_depth=161, classifier__max_features=25, classifier__min_samples_split=188; precision: (train=0.127, test=0.055) total time= 1.4min
# [CV 1/4; 9/40] START classifier__max_depth=417, classifier__max_features=14, classifier__min_samples_split=326
# [CV 1/4; 9/40] END classifier__max_depth=417, classifier__max_features=14, classifier__min_samples_split=326; precision: (train=0.157, test=0.067) total time=  44.9s
# [CV 2/4; 9/40] START classifier__max_depth=417, classifier__max_features=14, classifier__min_samples_split=326
# [CV 2/4; 9/40] END classifier__max_depth=417, classifier__max_features=14, classifier__min_samples_split=326; precision: (train=0.102, test=0.030) total time=  43.9s
# [CV 3/4; 9/40] START classifier__max_depth=417, classifier__max_features=14, classifier__min_samples_split=326
# [CV 3/4; 9/40] END classifier__max_depth=417, classifier__max_features=14, classifier__min_samples_split=326; precision: (train=0.132, test=0.062) total time=  44.3s
# [CV 4/4; 9/40] START classifier__max_depth=417, classifier__max_features=14, classifier__min_samples_split=326
# [CV 4/4; 9/40] END classifier__max_depth=417, classifier__max_features=14, classifier__min_samples_split=326; precision: (train=0.137, test=0.057) total time=  44.5s
# [CV 1/4; 10/40] START classifier__max_depth=674, classifier__max_features=30, classifier__min_samples_split=172
# [CV 1/4; 10/40] END classifier__max_depth=674, classifier__max_features=30, classifier__min_samples_split=172; precision: (train=0.110, test=0.044) total time= 1.7min
# [CV 2/4; 10/40] START classifier__max_depth=674, classifier__max_features=30, classifier__min_samples_split=172
# [CV 2/4; 10/40] END classifier__max_depth=674, classifier__max_features=30, classifier__min_samples_split=172; precision: (train=0.157, test=0.040) total time= 1.7min
# [CV 3/4; 10/40] START classifier__max_depth=674, classifier__max_features=30, classifier__min_samples_split=172
# [CV 3/4; 10/40] END classifier__max_depth=674, classifier__max_features=30, classifier__min_samples_split=172; precision: (train=0.110, test=0.050) total time= 1.7min
# [CV 4/4; 10/40] START classifier__max_depth=674, classifier__max_features=30, classifier__min_samples_split=172
# [CV 4/4; 10/40] END classifier__max_depth=674, classifier__max_features=30, classifier__min_samples_split=172; precision: (train=0.133, test=0.027) total time= 1.7min
# [CV 1/4; 11/40] START classifier__max_depth=659, classifier__max_features=8, classifier__min_samples_split=164
# [CV 1/4; 11/40] END classifier__max_depth=659, classifier__max_features=8, classifier__min_samples_split=164; precision: (train=0.324, test=0.089) total time=  28.3s
# [CV 2/4; 11/40] START classifier__max_depth=659, classifier__max_features=8, classifier__min_samples_split=164
# [CV 2/4; 11/40] END classifier__max_depth=659, classifier__max_features=8, classifier__min_samples_split=164; precision: (train=0.295, test=0.095) total time=  28.7s
# [CV 3/4; 11/40] START classifier__max_depth=659, classifier__max_features=8, classifier__min_samples_split=164
# [CV 3/4; 11/40] END classifier__max_depth=659, classifier__max_features=8, classifier__min_samples_split=164; precision: (train=0.311, test=0.146) total time=  28.5s
# [CV 4/4; 11/40] START classifier__max_depth=659, classifier__max_features=8, classifier__min_samples_split=164
# [CV 4/4; 11/40] END classifier__max_depth=659, classifier__max_features=8, classifier__min_samples_split=164; precision: (train=0.290, test=0.091) total time=  27.8s
# [CV 1/4; 12/40] START classifier__max_depth=10, classifier__max_features=19, classifier__min_samples_split=156
# [CV 1/4; 12/40] END classifier__max_depth=10, classifier__max_features=19, classifier__min_samples_split=156; precision: (train=0.146, test=0.052) total time=  56.4s
# [CV 2/4; 12/40] START classifier__max_depth=10, classifier__max_features=19, classifier__min_samples_split=156
# [CV 2/4; 12/40] END classifier__max_depth=10, classifier__max_features=19, classifier__min_samples_split=156; precision: (train=0.156, test=0.042) total time=  57.1s
# [CV 3/4; 12/40] START classifier__max_depth=10, classifier__max_features=19, classifier__min_samples_split=156
# [CV 3/4; 12/40] END classifier__max_depth=10, classifier__max_features=19, classifier__min_samples_split=156; precision: (train=0.167, test=0.089) total time=  57.9s
# [CV 4/4; 12/40] START classifier__max_depth=10, classifier__max_features=19, classifier__min_samples_split=156
# [CV 4/4; 12/40] END classifier__max_depth=10, classifier__max_features=19, classifier__min_samples_split=156; precision: (train=0.145, test=0.059) total time=  57.0s
# [CV 1/4; 13/40] START classifier__max_depth=598, classifier__max_features=30, classifier__min_samples_split=286
# [CV 1/4; 13/40] END classifier__max_depth=598, classifier__max_features=30, classifier__min_samples_split=286; precision: (train=0.068, test=0.040) total time= 1.5min
# [CV 2/4; 13/40] START classifier__max_depth=598, classifier__max_features=30, classifier__min_samples_split=286
# [CV 2/4; 13/40] END classifier__max_depth=598, classifier__max_features=30, classifier__min_samples_split=286; precision: (train=0.076, test=0.024) total time= 1.6min
# [CV 3/4; 13/40] START classifier__max_depth=598, classifier__max_features=30, classifier__min_samples_split=286
# [CV 3/4; 13/40] END classifier__max_depth=598, classifier__max_features=30, classifier__min_samples_split=286; precision: (train=0.060, test=0.043) total time= 1.7min
# [CV 4/4; 13/40] START classifier__max_depth=598, classifier__max_features=30, classifier__min_samples_split=286
# [CV 4/4; 13/40] END classifier__max_depth=598, classifier__max_features=30, classifier__min_samples_split=286; precision: (train=0.081, test=0.029) total time= 1.7min
# [CV 1/4; 14/40] START classifier__max_depth=629, classifier__max_features=37, classifier__min_samples_split=42
# [CV 1/4; 14/40] END classifier__max_depth=629, classifier__max_features=37, classifier__min_samples_split=42; precision: (train=0.531, test=0.086) total time= 1.7min
# [CV 2/4; 14/40] START classifier__max_depth=629, classifier__max_features=37, classifier__min_samples_split=42
# [CV 2/4; 14/40] END classifier__max_depth=629, classifier__max_features=37, classifier__min_samples_split=42; precision: (train=0.446, test=0.053) total time= 1.8min
# [CV 3/4; 14/40] START classifier__max_depth=629, classifier__max_features=37, classifier__min_samples_split=42
# [CV 3/4; 14/40] END classifier__max_depth=629, classifier__max_features=37, classifier__min_samples_split=42; precision: (train=0.594, test=0.172) total time= 1.7min
# [CV 4/4; 14/40] START classifier__max_depth=629, classifier__max_features=37, classifier__min_samples_split=42
# [CV 4/4; 14/40] END classifier__max_depth=629, classifier__max_features=37, classifier__min_samples_split=42; precision: (train=0.403, test=0.069) total time= 1.8min
# [CV 1/4; 15/40] START classifier__max_depth=659, classifier__max_features=10, classifier__min_samples_split=205
# [CV 1/4; 15/40] END classifier__max_depth=659, classifier__max_features=10, classifier__min_samples_split=205; precision: (train=0.259, test=0.060) total time=  34.3s
# [CV 2/4; 15/40] START classifier__max_depth=659, classifier__max_features=10, classifier__min_samples_split=205
# [CV 2/4; 15/40] END classifier__max_depth=659, classifier__max_features=10, classifier__min_samples_split=205; precision: (train=0.211, test=0.056) total time=  34.6s
# [CV 3/4; 15/40] START classifier__max_depth=659, classifier__max_features=10, classifier__min_samples_split=205
# [CV 3/4; 15/40] END classifier__max_depth=659, classifier__max_features=10, classifier__min_samples_split=205; precision: (train=0.236, test=0.135) total time=  34.1s
# [CV 4/4; 15/40] START classifier__max_depth=659, classifier__max_features=10, classifier__min_samples_split=205
# [CV 4/4; 15/40] END classifier__max_depth=659, classifier__max_features=10, classifier__min_samples_split=205; precision: (train=0.211, test=0.087) total time=  33.7s
# [CV 1/4; 16/40] START classifier__max_depth=689, classifier__max_features=12, classifier__min_samples_split=156
# [CV 1/4; 16/40] END classifier__max_depth=689, classifier__max_features=12, classifier__min_samples_split=156; precision: (train=0.327, test=0.070) total time=  41.9s
# [CV 2/4; 16/40] START classifier__max_depth=689, classifier__max_features=12, classifier__min_samples_split=156
# [CV 2/4; 16/40] END classifier__max_depth=689, classifier__max_features=12, classifier__min_samples_split=156; precision: (train=0.281, test=0.085) total time=  42.3s
# [CV 3/4; 16/40] START classifier__max_depth=689, classifier__max_features=12, classifier__min_samples_split=156
# [CV 3/4; 16/40] END classifier__max_depth=689, classifier__max_features=12, classifier__min_samples_split=156; precision: (train=0.300, test=0.167) total time=  42.2s
# [CV 4/4; 16/40] START classifier__max_depth=689, classifier__max_features=12, classifier__min_samples_split=156
# [CV 4/4; 16/40] END classifier__max_depth=689, classifier__max_features=12, classifier__min_samples_split=156; precision: (train=0.255, test=0.089) total time=  41.5s
# [CV 1/4; 17/40] START classifier__max_depth=55, classifier__max_features=20, classifier__min_samples_split=91
# [CV 1/4; 17/40] END classifier__max_depth=55, classifier__max_features=20, classifier__min_samples_split=91; precision: (train=0.420, test=0.073) total time= 1.2min
# [CV 2/4; 17/40] START classifier__max_depth=55, classifier__max_features=20, classifier__min_samples_split=91
# [CV 2/4; 17/40] END classifier__max_depth=55, classifier__max_features=20, classifier__min_samples_split=91; precision: (train=0.342, test=0.098) total time= 1.2min
# [CV 3/4; 17/40] START classifier__max_depth=55, classifier__max_features=20, classifier__min_samples_split=91
# [CV 3/4; 17/40] END classifier__max_depth=55, classifier__max_features=20, classifier__min_samples_split=91; precision: (train=0.336, test=0.158) total time= 1.2min
# [CV 4/4; 17/40] START classifier__max_depth=55, classifier__max_features=20, classifier__min_samples_split=91
# [CV 4/4; 17/40] END classifier__max_depth=55, classifier__max_features=20, classifier__min_samples_split=91; precision: (train=0.288, test=0.027) total time= 1.2min
# [CV 1/4; 18/40] START classifier__max_depth=538, classifier__max_features=30, classifier__min_samples_split=58
# [CV 1/4; 18/40] END classifier__max_depth=538, classifier__max_features=30, classifier__min_samples_split=58; precision: (train=0.367, test=0.067) total time= 1.7min
# [CV 2/4; 18/40] START classifier__max_depth=538, classifier__max_features=30, classifier__min_samples_split=58
# [CV 2/4; 18/40] END classifier__max_depth=538, classifier__max_features=30, classifier__min_samples_split=58; precision: (train=0.303, test=0.070) total time= 1.8min
# [CV 3/4; 18/40] START classifier__max_depth=538, classifier__max_features=30, classifier__min_samples_split=58
# [CV 3/4; 18/40] END classifier__max_depth=538, classifier__max_features=30, classifier__min_samples_split=58; precision: (train=0.325, test=0.100) total time= 1.9min
# [CV 4/4; 18/40] START classifier__max_depth=538, classifier__max_features=30, classifier__min_samples_split=58
# [CV 4/4; 18/40] END classifier__max_depth=538, classifier__max_features=30, classifier__min_samples_split=58; precision: (train=0.236, test=0.029) total time= 1.8min
# [CV 1/4; 19/40] START classifier__max_depth=296, classifier__max_features=4, classifier__min_samples_split=351
# [CV 1/4; 19/40] END classifier__max_depth=296, classifier__max_features=4, classifier__min_samples_split=351; precision: (train=0.154, test=0.057) total time=  14.2s
# [CV 2/4; 19/40] START classifier__max_depth=296, classifier__max_features=4, classifier__min_samples_split=351
# [CV 2/4; 19/40] END classifier__max_depth=296, classifier__max_features=4, classifier__min_samples_split=351; precision: (train=0.178, test=0.038) total time=  14.4s
# [CV 3/4; 19/40] START classifier__max_depth=296, classifier__max_features=4, classifier__min_samples_split=351
# [CV 3/4; 19/40] END classifier__max_depth=296, classifier__max_features=4, classifier__min_samples_split=351; precision: (train=0.148, test=0.089) total time=  14.0s
# [CV 4/4; 19/40] START classifier__max_depth=296, classifier__max_features=4, classifier__min_samples_split=351
# [CV 4/4; 19/40] END classifier__max_depth=296, classifier__max_features=4, classifier__min_samples_split=351; precision: (train=0.163, test=0.078) total time=  14.0s
# [CV 1/4; 20/40] START classifier__max_depth=719, classifier__max_features=35, classifier__min_samples_split=261
# [CV 1/4; 20/40] END classifier__max_depth=719, classifier__max_features=35, classifier__min_samples_split=261; precision: (train=0.073, test=0.040) total time= 1.6min
# [CV 2/4; 20/40] START classifier__max_depth=719, classifier__max_features=35, classifier__min_samples_split=261
# [CV 2/4; 20/40] END classifier__max_depth=719, classifier__max_features=35, classifier__min_samples_split=261; precision: (train=0.082, test=0.025) total time= 1.5min
# [CV 3/4; 20/40] START classifier__max_depth=719, classifier__max_features=35, classifier__min_samples_split=261
# [CV 3/4; 20/40] END classifier__max_depth=719, classifier__max_features=35, classifier__min_samples_split=261; precision: (train=0.072, test=0.048) total time= 2.1min
# [CV 4/4; 20/40] START classifier__max_depth=719, classifier__max_features=35, classifier__min_samples_split=261
# [CV 4/4; 20/40] END classifier__max_depth=719, classifier__max_features=35, classifier__min_samples_split=261; precision: (train=0.065, test=0.029) total time= 3.8min
# [CV 1/4; 21/40] START classifier__max_depth=266, classifier__max_features=4, classifier__min_samples_split=66
# [CV 1/4; 21/40] END classifier__max_depth=266, classifier__max_features=4, classifier__min_samples_split=66; precision: (train=0.700, test=0.300) total time=  39.1s
# [CV 2/4; 21/40] START classifier__max_depth=266, classifier__max_features=4, classifier__min_samples_split=66
# [CV 2/4; 21/40] END classifier__max_depth=266, classifier__max_features=4, classifier__min_samples_split=66; precision: (train=0.571, test=0.176) total time=  39.1s
# [CV 3/4; 21/40] START classifier__max_depth=266, classifier__max_features=4, classifier__min_samples_split=66
# [CV 3/4; 21/40] END classifier__max_depth=266, classifier__max_features=4, classifier__min_samples_split=66; precision: (train=0.829, test=0.167) total time=  38.6s
# [CV 4/4; 21/40] START classifier__max_depth=266, classifier__max_features=4, classifier__min_samples_split=66
# [CV 4/4; 21/40] END classifier__max_depth=266, classifier__max_features=4, classifier__min_samples_split=66; precision: (train=0.615, test=0.083) total time=  30.6s
# [CV 1/4; 22/40] START classifier__max_depth=191, classifier__max_features=10, classifier__min_samples_split=253
# [CV 1/4; 22/40] END classifier__max_depth=191, classifier__max_features=10, classifier__min_samples_split=253; precision: (train=0.197, test=0.074) total time=  33.0s
# [CV 2/4; 22/40] START classifier__max_depth=191, classifier__max_features=10, classifier__min_samples_split=253
# [CV 2/4; 22/40] END classifier__max_depth=191, classifier__max_features=10, classifier__min_samples_split=253; precision: (train=0.168, test=0.050) total time=  33.3s
# [CV 3/4; 22/40] START classifier__max_depth=191, classifier__max_features=10, classifier__min_samples_split=253
# [CV 3/4; 22/40] END classifier__max_depth=191, classifier__max_features=10, classifier__min_samples_split=253; precision: (train=0.179, test=0.101) total time=  33.0s
# [CV 4/4; 22/40] START classifier__max_depth=191, classifier__max_features=10, classifier__min_samples_split=253
# [CV 4/4; 22/40] END classifier__max_depth=191, classifier__max_features=10, classifier__min_samples_split=253; precision: (train=0.180, test=0.074) total time=  32.9s
# [CV 1/4; 23/40] START classifier__max_depth=25, classifier__max_features=30, classifier__min_samples_split=383
# [CV 1/4; 23/40] END classifier__max_depth=25, classifier__max_features=30, classifier__min_samples_split=383; precision: (train=0.049, test=0.027) total time= 1.5min
# [CV 2/4; 23/40] START classifier__max_depth=25, classifier__max_features=30, classifier__min_samples_split=383
# [CV 2/4; 23/40] END classifier__max_depth=25, classifier__max_features=30, classifier__min_samples_split=383; precision: (train=0.061, test=0.017) total time= 1.5min
# [CV 3/4; 23/40] START classifier__max_depth=25, classifier__max_features=30, classifier__min_samples_split=383
# [CV 3/4; 23/40] END classifier__max_depth=25, classifier__max_features=30, classifier__min_samples_split=383; precision: (train=0.062, test=0.037) total time= 1.6min
# [CV 4/4; 23/40] START classifier__max_depth=25, classifier__max_features=30, classifier__min_samples_split=383
# [CV 4/4; 23/40] END classifier__max_depth=25, classifier__max_features=30, classifier__min_samples_split=383; precision: (train=0.066, test=0.031) total time= 1.5min
# [CV 1/4; 24/40] START classifier__max_depth=598, classifier__max_features=17, classifier__min_samples_split=2
# [CV 1/4; 24/40] END classifier__max_depth=598, classifier__max_features=17, classifier__min_samples_split=2; precision: (train=1.000, test=0.100) total time= 1.0min
# [CV 2/4; 24/40] START classifier__max_depth=598, classifier__max_features=17, classifier__min_samples_split=2
# [CV 2/4; 24/40] END classifier__max_depth=598, classifier__max_features=17, classifier__min_samples_split=2; precision: (train=0.984, test=0.143) total time= 1.1min
# [CV 3/4; 24/40] START classifier__max_depth=598, classifier__max_features=17, classifier__min_samples_split=2
# [CV 3/4; 24/40] END classifier__max_depth=598, classifier__max_features=17, classifier__min_samples_split=2; precision: (train=1.000, test=0.167) total time= 1.1min
# [CV 4/4; 24/40] START classifier__max_depth=598, classifier__max_features=17, classifier__min_samples_split=2
# [CV 4/4; 24/40] END classifier__max_depth=598, classifier__max_features=17, classifier__min_samples_split=2; precision: (train=1.000, test=0.000) total time= 1.0min
# [CV 1/4; 25/40] START classifier__max_depth=659, classifier__max_features=30, classifier__min_samples_split=205
# [CV 1/4; 25/40] END classifier__max_depth=659, classifier__max_features=30, classifier__min_samples_split=205; precision: (train=0.110, test=0.044) total time= 1.6min
# [CV 2/4; 25/40] START classifier__max_depth=659, classifier__max_features=30, classifier__min_samples_split=205
# [CV 2/4; 25/40] END classifier__max_depth=659, classifier__max_features=30, classifier__min_samples_split=205; precision: (train=0.117, test=0.052) total time= 1.7min
# [CV 3/4; 25/40] START classifier__max_depth=659, classifier__max_features=30, classifier__min_samples_split=205
# [CV 3/4; 25/40] END classifier__max_depth=659, classifier__max_features=30, classifier__min_samples_split=205; precision: (train=0.094, test=0.056) total time= 1.7min
# [CV 4/4; 25/40] START classifier__max_depth=659, classifier__max_features=30, classifier__min_samples_split=205
# [CV 4/4; 25/40] END classifier__max_depth=659, classifier__max_features=30, classifier__min_samples_split=205; precision: (train=0.097, test=0.023) total time= 1.7min
# [CV 1/4; 26/40] START classifier__max_depth=357, classifier__max_features=32, classifier__min_samples_split=188
# [CV 1/4; 26/40] END classifier__max_depth=357, classifier__max_features=32, classifier__min_samples_split=188; precision: (train=0.115, test=0.059) total time= 1.7min
# [CV 2/4; 26/40] START classifier__max_depth=357, classifier__max_features=32, classifier__min_samples_split=188
# [CV 2/4; 26/40] END classifier__max_depth=357, classifier__max_features=32, classifier__min_samples_split=188; precision: (train=0.140, test=0.061) total time= 1.7min
# [CV 3/4; 26/40] START classifier__max_depth=357, classifier__max_features=32, classifier__min_samples_split=188
# [CV 3/4; 26/40] END classifier__max_depth=357, classifier__max_features=32, classifier__min_samples_split=188; precision: (train=0.117, test=0.054) total time= 1.8min
# [CV 4/4; 26/40] START classifier__max_depth=357, classifier__max_features=32, classifier__min_samples_split=188
# [CV 4/4; 26/40] END classifier__max_depth=357, classifier__max_features=32, classifier__min_samples_split=188; precision: (train=0.117, test=0.049) total time= 1.8min
# [CV 1/4; 27/40] START classifier__max_depth=674, classifier__max_features=35, classifier__min_samples_split=286
# [CV 1/4; 27/40] END classifier__max_depth=674, classifier__max_features=35, classifier__min_samples_split=286; precision: (train=0.065, test=0.035) total time= 1.5min
# [CV 2/4; 27/40] START classifier__max_depth=674, classifier__max_features=35, classifier__min_samples_split=286
# [CV 2/4; 27/40] END classifier__max_depth=674, classifier__max_features=35, classifier__min_samples_split=286; precision: (train=0.075, test=0.034) total time= 1.6min
# [CV 3/4; 27/40] START classifier__max_depth=674, classifier__max_features=35, classifier__min_samples_split=286
# [CV 3/4; 27/40] END classifier__max_depth=674, classifier__max_features=35, classifier__min_samples_split=286; precision: (train=0.072, test=0.042) total time= 1.6min
# [CV 4/4; 27/40] START classifier__max_depth=674, classifier__max_features=35, classifier__min_samples_split=286
# [CV 4/4; 27/40] END classifier__max_depth=674, classifier__max_features=35, classifier__min_samples_split=286; precision: (train=0.093, test=0.030) total time= 1.7min
# [CV 1/4; 28/40] START classifier__max_depth=568, classifier__max_features=34, classifier__min_samples_split=294
# [CV 1/4; 28/40] END classifier__max_depth=568, classifier__max_features=34, classifier__min_samples_split=294; precision: (train=0.058, test=0.033) total time= 1.6min
# [CV 2/4; 28/40] START classifier__max_depth=568, classifier__max_features=34, classifier__min_samples_split=294
# [CV 2/4; 28/40] END classifier__max_depth=568, classifier__max_features=34, classifier__min_samples_split=294; precision: (train=0.061, test=0.026) total time= 1.5min
# [CV 3/4; 28/40] START classifier__max_depth=568, classifier__max_features=34, classifier__min_samples_split=294
# [CV 3/4; 28/40] END classifier__max_depth=568, classifier__max_features=34, classifier__min_samples_split=294; precision: (train=0.053, test=0.042) total time= 1.7min
# [CV 4/4; 28/40] START classifier__max_depth=568, classifier__max_features=34, classifier__min_samples_split=294
# [CV 4/4; 28/40] END classifier__max_depth=568, classifier__max_features=34, classifier__min_samples_split=294; precision: (train=0.086, test=0.019) total time= 1.6min
# [CV 1/4; 29/40] START classifier__max_depth=674, classifier__max_features=20, classifier__min_samples_split=26
# [CV 1/4; 29/40] END classifier__max_depth=674, classifier__max_features=20, classifier__min_samples_split=26; precision: (train=0.717, test=0.111) total time= 1.2min
# [CV 2/4; 29/40] START classifier__max_depth=674, classifier__max_features=20, classifier__min_samples_split=26
# [CV 2/4; 29/40] END classifier__max_depth=674, classifier__max_features=20, classifier__min_samples_split=26; precision: (train=0.654, test=0.071) total time= 1.2min
# [CV 3/4; 29/40] START classifier__max_depth=674, classifier__max_features=20, classifier__min_samples_split=26
# [CV 3/4; 29/40] END classifier__max_depth=674, classifier__max_features=20, classifier__min_samples_split=26; precision: (train=0.974, test=0.125) total time= 1.2min
# [CV 4/4; 29/40] START classifier__max_depth=674, classifier__max_features=20, classifier__min_samples_split=26
# [CV 4/4; 29/40] END classifier__max_depth=674, classifier__max_features=20, classifier__min_samples_split=26; precision: (train=0.700, test=0.000) total time= 1.2min
# [CV 1/4; 30/40] START classifier__max_depth=327, classifier__max_features=2, classifier__min_samples_split=10
# [CV 1/4; 30/40] END classifier__max_depth=327, classifier__max_features=2, classifier__min_samples_split=10; precision: (train=0.971, test=0.333) total time=  12.2s
# [CV 2/4; 30/40] START classifier__max_depth=327, classifier__max_features=2, classifier__min_samples_split=10
# [CV 2/4; 30/40] END classifier__max_depth=327, classifier__max_features=2, classifier__min_samples_split=10; precision: (train=0.800, test=0.000) total time=  12.4s
# [CV 3/4; 30/40] START classifier__max_depth=327, classifier__max_features=2, classifier__min_samples_split=10
# [CV 3/4; 30/40] END classifier__max_depth=327, classifier__max_features=2, classifier__min_samples_split=10; precision: (train=1.000, test=0.000) total time=  12.2s
# [CV 4/4; 30/40] START classifier__max_depth=327, classifier__max_features=2, classifier__min_samples_split=10
# [CV 4/4; 30/40] END classifier__max_depth=327, classifier__max_features=2, classifier__min_samples_split=10; precision: (train=0.838, test=0.000) total time=  12.1s
# [CV 1/4; 31/40] START classifier__max_depth=115, classifier__max_features=22, classifier__min_samples_split=359
# [CV 1/4; 31/40] END classifier__max_depth=115, classifier__max_features=22, classifier__min_samples_split=359; precision: (train=0.092, test=0.044) total time= 1.1min
# [CV 2/4; 31/40] START classifier__max_depth=115, classifier__max_features=22, classifier__min_samples_split=359
# [CV 2/4; 31/40] END classifier__max_depth=115, classifier__max_features=22, classifier__min_samples_split=359; precision: (train=0.076, test=0.026) total time= 1.1min
# [CV 3/4; 31/40] START classifier__max_depth=115, classifier__max_features=22, classifier__min_samples_split=359
# [CV 3/4; 31/40] END classifier__max_depth=115, classifier__max_features=22, classifier__min_samples_split=359; precision: (train=0.091, test=0.045) total time= 1.2min
# [CV 4/4; 31/40] START classifier__max_depth=115, classifier__max_features=22, classifier__min_samples_split=359
# [CV 4/4; 31/40] END classifier__max_depth=115, classifier__max_features=22, classifier__min_samples_split=359; precision: (train=0.103, test=0.050) total time= 1.1min
# [CV 1/4; 32/40] START classifier__max_depth=704, classifier__max_features=2, classifier__min_samples_split=343
# [CV 1/4; 32/40] END classifier__max_depth=704, classifier__max_features=2, classifier__min_samples_split=343; precision: (train=0.162, test=0.093) total time=   8.8s
# [CV 2/4; 32/40] START classifier__max_depth=704, classifier__max_features=2, classifier__min_samples_split=343
# [CV 2/4; 32/40] END classifier__max_depth=704, classifier__max_features=2, classifier__min_samples_split=343; precision: (train=0.178, test=0.044) total time=   8.9s
# [CV 3/4; 32/40] START classifier__max_depth=704, classifier__max_features=2, classifier__min_samples_split=343
# [CV 3/4; 32/40] END classifier__max_depth=704, classifier__max_features=2, classifier__min_samples_split=343; precision: (train=0.164, test=0.080) total time=   8.8s
# [CV 4/4; 32/40] START classifier__max_depth=704, classifier__max_features=2, classifier__min_samples_split=343
# [CV 4/4; 32/40] END classifier__max_depth=704, classifier__max_features=2, classifier__min_samples_split=343; precision: (train=0.171, test=0.039) total time=   9.0s
# [CV 1/4; 33/40] START classifier__max_depth=40, classifier__max_features=22, classifier__min_samples_split=326
# [CV 1/4; 33/40] END classifier__max_depth=40, classifier__max_features=22, classifier__min_samples_split=326; precision: (train=0.125, test=0.075) total time= 1.2min
# [CV 2/4; 33/40] START classifier__max_depth=40, classifier__max_features=22, classifier__min_samples_split=326
# [CV 2/4; 33/40] END classifier__max_depth=40, classifier__max_features=22, classifier__min_samples_split=326; precision: (train=0.098, test=0.025) total time= 1.1min
# [CV 3/4; 33/40] START classifier__max_depth=40, classifier__max_features=22, classifier__min_samples_split=326
# [CV 3/4; 33/40] END classifier__max_depth=40, classifier__max_features=22, classifier__min_samples_split=326; precision: (train=0.096, test=0.049) total time= 1.2min
# [CV 4/4; 33/40] START classifier__max_depth=40, classifier__max_features=22, classifier__min_samples_split=326
# [CV 4/4; 33/40] END classifier__max_depth=40, classifier__max_features=22, classifier__min_samples_split=326; precision: (train=0.095, test=0.045) total time= 1.1min
# [CV 1/4; 34/40] START classifier__max_depth=417, classifier__max_features=28, classifier__min_samples_split=50
# [CV 1/4; 34/40] END classifier__max_depth=417, classifier__max_features=28, classifier__min_samples_split=50; precision: (train=0.430, test=0.061) total time= 1.6min
# [CV 2/4; 34/40] START classifier__max_depth=417, classifier__max_features=28, classifier__min_samples_split=50
# [CV 2/4; 34/40] END classifier__max_depth=417, classifier__max_features=28, classifier__min_samples_split=50; precision: (train=0.433, test=0.105) total time= 1.7min
# [CV 3/4; 34/40] START classifier__max_depth=417, classifier__max_features=28, classifier__min_samples_split=50
# [CV 3/4; 34/40] END classifier__max_depth=417, classifier__max_features=28, classifier__min_samples_split=50; precision: (train=0.486, test=0.208) total time= 1.7min
# [CV 4/4; 34/40] START classifier__max_depth=417, classifier__max_features=28, classifier__min_samples_split=50
# [CV 4/4; 34/40] END classifier__max_depth=417, classifier__max_features=28, classifier__min_samples_split=50; precision: (train=0.424, test=0.038) total time= 1.7min
# [CV 1/4; 35/40] START classifier__max_depth=115, classifier__max_features=3, classifier__min_samples_split=221
# [CV 1/4; 35/40] END classifier__max_depth=115, classifier__max_features=3, classifier__min_samples_split=221; precision: (train=0.271, test=0.089) total time=  12.3s
# [CV 2/4; 35/40] START classifier__max_depth=115, classifier__max_features=3, classifier__min_samples_split=221
# [CV 2/4; 35/40] END classifier__max_depth=115, classifier__max_features=3, classifier__min_samples_split=221; precision: (train=0.255, test=0.067) total time=  12.4s
# [CV 3/4; 35/40] START classifier__max_depth=115, classifier__max_features=3, classifier__min_samples_split=221
# [CV 3/4; 35/40] END classifier__max_depth=115, classifier__max_features=3, classifier__min_samples_split=221; precision: (train=0.245, test=0.109) total time=  12.2s
# [CV 4/4; 35/40] START classifier__max_depth=115, classifier__max_features=3, classifier__min_samples_split=221
# [CV 4/4; 35/40] END classifier__max_depth=115, classifier__max_features=3, classifier__min_samples_split=221; precision: (train=0.235, test=0.073) total time=  12.2s
# [CV 1/4; 36/40] START classifier__max_depth=85, classifier__max_features=32, classifier__min_samples_split=343
# [CV 1/4; 36/40] END classifier__max_depth=85, classifier__max_features=32, classifier__min_samples_split=343; precision: (train=0.059, test=0.035) total time= 1.6min
# [CV 2/4; 36/40] START classifier__max_depth=85, classifier__max_features=32, classifier__min_samples_split=343
# [CV 2/4; 36/40] END classifier__max_depth=85, classifier__max_features=32, classifier__min_samples_split=343; precision: (train=0.060, test=0.022) total time= 1.5min
# [CV 3/4; 36/40] START classifier__max_depth=85, classifier__max_features=32, classifier__min_samples_split=343
# [CV 3/4; 36/40] END classifier__max_depth=85, classifier__max_features=32, classifier__min_samples_split=343; precision: (train=0.064, test=0.047) total time= 1.6min
# [CV 4/4; 36/40] START classifier__max_depth=85, classifier__max_features=32, classifier__min_samples_split=343
# [CV 4/4; 36/40] END classifier__max_depth=85, classifier__max_features=32, classifier__min_samples_split=343; precision: (train=0.066, test=0.039) total time= 1.6min
# [CV 1/4; 37/40] START classifier__max_depth=750, classifier__max_features=12, classifier__min_samples_split=156
# [CV 1/4; 37/40] END classifier__max_depth=750, classifier__max_features=12, classifier__min_samples_split=156; precision: (train=0.336, test=0.065) total time=  41.7s
# [CV 2/4; 37/40] START classifier__max_depth=750, classifier__max_features=12, classifier__min_samples_split=156
# [CV 2/4; 37/40] END classifier__max_depth=750, classifier__max_features=12, classifier__min_samples_split=156; precision: (train=0.287, test=0.080) total time=  42.4s
# [CV 3/4; 37/40] START classifier__max_depth=750, classifier__max_features=12, classifier__min_samples_split=156
# [CV 3/4; 37/40] END classifier__max_depth=750, classifier__max_features=12, classifier__min_samples_split=156; precision: (train=0.293, test=0.158) total time=  42.1s
# [CV 4/4; 37/40] START classifier__max_depth=750, classifier__max_features=12, classifier__min_samples_split=156
# [CV 4/4; 37/40] END classifier__max_depth=750, classifier__max_features=12, classifier__min_samples_split=156; precision: (train=0.245, test=0.108) total time=  41.7s
# [CV 1/4; 38/40] START classifier__max_depth=432, classifier__max_features=25, classifier__min_samples_split=10
# [CV 1/4; 38/40] END classifier__max_depth=432, classifier__max_features=25, classifier__min_samples_split=10; precision: (train=0.889, test=0.111) total time= 1.5min
# [CV 2/4; 38/40] START classifier__max_depth=432, classifier__max_features=25, classifier__min_samples_split=10
# [CV 2/4; 38/40] END classifier__max_depth=432, classifier__max_features=25, classifier__min_samples_split=10; precision: (train=0.800, test=0.111) total time= 1.5min
# [CV 3/4; 38/40] START classifier__max_depth=432, classifier__max_features=25, classifier__min_samples_split=10
# [CV 3/4; 38/40] END classifier__max_depth=432, classifier__max_features=25, classifier__min_samples_split=10; precision: (train=0.891, test=0.286) total time= 1.5min
# [CV 4/4; 38/40] START classifier__max_depth=432, classifier__max_features=25, classifier__min_samples_split=10
# [CV 4/4; 38/40] END classifier__max_depth=432, classifier__max_features=25, classifier__min_samples_split=10; precision: (train=0.767, test=0.062) total time= 1.6min
# [CV 1/4; 39/40] START classifier__max_depth=236, classifier__max_features=34, classifier__min_samples_split=383
# [CV 1/4; 39/40] END classifier__max_depth=236, classifier__max_features=34, classifier__min_samples_split=383; precision: (train=0.059, test=0.040) total time= 1.5min
# [CV 2/4; 39/40] START classifier__max_depth=236, classifier__max_features=34, classifier__min_samples_split=383
# [CV 2/4; 39/40] END classifier__max_depth=236, classifier__max_features=34, classifier__min_samples_split=383; precision: (train=0.070, test=0.030) total time= 1.5min
# [CV 3/4; 39/40] START classifier__max_depth=236, classifier__max_features=34, classifier__min_samples_split=383
# [CV 3/4; 39/40] END classifier__max_depth=236, classifier__max_features=34, classifier__min_samples_split=383; precision: (train=0.059, test=0.028) total time= 1.7min
# [CV 4/4; 39/40] START classifier__max_depth=236, classifier__max_features=34, classifier__min_samples_split=383
# [CV 4/4; 39/40] END classifier__max_depth=236, classifier__max_features=34, classifier__min_samples_split=383; precision: (train=0.060, test=0.037) total time= 1.6min
# [CV 1/4; 40/40] START classifier__max_depth=689, classifier__max_features=15, classifier__min_samples_split=391
# [CV 1/4; 40/40] END classifier__max_depth=689, classifier__max_features=15, classifier__min_samples_split=391; precision: (train=0.121, test=0.048) total time=  46.6s
# [CV 2/4; 40/40] START classifier__max_depth=689, classifier__max_features=15, classifier__min_samples_split=391
# [CV 2/4; 40/40] END classifier__max_depth=689, classifier__max_features=15, classifier__min_samples_split=391; precision: (train=0.086, test=0.026) total time=  45.7s
# [CV 3/4; 40/40] START classifier__max_depth=689, classifier__max_features=15, classifier__min_samples_split=391
# [CV 3/4; 40/40] END classifier__max_depth=689, classifier__max_features=15, classifier__min_samples_split=391; precision: (train=0.103, test=0.057) total time=  46.5s
# [CV 4/4; 40/40] START classifier__max_depth=689, classifier__max_features=15, classifier__min_samples_split=391
# [CV 4/4; 40/40] END classifier__max_depth=689, classifier__max_features=15, classifier__min_samples_split=391; precision: (train=0.110, test=0.036) total time=  45.7s
# 0.18161764705882352 {'classifier__min_samples_split': 66, 'classifier__max_features': 4, 'classifier__max_depth': 266}
# 0.0

# %% [markdown]
# XGBoost
#
# a. balanced sampling

# %%
counter = Counter(df[target])
scale_pos_weight = counter[0] / counter[1]
scale_pos_weight
# Out:
# 176.52747252747253

# %%
param_distributions = {
        #"classifier__eta": [i for i in np.linspace(0, 1, 20)]
        "classifier__gamma": [i for i in np.linspace(0, 20, 20)]
        ,"classifier__max_depth": [np.int64(i) for i in np.linspace(2, 750, 50)]
        ,"classifier__lambda": [i for i in np.linspace(0, 20, 20)]
        ,"classifier__alpha": [i for i in np.linspace(0, 20, 20)]
        ,"classifier__min_child_weight": [i for i in np.linspace(0, 20, 20)]
        ,"classifier__colsample_bytree": [i for i in np.linspace(0.5, 1, 10)]
        ,"classifier__subsample": [i for i in np.linspace(0.5, 1, 10)]
    }
classifier = XGBClassifier(n_jobs=None, eval_metric='pre', scale_pos_weight=scale_pos_weight, eta=0.63)
pipeline = Pipeline([
        ('custom_preprocessor', CustomPreprocessor(one_hot_encoded_cols)),
        ('classifier', classifier)
    ])
random_search = run_experiment(features, param_distributions, pipeline, 
                               n_iter=100, n_splits=4, 
                               classifier=classifier, one_hot_encoded_cols=one_hot_encoded_cols)
# Out:
# Fitting 4 folds for each of 100 candidates, totalling 400 fits
# [CV 1/4; 1/100] START classifier__alpha=13.68421052631579, classifier__colsample_bytree=0.6666666666666666, classifier__gamma=14.736842105263158, classifier__lambda=9.473684210526315, classifier__max_depth=429, classifier__min_child_weight=11.578947368421051, classifier__subsample=0.9444444444444444
# [CV 1/4; 1/100] END classifier__alpha=13.68421052631579, classifier__colsample_bytree=0.6666666666666666, classifier__gamma=14.736842105263158, classifier__lambda=9.473684210526315, classifier__max_depth=429, classifier__min_child_weight=11.578947368421051, classifier__subsample=0.9444444444444444; precision: (train=0.137, test=0.043) total time=   0.3s
# [CV 2/4; 1/100] START classifier__alpha=13.68421052631579, classifier__colsample_bytree=0.6666666666666666, classifier__gamma=14.736842105263158, classifier__lambda=9.473684210526315, classifier__max_depth=429, classifier__min_child_weight=11.578947368421051, classifier__subsample=0.9444444444444444
# [CV 2/4; 1/100] END classifier__alpha=13.68421052631579, classifier__colsample_bytree=0.6666666666666666, classifier__gamma=14.736842105263158, classifier__lambda=9.473684210526315, classifier__max_depth=429, classifier__min_child_weight=11.578947368421051, classifier__subsample=0.9444444444444444; precision: (train=0.128, test=0.040) total time=   0.3s
# [CV 3/4; 1/100] START classifier__alpha=13.68421052631579, classifier__colsample_bytree=0.6666666666666666, classifier__gamma=14.736842105263158, classifier__lambda=9.473684210526315, classifier__max_depth=429, classifier__min_child_weight=11.578947368421051, classifier__subsample=0.9444444444444444
# [CV 3/4; 1/100] END classifier__alpha=13.68421052631579, classifier__colsample_bytree=0.6666666666666666, classifier__gamma=14.736842105263158, classifier__lambda=9.473684210526315, classifier__max_depth=429, classifier__min_child_weight=11.578947368421051, classifier__subsample=0.9444444444444444; precision: (train=0.143, test=0.046) total time=   0.4s
# [CV 4/4; 1/100] START classifier__alpha=13.68421052631579, classifier__colsample_bytree=0.6666666666666666, classifier__gamma=14.736842105263158, classifier__lambda=9.473684210526315, classifier__max_depth=429, classifier__min_child_weight=11.578947368421051, classifier__subsample=0.9444444444444444
# [CV 4/4; 1/100] END classifier__alpha=13.68421052631579, classifier__colsample_bytree=0.6666666666666666, classifier__gamma=14.736842105263158, classifier__lambda=9.473684210526315, classifier__max_depth=429, classifier__min_child_weight=11.578947368421051, classifier__subsample=0.9444444444444444; precision: (train=0.140, test=0.036) total time=   0.4s
# [CV 1/4; 2/100] START classifier__alpha=4.2105263157894735, classifier__colsample_bytree=1.0, classifier__gamma=20.0, classifier__lambda=10.526315789473683, classifier__max_depth=32, classifier__min_child_weight=20.0, classifier__subsample=0.7777777777777778
# [CV 1/4; 2/100] END classifier__alpha=4.2105263157894735, classifier__colsample_bytree=1.0, classifier__gamma=20.0, classifier__lambda=10.526315789473683, classifier__max_depth=32, classifier__min_child_weight=20.0, classifier__subsample=0.7777777777777778; precision: (train=0.180, test=0.048) total time=   0.5s
# [CV 2/4; 2/100] START classifier__alpha=4.2105263157894735, classifier__colsample_bytree=1.0, classifier__gamma=20.0, classifier__lambda=10.526315789473683, classifier__max_depth=32, classifier__min_child_weight=20.0, classifier__subsample=0.7777777777777778
# [CV 2/4; 2/100] END classifier__alpha=4.2105263157894735, classifier__colsample_bytree=1.0, classifier__gamma=20.0, classifier__lambda=10.526315789473683, classifier__max_depth=32, classifier__min_child_weight=20.0, classifier__subsample=0.7777777777777778; precision: (train=0.178, test=0.039) total time=   0.4s
# [CV 3/4; 2/100] START classifier__alpha=4.2105263157894735, classifier__colsample_bytree=1.0, classifier__gamma=20.0, classifier__lambda=10.526315789473683, classifier__max_depth=32, classifier__min_child_weight=20.0, classifier__subsample=0.7777777777777778
# [CV 3/4; 2/100] END classifier__alpha=4.2105263157894735, classifier__colsample_bytree=1.0, classifier__gamma=20.0, classifier__lambda=10.526315789473683, classifier__max_depth=32, classifier__min_child_weight=20.0, classifier__subsample=0.7777777777777778; precision: (train=0.178, test=0.071) total time=   0.4s
# [CV 4/4; 2/100] START classifier__alpha=4.2105263157894735, classifier__colsample_bytree=1.0, classifier__gamma=20.0, classifier__lambda=10.526315789473683, classifier__max_depth=32, classifier__min_child_weight=20.0, classifier__subsample=0.7777777777777778
# [CV 4/4; 2/100] END classifier__alpha=4.2105263157894735, classifier__colsample_bytree=1.0, classifier__gamma=20.0, classifier__lambda=10.526315789473683, classifier__max_depth=32, classifier__min_child_weight=20.0, classifier__subsample=0.7777777777777778; precision: (train=0.186, test=0.028) total time=   0.5s
# [CV 1/4; 3/100] START classifier__alpha=20.0, classifier__colsample_bytree=0.8333333333333333, classifier__gamma=20.0, classifier__lambda=4.2105263157894735, classifier__max_depth=490, classifier__min_child_weight=1.0526315789473684, classifier__subsample=0.7222222222222222
# [CV 1/4; 3/100] END classifier__alpha=20.0, classifier__colsample_bytree=0.8333333333333333, classifier__gamma=20.0, classifier__lambda=4.2105263157894735, classifier__max_depth=490, classifier__min_child_weight=1.0526315789473684, classifier__subsample=0.7222222222222222; precision: (train=0.155, test=0.063) total time=   0.4s
# [CV 2/4; 3/100] START classifier__alpha=20.0, classifier__colsample_bytree=0.8333333333333333, classifier__gamma=20.0, classifier__lambda=4.2105263157894735, classifier__max_depth=490, classifier__min_child_weight=1.0526315789473684, classifier__subsample=0.7222222222222222
# [CV 2/4; 3/100] END classifier__alpha=20.0, classifier__colsample_bytree=0.8333333333333333, classifier__gamma=20.0, classifier__lambda=4.2105263157894735, classifier__max_depth=490, classifier__min_child_weight=1.0526315789473684, classifier__subsample=0.7222222222222222; precision: (train=0.163, test=0.049) total time=   0.4s
# [CV 3/4; 3/100] START classifier__alpha=20.0, classifier__colsample_bytree=0.8333333333333333, classifier__gamma=20.0, classifier__lambda=4.2105263157894735, classifier__max_depth=490, classifier__min_child_weight=1.0526315789473684, classifier__subsample=0.7222222222222222
# [CV 3/4; 3/100] END classifier__alpha=20.0, classifier__colsample_bytree=0.8333333333333333, classifier__gamma=20.0, classifier__lambda=4.2105263157894735, classifier__max_depth=490, classifier__min_child_weight=1.0526315789473684, classifier__subsample=0.7222222222222222; precision: (train=0.177, test=0.077) total time=   0.3s
# [CV 4/4; 3/100] START classifier__alpha=20.0, classifier__colsample_bytree=0.8333333333333333, classifier__gamma=20.0, classifier__lambda=4.2105263157894735, classifier__max_depth=490, classifier__min_child_weight=1.0526315789473684, classifier__subsample=0.7222222222222222
# [CV 4/4; 3/100] END classifier__alpha=20.0, classifier__colsample_bytree=0.8333333333333333, classifier__gamma=20.0, classifier__lambda=4.2105263157894735, classifier__max_depth=490, classifier__min_child_weight=1.0526315789473684, classifier__subsample=0.7222222222222222; precision: (train=0.161, test=0.041) total time=   0.5s
# [CV 1/4; 4/100] START classifier__alpha=3.1578947368421053, classifier__colsample_bytree=0.5555555555555556, classifier__gamma=17.894736842105264, classifier__lambda=12.631578947368421, classifier__max_depth=139, classifier__min_child_weight=6.315789473684211, classifier__subsample=0.6666666666666666
# [CV 1/4; 4/100] END classifier__alpha=3.1578947368421053, classifier__colsample_bytree=0.5555555555555556, classifier__gamma=17.894736842105264, classifier__lambda=12.631578947368421, classifier__max_depth=139, classifier__min_child_weight=6.315789473684211, classifier__subsample=0.6666666666666666; precision: (train=0.181, test=0.073) total time=   0.5s
# [CV 2/4; 4/100] START classifier__alpha=3.1578947368421053, classifier__colsample_bytree=0.5555555555555556, classifier__gamma=17.894736842105264, classifier__lambda=12.631578947368421, classifier__max_depth=139, classifier__min_child_weight=6.315789473684211, classifier__subsample=0.6666666666666666
# [CV 2/4; 4/100] END classifier__alpha=3.1578947368421053, classifier__colsample_bytree=0.5555555555555556, classifier__gamma=17.894736842105264, classifier__lambda=12.631578947368421, classifier__max_depth=139, classifier__min_child_weight=6.315789473684211, classifier__subsample=0.6666666666666666; precision: (train=0.202, test=0.063) total time=   0.4s
# [CV 3/4; 4/100] START classifier__alpha=3.1578947368421053, classifier__colsample_bytree=0.5555555555555556, classifier__gamma=17.894736842105264, classifier__lambda=12.631578947368421, classifier__max_depth=139, classifier__min_child_weight=6.315789473684211, classifier__subsample=0.6666666666666666
# [CV 3/4; 4/100] END classifier__alpha=3.1578947368421053, classifier__colsample_bytree=0.5555555555555556, classifier__gamma=17.894736842105264, classifier__lambda=12.631578947368421, classifier__max_depth=139, classifier__min_child_weight=6.315789473684211, classifier__subsample=0.6666666666666666; precision: (train=0.209, test=0.057) total time=   0.4s
# [CV 4/4; 4/100] START classifier__alpha=3.1578947368421053, classifier__colsample_bytree=0.5555555555555556, classifier__gamma=17.894736842105264, classifier__lambda=12.631578947368421, classifier__max_depth=139, classifier__min_child_weight=6.315789473684211, classifier__subsample=0.6666666666666666
# [CV 4/4; 4/100] END classifier__alpha=3.1578947368421053, classifier__colsample_bytree=0.5555555555555556, classifier__gamma=17.894736842105264, classifier__lambda=12.631578947368421, classifier__max_depth=139, classifier__min_child_weight=6.315789473684211, classifier__subsample=0.6666666666666666; precision: (train=0.188, test=0.044) total time=   0.4s
# [CV 1/4; 5/100] START classifier__alpha=10.526315789473683, classifier__colsample_bytree=0.7777777777777778, classifier__gamma=18.94736842105263, classifier__lambda=13.68421052631579, classifier__max_depth=368, classifier__min_child_weight=17.894736842105264, classifier__subsample=0.6111111111111112
# [CV 1/4; 5/100] END classifier__alpha=10.526315789473683, classifier__colsample_bytree=0.7777777777777778, classifier__gamma=18.94736842105263, classifier__lambda=13.68421052631579, classifier__max_depth=368, classifier__min_child_weight=17.894736842105264, classifier__subsample=0.6111111111111112; precision: (train=0.180, test=0.041) total time=   0.5s
# [CV 2/4; 5/100] START classifier__alpha=10.526315789473683, classifier__colsample_bytree=0.7777777777777778, classifier__gamma=18.94736842105263, classifier__lambda=13.68421052631579, classifier__max_depth=368, classifier__min_child_weight=17.894736842105264, classifier__subsample=0.6111111111111112
# [CV 2/4; 5/100] END classifier__alpha=10.526315789473683, classifier__colsample_bytree=0.7777777777777778, classifier__gamma=18.94736842105263, classifier__lambda=13.68421052631579, classifier__max_depth=368, classifier__min_child_weight=17.894736842105264, classifier__subsample=0.6111111111111112; precision: (train=0.169, test=0.052) total time=   0.4s
# [CV 3/4; 5/100] START classifier__alpha=10.526315789473683, classifier__colsample_bytree=0.7777777777777778, classifier__gamma=18.94736842105263, classifier__lambda=13.68421052631579, classifier__max_depth=368, classifier__min_child_weight=17.894736842105264, classifier__subsample=0.6111111111111112
# [CV 3/4; 5/100] END classifier__alpha=10.526315789473683, classifier__colsample_bytree=0.7777777777777778, classifier__gamma=18.94736842105263, classifier__lambda=13.68421052631579, classifier__max_depth=368, classifier__min_child_weight=17.894736842105264, classifier__subsample=0.6111111111111112; precision: (train=0.178, test=0.054) total time=   0.5s
# [CV 4/4; 5/100] START classifier__alpha=10.526315789473683, classifier__colsample_bytree=0.7777777777777778, classifier__gamma=18.94736842105263, classifier__lambda=13.68421052631579, classifier__max_depth=368, classifier__min_child_weight=17.894736842105264, classifier__subsample=0.6111111111111112
# [CV 4/4; 5/100] END classifier__alpha=10.526315789473683, classifier__colsample_bytree=0.7777777777777778, classifier__gamma=18.94736842105263, classifier__lambda=13.68421052631579, classifier__max_depth=368, classifier__min_child_weight=17.894736842105264, classifier__subsample=0.6111111111111112; precision: (train=0.168, test=0.033) total time=   0.5s
# [CV 1/4; 6/100] START classifier__alpha=10.526315789473683, classifier__colsample_bytree=0.6666666666666666, classifier__gamma=20.0, classifier__lambda=16.842105263157894, classifier__max_depth=627, classifier__min_child_weight=7.368421052631579, classifier__subsample=0.8333333333333333
# [CV 1/4; 6/100] END classifier__alpha=10.526315789473683, classifier__colsample_bytree=0.6666666666666666, classifier__gamma=20.0, classifier__lambda=16.842105263157894, classifier__max_depth=627, classifier__min_child_weight=7.368421052631579, classifier__subsample=0.8333333333333333; precision: (train=0.134, test=0.045) total time=   0.4s
# [CV 2/4; 6/100] START classifier__alpha=10.526315789473683, classifier__colsample_bytree=0.6666666666666666, classifier__gamma=20.0, classifier__lambda=16.842105263157894, classifier__max_depth=627, classifier__min_child_weight=7.368421052631579, classifier__subsample=0.8333333333333333
# [CV 2/4; 6/100] END classifier__alpha=10.526315789473683, classifier__colsample_bytree=0.6666666666666666, classifier__gamma=20.0, classifier__lambda=16.842105263157894, classifier__max_depth=627, classifier__min_child_weight=7.368421052631579, classifier__subsample=0.8333333333333333; precision: (train=0.145, test=0.043) total time=   0.3s
# [CV 3/4; 6/100] START classifier__alpha=10.526315789473683, classifier__colsample_bytree=0.6666666666666666, classifier__gamma=20.0, classifier__lambda=16.842105263157894, classifier__max_depth=627, classifier__min_child_weight=7.368421052631579, classifier__subsample=0.8333333333333333
# [CV 3/4; 6/100] END classifier__alpha=10.526315789473683, classifier__colsample_bytree=0.6666666666666666, classifier__gamma=20.0, classifier__lambda=16.842105263157894, classifier__max_depth=627, classifier__min_child_weight=7.368421052631579, classifier__subsample=0.8333333333333333; precision: (train=0.166, test=0.070) total time=   0.3s
# [CV 4/4; 6/100] START classifier__alpha=10.526315789473683, classifier__colsample_bytree=0.6666666666666666, classifier__gamma=20.0, classifier__lambda=16.842105263157894, classifier__max_depth=627, classifier__min_child_weight=7.368421052631579, classifier__subsample=0.8333333333333333
# [CV 4/4; 6/100] END classifier__alpha=10.526315789473683, classifier__colsample_bytree=0.6666666666666666, classifier__gamma=20.0, classifier__lambda=16.842105263157894, classifier__max_depth=627, classifier__min_child_weight=7.368421052631579, classifier__subsample=0.8333333333333333; precision: (train=0.140, test=0.032) total time=   0.3s
# [CV 1/4; 7/100] START classifier__alpha=16.842105263157894, classifier__colsample_bytree=0.8888888888888888, classifier__gamma=10.526315789473683, classifier__lambda=9.473684210526315, classifier__max_depth=368, classifier__min_child_weight=15.789473684210526, classifier__subsample=0.5
# [CV 1/4; 7/100] END classifier__alpha=16.842105263157894, classifier__colsample_bytree=0.8888888888888888, classifier__gamma=10.526315789473683, classifier__lambda=9.473684210526315, classifier__max_depth=368, classifier__min_child_weight=15.789473684210526, classifier__subsample=0.5; precision: (train=0.165, test=0.061) total time=   0.4s
# [CV 2/4; 7/100] START classifier__alpha=16.842105263157894, classifier__colsample_bytree=0.8888888888888888, classifier__gamma=10.526315789473683, classifier__lambda=9.473684210526315, classifier__max_depth=368, classifier__min_child_weight=15.789473684210526, classifier__subsample=0.5
# [CV 2/4; 7/100] END classifier__alpha=16.842105263157894, classifier__colsample_bytree=0.8888888888888888, classifier__gamma=10.526315789473683, classifier__lambda=9.473684210526315, classifier__max_depth=368, classifier__min_child_weight=15.789473684210526, classifier__subsample=0.5; precision: (train=0.173, test=0.063) total time=   0.4s
# [CV 3/4; 7/100] START classifier__alpha=16.842105263157894, classifier__colsample_bytree=0.8888888888888888, classifier__gamma=10.526315789473683, classifier__lambda=9.473684210526315, classifier__max_depth=368, classifier__min_child_weight=15.789473684210526, classifier__subsample=0.5
# [CV 3/4; 7/100] END classifier__alpha=16.842105263157894, classifier__colsample_bytree=0.8888888888888888, classifier__gamma=10.526315789473683, classifier__lambda=9.473684210526315, classifier__max_depth=368, classifier__min_child_weight=15.789473684210526, classifier__subsample=0.5; precision: (train=0.178, test=0.054) total time=   0.4s
# [CV 4/4; 7/100] START classifier__alpha=16.842105263157894, classifier__colsample_bytree=0.8888888888888888, classifier__gamma=10.526315789473683, classifier__lambda=9.473684210526315, classifier__max_depth=368, classifier__min_child_weight=15.789473684210526, classifier__subsample=0.5
# [CV 4/4; 7/100] END classifier__alpha=16.842105263157894, classifier__colsample_bytree=0.8888888888888888, classifier__gamma=10.526315789473683, classifier__lambda=9.473684210526315, classifier__max_depth=368, classifier__min_child_weight=15.789473684210526, classifier__subsample=0.5; precision: (train=0.177, test=0.060) total time=   0.4s
# [CV 1/4; 8/100] START classifier__alpha=16.842105263157894, classifier__colsample_bytree=0.8888888888888888, classifier__gamma=9.473684210526315, classifier__lambda=20.0, classifier__max_depth=93, classifier__min_child_weight=17.894736842105264, classifier__subsample=0.9444444444444444
# [CV 1/4; 8/100] END classifier__alpha=16.842105263157894, classifier__colsample_bytree=0.8888888888888888, classifier__gamma=9.473684210526315, classifier__lambda=20.0, classifier__max_depth=93, classifier__min_child_weight=17.894736842105264, classifier__subsample=0.9444444444444444; precision: (train=0.138, test=0.034) total time=   0.4s
# [CV 2/4; 8/100] START classifier__alpha=16.842105263157894, classifier__colsample_bytree=0.8888888888888888, classifier__gamma=9.473684210526315, classifier__lambda=20.0, classifier__max_depth=93, classifier__min_child_weight=17.894736842105264, classifier__subsample=0.9444444444444444
# [CV 2/4; 8/100] END classifier__alpha=16.842105263157894, classifier__colsample_bytree=0.8888888888888888, classifier__gamma=9.473684210526315, classifier__lambda=20.0, classifier__max_depth=93, classifier__min_child_weight=17.894736842105264, classifier__subsample=0.9444444444444444; precision: (train=0.129, test=0.046) total time=   0.4s
# [CV 3/4; 8/100] START classifier__alpha=16.842105263157894, classifier__colsample_bytree=0.8888888888888888, classifier__gamma=9.473684210526315, classifier__lambda=20.0, classifier__max_depth=93, classifier__min_child_weight=17.894736842105264, classifier__subsample=0.9444444444444444
# [CV 3/4; 8/100] END classifier__alpha=16.842105263157894, classifier__colsample_bytree=0.8888888888888888, classifier__gamma=9.473684210526315, classifier__lambda=20.0, classifier__max_depth=93, classifier__min_child_weight=17.894736842105264, classifier__subsample=0.9444444444444444; precision: (train=0.157, test=0.069) total time=   0.4s
# [CV 4/4; 8/100] START classifier__alpha=16.842105263157894, classifier__colsample_bytree=0.8888888888888888, classifier__gamma=9.473684210526315, classifier__lambda=20.0, classifier__max_depth=93, classifier__min_child_weight=17.894736842105264, classifier__subsample=0.9444444444444444
# [CV 4/4; 8/100] END classifier__alpha=16.842105263157894, classifier__colsample_bytree=0.8888888888888888, classifier__gamma=9.473684210526315, classifier__lambda=20.0, classifier__max_depth=93, classifier__min_child_weight=17.894736842105264, classifier__subsample=0.9444444444444444; precision: (train=0.142, test=0.056) total time=   0.4s
# [CV 1/4; 9/100] START classifier__alpha=10.526315789473683, classifier__colsample_bytree=0.8888888888888888, classifier__gamma=6.315789473684211, classifier__lambda=18.94736842105263, classifier__max_depth=688, classifier__min_child_weight=1.0526315789473684, classifier__subsample=0.7222222222222222
# [CV 1/4; 9/100] END classifier__alpha=10.526315789473683, classifier__colsample_bytree=0.8888888888888888, classifier__gamma=6.315789473684211, classifier__lambda=18.94736842105263, classifier__max_depth=688, classifier__min_child_weight=1.0526315789473684, classifier__subsample=0.7222222222222222; precision: (train=0.264, test=0.077) total time=   0.4s
# [CV 2/4; 9/100] START classifier__alpha=10.526315789473683, classifier__colsample_bytree=0.8888888888888888, classifier__gamma=6.315789473684211, classifier__lambda=18.94736842105263, classifier__max_depth=688, classifier__min_child_weight=1.0526315789473684, classifier__subsample=0.7222222222222222
# [CV 2/4; 9/100] END classifier__alpha=10.526315789473683, classifier__colsample_bytree=0.8888888888888888, classifier__gamma=6.315789473684211, classifier__lambda=18.94736842105263, classifier__max_depth=688, classifier__min_child_weight=1.0526315789473684, classifier__subsample=0.7222222222222222; precision: (train=0.260, test=0.066) total time=   0.4s
# [CV 3/4; 9/100] START classifier__alpha=10.526315789473683, classifier__colsample_bytree=0.8888888888888888, classifier__gamma=6.315789473684211, classifier__lambda=18.94736842105263, classifier__max_depth=688, classifier__min_child_weight=1.0526315789473684, classifier__subsample=0.7222222222222222
# [CV 3/4; 9/100] END classifier__alpha=10.526315789473683, classifier__colsample_bytree=0.8888888888888888, classifier__gamma=6.315789473684211, classifier__lambda=18.94736842105263, classifier__max_depth=688, classifier__min_child_weight=1.0526315789473684, classifier__subsample=0.7222222222222222; precision: (train=0.275, test=0.104) total time=   0.4s
# [CV 4/4; 9/100] START classifier__alpha=10.526315789473683, classifier__colsample_bytree=0.8888888888888888, classifier__gamma=6.315789473684211, classifier__lambda=18.94736842105263, classifier__max_depth=688, classifier__min_child_weight=1.0526315789473684, classifier__subsample=0.7222222222222222
# [CV 4/4; 9/100] END classifier__alpha=10.526315789473683, classifier__colsample_bytree=0.8888888888888888, classifier__gamma=6.315789473684211, classifier__lambda=18.94736842105263, classifier__max_depth=688, classifier__min_child_weight=1.0526315789473684, classifier__subsample=0.7222222222222222; precision: (train=0.272, test=0.074) total time=   0.4s
# [CV 1/4; 10/100] START classifier__alpha=6.315789473684211, classifier__colsample_bytree=0.6111111111111112, classifier__gamma=7.368421052631579, classifier__lambda=6.315789473684211, classifier__max_depth=551, classifier__min_child_weight=1.0526315789473684, classifier__subsample=0.5
# [CV 1/4; 10/100] END classifier__alpha=6.315789473684211, classifier__colsample_bytree=0.6111111111111112, classifier__gamma=7.368421052631579, classifier__lambda=6.315789473684211, classifier__max_depth=551, classifier__min_child_weight=1.0526315789473684, classifier__subsample=0.5; precision: (train=0.279, test=0.047) total time=   0.5s
# [CV 2/4; 10/100] START classifier__alpha=6.315789473684211, classifier__colsample_bytree=0.6111111111111112, classifier__gamma=7.368421052631579, classifier__lambda=6.315789473684211, classifier__max_depth=551, classifier__min_child_weight=1.0526315789473684, classifier__subsample=0.5
# [CV 2/4; 10/100] END classifier__alpha=6.315789473684211, classifier__colsample_bytree=0.6111111111111112, classifier__gamma=7.368421052631579, classifier__lambda=6.315789473684211, classifier__max_depth=551, classifier__min_child_weight=1.0526315789473684, classifier__subsample=0.5; precision: (train=0.274, test=0.068) total time=   0.5s
# [CV 3/4; 10/100] START classifier__alpha=6.315789473684211, classifier__colsample_bytree=0.6111111111111112, classifier__gamma=7.368421052631579, classifier__lambda=6.315789473684211, classifier__max_depth=551, classifier__min_child_weight=1.0526315789473684, classifier__subsample=0.5
# [CV 3/4; 10/100] END classifier__alpha=6.315789473684211, classifier__colsample_bytree=0.6111111111111112, classifier__gamma=7.368421052631579, classifier__lambda=6.315789473684211, classifier__max_depth=551, classifier__min_child_weight=1.0526315789473684, classifier__subsample=0.5; precision: (train=0.330, test=0.072) total time=   0.5s
# [CV 4/4; 10/100] START classifier__alpha=6.315789473684211, classifier__colsample_bytree=0.6111111111111112, classifier__gamma=7.368421052631579, classifier__lambda=6.315789473684211, classifier__max_depth=551, classifier__min_child_weight=1.0526315789473684, classifier__subsample=0.5
# [CV 4/4; 10/100] END classifier__alpha=6.315789473684211, classifier__colsample_bytree=0.6111111111111112, classifier__gamma=7.368421052631579, classifier__lambda=6.315789473684211, classifier__max_depth=551, classifier__min_child_weight=1.0526315789473684, classifier__subsample=0.5; precision: (train=0.298, test=0.058) total time=   0.6s
# [CV 1/4; 11/100] START classifier__alpha=12.631578947368421, classifier__colsample_bytree=0.7222222222222222, classifier__gamma=14.736842105263158, classifier__lambda=17.894736842105264, classifier__max_depth=200, classifier__min_child_weight=15.789473684210526, classifier__subsample=1.0
# [CV 1/4; 11/100] END classifier__alpha=12.631578947368421, classifier__colsample_bytree=0.7222222222222222, classifier__gamma=14.736842105263158, classifier__lambda=17.894736842105264, classifier__max_depth=200, classifier__min_child_weight=15.789473684210526, classifier__subsample=1.0; precision: (train=0.119, test=0.041) total time=   0.4s
# [CV 2/4; 11/100] START classifier__alpha=12.631578947368421, classifier__colsample_bytree=0.7222222222222222, classifier__gamma=14.736842105263158, classifier__lambda=17.894736842105264, classifier__max_depth=200, classifier__min_child_weight=15.789473684210526, classifier__subsample=1.0
# [CV 2/4; 11/100] END classifier__alpha=12.631578947368421, classifier__colsample_bytree=0.7222222222222222, classifier__gamma=14.736842105263158, classifier__lambda=17.894736842105264, classifier__max_depth=200, classifier__min_child_weight=15.789473684210526, classifier__subsample=1.0; precision: (train=0.121, test=0.034) total time=   0.5s
# [CV 3/4; 11/100] START classifier__alpha=12.631578947368421, classifier__colsample_bytree=0.7222222222222222, classifier__gamma=14.736842105263158, classifier__lambda=17.894736842105264, classifier__max_depth=200, classifier__min_child_weight=15.789473684210526, classifier__subsample=1.0
# [CV 3/4; 11/100] END classifier__alpha=12.631578947368421, classifier__colsample_bytree=0.7222222222222222, classifier__gamma=14.736842105263158, classifier__lambda=17.894736842105264, classifier__max_depth=200, classifier__min_child_weight=15.789473684210526, classifier__subsample=1.0; precision: (train=0.124, test=0.067) total time=   0.5s
# [CV 4/4; 11/100] START classifier__alpha=12.631578947368421, classifier__colsample_bytree=0.7222222222222222, classifier__gamma=14.736842105263158, classifier__lambda=17.894736842105264, classifier__max_depth=200, classifier__min_child_weight=15.789473684210526, classifier__subsample=1.0
# [CV 4/4; 11/100] END classifier__alpha=12.631578947368421, classifier__colsample_bytree=0.7222222222222222, classifier__gamma=14.736842105263158, classifier__lambda=17.894736842105264, classifier__max_depth=200, classifier__min_child_weight=15.789473684210526, classifier__subsample=1.0; precision: (train=0.110, test=0.030) total time=   0.4s
# [CV 1/4; 12/100] START classifier__alpha=8.421052631578947, classifier__colsample_bytree=1.0, classifier__gamma=17.894736842105264, classifier__lambda=12.631578947368421, classifier__max_depth=429, classifier__min_child_weight=14.736842105263158, classifier__subsample=0.9444444444444444
# [CV 1/4; 12/100] END classifier__alpha=8.421052631578947, classifier__colsample_bytree=1.0, classifier__gamma=17.894736842105264, classifier__lambda=12.631578947368421, classifier__max_depth=429, classifier__min_child_weight=14.736842105263158, classifier__subsample=0.9444444444444444; precision: (train=0.127, test=0.035) total time=   0.4s
# [CV 2/4; 12/100] START classifier__alpha=8.421052631578947, classifier__colsample_bytree=1.0, classifier__gamma=17.894736842105264, classifier__lambda=12.631578947368421, classifier__max_depth=429, classifier__min_child_weight=14.736842105263158, classifier__subsample=0.9444444444444444
# [CV 2/4; 12/100] END classifier__alpha=8.421052631578947, classifier__colsample_bytree=1.0, classifier__gamma=17.894736842105264, classifier__lambda=12.631578947368421, classifier__max_depth=429, classifier__min_child_weight=14.736842105263158, classifier__subsample=0.9444444444444444; precision: (train=0.136, test=0.043) total time=   0.6s
# [CV 3/4; 12/100] START classifier__alpha=8.421052631578947, classifier__colsample_bytree=1.0, classifier__gamma=17.894736842105264, classifier__lambda=12.631578947368421, classifier__max_depth=429, classifier__min_child_weight=14.736842105263158, classifier__subsample=0.9444444444444444
# [CV 3/4; 12/100] END classifier__alpha=8.421052631578947, classifier__colsample_bytree=1.0, classifier__gamma=17.894736842105264, classifier__lambda=12.631578947368421, classifier__max_depth=429, classifier__min_child_weight=14.736842105263158, classifier__subsample=0.9444444444444444; precision: (train=0.147, test=0.059) total time=   0.4s
# [CV 4/4; 12/100] START classifier__alpha=8.421052631578947, classifier__colsample_bytree=1.0, classifier__gamma=17.894736842105264, classifier__lambda=12.631578947368421, classifier__max_depth=429, classifier__min_child_weight=14.736842105263158, classifier__subsample=0.9444444444444444
# [CV 4/4; 12/100] END classifier__alpha=8.421052631578947, classifier__colsample_bytree=1.0, classifier__gamma=17.894736842105264, classifier__lambda=12.631578947368421, classifier__max_depth=429, classifier__min_child_weight=14.736842105263158, classifier__subsample=0.9444444444444444; precision: (train=0.148, test=0.025) total time=   0.4s
# [CV 1/4; 13/100] START classifier__alpha=10.526315789473683, classifier__colsample_bytree=0.9444444444444444, classifier__gamma=11.578947368421051, classifier__lambda=8.421052631578947, classifier__max_depth=429, classifier__min_child_weight=6.315789473684211, classifier__subsample=0.8888888888888888
# [CV 1/4; 13/100] END classifier__alpha=10.526315789473683, classifier__colsample_bytree=0.9444444444444444, classifier__gamma=11.578947368421051, classifier__lambda=8.421052631578947, classifier__max_depth=429, classifier__min_child_weight=6.315789473684211, classifier__subsample=0.8888888888888888; precision: (train=0.197, test=0.060) total time=   0.4s
# [CV 2/4; 13/100] START classifier__alpha=10.526315789473683, classifier__colsample_bytree=0.9444444444444444, classifier__gamma=11.578947368421051, classifier__lambda=8.421052631578947, classifier__max_depth=429, classifier__min_child_weight=6.315789473684211, classifier__subsample=0.8888888888888888
# [CV 2/4; 13/100] END classifier__alpha=10.526315789473683, classifier__colsample_bytree=0.9444444444444444, classifier__gamma=11.578947368421051, classifier__lambda=8.421052631578947, classifier__max_depth=429, classifier__min_child_weight=6.315789473684211, classifier__subsample=0.8888888888888888; precision: (train=0.186, test=0.066) total time=   0.4s
# [CV 3/4; 13/100] START classifier__alpha=10.526315789473683, classifier__colsample_bytree=0.9444444444444444, classifier__gamma=11.578947368421051, classifier__lambda=8.421052631578947, classifier__max_depth=429, classifier__min_child_weight=6.315789473684211, classifier__subsample=0.8888888888888888
# [CV 3/4; 13/100] END classifier__alpha=10.526315789473683, classifier__colsample_bytree=0.9444444444444444, classifier__gamma=11.578947368421051, classifier__lambda=8.421052631578947, classifier__max_depth=429, classifier__min_child_weight=6.315789473684211, classifier__subsample=0.8888888888888888; precision: (train=0.201, test=0.100) total time=   0.4s
# [CV 4/4; 13/100] START classifier__alpha=10.526315789473683, classifier__colsample_bytree=0.9444444444444444, classifier__gamma=11.578947368421051, classifier__lambda=8.421052631578947, classifier__max_depth=429, classifier__min_child_weight=6.315789473684211, classifier__subsample=0.8888888888888888
# [CV 4/4; 13/100] END classifier__alpha=10.526315789473683, classifier__colsample_bytree=0.9444444444444444, classifier__gamma=11.578947368421051, classifier__lambda=8.421052631578947, classifier__max_depth=429, classifier__min_child_weight=6.315789473684211, classifier__subsample=0.8888888888888888; precision: (train=0.200, test=0.032) total time=   0.4s
# [CV 1/4; 14/100] START classifier__alpha=15.789473684210526, classifier__colsample_bytree=0.6666666666666666, classifier__gamma=8.421052631578947, classifier__lambda=0.0, classifier__max_depth=627, classifier__min_child_weight=9.473684210526315, classifier__subsample=0.7777777777777778
# [CV 1/4; 14/100] END classifier__alpha=15.789473684210526, classifier__colsample_bytree=0.6666666666666666, classifier__gamma=8.421052631578947, classifier__lambda=0.0, classifier__max_depth=627, classifier__min_child_weight=9.473684210526315, classifier__subsample=0.7777777777777778; precision: (train=0.192, test=0.061) total time=   0.4s
# [CV 2/4; 14/100] START classifier__alpha=15.789473684210526, classifier__colsample_bytree=0.6666666666666666, classifier__gamma=8.421052631578947, classifier__lambda=0.0, classifier__max_depth=627, classifier__min_child_weight=9.473684210526315, classifier__subsample=0.7777777777777778
# [CV 2/4; 14/100] END classifier__alpha=15.789473684210526, classifier__colsample_bytree=0.6666666666666666, classifier__gamma=8.421052631578947, classifier__lambda=0.0, classifier__max_depth=627, classifier__min_child_weight=9.473684210526315, classifier__subsample=0.7777777777777778; precision: (train=0.214, test=0.059) total time=   0.5s
# [CV 3/4; 14/100] START classifier__alpha=15.789473684210526, classifier__colsample_bytree=0.6666666666666666, classifier__gamma=8.421052631578947, classifier__lambda=0.0, classifier__max_depth=627, classifier__min_child_weight=9.473684210526315, classifier__subsample=0.7777777777777778
# [CV 3/4; 14/100] END classifier__alpha=15.789473684210526, classifier__colsample_bytree=0.6666666666666666, classifier__gamma=8.421052631578947, classifier__lambda=0.0, classifier__max_depth=627, classifier__min_child_weight=9.473684210526315, classifier__subsample=0.7777777777777778; precision: (train=0.188, test=0.087) total time=   0.4s
# [CV 4/4; 14/100] START classifier__alpha=15.789473684210526, classifier__colsample_bytree=0.6666666666666666, classifier__gamma=8.421052631578947, classifier__lambda=0.0, classifier__max_depth=627, classifier__min_child_weight=9.473684210526315, classifier__subsample=0.7777777777777778
# [CV 4/4; 14/100] END classifier__alpha=15.789473684210526, classifier__colsample_bytree=0.6666666666666666, classifier__gamma=8.421052631578947, classifier__lambda=0.0, classifier__max_depth=627, classifier__min_child_weight=9.473684210526315, classifier__subsample=0.7777777777777778; precision: (train=0.210, test=0.045) total time=   0.4s
# [CV 1/4; 15/100] START classifier__alpha=16.842105263157894, classifier__colsample_bytree=0.6111111111111112, classifier__gamma=0.0, classifier__lambda=6.315789473684211, classifier__max_depth=78, classifier__min_child_weight=5.263157894736842, classifier__subsample=0.9444444444444444
# [CV 1/4; 15/100] END classifier__alpha=16.842105263157894, classifier__colsample_bytree=0.6111111111111112, classifier__gamma=0.0, classifier__lambda=6.315789473684211, classifier__max_depth=78, classifier__min_child_weight=5.263157894736842, classifier__subsample=0.9444444444444444; precision: (train=0.346, test=0.095) total time=   0.6s
# [CV 2/4; 15/100] START classifier__alpha=16.842105263157894, classifier__colsample_bytree=0.6111111111111112, classifier__gamma=0.0, classifier__lambda=6.315789473684211, classifier__max_depth=78, classifier__min_child_weight=5.263157894736842, classifier__subsample=0.9444444444444444
# [CV 2/4; 15/100] END classifier__alpha=16.842105263157894, classifier__colsample_bytree=0.6111111111111112, classifier__gamma=0.0, classifier__lambda=6.315789473684211, classifier__max_depth=78, classifier__min_child_weight=5.263157894736842, classifier__subsample=0.9444444444444444; precision: (train=0.350, test=0.088) total time=   0.7s
# [CV 3/4; 15/100] START classifier__alpha=16.842105263157894, classifier__colsample_bytree=0.6111111111111112, classifier__gamma=0.0, classifier__lambda=6.315789473684211, classifier__max_depth=78, classifier__min_child_weight=5.263157894736842, classifier__subsample=0.9444444444444444
# [CV 3/4; 15/100] END classifier__alpha=16.842105263157894, classifier__colsample_bytree=0.6111111111111112, classifier__gamma=0.0, classifier__lambda=6.315789473684211, classifier__max_depth=78, classifier__min_child_weight=5.263157894736842, classifier__subsample=0.9444444444444444; precision: (train=0.375, test=0.127) total time=   0.7s
# [CV 4/4; 15/100] START classifier__alpha=16.842105263157894, classifier__colsample_bytree=0.6111111111111112, classifier__gamma=0.0, classifier__lambda=6.315789473684211, classifier__max_depth=78, classifier__min_child_weight=5.263157894736842, classifier__subsample=0.9444444444444444
# [CV 4/4; 15/100] END classifier__alpha=16.842105263157894, classifier__colsample_bytree=0.6111111111111112, classifier__gamma=0.0, classifier__lambda=6.315789473684211, classifier__max_depth=78, classifier__min_child_weight=5.263157894736842, classifier__subsample=0.9444444444444444; precision: (train=0.376, test=0.054) total time=   0.7s
# [CV 1/4; 16/100] START classifier__alpha=2.1052631578947367, classifier__colsample_bytree=0.6111111111111112, classifier__gamma=2.1052631578947367, classifier__lambda=0.0, classifier__max_depth=734, classifier__min_child_weight=14.736842105263158, classifier__subsample=1.0
# [CV 1/4; 16/100] END classifier__alpha=2.1052631578947367, classifier__colsample_bytree=0.6111111111111112, classifier__gamma=2.1052631578947367, classifier__lambda=0.0, classifier__max_depth=734, classifier__min_child_weight=14.736842105263158, classifier__subsample=1.0; precision: (train=0.323, test=0.065) total time=   0.6s
# [CV 2/4; 16/100] START classifier__alpha=2.1052631578947367, classifier__colsample_bytree=0.6111111111111112, classifier__gamma=2.1052631578947367, classifier__lambda=0.0, classifier__max_depth=734, classifier__min_child_weight=14.736842105263158, classifier__subsample=1.0
# [CV 2/4; 16/100] END classifier__alpha=2.1052631578947367, classifier__colsample_bytree=0.6111111111111112, classifier__gamma=2.1052631578947367, classifier__lambda=0.0, classifier__max_depth=734, classifier__min_child_weight=14.736842105263158, classifier__subsample=1.0; precision: (train=0.358, test=0.036) total time=   0.5s
# [CV 3/4; 16/100] START classifier__alpha=2.1052631578947367, classifier__colsample_bytree=0.6111111111111112, classifier__gamma=2.1052631578947367, classifier__lambda=0.0, classifier__max_depth=734, classifier__min_child_weight=14.736842105263158, classifier__subsample=1.0
# [CV 3/4; 16/100] END classifier__alpha=2.1052631578947367, classifier__colsample_bytree=0.6111111111111112, classifier__gamma=2.1052631578947367, classifier__lambda=0.0, classifier__max_depth=734, classifier__min_child_weight=14.736842105263158, classifier__subsample=1.0; precision: (train=0.394, test=0.128) total time=   0.5s
# [CV 4/4; 16/100] START classifier__alpha=2.1052631578947367, classifier__colsample_bytree=0.6111111111111112, classifier__gamma=2.1052631578947367, classifier__lambda=0.0, classifier__max_depth=734, classifier__min_child_weight=14.736842105263158, classifier__subsample=1.0
# [CV 4/4; 16/100] END classifier__alpha=2.1052631578947367, classifier__colsample_bytree=0.6111111111111112, classifier__gamma=2.1052631578947367, classifier__lambda=0.0, classifier__max_depth=734, classifier__min_child_weight=14.736842105263158, classifier__subsample=1.0; precision: (train=0.294, test=0.031) total time=   0.4s
# [CV 1/4; 17/100] START classifier__alpha=6.315789473684211, classifier__colsample_bytree=0.5, classifier__gamma=11.578947368421051, classifier__lambda=8.421052631578947, classifier__max_depth=444, classifier__min_child_weight=7.368421052631579, classifier__subsample=0.8333333333333333
# [CV 1/4; 17/100] END classifier__alpha=6.315789473684211, classifier__colsample_bytree=0.5, classifier__gamma=11.578947368421051, classifier__lambda=8.421052631578947, classifier__max_depth=444, classifier__min_child_weight=7.368421052631579, classifier__subsample=0.8333333333333333; precision: (train=0.197, test=0.043) total time=   0.4s
# [CV 2/4; 17/100] START classifier__alpha=6.315789473684211, classifier__colsample_bytree=0.5, classifier__gamma=11.578947368421051, classifier__lambda=8.421052631578947, classifier__max_depth=444, classifier__min_child_weight=7.368421052631579, classifier__subsample=0.8333333333333333
# [CV 2/4; 17/100] END classifier__alpha=6.315789473684211, classifier__colsample_bytree=0.5, classifier__gamma=11.578947368421051, classifier__lambda=8.421052631578947, classifier__max_depth=444, classifier__min_child_weight=7.368421052631579, classifier__subsample=0.8333333333333333; precision: (train=0.203, test=0.064) total time=   0.4s
# [CV 3/4; 17/100] START classifier__alpha=6.315789473684211, classifier__colsample_bytree=0.5, classifier__gamma=11.578947368421051, classifier__lambda=8.421052631578947, classifier__max_depth=444, classifier__min_child_weight=7.368421052631579, classifier__subsample=0.8333333333333333
# [CV 3/4; 17/100] END classifier__alpha=6.315789473684211, classifier__colsample_bytree=0.5, classifier__gamma=11.578947368421051, classifier__lambda=8.421052631578947, classifier__max_depth=444, classifier__min_child_weight=7.368421052631579, classifier__subsample=0.8333333333333333; precision: (train=0.232, test=0.093) total time=   0.5s
# [CV 4/4; 17/100] START classifier__alpha=6.315789473684211, classifier__colsample_bytree=0.5, classifier__gamma=11.578947368421051, classifier__lambda=8.421052631578947, classifier__max_depth=444, classifier__min_child_weight=7.368421052631579, classifier__subsample=0.8333333333333333
# [CV 4/4; 17/100] END classifier__alpha=6.315789473684211, classifier__colsample_bytree=0.5, classifier__gamma=11.578947368421051, classifier__lambda=8.421052631578947, classifier__max_depth=444, classifier__min_child_weight=7.368421052631579, classifier__subsample=0.8333333333333333; precision: (train=0.205, test=0.042) total time=   0.5s
# [CV 1/4; 18/100] START classifier__alpha=8.421052631578947, classifier__colsample_bytree=0.9444444444444444, classifier__gamma=10.526315789473683, classifier__lambda=8.421052631578947, classifier__max_depth=643, classifier__min_child_weight=2.1052631578947367, classifier__subsample=0.8888888888888888
# [CV 1/4; 18/100] END classifier__alpha=8.421052631578947, classifier__colsample_bytree=0.9444444444444444, classifier__gamma=10.526315789473683, classifier__lambda=8.421052631578947, classifier__max_depth=643, classifier__min_child_weight=2.1052631578947367, classifier__subsample=0.8888888888888888; precision: (train=0.211, test=0.065) total time=   0.4s
# [CV 2/4; 18/100] START classifier__alpha=8.421052631578947, classifier__colsample_bytree=0.9444444444444444, classifier__gamma=10.526315789473683, classifier__lambda=8.421052631578947, classifier__max_depth=643, classifier__min_child_weight=2.1052631578947367, classifier__subsample=0.8888888888888888
# [CV 2/4; 18/100] END classifier__alpha=8.421052631578947, classifier__colsample_bytree=0.9444444444444444, classifier__gamma=10.526315789473683, classifier__lambda=8.421052631578947, classifier__max_depth=643, classifier__min_child_weight=2.1052631578947367, classifier__subsample=0.8888888888888888; precision: (train=0.224, test=0.045) total time=   0.5s
# [CV 3/4; 18/100] START classifier__alpha=8.421052631578947, classifier__colsample_bytree=0.9444444444444444, classifier__gamma=10.526315789473683, classifier__lambda=8.421052631578947, classifier__max_depth=643, classifier__min_child_weight=2.1052631578947367, classifier__subsample=0.8888888888888888
# [CV 3/4; 18/100] END classifier__alpha=8.421052631578947, classifier__colsample_bytree=0.9444444444444444, classifier__gamma=10.526315789473683, classifier__lambda=8.421052631578947, classifier__max_depth=643, classifier__min_child_weight=2.1052631578947367, classifier__subsample=0.8888888888888888; precision: (train=0.241, test=0.095) total time=   0.4s
# [CV 4/4; 18/100] START classifier__alpha=8.421052631578947, classifier__colsample_bytree=0.9444444444444444, classifier__gamma=10.526315789473683, classifier__lambda=8.421052631578947, classifier__max_depth=643, classifier__min_child_weight=2.1052631578947367, classifier__subsample=0.8888888888888888
# [CV 4/4; 18/100] END classifier__alpha=8.421052631578947, classifier__colsample_bytree=0.9444444444444444, classifier__gamma=10.526315789473683, classifier__lambda=8.421052631578947, classifier__max_depth=643, classifier__min_child_weight=2.1052631578947367, classifier__subsample=0.8888888888888888; precision: (train=0.208, test=0.043) total time=   0.4s
# [CV 1/4; 19/100] START classifier__alpha=0.0, classifier__colsample_bytree=0.5, classifier__gamma=16.842105263157894, classifier__lambda=14.736842105263158, classifier__max_depth=353, classifier__min_child_weight=16.842105263157894, classifier__subsample=1.0
# [CV 1/4; 19/100] END classifier__alpha=0.0, classifier__colsample_bytree=0.5, classifier__gamma=16.842105263157894, classifier__lambda=14.736842105263158, classifier__max_depth=353, classifier__min_child_weight=16.842105263157894, classifier__subsample=1.0; precision: (train=0.121, test=0.038) total time=   0.4s
# [CV 2/4; 19/100] START classifier__alpha=0.0, classifier__colsample_bytree=0.5, classifier__gamma=16.842105263157894, classifier__lambda=14.736842105263158, classifier__max_depth=353, classifier__min_child_weight=16.842105263157894, classifier__subsample=1.0
# [CV 2/4; 19/100] END classifier__alpha=0.0, classifier__colsample_bytree=0.5, classifier__gamma=16.842105263157894, classifier__lambda=14.736842105263158, classifier__max_depth=353, classifier__min_child_weight=16.842105263157894, classifier__subsample=1.0; precision: (train=0.125, test=0.040) total time=   0.6s
# [CV 3/4; 19/100] START classifier__alpha=0.0, classifier__colsample_bytree=0.5, classifier__gamma=16.842105263157894, classifier__lambda=14.736842105263158, classifier__max_depth=353, classifier__min_child_weight=16.842105263157894, classifier__subsample=1.0
# [CV 3/4; 19/100] END classifier__alpha=0.0, classifier__colsample_bytree=0.5, classifier__gamma=16.842105263157894, classifier__lambda=14.736842105263158, classifier__max_depth=353, classifier__min_child_weight=16.842105263157894, classifier__subsample=1.0; precision: (train=0.153, test=0.079) total time=   0.6s
# [CV 4/4; 19/100] START classifier__alpha=0.0, classifier__colsample_bytree=0.5, classifier__gamma=16.842105263157894, classifier__lambda=14.736842105263158, classifier__max_depth=353, classifier__min_child_weight=16.842105263157894, classifier__subsample=1.0
# [CV 4/4; 19/100] END classifier__alpha=0.0, classifier__colsample_bytree=0.5, classifier__gamma=16.842105263157894, classifier__lambda=14.736842105263158, classifier__max_depth=353, classifier__min_child_weight=16.842105263157894, classifier__subsample=1.0; precision: (train=0.126, test=0.036) total time=   0.5s
# ...
# [CV 1/4; 95/100] START classifier__alpha=11.578947368421051, classifier__colsample_bytree=0.7222222222222222, classifier__gamma=12.631578947368421, classifier__lambda=10.526315789473683, classifier__max_depth=154, classifier__min_child_weight=4.2105263157894735, classifier__subsample=0.5555555555555556
# [CV 1/4; 95/100] END classifier__alpha=11.578947368421051, classifier__colsample_bytree=0.7222222222222222, classifier__gamma=12.631578947368421, classifier__lambda=10.526315789473683, classifier__max_depth=154, classifier__min_child_weight=4.2105263157894735, classifier__subsample=0.5555555555555556; precision: (train=0.194, test=0.060) total time=   1.3s
# [CV 2/4; 95/100] START classifier__alpha=11.578947368421051, classifier__colsample_bytree=0.7222222222222222, classifier__gamma=12.631578947368421, classifier__lambda=10.526315789473683, classifier__max_depth=154, classifier__min_child_weight=4.2105263157894735, classifier__subsample=0.5555555555555556
# [CV 2/4; 95/100] END classifier__alpha=11.578947368421051, classifier__colsample_bytree=0.7222222222222222, classifier__gamma=12.631578947368421, classifier__lambda=10.526315789473683, classifier__max_depth=154, classifier__min_child_weight=4.2105263157894735, classifier__subsample=0.5555555555555556; precision: (train=0.201, test=0.051) total time=   1.1s
# [CV 3/4; 95/100] START classifier__alpha=11.578947368421051, classifier__colsample_bytree=0.7222222222222222, classifier__gamma=12.631578947368421, classifier__lambda=10.526315789473683, classifier__max_depth=154, classifier__min_child_weight=4.2105263157894735, classifier__subsample=0.5555555555555556
# [CV 3/4; 95/100] END classifier__alpha=11.578947368421051, classifier__colsample_bytree=0.7222222222222222, classifier__gamma=12.631578947368421, classifier__lambda=10.526315789473683, classifier__max_depth=154, classifier__min_child_weight=4.2105263157894735, classifier__subsample=0.5555555555555556; precision: (train=0.216, test=0.071) total time=   0.7s
# [CV 4/4; 95/100] START classifier__alpha=11.578947368421051, classifier__colsample_bytree=0.7222222222222222, classifier__gamma=12.631578947368421, classifier__lambda=10.526315789473683, classifier__max_depth=154, classifier__min_child_weight=4.2105263157894735, classifier__subsample=0.5555555555555556
# [CV 4/4; 95/100] END classifier__alpha=11.578947368421051, classifier__colsample_bytree=0.7222222222222222, classifier__gamma=12.631578947368421, classifier__lambda=10.526315789473683, classifier__max_depth=154, classifier__min_child_weight=4.2105263157894735, classifier__subsample=0.5555555555555556; precision: (train=0.205, test=0.053) total time=   0.8s
# [CV 1/4; 96/100] START classifier__alpha=3.1578947368421053, classifier__colsample_bytree=0.6666666666666666, classifier__gamma=4.2105263157894735, classifier__lambda=6.315789473684211, classifier__max_depth=200, classifier__min_child_weight=11.578947368421051, classifier__subsample=0.7777777777777778
# [CV 1/4; 96/100] END classifier__alpha=3.1578947368421053, classifier__colsample_bytree=0.6666666666666666, classifier__gamma=4.2105263157894735, classifier__lambda=6.315789473684211, classifier__max_depth=200, classifier__min_child_weight=11.578947368421051, classifier__subsample=0.7777777777777778; precision: (train=0.376, test=0.096) total time=   0.9s
# [CV 2/4; 96/100] START classifier__alpha=3.1578947368421053, classifier__colsample_bytree=0.6666666666666666, classifier__gamma=4.2105263157894735, classifier__lambda=6.315789473684211, classifier__max_depth=200, classifier__min_child_weight=11.578947368421051, classifier__subsample=0.7777777777777778
# [CV 2/4; 96/100] END classifier__alpha=3.1578947368421053, classifier__colsample_bytree=0.6666666666666666, classifier__gamma=4.2105263157894735, classifier__lambda=6.315789473684211, classifier__max_depth=200, classifier__min_child_weight=11.578947368421051, classifier__subsample=0.7777777777777778; precision: (train=0.358, test=0.077) total time=   2.4s
# [CV 3/4; 96/100] START classifier__alpha=3.1578947368421053, classifier__colsample_bytree=0.6666666666666666, classifier__gamma=4.2105263157894735, classifier__lambda=6.315789473684211, classifier__max_depth=200, classifier__min_child_weight=11.578947368421051, classifier__subsample=0.7777777777777778
# [CV 3/4; 96/100] END classifier__alpha=3.1578947368421053, classifier__colsample_bytree=0.6666666666666666, classifier__gamma=4.2105263157894735, classifier__lambda=6.315789473684211, classifier__max_depth=200, classifier__min_child_weight=11.578947368421051, classifier__subsample=0.7777777777777778; precision: (train=0.395, test=0.150) total time=   1.5s
# [CV 4/4; 96/100] START classifier__alpha=3.1578947368421053, classifier__colsample_bytree=0.6666666666666666, classifier__gamma=4.2105263157894735, classifier__lambda=6.315789473684211, classifier__max_depth=200, classifier__min_child_weight=11.578947368421051, classifier__subsample=0.7777777777777778
# [CV 4/4; 96/100] END classifier__alpha=3.1578947368421053, classifier__colsample_bytree=0.6666666666666666, classifier__gamma=4.2105263157894735, classifier__lambda=6.315789473684211, classifier__max_depth=200, classifier__min_child_weight=11.578947368421051, classifier__subsample=0.7777777777777778; precision: (train=0.421, test=0.023) total time=   1.5s
# [CV 1/4; 97/100] START classifier__alpha=11.578947368421051, classifier__colsample_bytree=0.7222222222222222, classifier__gamma=18.94736842105263, classifier__lambda=10.526315789473683, classifier__max_depth=658, classifier__min_child_weight=0.0, classifier__subsample=0.6666666666666666
# [CV 1/4; 97/100] END classifier__alpha=11.578947368421051, classifier__colsample_bytree=0.7222222222222222, classifier__gamma=18.94736842105263, classifier__lambda=10.526315789473683, classifier__max_depth=658, classifier__min_child_weight=0.0, classifier__subsample=0.6666666666666666; precision: (train=0.181, test=0.048) total time=   0.7s
# [CV 2/4; 97/100] START classifier__alpha=11.578947368421051, classifier__colsample_bytree=0.7222222222222222, classifier__gamma=18.94736842105263, classifier__lambda=10.526315789473683, classifier__max_depth=658, classifier__min_child_weight=0.0, classifier__subsample=0.6666666666666666
# [CV 2/4; 97/100] END classifier__alpha=11.578947368421051, classifier__colsample_bytree=0.7222222222222222, classifier__gamma=18.94736842105263, classifier__lambda=10.526315789473683, classifier__max_depth=658, classifier__min_child_weight=0.0, classifier__subsample=0.6666666666666666; precision: (train=0.161, test=0.040) total time=   0.6s
# [CV 3/4; 97/100] START classifier__alpha=11.578947368421051, classifier__colsample_bytree=0.7222222222222222, classifier__gamma=18.94736842105263, classifier__lambda=10.526315789473683, classifier__max_depth=658, classifier__min_child_weight=0.0, classifier__subsample=0.6666666666666666
# [CV 3/4; 97/100] END classifier__alpha=11.578947368421051, classifier__colsample_bytree=0.7222222222222222, classifier__gamma=18.94736842105263, classifier__lambda=10.526315789473683, classifier__max_depth=658, classifier__min_child_weight=0.0, classifier__subsample=0.6666666666666666; precision: (train=0.174, test=0.068) total time=   0.4s
# [CV 4/4; 97/100] START classifier__alpha=11.578947368421051, classifier__colsample_bytree=0.7222222222222222, classifier__gamma=18.94736842105263, classifier__lambda=10.526315789473683, classifier__max_depth=658, classifier__min_child_weight=0.0, classifier__subsample=0.6666666666666666
# [CV 4/4; 97/100] END classifier__alpha=11.578947368421051, classifier__colsample_bytree=0.7222222222222222, classifier__gamma=18.94736842105263, classifier__lambda=10.526315789473683, classifier__max_depth=658, classifier__min_child_weight=0.0, classifier__subsample=0.6666666666666666; precision: (train=0.181, test=0.025) total time=   0.4s
# [CV 1/4; 98/100] START classifier__alpha=4.2105263157894735, classifier__colsample_bytree=0.7777777777777778, classifier__gamma=16.842105263157894, classifier__lambda=17.894736842105264, classifier__max_depth=627, classifier__min_child_weight=9.473684210526315, classifier__subsample=1.0
# [CV 1/4; 98/100] END classifier__alpha=4.2105263157894735, classifier__colsample_bytree=0.7777777777777778, classifier__gamma=16.842105263157894, classifier__lambda=17.894736842105264, classifier__max_depth=627, classifier__min_child_weight=9.473684210526315, classifier__subsample=1.0; precision: (train=0.139, test=0.044) total time=   0.4s
# [CV 2/4; 98/100] START classifier__alpha=4.2105263157894735, classifier__colsample_bytree=0.7777777777777778, classifier__gamma=16.842105263157894, classifier__lambda=17.894736842105264, classifier__max_depth=627, classifier__min_child_weight=9.473684210526315, classifier__subsample=1.0
# [CV 2/4; 98/100] END classifier__alpha=4.2105263157894735, classifier__colsample_bytree=0.7777777777777778, classifier__gamma=16.842105263157894, classifier__lambda=17.894736842105264, classifier__max_depth=627, classifier__min_child_weight=9.473684210526315, classifier__subsample=1.0; precision: (train=0.133, test=0.044) total time=   0.4s
# [CV 3/4; 98/100] START classifier__alpha=4.2105263157894735, classifier__colsample_bytree=0.7777777777777778, classifier__gamma=16.842105263157894, classifier__lambda=17.894736842105264, classifier__max_depth=627, classifier__min_child_weight=9.473684210526315, classifier__subsample=1.0
# [CV 3/4; 98/100] END classifier__alpha=4.2105263157894735, classifier__colsample_bytree=0.7777777777777778, classifier__gamma=16.842105263157894, classifier__lambda=17.894736842105264, classifier__max_depth=627, classifier__min_child_weight=9.473684210526315, classifier__subsample=1.0; precision: (train=0.136, test=0.061) total time=   0.4s
# [CV 4/4; 98/100] START classifier__alpha=4.2105263157894735, classifier__colsample_bytree=0.7777777777777778, classifier__gamma=16.842105263157894, classifier__lambda=17.894736842105264, classifier__max_depth=627, classifier__min_child_weight=9.473684210526315, classifier__subsample=1.0
# [CV 4/4; 98/100] END classifier__alpha=4.2105263157894735, classifier__colsample_bytree=0.7777777777777778, classifier__gamma=16.842105263157894, classifier__lambda=17.894736842105264, classifier__max_depth=627, classifier__min_child_weight=9.473684210526315, classifier__subsample=1.0; precision: (train=0.118, test=0.036) total time=   0.4s
# [CV 1/4; 99/100] START classifier__alpha=2.1052631578947367, classifier__colsample_bytree=0.8888888888888888, classifier__gamma=18.94736842105263, classifier__lambda=6.315789473684211, classifier__max_depth=429, classifier__min_child_weight=4.2105263157894735, classifier__subsample=0.7222222222222222
# [CV 1/4; 99/100] END classifier__alpha=2.1052631578947367, classifier__colsample_bytree=0.8888888888888888, classifier__gamma=18.94736842105263, classifier__lambda=6.315789473684211, classifier__max_depth=429, classifier__min_child_weight=4.2105263157894735, classifier__subsample=0.7222222222222222; precision: (train=0.227, test=0.057) total time=   0.4s
# [CV 2/4; 99/100] START classifier__alpha=2.1052631578947367, classifier__colsample_bytree=0.8888888888888888, classifier__gamma=18.94736842105263, classifier__lambda=6.315789473684211, classifier__max_depth=429, classifier__min_child_weight=4.2105263157894735, classifier__subsample=0.7222222222222222
# [CV 2/4; 99/100] END classifier__alpha=2.1052631578947367, classifier__colsample_bytree=0.8888888888888888, classifier__gamma=18.94736842105263, classifier__lambda=6.315789473684211, classifier__max_depth=429, classifier__min_child_weight=4.2105263157894735, classifier__subsample=0.7222222222222222; precision: (train=0.229, test=0.068) total time=   0.4s
# [CV 3/4; 99/100] START classifier__alpha=2.1052631578947367, classifier__colsample_bytree=0.8888888888888888, classifier__gamma=18.94736842105263, classifier__lambda=6.315789473684211, classifier__max_depth=429, classifier__min_child_weight=4.2105263157894735, classifier__subsample=0.7222222222222222
# [CV 3/4; 99/100] END classifier__alpha=2.1052631578947367, classifier__colsample_bytree=0.8888888888888888, classifier__gamma=18.94736842105263, classifier__lambda=6.315789473684211, classifier__max_depth=429, classifier__min_child_weight=4.2105263157894735, classifier__subsample=0.7222222222222222; precision: (train=0.267, test=0.065) total time=   0.4s
# [CV 4/4; 99/100] START classifier__alpha=2.1052631578947367, classifier__colsample_bytree=0.8888888888888888, classifier__gamma=18.94736842105263, classifier__lambda=6.315789473684211, classifier__max_depth=429, classifier__min_child_weight=4.2105263157894735, classifier__subsample=0.7222222222222222
# [CV 4/4; 99/100] END classifier__alpha=2.1052631578947367, classifier__colsample_bytree=0.8888888888888888, classifier__gamma=18.94736842105263, classifier__lambda=6.315789473684211, classifier__max_depth=429, classifier__min_child_weight=4.2105263157894735, classifier__subsample=0.7222222222222222; precision: (train=0.242, test=0.037) total time=   0.4s
# [CV 1/4; 100/100] START classifier__alpha=15.789473684210526, classifier__colsample_bytree=0.5555555555555556, classifier__gamma=6.315789473684211, classifier__lambda=6.315789473684211, classifier__max_depth=368, classifier__min_child_weight=13.68421052631579, classifier__subsample=0.8333333333333333
# [CV 1/4; 100/100] END classifier__alpha=15.789473684210526, classifier__colsample_bytree=0.5555555555555556, classifier__gamma=6.315789473684211, classifier__lambda=6.315789473684211, classifier__max_depth=368, classifier__min_child_weight=13.68421052631579, classifier__subsample=0.8333333333333333; precision: (train=0.199, test=0.081) total time=   0.4s
# [CV 2/4; 100/100] START classifier__alpha=15.789473684210526, classifier__colsample_bytree=0.5555555555555556, classifier__gamma=6.315789473684211, classifier__lambda=6.315789473684211, classifier__max_depth=368, classifier__min_child_weight=13.68421052631579, classifier__subsample=0.8333333333333333
# [CV 2/4; 100/100] END classifier__alpha=15.789473684210526, classifier__colsample_bytree=0.5555555555555556, classifier__gamma=6.315789473684211, classifier__lambda=6.315789473684211, classifier__max_depth=368, classifier__min_child_weight=13.68421052631579, classifier__subsample=0.8333333333333333; precision: (train=0.182, test=0.050) total time=   0.4s
# [CV 3/4; 100/100] START classifier__alpha=15.789473684210526, classifier__colsample_bytree=0.5555555555555556, classifier__gamma=6.315789473684211, classifier__lambda=6.315789473684211, classifier__max_depth=368, classifier__min_child_weight=13.68421052631579, classifier__subsample=0.8333333333333333
# [CV 3/4; 100/100] END classifier__alpha=15.789473684210526, classifier__colsample_bytree=0.5555555555555556, classifier__gamma=6.315789473684211, classifier__lambda=6.315789473684211, classifier__max_depth=368, classifier__min_child_weight=13.68421052631579, classifier__subsample=0.8333333333333333; precision: (train=0.189, test=0.097) total time=   0.4s
# [CV 4/4; 100/100] START classifier__alpha=15.789473684210526, classifier__colsample_bytree=0.5555555555555556, classifier__gamma=6.315789473684211, classifier__lambda=6.315789473684211, classifier__max_depth=368, classifier__min_child_weight=13.68421052631579, classifier__subsample=0.8333333333333333
# [CV 4/4; 100/100] END classifier__alpha=15.789473684210526, classifier__colsample_bytree=0.5555555555555556, classifier__gamma=6.315789473684211, classifier__lambda=6.315789473684211, classifier__max_depth=368, classifier__min_child_weight=13.68421052631579, classifier__subsample=0.8333333333333333; precision: (train=0.209, test=0.037) total time=   0.4s
# 0.11239399059166501 {'classifier__subsample': 0.7222222222222222, 'classifier__min_child_weight': 1.0526315789473684, 'classifier__max_depth': 17, 'classifier__lambda': 15.789473684210526, 'classifier__gamma': 0.0, 'classifier__colsample_bytree': 0.5555555555555556, 'classifier__alpha': 13.68421052631579}
# 0.0

# %% [markdown]
# b. SMOTE

# %%
randsearch_params = {}
for param in list(random_search.best_params_.keys()):
    randsearch_params[param[12:]] = random_search.best_params_[param]

# %%
classifier = XGBClassifier(n_jobs=None, eval_metric='pre', eta=0.63, **randsearch_params)
pipeline = Pipeline([
        ('custom_preprocessor', CustomPreprocessor(one_hot_encoded_cols)),
        ('over', SMOTE(sampling_strategy='not majority')),        
        ('classifier', classifier)
    ])
pipeline.fit(X_train, y_train)
y_pred = pipeline.predict(X_test)
cm = confusion_matrix(y_test, y_pred)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=pipeline.classes_)
disp.plot()
print(precision_score(y_test, y_pred))
# Out:
# 0.0

# %%
param_distributions = {
        #"classifier__eta": [i for i in np.linspace(0, 1, 20)]
        "classifier__gamma": [i for i in np.linspace(0, 20, 20)]
        ,"classifier__max_depth": [np.int64(i) for i in np.linspace(2, 750, 50)]
        ,"classifier__lambda": [i for i in np.linspace(0, 20, 20)]
        ,"classifier__alpha": [i for i in np.linspace(0, 20, 20)]
        ,"classifier__min_child_weight": [i for i in np.linspace(0, 20, 20)]
        ,"classifier__colsample_bytree": [i for i in np.linspace(0.5, 1, 10)]
        ,"classifier__subsample": [i for i in np.linspace(0.5, 1, 10)]
    }
classifier = XGBClassifier(n_jobs=None, eval_metric='pre', eta=0.89)
pipeline = Pipeline([
        ('custom_preprocessor', CustomPreprocessor(one_hot_encoded_cols)),
        ('over', SMOTE(sampling_strategy='not majority')),
        ('classifier', classifier)
    ])
random_search = run_experiment(features, param_distributions, pipeline, 
                               n_iter=100, n_splits=4, 
                               classifier=classifier, one_hot_encoded_cols=one_hot_encoded_cols)
# Out:
# Fitting 4 folds for each of 100 candidates, totalling 400 fits
# [CV 1/4; 1/100] START classifier__alpha=13.68421052631579, classifier__colsample_bytree=0.6666666666666666, classifier__gamma=14.736842105263158, classifier__lambda=9.473684210526315, classifier__max_depth=429, classifier__min_child_weight=11.578947368421051, classifier__subsample=0.9444444444444444
# [CV 1/4; 1/100] END classifier__alpha=13.68421052631579, classifier__colsample_bytree=0.6666666666666666, classifier__gamma=14.736842105263158, classifier__lambda=9.473684210526315, classifier__max_depth=429, classifier__min_child_weight=11.578947368421051, classifier__subsample=0.9444444444444444; precision: (train=0.197, test=0.067) total time=   0.5s
# [CV 2/4; 1/100] START classifier__alpha=13.68421052631579, classifier__colsample_bytree=0.6666666666666666, classifier__gamma=14.736842105263158, classifier__lambda=9.473684210526315, classifier__max_depth=429, classifier__min_child_weight=11.578947368421051, classifier__subsample=0.9444444444444444
# [CV 2/4; 1/100] END classifier__alpha=13.68421052631579, classifier__colsample_bytree=0.6666666666666666, classifier__gamma=14.736842105263158, classifier__lambda=9.473684210526315, classifier__max_depth=429, classifier__min_child_weight=11.578947368421051, classifier__subsample=0.9444444444444444; precision: (train=0.148, test=0.041) total time=   0.5s
# [CV 3/4; 1/100] START classifier__alpha=13.68421052631579, classifier__colsample_bytree=0.6666666666666666, classifier__gamma=14.736842105263158, classifier__lambda=9.473684210526315, classifier__max_depth=429, classifier__min_child_weight=11.578947368421051, classifier__subsample=0.9444444444444444
# [CV 3/4; 1/100] END classifier__alpha=13.68421052631579, classifier__colsample_bytree=0.6666666666666666, classifier__gamma=14.736842105263158, classifier__lambda=9.473684210526315, classifier__max_depth=429, classifier__min_child_weight=11.578947368421051, classifier__subsample=0.9444444444444444; precision: (train=0.169, test=0.111) total time=   0.6s
# [CV 4/4; 1/100] START classifier__alpha=13.68421052631579, classifier__colsample_bytree=0.6666666666666666, classifier__gamma=14.736842105263158, classifier__lambda=9.473684210526315, classifier__max_depth=429, classifier__min_child_weight=11.578947368421051, classifier__subsample=0.9444444444444444
# [CV 4/4; 1/100] END classifier__alpha=13.68421052631579, classifier__colsample_bytree=0.6666666666666666, classifier__gamma=14.736842105263158, classifier__lambda=9.473684210526315, classifier__max_depth=429, classifier__min_child_weight=11.578947368421051, classifier__subsample=0.9444444444444444; precision: (train=0.152, test=0.013) total time=   0.4s
# [CV 1/4; 2/100] START classifier__alpha=4.2105263157894735, classifier__colsample_bytree=1.0, classifier__gamma=20.0, classifier__lambda=10.526315789473683, classifier__max_depth=32, classifier__min_child_weight=20.0, classifier__subsample=0.7777777777777778
# [CV 1/4; 2/100] END classifier__alpha=4.2105263157894735, classifier__colsample_bytree=1.0, classifier__gamma=20.0, classifier__lambda=10.526315789473683, classifier__max_depth=32, classifier__min_child_weight=20.0, classifier__subsample=0.7777777777777778; precision: (train=0.153, test=0.054) total time=   0.4s
# [CV 2/4; 2/100] START classifier__alpha=4.2105263157894735, classifier__colsample_bytree=1.0, classifier__gamma=20.0, classifier__lambda=10.526315789473683, classifier__max_depth=32, classifier__min_child_weight=20.0, classifier__subsample=0.7777777777777778
# [CV 2/4; 2/100] END classifier__alpha=4.2105263157894735, classifier__colsample_bytree=1.0, classifier__gamma=20.0, classifier__lambda=10.526315789473683, classifier__max_depth=32, classifier__min_child_weight=20.0, classifier__subsample=0.7777777777777778; precision: (train=0.148, test=0.045) total time=   0.5s
# [CV 3/4; 2/100] START classifier__alpha=4.2105263157894735, classifier__colsample_bytree=1.0, classifier__gamma=20.0, classifier__lambda=10.526315789473683, classifier__max_depth=32, classifier__min_child_weight=20.0, classifier__subsample=0.7777777777777778
# [CV 3/4; 2/100] END classifier__alpha=4.2105263157894735, classifier__colsample_bytree=1.0, classifier__gamma=20.0, classifier__lambda=10.526315789473683, classifier__max_depth=32, classifier__min_child_weight=20.0, classifier__subsample=0.7777777777777778; precision: (train=0.181, test=0.097) total time=   0.6s
# [CV 4/4; 2/100] START classifier__alpha=4.2105263157894735, classifier__colsample_bytree=1.0, classifier__gamma=20.0, classifier__lambda=10.526315789473683, classifier__max_depth=32, classifier__min_child_weight=20.0, classifier__subsample=0.7777777777777778
# [CV 4/4; 2/100] END classifier__alpha=4.2105263157894735, classifier__colsample_bytree=1.0, classifier__gamma=20.0, classifier__lambda=10.526315789473683, classifier__max_depth=32, classifier__min_child_weight=20.0, classifier__subsample=0.7777777777777778; precision: (train=0.142, test=0.076) total time=   0.4s
# [CV 1/4; 3/100] START classifier__alpha=20.0, classifier__colsample_bytree=0.8333333333333333, classifier__gamma=20.0, classifier__lambda=4.2105263157894735, classifier__max_depth=490, classifier__min_child_weight=1.0526315789473684, classifier__subsample=0.7222222222222222
# [CV 1/4; 3/100] END classifier__alpha=20.0, classifier__colsample_bytree=0.8333333333333333, classifier__gamma=20.0, classifier__lambda=4.2105263157894735, classifier__max_depth=490, classifier__min_child_weight=1.0526315789473684, classifier__subsample=0.7222222222222222; precision: (train=0.113, test=0.058) total time=   0.4s
# [CV 2/4; 3/100] START classifier__alpha=20.0, classifier__colsample_bytree=0.8333333333333333, classifier__gamma=20.0, classifier__lambda=4.2105263157894735, classifier__max_depth=490, classifier__min_child_weight=1.0526315789473684, classifier__subsample=0.7222222222222222
# [CV 2/4; 3/100] END classifier__alpha=20.0, classifier__colsample_bytree=0.8333333333333333, classifier__gamma=20.0, classifier__lambda=4.2105263157894735, classifier__max_depth=490, classifier__min_child_weight=1.0526315789473684, classifier__subsample=0.7222222222222222; precision: (train=0.107, test=0.050) total time=   0.4s
# [CV 3/4; 3/100] START classifier__alpha=20.0, classifier__colsample_bytree=0.8333333333333333, classifier__gamma=20.0, classifier__lambda=4.2105263157894735, classifier__max_depth=490, classifier__min_child_weight=1.0526315789473684, classifier__subsample=0.7222222222222222
# [CV 3/4; 3/100] END classifier__alpha=20.0, classifier__colsample_bytree=0.8333333333333333, classifier__gamma=20.0, classifier__lambda=4.2105263157894735, classifier__max_depth=490, classifier__min_child_weight=1.0526315789473684, classifier__subsample=0.7222222222222222; precision: (train=0.121, test=0.080) total time=   0.5s
# [CV 4/4; 3/100] START classifier__alpha=20.0, classifier__colsample_bytree=0.8333333333333333, classifier__gamma=20.0, classifier__lambda=4.2105263157894735, classifier__max_depth=490, classifier__min_child_weight=1.0526315789473684, classifier__subsample=0.7222222222222222
# [CV 4/4; 3/100] END classifier__alpha=20.0, classifier__colsample_bytree=0.8333333333333333, classifier__gamma=20.0, classifier__lambda=4.2105263157894735, classifier__max_depth=490, classifier__min_child_weight=1.0526315789473684, classifier__subsample=0.7222222222222222; precision: (train=0.115, test=0.090) total time=   0.4s
# [CV 1/4; 4/100] START classifier__alpha=3.1578947368421053, classifier__colsample_bytree=0.5555555555555556, classifier__gamma=17.894736842105264, classifier__lambda=12.631578947368421, classifier__max_depth=139, classifier__min_child_weight=6.315789473684211, classifier__subsample=0.6666666666666666
# [CV 1/4; 4/100] END classifier__alpha=3.1578947368421053, classifier__colsample_bytree=0.5555555555555556, classifier__gamma=17.894736842105264, classifier__lambda=12.631578947368421, classifier__max_depth=139, classifier__min_child_weight=6.315789473684211, classifier__subsample=0.6666666666666666; precision: (train=0.158, test=0.111) total time=   0.4s
# [CV 2/4; 4/100] START classifier__alpha=3.1578947368421053, classifier__colsample_bytree=0.5555555555555556, classifier__gamma=17.894736842105264, classifier__lambda=12.631578947368421, classifier__max_depth=139, classifier__min_child_weight=6.315789473684211, classifier__subsample=0.6666666666666666
# [CV 2/4; 4/100] END classifier__alpha=3.1578947368421053, classifier__colsample_bytree=0.5555555555555556, classifier__gamma=17.894736842105264, classifier__lambda=12.631578947368421, classifier__max_depth=139, classifier__min_child_weight=6.315789473684211, classifier__subsample=0.6666666666666666; precision: (train=0.133, test=0.044) total time=   0.5s
# [CV 3/4; 4/100] START classifier__alpha=3.1578947368421053, classifier__colsample_bytree=0.5555555555555556, classifier__gamma=17.894736842105264, classifier__lambda=12.631578947368421, classifier__max_depth=139, classifier__min_child_weight=6.315789473684211, classifier__subsample=0.6666666666666666
# [CV 3/4; 4/100] END classifier__alpha=3.1578947368421053, classifier__colsample_bytree=0.5555555555555556, classifier__gamma=17.894736842105264, classifier__lambda=12.631578947368421, classifier__max_depth=139, classifier__min_child_weight=6.315789473684211, classifier__subsample=0.6666666666666666; precision: (train=0.160, test=0.109) total time=   0.5s
# [CV 4/4; 4/100] START classifier__alpha=3.1578947368421053, classifier__colsample_bytree=0.5555555555555556, classifier__gamma=17.894736842105264, classifier__lambda=12.631578947368421, classifier__max_depth=139, classifier__min_child_weight=6.315789473684211, classifier__subsample=0.6666666666666666
# [CV 4/4; 4/100] END classifier__alpha=3.1578947368421053, classifier__colsample_bytree=0.5555555555555556, classifier__gamma=17.894736842105264, classifier__lambda=12.631578947368421, classifier__max_depth=139, classifier__min_child_weight=6.315789473684211, classifier__subsample=0.6666666666666666; precision: (train=0.137, test=0.048) total time=   0.4s
# [CV 1/4; 5/100] START classifier__alpha=10.526315789473683, classifier__colsample_bytree=0.7777777777777778, classifier__gamma=18.94736842105263, classifier__lambda=13.68421052631579, classifier__max_depth=368, classifier__min_child_weight=17.894736842105264, classifier__subsample=0.6111111111111112
# [CV 1/4; 5/100] END classifier__alpha=10.526315789473683, classifier__colsample_bytree=0.7777777777777778, classifier__gamma=18.94736842105263, classifier__lambda=13.68421052631579, classifier__max_depth=368, classifier__min_child_weight=17.894736842105264, classifier__subsample=0.6111111111111112; precision: (train=0.133, test=0.055) total time=   0.4s
# [CV 2/4; 5/100] START classifier__alpha=10.526315789473683, classifier__colsample_bytree=0.7777777777777778, classifier__gamma=18.94736842105263, classifier__lambda=13.68421052631579, classifier__max_depth=368, classifier__min_child_weight=17.894736842105264, classifier__subsample=0.6111111111111112
# [CV 2/4; 5/100] END classifier__alpha=10.526315789473683, classifier__colsample_bytree=0.7777777777777778, classifier__gamma=18.94736842105263, classifier__lambda=13.68421052631579, classifier__max_depth=368, classifier__min_child_weight=17.894736842105264, classifier__subsample=0.6111111111111112; precision: (train=0.103, test=0.057) total time=   0.5s
# [CV 3/4; 5/100] START classifier__alpha=10.526315789473683, classifier__colsample_bytree=0.7777777777777778, classifier__gamma=18.94736842105263, classifier__lambda=13.68421052631579, classifier__max_depth=368, classifier__min_child_weight=17.894736842105264, classifier__subsample=0.6111111111111112
# [CV 3/4; 5/100] END classifier__alpha=10.526315789473683, classifier__colsample_bytree=0.7777777777777778, classifier__gamma=18.94736842105263, classifier__lambda=13.68421052631579, classifier__max_depth=368, classifier__min_child_weight=17.894736842105264, classifier__subsample=0.6111111111111112; precision: (train=0.124, test=0.089) total time=   0.5s
# [CV 4/4; 5/100] START classifier__alpha=10.526315789473683, classifier__colsample_bytree=0.7777777777777778, classifier__gamma=18.94736842105263, classifier__lambda=13.68421052631579, classifier__max_depth=368, classifier__min_child_weight=17.894736842105264, classifier__subsample=0.6111111111111112
# [CV 4/4; 5/100] END classifier__alpha=10.526315789473683, classifier__colsample_bytree=0.7777777777777778, classifier__gamma=18.94736842105263, classifier__lambda=13.68421052631579, classifier__max_depth=368, classifier__min_child_weight=17.894736842105264, classifier__subsample=0.6111111111111112; precision: (train=0.113, test=0.050) total time=   0.4s
# [CV 1/4; 6/100] START classifier__alpha=10.526315789473683, classifier__colsample_bytree=0.6666666666666666, classifier__gamma=20.0, classifier__lambda=16.842105263157894, classifier__max_depth=627, classifier__min_child_weight=7.368421052631579, classifier__subsample=0.8333333333333333
# [CV 1/4; 6/100] END classifier__alpha=10.526315789473683, classifier__colsample_bytree=0.6666666666666666, classifier__gamma=20.0, classifier__lambda=16.842105263157894, classifier__max_depth=627, classifier__min_child_weight=7.368421052631579, classifier__subsample=0.8333333333333333; precision: (train=0.129, test=0.057) total time=   0.4s
# [CV 2/4; 6/100] START classifier__alpha=10.526315789473683, classifier__colsample_bytree=0.6666666666666666, classifier__gamma=20.0, classifier__lambda=16.842105263157894, classifier__max_depth=627, classifier__min_child_weight=7.368421052631579, classifier__subsample=0.8333333333333333
# [CV 2/4; 6/100] END classifier__alpha=10.526315789473683, classifier__colsample_bytree=0.6666666666666666, classifier__gamma=20.0, classifier__lambda=16.842105263157894, classifier__max_depth=627, classifier__min_child_weight=7.368421052631579, classifier__subsample=0.8333333333333333; precision: (train=0.120, test=0.029) total time=   0.4s
# [CV 3/4; 6/100] START classifier__alpha=10.526315789473683, classifier__colsample_bytree=0.6666666666666666, classifier__gamma=20.0, classifier__lambda=16.842105263157894, classifier__max_depth=627, classifier__min_child_weight=7.368421052631579, classifier__subsample=0.8333333333333333
# [CV 3/4; 6/100] END classifier__alpha=10.526315789473683, classifier__colsample_bytree=0.6666666666666666, classifier__gamma=20.0, classifier__lambda=16.842105263157894, classifier__max_depth=627, classifier__min_child_weight=7.368421052631579, classifier__subsample=0.8333333333333333; precision: (train=0.166, test=0.111) total time=   0.4s
# [CV 4/4; 6/100] START classifier__alpha=10.526315789473683, classifier__colsample_bytree=0.6666666666666666, classifier__gamma=20.0, classifier__lambda=16.842105263157894, classifier__max_depth=627, classifier__min_child_weight=7.368421052631579, classifier__subsample=0.8333333333333333
# [CV 4/4; 6/100] END classifier__alpha=10.526315789473683, classifier__colsample_bytree=0.6666666666666666, classifier__gamma=20.0, classifier__lambda=16.842105263157894, classifier__max_depth=627, classifier__min_child_weight=7.368421052631579, classifier__subsample=0.8333333333333333; precision: (train=0.111, test=0.046) total time=   0.4s
# [CV 1/4; 7/100] START classifier__alpha=16.842105263157894, classifier__colsample_bytree=0.8888888888888888, classifier__gamma=10.526315789473683, classifier__lambda=9.473684210526315, classifier__max_depth=368, classifier__min_child_weight=15.789473684210526, classifier__subsample=0.5
# [CV 1/4; 7/100] END classifier__alpha=16.842105263157894, classifier__colsample_bytree=0.8888888888888888, classifier__gamma=10.526315789473683, classifier__lambda=9.473684210526315, classifier__max_depth=368, classifier__min_child_weight=15.789473684210526, classifier__subsample=0.5; precision: (train=0.142, test=0.064) total time=   0.4s
# [CV 2/4; 7/100] START classifier__alpha=16.842105263157894, classifier__colsample_bytree=0.8888888888888888, classifier__gamma=10.526315789473683, classifier__lambda=9.473684210526315, classifier__max_depth=368, classifier__min_child_weight=15.789473684210526, classifier__subsample=0.5
# [CV 2/4; 7/100] END classifier__alpha=16.842105263157894, classifier__colsample_bytree=0.8888888888888888, classifier__gamma=10.526315789473683, classifier__lambda=9.473684210526315, classifier__max_depth=368, classifier__min_child_weight=15.789473684210526, classifier__subsample=0.5; precision: (train=0.128, test=0.061) total time=   0.4s
# [CV 3/4; 7/100] START classifier__alpha=16.842105263157894, classifier__colsample_bytree=0.8888888888888888, classifier__gamma=10.526315789473683, classifier__lambda=9.473684210526315, classifier__max_depth=368, classifier__min_child_weight=15.789473684210526, classifier__subsample=0.5
# [CV 3/4; 7/100] END classifier__alpha=16.842105263157894, classifier__colsample_bytree=0.8888888888888888, classifier__gamma=10.526315789473683, classifier__lambda=9.473684210526315, classifier__max_depth=368, classifier__min_child_weight=15.789473684210526, classifier__subsample=0.5; precision: (train=0.113, test=0.075) total time=   0.4s
# [CV 4/4; 7/100] START classifier__alpha=16.842105263157894, classifier__colsample_bytree=0.8888888888888888, classifier__gamma=10.526315789473683, classifier__lambda=9.473684210526315, classifier__max_depth=368, classifier__min_child_weight=15.789473684210526, classifier__subsample=0.5
# [CV 4/4; 7/100] END classifier__alpha=16.842105263157894, classifier__colsample_bytree=0.8888888888888888, classifier__gamma=10.526315789473683, classifier__lambda=9.473684210526315, classifier__max_depth=368, classifier__min_child_weight=15.789473684210526, classifier__subsample=0.5; precision: (train=0.132, test=0.064) total time=   0.4s
# [CV 1/4; 8/100] START classifier__alpha=16.842105263157894, classifier__colsample_bytree=0.8888888888888888, classifier__gamma=9.473684210526315, classifier__lambda=20.0, classifier__max_depth=93, classifier__min_child_weight=17.894736842105264, classifier__subsample=0.9444444444444444
# [CV 1/4; 8/100] END classifier__alpha=16.842105263157894, classifier__colsample_bytree=0.8888888888888888, classifier__gamma=9.473684210526315, classifier__lambda=20.0, classifier__max_depth=93, classifier__min_child_weight=17.894736842105264, classifier__subsample=0.9444444444444444; precision: (train=0.165, test=0.074) total time=   0.4s
# [CV 2/4; 8/100] START classifier__alpha=16.842105263157894, classifier__colsample_bytree=0.8888888888888888, classifier__gamma=9.473684210526315, classifier__lambda=20.0, classifier__max_depth=93, classifier__min_child_weight=17.894736842105264, classifier__subsample=0.9444444444444444
# [CV 2/4; 8/100] END classifier__alpha=16.842105263157894, classifier__colsample_bytree=0.8888888888888888, classifier__gamma=9.473684210526315, classifier__lambda=20.0, classifier__max_depth=93, classifier__min_child_weight=17.894736842105264, classifier__subsample=0.9444444444444444; precision: (train=0.139, test=0.064) total time=   0.4s
# [CV 3/4; 8/100] START classifier__alpha=16.842105263157894, classifier__colsample_bytree=0.8888888888888888, classifier__gamma=9.473684210526315, classifier__lambda=20.0, classifier__max_depth=93, classifier__min_child_weight=17.894736842105264, classifier__subsample=0.9444444444444444
# [CV 3/4; 8/100] END classifier__alpha=16.842105263157894, classifier__colsample_bytree=0.8888888888888888, classifier__gamma=9.473684210526315, classifier__lambda=20.0, classifier__max_depth=93, classifier__min_child_weight=17.894736842105264, classifier__subsample=0.9444444444444444; precision: (train=0.156, test=0.140) total time=   0.5s
# [CV 4/4; 8/100] START classifier__alpha=16.842105263157894, classifier__colsample_bytree=0.8888888888888888, classifier__gamma=9.473684210526315, classifier__lambda=20.0, classifier__max_depth=93, classifier__min_child_weight=17.894736842105264, classifier__subsample=0.9444444444444444
# [CV 4/4; 8/100] END classifier__alpha=16.842105263157894, classifier__colsample_bytree=0.8888888888888888, classifier__gamma=9.473684210526315, classifier__lambda=20.0, classifier__max_depth=93, classifier__min_child_weight=17.894736842105264, classifier__subsample=0.9444444444444444; precision: (train=0.147, test=0.057) total time=   0.5s
# [CV 1/4; 9/100] START classifier__alpha=10.526315789473683, classifier__colsample_bytree=0.8888888888888888, classifier__gamma=6.315789473684211, classifier__lambda=18.94736842105263, classifier__max_depth=688, classifier__min_child_weight=1.0526315789473684, classifier__subsample=0.7222222222222222
# [CV 1/4; 9/100] END classifier__alpha=10.526315789473683, classifier__colsample_bytree=0.8888888888888888, classifier__gamma=6.315789473684211, classifier__lambda=18.94736842105263, classifier__max_depth=688, classifier__min_child_weight=1.0526315789473684, classifier__subsample=0.7222222222222222; precision: (train=0.233, test=0.096) total time=   0.5s
# [CV 2/4; 9/100] START classifier__alpha=10.526315789473683, classifier__colsample_bytree=0.8888888888888888, classifier__gamma=6.315789473684211, classifier__lambda=18.94736842105263, classifier__max_depth=688, classifier__min_child_weight=1.0526315789473684, classifier__subsample=0.7222222222222222
# [CV 2/4; 9/100] END classifier__alpha=10.526315789473683, classifier__colsample_bytree=0.8888888888888888, classifier__gamma=6.315789473684211, classifier__lambda=18.94736842105263, classifier__max_depth=688, classifier__min_child_weight=1.0526315789473684, classifier__subsample=0.7222222222222222; precision: (train=0.170, test=0.051) total time=   0.5s
# [CV 3/4; 9/100] START classifier__alpha=10.526315789473683, classifier__colsample_bytree=0.8888888888888888, classifier__gamma=6.315789473684211, classifier__lambda=18.94736842105263, classifier__max_depth=688, classifier__min_child_weight=1.0526315789473684, classifier__subsample=0.7222222222222222
# [CV 3/4; 9/100] END classifier__alpha=10.526315789473683, classifier__colsample_bytree=0.8888888888888888, classifier__gamma=6.315789473684211, classifier__lambda=18.94736842105263, classifier__max_depth=688, classifier__min_child_weight=1.0526315789473684, classifier__subsample=0.7222222222222222; precision: (train=0.190, test=0.151) total time=   0.5s
# [CV 4/4; 9/100] START classifier__alpha=10.526315789473683, classifier__colsample_bytree=0.8888888888888888, classifier__gamma=6.315789473684211, classifier__lambda=18.94736842105263, classifier__max_depth=688, classifier__min_child_weight=1.0526315789473684, classifier__subsample=0.7222222222222222
# [CV 4/4; 9/100] END classifier__alpha=10.526315789473683, classifier__colsample_bytree=0.8888888888888888, classifier__gamma=6.315789473684211, classifier__lambda=18.94736842105263, classifier__max_depth=688, classifier__min_child_weight=1.0526315789473684, classifier__subsample=0.7222222222222222; precision: (train=0.168, test=0.074) total time=   0.5s
# [CV 1/4; 10/100] START classifier__alpha=6.315789473684211, classifier__colsample_bytree=0.6111111111111112, classifier__gamma=7.368421052631579, classifier__lambda=6.315789473684211, classifier__max_depth=551, classifier__min_child_weight=1.0526315789473684, classifier__subsample=0.5
# [CV 1/4; 10/100] END classifier__alpha=6.315789473684211, classifier__colsample_bytree=0.6111111111111112, classifier__gamma=7.368421052631579, classifier__lambda=6.315789473684211, classifier__max_depth=551, classifier__min_child_weight=1.0526315789473684, classifier__subsample=0.5; precision: (train=0.199, test=0.071) total time=   0.5s
# [CV 2/4; 10/100] START classifier__alpha=6.315789473684211, classifier__colsample_bytree=0.6111111111111112, classifier__gamma=7.368421052631579, classifier__lambda=6.315789473684211, classifier__max_depth=551, classifier__min_child_weight=1.0526315789473684, classifier__subsample=0.5
# [CV 2/4; 10/100] END classifier__alpha=6.315789473684211, classifier__colsample_bytree=0.6111111111111112, classifier__gamma=7.368421052631579, classifier__lambda=6.315789473684211, classifier__max_depth=551, classifier__min_child_weight=1.0526315789473684, classifier__subsample=0.5; precision: (train=0.150, test=0.061) total time=   0.5s
# [CV 3/4; 10/100] START classifier__alpha=6.315789473684211, classifier__colsample_bytree=0.6111111111111112, classifier__gamma=7.368421052631579, classifier__lambda=6.315789473684211, classifier__max_depth=551, classifier__min_child_weight=1.0526315789473684, classifier__subsample=0.5
# [CV 3/4; 10/100] END classifier__alpha=6.315789473684211, classifier__colsample_bytree=0.6111111111111112, classifier__gamma=7.368421052631579, classifier__lambda=6.315789473684211, classifier__max_depth=551, classifier__min_child_weight=1.0526315789473684, classifier__subsample=0.5; precision: (train=0.205, test=0.090) total time=   0.5s
# [CV 4/4; 10/100] START classifier__alpha=6.315789473684211, classifier__colsample_bytree=0.6111111111111112, classifier__gamma=7.368421052631579, classifier__lambda=6.315789473684211, classifier__max_depth=551, classifier__min_child_weight=1.0526315789473684, classifier__subsample=0.5
# [CV 4/4; 10/100] END classifier__alpha=6.315789473684211, classifier__colsample_bytree=0.6111111111111112, classifier__gamma=7.368421052631579, classifier__lambda=6.315789473684211, classifier__max_depth=551, classifier__min_child_weight=1.0526315789473684, classifier__subsample=0.5; precision: (train=0.169, test=0.061) total time=   0.5s
# [CV 1/4; 11/100] START classifier__alpha=12.631578947368421, classifier__colsample_bytree=0.7222222222222222, classifier__gamma=14.736842105263158, classifier__lambda=17.894736842105264, classifier__max_depth=200, classifier__min_child_weight=15.789473684210526, classifier__subsample=1.0
# [CV 1/4; 11/100] END classifier__alpha=12.631578947368421, classifier__colsample_bytree=0.7222222222222222, classifier__gamma=14.736842105263158, classifier__lambda=17.894736842105264, classifier__max_depth=200, classifier__min_child_weight=15.789473684210526, classifier__subsample=1.0; precision: (train=0.130, test=0.116) total time=   0.5s
# [CV 2/4; 11/100] START classifier__alpha=12.631578947368421, classifier__colsample_bytree=0.7222222222222222, classifier__gamma=14.736842105263158, classifier__lambda=17.894736842105264, classifier__max_depth=200, classifier__min_child_weight=15.789473684210526, classifier__subsample=1.0
# [CV 2/4; 11/100] END classifier__alpha=12.631578947368421, classifier__colsample_bytree=0.7222222222222222, classifier__gamma=14.736842105263158, classifier__lambda=17.894736842105264, classifier__max_depth=200, classifier__min_child_weight=15.789473684210526, classifier__subsample=1.0; precision: (train=0.139, test=0.034) total time=   0.5s
# [CV 3/4; 11/100] START classifier__alpha=12.631578947368421, classifier__colsample_bytree=0.7222222222222222, classifier__gamma=14.736842105263158, classifier__lambda=17.894736842105264, classifier__max_depth=200, classifier__min_child_weight=15.789473684210526, classifier__subsample=1.0
# [CV 3/4; 11/100] END classifier__alpha=12.631578947368421, classifier__colsample_bytree=0.7222222222222222, classifier__gamma=14.736842105263158, classifier__lambda=17.894736842105264, classifier__max_depth=200, classifier__min_child_weight=15.789473684210526, classifier__subsample=1.0; precision: (train=0.174, test=0.086) total time=   0.5s
# [CV 4/4; 11/100] START classifier__alpha=12.631578947368421, classifier__colsample_bytree=0.7222222222222222, classifier__gamma=14.736842105263158, classifier__lambda=17.894736842105264, classifier__max_depth=200, classifier__min_child_weight=15.789473684210526, classifier__subsample=1.0
# [CV 4/4; 11/100] END classifier__alpha=12.631578947368421, classifier__colsample_bytree=0.7222222222222222, classifier__gamma=14.736842105263158, classifier__lambda=17.894736842105264, classifier__max_depth=200, classifier__min_child_weight=15.789473684210526, classifier__subsample=1.0; precision: (train=0.124, test=0.014) total time=   0.4s
# [CV 1/4; 12/100] START classifier__alpha=8.421052631578947, classifier__colsample_bytree=1.0, classifier__gamma=17.894736842105264, classifier__lambda=12.631578947368421, classifier__max_depth=429, classifier__min_child_weight=14.736842105263158, classifier__subsample=0.9444444444444444
# [CV 1/4; 12/100] END classifier__alpha=8.421052631578947, classifier__colsample_bytree=1.0, classifier__gamma=17.894736842105264, classifier__lambda=12.631578947368421, classifier__max_depth=429, classifier__min_child_weight=14.736842105263158, classifier__subsample=0.9444444444444444; precision: (train=0.163, test=0.069) total time=   0.5s
# [CV 2/4; 12/100] START classifier__alpha=8.421052631578947, classifier__colsample_bytree=1.0, classifier__gamma=17.894736842105264, classifier__lambda=12.631578947368421, classifier__max_depth=429, classifier__min_child_weight=14.736842105263158, classifier__subsample=0.9444444444444444
# [CV 2/4; 12/100] END classifier__alpha=8.421052631578947, classifier__colsample_bytree=1.0, classifier__gamma=17.894736842105264, classifier__lambda=12.631578947368421, classifier__max_depth=429, classifier__min_child_weight=14.736842105263158, classifier__subsample=0.9444444444444444; precision: (train=0.149, test=0.044) total time=   0.5s
# [CV 3/4; 12/100] START classifier__alpha=8.421052631578947, classifier__colsample_bytree=1.0, classifier__gamma=17.894736842105264, classifier__lambda=12.631578947368421, classifier__max_depth=429, classifier__min_child_weight=14.736842105263158, classifier__subsample=0.9444444444444444
# [CV 3/4; 12/100] END classifier__alpha=8.421052631578947, classifier__colsample_bytree=1.0, classifier__gamma=17.894736842105264, classifier__lambda=12.631578947368421, classifier__max_depth=429, classifier__min_child_weight=14.736842105263158, classifier__subsample=0.9444444444444444; precision: (train=0.172, test=0.116) total time=   0.5s
# [CV 4/4; 12/100] START classifier__alpha=8.421052631578947, classifier__colsample_bytree=1.0, classifier__gamma=17.894736842105264, classifier__lambda=12.631578947368421, classifier__max_depth=429, classifier__min_child_weight=14.736842105263158, classifier__subsample=0.9444444444444444
# [CV 4/4; 12/100] END classifier__alpha=8.421052631578947, classifier__colsample_bytree=1.0, classifier__gamma=17.894736842105264, classifier__lambda=12.631578947368421, classifier__max_depth=429, classifier__min_child_weight=14.736842105263158, classifier__subsample=0.9444444444444444; precision: (train=0.126, test=0.057) total time=   0.5s
# [CV 1/4; 13/100] START classifier__alpha=10.526315789473683, classifier__colsample_bytree=0.9444444444444444, classifier__gamma=11.578947368421051, classifier__lambda=8.421052631578947, classifier__max_depth=429, classifier__min_child_weight=6.315789473684211, classifier__subsample=0.8888888888888888
# [CV 1/4; 13/100] END classifier__alpha=10.526315789473683, classifier__colsample_bytree=0.9444444444444444, classifier__gamma=11.578947368421051, classifier__lambda=8.421052631578947, classifier__max_depth=429, classifier__min_child_weight=6.315789473684211, classifier__subsample=0.8888888888888888; precision: (train=0.186, test=0.098) total time=   0.5s
# [CV 2/4; 13/100] START classifier__alpha=10.526315789473683, classifier__colsample_bytree=0.9444444444444444, classifier__gamma=11.578947368421051, classifier__lambda=8.421052631578947, classifier__max_depth=429, classifier__min_child_weight=6.315789473684211, classifier__subsample=0.8888888888888888
# [CV 2/4; 13/100] END classifier__alpha=10.526315789473683, classifier__colsample_bytree=0.9444444444444444, classifier__gamma=11.578947368421051, classifier__lambda=8.421052631578947, classifier__max_depth=429, classifier__min_child_weight=6.315789473684211, classifier__subsample=0.8888888888888888; precision: (train=0.194, test=0.063) total time=   0.5s
# [CV 3/4; 13/100] START classifier__alpha=10.526315789473683, classifier__colsample_bytree=0.9444444444444444, classifier__gamma=11.578947368421051, classifier__lambda=8.421052631578947, classifier__max_depth=429, classifier__min_child_weight=6.315789473684211, classifier__subsample=0.8888888888888888
# [CV 3/4; 13/100] END classifier__alpha=10.526315789473683, classifier__colsample_bytree=0.9444444444444444, classifier__gamma=11.578947368421051, classifier__lambda=8.421052631578947, classifier__max_depth=429, classifier__min_child_weight=6.315789473684211, classifier__subsample=0.8888888888888888; precision: (train=0.180, test=0.148) total time=   0.5s
# [CV 4/4; 13/100] START classifier__alpha=10.526315789473683, classifier__colsample_bytree=0.9444444444444444, classifier__gamma=11.578947368421051, classifier__lambda=8.421052631578947, classifier__max_depth=429, classifier__min_child_weight=6.315789473684211, classifier__subsample=0.8888888888888888
# [CV 4/4; 13/100] END classifier__alpha=10.526315789473683, classifier__colsample_bytree=0.9444444444444444, classifier__gamma=11.578947368421051, classifier__lambda=8.421052631578947, classifier__max_depth=429, classifier__min_child_weight=6.315789473684211, classifier__subsample=0.8888888888888888; precision: (train=0.155, test=0.060) total time=   0.5s
# [CV 1/4; 14/100] START classifier__alpha=15.789473684210526, classifier__colsample_bytree=0.6666666666666666, classifier__gamma=8.421052631578947, classifier__lambda=0.0, classifier__max_depth=627, classifier__min_child_weight=9.473684210526315, classifier__subsample=0.7777777777777778
# [CV 1/4; 14/100] END classifier__alpha=15.789473684210526, classifier__colsample_bytree=0.6666666666666666, classifier__gamma=8.421052631578947, classifier__lambda=0.0, classifier__max_depth=627, classifier__min_child_weight=9.473684210526315, classifier__subsample=0.7777777777777778; precision: (train=0.220, test=0.089) total time=   0.5s
# [CV 2/4; 14/100] START classifier__alpha=15.789473684210526, classifier__colsample_bytree=0.6666666666666666, classifier__gamma=8.421052631578947, classifier__lambda=0.0, classifier__max_depth=627, classifier__min_child_weight=9.473684210526315, classifier__subsample=0.7777777777777778
# [CV 2/4; 14/100] END classifier__alpha=15.789473684210526, classifier__colsample_bytree=0.6666666666666666, classifier__gamma=8.421052631578947, classifier__lambda=0.0, classifier__max_depth=627, classifier__min_child_weight=9.473684210526315, classifier__subsample=0.7777777777777778; precision: (train=0.138, test=0.050) total time=   0.5s
# [CV 3/4; 14/100] START classifier__alpha=15.789473684210526, classifier__colsample_bytree=0.6666666666666666, classifier__gamma=8.421052631578947, classifier__lambda=0.0, classifier__max_depth=627, classifier__min_child_weight=9.473684210526315, classifier__subsample=0.7777777777777778
# [CV 3/4; 14/100] END classifier__alpha=15.789473684210526, classifier__colsample_bytree=0.6666666666666666, classifier__gamma=8.421052631578947, classifier__lambda=0.0, classifier__max_depth=627, classifier__min_child_weight=9.473684210526315, classifier__subsample=0.7777777777777778; precision: (train=0.199, test=0.102) total time=   0.5s
# [CV 4/4; 14/100] START classifier__alpha=15.789473684210526, classifier__colsample_bytree=0.6666666666666666, classifier__gamma=8.421052631578947, classifier__lambda=0.0, classifier__max_depth=627, classifier__min_child_weight=9.473684210526315, classifier__subsample=0.7777777777777778
# [CV 4/4; 14/100] END classifier__alpha=15.789473684210526, classifier__colsample_bytree=0.6666666666666666, classifier__gamma=8.421052631578947, classifier__lambda=0.0, classifier__max_depth=627, classifier__min_child_weight=9.473684210526315, classifier__subsample=0.7777777777777778; precision: (train=0.140, test=0.060) total time=   0.5s
# [CV 1/4; 15/100] START classifier__alpha=16.842105263157894, classifier__colsample_bytree=0.6111111111111112, classifier__gamma=0.0, classifier__lambda=6.315789473684211, classifier__max_depth=78, classifier__min_child_weight=5.263157894736842, classifier__subsample=0.9444444444444444
# [CV 1/4; 15/100] END classifier__alpha=16.842105263157894, classifier__colsample_bytree=0.6111111111111112, classifier__gamma=0.0, classifier__lambda=6.315789473684211, classifier__max_depth=78, classifier__min_child_weight=5.263157894736842, classifier__subsample=0.9444444444444444; precision: (train=0.300, test=0.061) total time=   0.5s
# [CV 2/4; 15/100] START classifier__alpha=16.842105263157894, classifier__colsample_bytree=0.6111111111111112, classifier__gamma=0.0, classifier__lambda=6.315789473684211, classifier__max_depth=78, classifier__min_child_weight=5.263157894736842, classifier__subsample=0.9444444444444444
# [CV 2/4; 15/100] END classifier__alpha=16.842105263157894, classifier__colsample_bytree=0.6111111111111112, classifier__gamma=0.0, classifier__lambda=6.315789473684211, classifier__max_depth=78, classifier__min_child_weight=5.263157894736842, classifier__subsample=0.9444444444444444; precision: (train=0.288, test=0.049) total time=   0.6s
# [CV 3/4; 15/100] START classifier__alpha=16.842105263157894, classifier__colsample_bytree=0.6111111111111112, classifier__gamma=0.0, classifier__lambda=6.315789473684211, classifier__max_depth=78, classifier__min_child_weight=5.263157894736842, classifier__subsample=0.9444444444444444
# [CV 3/4; 15/100] END classifier__alpha=16.842105263157894, classifier__colsample_bytree=0.6111111111111112, classifier__gamma=0.0, classifier__lambda=6.315789473684211, classifier__max_depth=78, classifier__min_child_weight=5.263157894736842, classifier__subsample=0.9444444444444444; precision: (train=0.347, test=0.226) total time=   0.5s
# [CV 4/4; 15/100] START classifier__alpha=16.842105263157894, classifier__colsample_bytree=0.6111111111111112, classifier__gamma=0.0, classifier__lambda=6.315789473684211, classifier__max_depth=78, classifier__min_child_weight=5.263157894736842, classifier__subsample=0.9444444444444444
# [CV 4/4; 15/100] END classifier__alpha=16.842105263157894, classifier__colsample_bytree=0.6111111111111112, classifier__gamma=0.0, classifier__lambda=6.315789473684211, classifier__max_depth=78, classifier__min_child_weight=5.263157894736842, classifier__subsample=0.9444444444444444; precision: (train=0.252, test=0.086) total time=   0.5s
# [CV 1/4; 16/100] START classifier__alpha=2.1052631578947367, classifier__colsample_bytree=0.6111111111111112, classifier__gamma=2.1052631578947367, classifier__lambda=0.0, classifier__max_depth=734, classifier__min_child_weight=14.736842105263158, classifier__subsample=1.0
# [CV 1/4; 16/100] END classifier__alpha=2.1052631578947367, classifier__colsample_bytree=0.6111111111111112, classifier__gamma=2.1052631578947367, classifier__lambda=0.0, classifier__max_depth=734, classifier__min_child_weight=14.736842105263158, classifier__subsample=1.0; precision: (train=0.337, test=0.147) total time=   0.5s
# [CV 2/4; 16/100] START classifier__alpha=2.1052631578947367, classifier__colsample_bytree=0.6111111111111112, classifier__gamma=2.1052631578947367, classifier__lambda=0.0, classifier__max_depth=734, classifier__min_child_weight=14.736842105263158, classifier__subsample=1.0
# [CV 2/4; 16/100] END classifier__alpha=2.1052631578947367, classifier__colsample_bytree=0.6111111111111112, classifier__gamma=2.1052631578947367, classifier__lambda=0.0, classifier__max_depth=734, classifier__min_child_weight=14.736842105263158, classifier__subsample=1.0; precision: (train=0.303, test=0.029) total time=   0.5s
# [CV 3/4; 16/100] START classifier__alpha=2.1052631578947367, classifier__colsample_bytree=0.6111111111111112, classifier__gamma=2.1052631578947367, classifier__lambda=0.0, classifier__max_depth=734, classifier__min_child_weight=14.736842105263158, classifier__subsample=1.0
# [CV 3/4; 16/100] END classifier__alpha=2.1052631578947367, classifier__colsample_bytree=0.6111111111111112, classifier__gamma=2.1052631578947367, classifier__lambda=0.0, classifier__max_depth=734, classifier__min_child_weight=14.736842105263158, classifier__subsample=1.0; precision: (train=0.433, test=0.179) total time=   0.5s
# [CV 4/4; 16/100] START classifier__alpha=2.1052631578947367, classifier__colsample_bytree=0.6111111111111112, classifier__gamma=2.1052631578947367, classifier__lambda=0.0, classifier__max_depth=734, classifier__min_child_weight=14.736842105263158, classifier__subsample=1.0
# [CV 4/4; 16/100] END classifier__alpha=2.1052631578947367, classifier__colsample_bytree=0.6111111111111112, classifier__gamma=2.1052631578947367, classifier__lambda=0.0, classifier__max_depth=734, classifier__min_child_weight=14.736842105263158, classifier__subsample=1.0; precision: (train=0.306, test=0.065) total time=   0.5s
# [CV 1/4; 17/100] START classifier__alpha=6.315789473684211, classifier__colsample_bytree=0.5, classifier__gamma=11.578947368421051, classifier__lambda=8.421052631578947, classifier__max_depth=444, classifier__min_child_weight=7.368421052631579, classifier__subsample=0.8333333333333333
# [CV 1/4; 17/100] END classifier__alpha=6.315789473684211, classifier__colsample_bytree=0.5, classifier__gamma=11.578947368421051, classifier__lambda=8.421052631578947, classifier__max_depth=444, classifier__min_child_weight=7.368421052631579, classifier__subsample=0.8333333333333333; precision: (train=0.186, test=0.063) total time=   0.5s
# [CV 2/4; 17/100] START classifier__alpha=6.315789473684211, classifier__colsample_bytree=0.5, classifier__gamma=11.578947368421051, classifier__lambda=8.421052631578947, classifier__max_depth=444, classifier__min_child_weight=7.368421052631579, classifier__subsample=0.8333333333333333
# [CV 2/4; 17/100] END classifier__alpha=6.315789473684211, classifier__colsample_bytree=0.5, classifier__gamma=11.578947368421051, classifier__lambda=8.421052631578947, classifier__max_depth=444, classifier__min_child_weight=7.368421052631579, classifier__subsample=0.8333333333333333; precision: (train=0.162, test=0.030) total time=   0.5s
# [CV 3/4; 17/100] START classifier__alpha=6.315789473684211, classifier__colsample_bytree=0.5, classifier__gamma=11.578947368421051, classifier__lambda=8.421052631578947, classifier__max_depth=444, classifier__min_child_weight=7.368421052631579, classifier__subsample=0.8333333333333333
# [CV 3/4; 17/100] END classifier__alpha=6.315789473684211, classifier__colsample_bytree=0.5, classifier__gamma=11.578947368421051, classifier__lambda=8.421052631578947, classifier__max_depth=444, classifier__min_child_weight=7.368421052631579, classifier__subsample=0.8333333333333333; precision: (train=0.175, test=0.114) total time=   0.5s
# [CV 4/4; 17/100] START classifier__alpha=6.315789473684211, classifier__colsample_bytree=0.5, classifier__gamma=11.578947368421051, classifier__lambda=8.421052631578947, classifier__max_depth=444, classifier__min_child_weight=7.368421052631579, classifier__subsample=0.8333333333333333
# [CV 4/4; 17/100] END classifier__alpha=6.315789473684211, classifier__colsample_bytree=0.5, classifier__gamma=11.578947368421051, classifier__lambda=8.421052631578947, classifier__max_depth=444, classifier__min_child_weight=7.368421052631579, classifier__subsample=0.8333333333333333; precision: (train=0.151, test=0.065) total time=   0.5s
# [CV 1/4; 18/100] START classifier__alpha=8.421052631578947, classifier__colsample_bytree=0.9444444444444444, classifier__gamma=10.526315789473683, classifier__lambda=8.421052631578947, classifier__max_depth=643, classifier__min_child_weight=2.1052631578947367, classifier__subsample=0.8888888888888888
# [CV 1/4; 18/100] END classifier__alpha=8.421052631578947, classifier__colsample_bytree=0.9444444444444444, classifier__gamma=10.526315789473683, classifier__lambda=8.421052631578947, classifier__max_depth=643, classifier__min_child_weight=2.1052631578947367, classifier__subsample=0.8888888888888888; precision: (train=0.215, test=0.070) total time=   0.5s
# [CV 2/4; 18/100] START classifier__alpha=8.421052631578947, classifier__colsample_bytree=0.9444444444444444, classifier__gamma=10.526315789473683, classifier__lambda=8.421052631578947, classifier__max_depth=643, classifier__min_child_weight=2.1052631578947367, classifier__subsample=0.8888888888888888
# [CV 2/4; 18/100] END classifier__alpha=8.421052631578947, classifier__colsample_bytree=0.9444444444444444, classifier__gamma=10.526315789473683, classifier__lambda=8.421052631578947, classifier__max_depth=643, classifier__min_child_weight=2.1052631578947367, classifier__subsample=0.8888888888888888; precision: (train=0.179, test=0.056) total time=   0.5s
# [CV 3/4; 18/100] START classifier__alpha=8.421052631578947, classifier__colsample_bytree=0.9444444444444444, classifier__gamma=10.526315789473683, classifier__lambda=8.421052631578947, classifier__max_depth=643, classifier__min_child_weight=2.1052631578947367, classifier__subsample=0.8888888888888888
# [CV 3/4; 18/100] END classifier__alpha=8.421052631578947, classifier__colsample_bytree=0.9444444444444444, classifier__gamma=10.526315789473683, classifier__lambda=8.421052631578947, classifier__max_depth=643, classifier__min_child_weight=2.1052631578947367, classifier__subsample=0.8888888888888888; precision: (train=0.209, test=0.120) total time=   0.5s
# [CV 4/4; 18/100] START classifier__alpha=8.421052631578947, classifier__colsample_bytree=0.9444444444444444, classifier__gamma=10.526315789473683, classifier__lambda=8.421052631578947, classifier__max_depth=643, classifier__min_child_weight=2.1052631578947367, classifier__subsample=0.8888888888888888
# [CV 4/4; 18/100] END classifier__alpha=8.421052631578947, classifier__colsample_bytree=0.9444444444444444, classifier__gamma=10.526315789473683, classifier__lambda=8.421052631578947, classifier__max_depth=643, classifier__min_child_weight=2.1052631578947367, classifier__subsample=0.8888888888888888; precision: (train=0.187, test=0.063) total time=   0.5s
# [CV 1/4; 19/100] START classifier__alpha=0.0, classifier__colsample_bytree=0.5, classifier__gamma=16.842105263157894, classifier__lambda=14.736842105263158, classifier__max_depth=353, classifier__min_child_weight=16.842105263157894, classifier__subsample=1.0
# [CV 1/4; 19/100] END classifier__alpha=0.0, classifier__colsample_bytree=0.5, classifier__gamma=16.842105263157894, classifier__lambda=14.736842105263158, classifier__max_depth=353, classifier__min_child_weight=16.842105263157894, classifier__subsample=1.0; precision: (train=0.190, test=0.063) total time=   0.4s
# [CV 2/4; 19/100] START classifier__alpha=0.0, classifier__colsample_bytree=0.5, classifier__gamma=16.842105263157894, classifier__lambda=14.736842105263158, classifier__max_depth=353, classifier__min_child_weight=16.842105263157894, classifier__subsample=1.0
# [CV 2/4; 19/100] END classifier__alpha=0.0, classifier__colsample_bytree=0.5, classifier__gamma=16.842105263157894, classifier__lambda=14.736842105263158, classifier__max_depth=353, classifier__min_child_weight=16.842105263157894, classifier__subsample=1.0; precision: (train=0.145, test=0.062) total time=   0.4s
# [CV 3/4; 19/100] START classifier__alpha=0.0, classifier__colsample_bytree=0.5, classifier__gamma=16.842105263157894, classifier__lambda=14.736842105263158, classifier__max_depth=353, classifier__min_child_weight=16.842105263157894, classifier__subsample=1.0
# [CV 3/4; 19/100] END classifier__alpha=0.0, classifier__colsample_bytree=0.5, classifier__gamma=16.842105263157894, classifier__lambda=14.736842105263158, classifier__max_depth=353, classifier__min_child_weight=16.842105263157894, classifier__subsample=1.0; precision: (train=0.171, test=0.102) total time=   0.4s
# [CV 4/4; 19/100] START classifier__alpha=0.0, classifier__colsample_bytree=0.5, classifier__gamma=16.842105263157894, classifier__lambda=14.736842105263158, classifier__max_depth=353, classifier__min_child_weight=16.842105263157894, classifier__subsample=1.0
# [CV 4/4; 19/100] END classifier__alpha=0.0, classifier__colsample_bytree=0.5, classifier__gamma=16.842105263157894, classifier__lambda=14.736842105263158, classifier__max_depth=353, classifier__min_child_weight=16.842105263157894, classifier__subsample=1.0; precision: (train=0.158, test=0.089) total time=   0.4s
# ...
# [CV 1/4; 95/100] START classifier__alpha=11.578947368421051, classifier__colsample_bytree=0.7222222222222222, classifier__gamma=12.631578947368421, classifier__lambda=10.526315789473683, classifier__max_depth=154, classifier__min_child_weight=4.2105263157894735, classifier__subsample=0.5555555555555556
# [CV 1/4; 95/100] END classifier__alpha=11.578947368421051, classifier__colsample_bytree=0.7222222222222222, classifier__gamma=12.631578947368421, classifier__lambda=10.526315789473683, classifier__max_depth=154, classifier__min_child_weight=4.2105263157894735, classifier__subsample=0.5555555555555556; precision: (train=0.137, test=0.063) total time=   0.5s
# [CV 2/4; 95/100] START classifier__alpha=11.578947368421051, classifier__colsample_bytree=0.7222222222222222, classifier__gamma=12.631578947368421, classifier__lambda=10.526315789473683, classifier__max_depth=154, classifier__min_child_weight=4.2105263157894735, classifier__subsample=0.5555555555555556
# [CV 2/4; 95/100] END classifier__alpha=11.578947368421051, classifier__colsample_bytree=0.7222222222222222, classifier__gamma=12.631578947368421, classifier__lambda=10.526315789473683, classifier__max_depth=154, classifier__min_child_weight=4.2105263157894735, classifier__subsample=0.5555555555555556; precision: (train=0.110, test=0.045) total time=   0.5s
# [CV 3/4; 95/100] START classifier__alpha=11.578947368421051, classifier__colsample_bytree=0.7222222222222222, classifier__gamma=12.631578947368421, classifier__lambda=10.526315789473683, classifier__max_depth=154, classifier__min_child_weight=4.2105263157894735, classifier__subsample=0.5555555555555556
# [CV 3/4; 95/100] END classifier__alpha=11.578947368421051, classifier__colsample_bytree=0.7222222222222222, classifier__gamma=12.631578947368421, classifier__lambda=10.526315789473683, classifier__max_depth=154, classifier__min_child_weight=4.2105263157894735, classifier__subsample=0.5555555555555556; precision: (train=0.153, test=0.132) total time=   0.5s
# [CV 4/4; 95/100] START classifier__alpha=11.578947368421051, classifier__colsample_bytree=0.7222222222222222, classifier__gamma=12.631578947368421, classifier__lambda=10.526315789473683, classifier__max_depth=154, classifier__min_child_weight=4.2105263157894735, classifier__subsample=0.5555555555555556
# [CV 4/4; 95/100] END classifier__alpha=11.578947368421051, classifier__colsample_bytree=0.7222222222222222, classifier__gamma=12.631578947368421, classifier__lambda=10.526315789473683, classifier__max_depth=154, classifier__min_child_weight=4.2105263157894735, classifier__subsample=0.5555555555555556; precision: (train=0.117, test=0.055) total time=   0.5s
# [CV 1/4; 96/100] START classifier__alpha=3.1578947368421053, classifier__colsample_bytree=0.6666666666666666, classifier__gamma=4.2105263157894735, classifier__lambda=6.315789473684211, classifier__max_depth=200, classifier__min_child_weight=11.578947368421051, classifier__subsample=0.7777777777777778
# [CV 1/4; 96/100] END classifier__alpha=3.1578947368421053, classifier__colsample_bytree=0.6666666666666666, classifier__gamma=4.2105263157894735, classifier__lambda=6.315789473684211, classifier__max_depth=200, classifier__min_child_weight=11.578947368421051, classifier__subsample=0.7777777777777778; precision: (train=0.294, test=0.067) total time=   0.5s
# [CV 2/4; 96/100] START classifier__alpha=3.1578947368421053, classifier__colsample_bytree=0.6666666666666666, classifier__gamma=4.2105263157894735, classifier__lambda=6.315789473684211, classifier__max_depth=200, classifier__min_child_weight=11.578947368421051, classifier__subsample=0.7777777777777778
# [CV 2/4; 96/100] END classifier__alpha=3.1578947368421053, classifier__colsample_bytree=0.6666666666666666, classifier__gamma=4.2105263157894735, classifier__lambda=6.315789473684211, classifier__max_depth=200, classifier__min_child_weight=11.578947368421051, classifier__subsample=0.7777777777777778; precision: (train=0.230, test=0.152) total time=   0.5s
# [CV 3/4; 96/100] START classifier__alpha=3.1578947368421053, classifier__colsample_bytree=0.6666666666666666, classifier__gamma=4.2105263157894735, classifier__lambda=6.315789473684211, classifier__max_depth=200, classifier__min_child_weight=11.578947368421051, classifier__subsample=0.7777777777777778
# [CV 3/4; 96/100] END classifier__alpha=3.1578947368421053, classifier__colsample_bytree=0.6666666666666666, classifier__gamma=4.2105263157894735, classifier__lambda=6.315789473684211, classifier__max_depth=200, classifier__min_child_weight=11.578947368421051, classifier__subsample=0.7777777777777778; precision: (train=0.247, test=0.195) total time=   0.5s
# [CV 4/4; 96/100] START classifier__alpha=3.1578947368421053, classifier__colsample_bytree=0.6666666666666666, classifier__gamma=4.2105263157894735, classifier__lambda=6.315789473684211, classifier__max_depth=200, classifier__min_child_weight=11.578947368421051, classifier__subsample=0.7777777777777778
# [CV 4/4; 96/100] END classifier__alpha=3.1578947368421053, classifier__colsample_bytree=0.6666666666666666, classifier__gamma=4.2105263157894735, classifier__lambda=6.315789473684211, classifier__max_depth=200, classifier__min_child_weight=11.578947368421051, classifier__subsample=0.7777777777777778; precision: (train=0.240, test=0.086) total time=   0.5s
# [CV 1/4; 97/100] START classifier__alpha=11.578947368421051, classifier__colsample_bytree=0.7222222222222222, classifier__gamma=18.94736842105263, classifier__lambda=10.526315789473683, classifier__max_depth=658, classifier__min_child_weight=0.0, classifier__subsample=0.6666666666666666
# [CV 1/4; 97/100] END classifier__alpha=11.578947368421051, classifier__colsample_bytree=0.7222222222222222, classifier__gamma=18.94736842105263, classifier__lambda=10.526315789473683, classifier__max_depth=658, classifier__min_child_weight=0.0, classifier__subsample=0.6666666666666666; precision: (train=0.126, test=0.072) total time=   0.5s
# [CV 2/4; 97/100] START classifier__alpha=11.578947368421051, classifier__colsample_bytree=0.7222222222222222, classifier__gamma=18.94736842105263, classifier__lambda=10.526315789473683, classifier__max_depth=658, classifier__min_child_weight=0.0, classifier__subsample=0.6666666666666666
# [CV 2/4; 97/100] END classifier__alpha=11.578947368421051, classifier__colsample_bytree=0.7222222222222222, classifier__gamma=18.94736842105263, classifier__lambda=10.526315789473683, classifier__max_depth=658, classifier__min_child_weight=0.0, classifier__subsample=0.6666666666666666; precision: (train=0.111, test=0.058) total time=   0.5s
# [CV 3/4; 97/100] START classifier__alpha=11.578947368421051, classifier__colsample_bytree=0.7222222222222222, classifier__gamma=18.94736842105263, classifier__lambda=10.526315789473683, classifier__max_depth=658, classifier__min_child_weight=0.0, classifier__subsample=0.6666666666666666
# [CV 3/4; 97/100] END classifier__alpha=11.578947368421051, classifier__colsample_bytree=0.7222222222222222, classifier__gamma=18.94736842105263, classifier__lambda=10.526315789473683, classifier__max_depth=658, classifier__min_child_weight=0.0, classifier__subsample=0.6666666666666666; precision: (train=0.122, test=0.084) total time=   0.5s
# [CV 4/4; 97/100] START classifier__alpha=11.578947368421051, classifier__colsample_bytree=0.7222222222222222, classifier__gamma=18.94736842105263, classifier__lambda=10.526315789473683, classifier__max_depth=658, classifier__min_child_weight=0.0, classifier__subsample=0.6666666666666666
# [CV 4/4; 97/100] END classifier__alpha=11.578947368421051, classifier__colsample_bytree=0.7222222222222222, classifier__gamma=18.94736842105263, classifier__lambda=10.526315789473683, classifier__max_depth=658, classifier__min_child_weight=0.0, classifier__subsample=0.6666666666666666; precision: (train=0.137, test=0.024) total time=   0.5s
# [CV 1/4; 98/100] START classifier__alpha=4.2105263157894735, classifier__colsample_bytree=0.7777777777777778, classifier__gamma=16.842105263157894, classifier__lambda=17.894736842105264, classifier__max_depth=627, classifier__min_child_weight=9.473684210526315, classifier__subsample=1.0
# [CV 1/4; 98/100] END classifier__alpha=4.2105263157894735, classifier__colsample_bytree=0.7777777777777778, classifier__gamma=16.842105263157894, classifier__lambda=17.894736842105264, classifier__max_depth=627, classifier__min_child_weight=9.473684210526315, classifier__subsample=1.0; precision: (train=0.225, test=0.094) total time=   0.5s
# [CV 2/4; 98/100] START classifier__alpha=4.2105263157894735, classifier__colsample_bytree=0.7777777777777778, classifier__gamma=16.842105263157894, classifier__lambda=17.894736842105264, classifier__max_depth=627, classifier__min_child_weight=9.473684210526315, classifier__subsample=1.0
# [CV 2/4; 98/100] END classifier__alpha=4.2105263157894735, classifier__colsample_bytree=0.7777777777777778, classifier__gamma=16.842105263157894, classifier__lambda=17.894736842105264, classifier__max_depth=627, classifier__min_child_weight=9.473684210526315, classifier__subsample=1.0; precision: (train=0.165, test=0.062) total time=   0.4s
# [CV 3/4; 98/100] START classifier__alpha=4.2105263157894735, classifier__colsample_bytree=0.7777777777777778, classifier__gamma=16.842105263157894, classifier__lambda=17.894736842105264, classifier__max_depth=627, classifier__min_child_weight=9.473684210526315, classifier__subsample=1.0
# [CV 3/4; 98/100] END classifier__alpha=4.2105263157894735, classifier__colsample_bytree=0.7777777777777778, classifier__gamma=16.842105263157894, classifier__lambda=17.894736842105264, classifier__max_depth=627, classifier__min_child_weight=9.473684210526315, classifier__subsample=1.0; precision: (train=0.171, test=0.109) total time=   0.5s
# [CV 4/4; 98/100] START classifier__alpha=4.2105263157894735, classifier__colsample_bytree=0.7777777777777778, classifier__gamma=16.842105263157894, classifier__lambda=17.894736842105264, classifier__max_depth=627, classifier__min_child_weight=9.473684210526315, classifier__subsample=1.0
# [CV 4/4; 98/100] END classifier__alpha=4.2105263157894735, classifier__colsample_bytree=0.7777777777777778, classifier__gamma=16.842105263157894, classifier__lambda=17.894736842105264, classifier__max_depth=627, classifier__min_child_weight=9.473684210526315, classifier__subsample=1.0; precision: (train=0.171, test=0.072) total time=   0.5s
# [CV 1/4; 99/100] START classifier__alpha=2.1052631578947367, classifier__colsample_bytree=0.8888888888888888, classifier__gamma=18.94736842105263, classifier__lambda=6.315789473684211, classifier__max_depth=429, classifier__min_child_weight=4.2105263157894735, classifier__subsample=0.7222222222222222
# [CV 1/4; 99/100] END classifier__alpha=2.1052631578947367, classifier__colsample_bytree=0.8888888888888888, classifier__gamma=18.94736842105263, classifier__lambda=6.315789473684211, classifier__max_depth=429, classifier__min_child_weight=4.2105263157894735, classifier__subsample=0.7222222222222222; precision: (train=0.213, test=0.104) total time=   0.5s
# [CV 2/4; 99/100] START classifier__alpha=2.1052631578947367, classifier__colsample_bytree=0.8888888888888888, classifier__gamma=18.94736842105263, classifier__lambda=6.315789473684211, classifier__max_depth=429, classifier__min_child_weight=4.2105263157894735, classifier__subsample=0.7222222222222222
# [CV 2/4; 99/100] END classifier__alpha=2.1052631578947367, classifier__colsample_bytree=0.8888888888888888, classifier__gamma=18.94736842105263, classifier__lambda=6.315789473684211, classifier__max_depth=429, classifier__min_child_weight=4.2105263157894735, classifier__subsample=0.7222222222222222; precision: (train=0.169, test=0.068) total time=   0.6s
# [CV 3/4; 99/100] START classifier__alpha=2.1052631578947367, classifier__colsample_bytree=0.8888888888888888, classifier__gamma=18.94736842105263, classifier__lambda=6.315789473684211, classifier__max_depth=429, classifier__min_child_weight=4.2105263157894735, classifier__subsample=0.7222222222222222
# [CV 3/4; 99/100] END classifier__alpha=2.1052631578947367, classifier__colsample_bytree=0.8888888888888888, classifier__gamma=18.94736842105263, classifier__lambda=6.315789473684211, classifier__max_depth=429, classifier__min_child_weight=4.2105263157894735, classifier__subsample=0.7222222222222222; precision: (train=0.191, test=0.154) total time=   0.6s
# [CV 4/4; 99/100] START classifier__alpha=2.1052631578947367, classifier__colsample_bytree=0.8888888888888888, classifier__gamma=18.94736842105263, classifier__lambda=6.315789473684211, classifier__max_depth=429, classifier__min_child_weight=4.2105263157894735, classifier__subsample=0.7222222222222222
# [CV 4/4; 99/100] END classifier__alpha=2.1052631578947367, classifier__colsample_bytree=0.8888888888888888, classifier__gamma=18.94736842105263, classifier__lambda=6.315789473684211, classifier__max_depth=429, classifier__min_child_weight=4.2105263157894735, classifier__subsample=0.7222222222222222; precision: (train=0.167, test=0.109) total time=   0.5s
# [CV 1/4; 100/100] START classifier__alpha=15.789473684210526, classifier__colsample_bytree=0.5555555555555556, classifier__gamma=6.315789473684211, classifier__lambda=6.315789473684211, classifier__max_depth=368, classifier__min_child_weight=13.68421052631579, classifier__subsample=0.8333333333333333
# [CV 1/4; 100/100] END classifier__alpha=15.789473684210526, classifier__colsample_bytree=0.5555555555555556, classifier__gamma=6.315789473684211, classifier__lambda=6.315789473684211, classifier__max_depth=368, classifier__min_child_weight=13.68421052631579, classifier__subsample=0.8333333333333333; precision: (train=0.199, test=0.088) total time=   0.5s
# [CV 2/4; 100/100] START classifier__alpha=15.789473684210526, classifier__colsample_bytree=0.5555555555555556, classifier__gamma=6.315789473684211, classifier__lambda=6.315789473684211, classifier__max_depth=368, classifier__min_child_weight=13.68421052631579, classifier__subsample=0.8333333333333333
# [CV 2/4; 100/100] END classifier__alpha=15.789473684210526, classifier__colsample_bytree=0.5555555555555556, classifier__gamma=6.315789473684211, classifier__lambda=6.315789473684211, classifier__max_depth=368, classifier__min_child_weight=13.68421052631579, classifier__subsample=0.8333333333333333; precision: (train=0.153, test=0.029) total time=   0.5s
# [CV 3/4; 100/100] START classifier__alpha=15.789473684210526, classifier__colsample_bytree=0.5555555555555556, classifier__gamma=6.315789473684211, classifier__lambda=6.315789473684211, classifier__max_depth=368, classifier__min_child_weight=13.68421052631579, classifier__subsample=0.8333333333333333
# [CV 3/4; 100/100] END classifier__alpha=15.789473684210526, classifier__colsample_bytree=0.5555555555555556, classifier__gamma=6.315789473684211, classifier__lambda=6.315789473684211, classifier__max_depth=368, classifier__min_child_weight=13.68421052631579, classifier__subsample=0.8333333333333333; precision: (train=0.195, test=0.102) total time=   0.5s
# [CV 4/4; 100/100] START classifier__alpha=15.789473684210526, classifier__colsample_bytree=0.5555555555555556, classifier__gamma=6.315789473684211, classifier__lambda=6.315789473684211, classifier__max_depth=368, classifier__min_child_weight=13.68421052631579, classifier__subsample=0.8333333333333333
# [CV 4/4; 100/100] END classifier__alpha=15.789473684210526, classifier__colsample_bytree=0.5555555555555556, classifier__gamma=6.315789473684211, classifier__lambda=6.315789473684211, classifier__max_depth=368, classifier__min_child_weight=13.68421052631579, classifier__subsample=0.8333333333333333; precision: (train=0.165, test=0.028) total time=   0.5s
# 0.1593151616875894 {'classifier__subsample': 0.8333333333333333, 'classifier__min_child_weight': 3.1578947368421053, 'classifier__max_depth': 32, 'classifier__lambda': 20.0, 'classifier__gamma': 0.0, 'classifier__colsample_bytree': 0.9444444444444444, 'classifier__alpha': 11.578947368421051}
# 0.09090909090909091
