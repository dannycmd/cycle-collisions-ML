# %%
from functions import transform_raw_data, clean_df, impute_fit_df_TE, impute_transform_df_TE

from imblearn.pipeline import Pipeline
from imblearn.over_sampling import SMOTE
from sklearn.base import BaseEstimator, TransformerMixin
from sklearn.dummy import DummyClassifier
from sklearn.metrics import  f1_score, make_scorer, confusion_matrix, ConfusionMatrixDisplay, roc_auc_score, precision_score, PrecisionRecallDisplay
from sklearn.model_selection import train_test_split,  StratifiedKFold, RandomizedSearchCV
from sklearn.ensemble import RandomForestClassifier
import xgboost as xgb
from xgboost import XGBClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC, OneClassSVM
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import GaussianNB, MultinomialNB, BernoulliNB
from hyperopt import fmin, tpe, hp, STATUS_OK

import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
from collections import Counter

# %% [markdown]
# - target = fatality
# - only considered columns with roughly <30% missing
# - removing missing values
# - target encoding categorical features

# %%
# custom Transformer class for applying preprocessing in pipeline
class CustomPreprocessor(BaseEstimator, TransformerMixin):
    def __init__(self):
        self.categorical_freqs = None
        self.continuous_medians_grouped = None
        self.continuous_medians = None
        self.vars_to_groupby = None
        self.scaler = None
        self.features = None
        self.encoder = None

    # fit is only called on the train data
    def fit(self, X, y):
        # calculate impute values
        self.categorical_freqs, self.vars_to_groupby, self.continuous_medians_grouped, self.continuous_medians, self.scaler, self.encoder = impute_fit_df_TE(X, y)
        return self

    # transform is called on the both the train and test data
    def transform(self, X, y=None):
        # apply the preprocessing function to the data
        df = impute_transform_df_TE(X, self.categorical_freqs, self.vars_to_groupby, self.continuous_medians_grouped,
                                    self.continuous_medians, self.scaler, X.columns, self.encoder)
        self.features = df.columns
        return df
    
    def get_feature_names_out(self):
        return self.features

# %%
df = transform_raw_data(path_to_csv="stats19CycleCollisions2022.csv")
cols = ['age_of_casualty','engine_capacity_cc','age_of_driver',
            'vehicle_type','vehicle_subtype','junction_detail','towing_and_articulation','vehicle_manoeuvre',
            'casualty_imd_decile','pedestrian_crossing_physical_facilities','pedestrian_crossing_human_control','driver_imd_decile',
            'day_of_week','time_period','season',
            'first_road_class','road_type','speed_limit','junction_control','second_road_class',
            'light_conditions','weather_conditions','road_surface_conditions','propulsion_code','sex_of_casualty','sex_of_driver',
            'urban_or_rural_area','casualty_home_area_type','first_point_of_impact','junction_location','casualty_severity','time'
        ]
df = clean_df(df)
df['fatality'] = np.where(df['casualty_severity'] == "Fatal", 1, 0)
target = 'fatality'
df = df[cols + [target]]
df = df[~df.isin(['Missing']).any(axis=1)]
df["vehicle_type_2"] = [
            "Goods over 3.5t. and under 7.5t" if vehicle_type in ["Agricultural vehicle", "Goods vehicle - unknown weight"]
            else "Motorcycle 50cc and under" if vehicle_type == "Electric motorcycle"
            else "Motorcycle 125cc and under" if vehicle_type == "Motorcycle - unknown cc"
            else "Car" if vehicle_type == "Unknown vehicle type (self rep only)"
            else vehicle_type
            for vehicle_type in df["vehicle_type"]
    ]
engine_capacity_car = df.groupby("vehicle_type_2")["engine_capacity_cc"].median().loc["Car"]
df["engine_capacity_cc"] = np.where(df["vehicle_type"] == "Pedal cycle", 0.00065 * engine_capacity_car, df["engine_capacity_cc"])
df['log_engine_capacity_cc'] = np.log(df['engine_capacity_cc'] + 0.0000001)
df.dropna(axis=0, inplace=True)
# Out:
# c:\Users\danjr\Documents\Projects\cycle collisions\functions.py:6: DtypeWarning: Columns (0,2,39,72) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(path_to_csv, header=0)

# %%
df.shape
# Out:
# (7325, 35)

# %% [markdown]
# feature engineering

# %%
df['hour'] = df.time.str.slice(start=0, stop=2).astype('int')
df['morning'] = np.where((df['hour'] >= 0) & (df['hour'] <= 12), 1, 0)
df['evening'] = np.where((df['hour'] >= 16) & (df['hour'] <= 22), 1, 0)

df['casualty_imd_decile_lessdeprived'] = np.where(df['casualty_imd_decile'].str.contains('Le'), 1, 0)
df['casualty_imd_decile_moredeprived'] = np.where(df['casualty_imd_decile'].str.contains('Mo'), 1, 0)
df['driver_imd_decile_lessdeprived'] = np.where(df['driver_imd_decile'].str.contains('Le'), 1, 0)
df['driver_imd_decile_moredeprived'] = np.where(df['driver_imd_decile'].str.contains('Mo'), 1, 0)

df['turning_left_or_right'] = np.where(df['vehicle_manoeuvre'].str.contains('Turning'), 1, 0)

df['poor_lighting'] = np.where(df['light_conditions'].str.contains('lights un|no lighting'), 1, 0)

df['raining_no_high_wind'] = np.where(df['weather_conditions'] == 'Raining no high wind', 1, 0)
df['high_wind_or_fog'] = np.where((df['weather_conditions'].str.contains('high winds|Fog|Other')) & ~(df['weather_conditions'].str.contains('no')), 1, 0)

# %% [markdown]
# experiments

# %%
features = ['age_of_casualty','engine_capacity_cc','vehicle_type','vehicle_subtype',
            'junction_detail','vehicle_manoeuvre','sex_of_driver',
            'casualty_imd_decile',
            'driver_imd_decile',
            'time_period','light_conditions','weather_conditions',
            'season','first_road_class','second_road_class','road_type',
            'speed_limit','junction_control','road_surface_conditions','propulsion_code',
            'urban_or_rural_area','first_point_of_impact','day_of_week','sex_of_casualty','towing_and_articulation']
df = df[features + [target]]

# %%
# baseline accuracy -> dummy classifier predicting class at random
pipeline = Pipeline([
    ('custom_preprocessor', CustomPreprocessor()),
    ('classifier', DummyClassifier(strategy="uniform"))
])
X_train, X_test, y_train, y_test = train_test_split(df[features], df[target], test_size=0.1, random_state=42)
pipeline.fit(X_train, y_train)
y_pred_dummy = pipeline.predict(X_test)
precision = f1_score(y_test, y_pred_dummy)
print(precision)
cm = confusion_matrix(y_test, y_pred_dummy)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=pipeline.classes_)
disp.plot()

PrecisionRecallDisplay.from_estimator(pipeline, X_test, y_test)
plt.show()
# Out:
# 0.005291005291005292

# %%
X_train, X_test, y_train, y_test = train_test_split(df[features], df[target], test_size=0.1, random_state=42)

# %%
counter = Counter(y_train)
print(counter)
# Out:
# Counter({0: 6537, 1: 55})

# %%
def run_experiment(features, param_distributions, pipeline,
                   n_splits=4, n_iter=40, 
                   classifier=None, plot_param_charts=True):

    cv = StratifiedKFold(n_splits=n_splits)
    scoring = {
        "precision": make_scorer(precision_score)
    }
    random_search = RandomizedSearchCV(
        estimator=pipeline,
        param_distributions=param_distributions,
        n_iter=n_iter,  # Number of random combinations to try
        scoring=scoring,  # Choose your preferred metric
        cv=cv,  # StratifiedKFold cross-validation
        verbose=10,  # Print out progress
        n_jobs=1,  # Use all available cores
        random_state=42,  # Reproducibility
        refit="precision",
        return_train_score=True
    )
    random_search.fit(X_train, y_train)
    print(random_search.best_score_, random_search.best_params_)

    clf = random_search.best_estimator_
    clf.fit(X_train, y_train)
    y_pred = clf.predict(X_test)
    cm = confusion_matrix(y_test, y_pred)
    disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=clf.classes_)
    disp.plot()
    print(precision_score(y_test, y_pred))
    PrecisionRecallDisplay.from_estimator(clf, X_test, y_test)
    plt.show()

    # for each parameter, plot line graphs of the train auc score, test auc score, and train - test score (to identify overfitting)
    if plot_param_charts:
        cv_results_df = pd.DataFrame(random_search.cv_results_)
        params = list(cv_results_df.params[0].keys())
        cv_results_df['train_test_diff_precision'] = cv_results_df['mean_train_precision'] - cv_results_df['mean_test_precision']

        num_cols = 3
        num_rows = (3*len(param_distributions) + num_cols - 1) // num_cols
        fig, ax = plt.subplots(ncols=num_cols, nrows=num_rows, figsize=(15, 4*num_rows))
        ax = ax.flatten()

        for i, param in enumerate(params):
            sns.lineplot(cv_results_df, x='param_' + param, y='mean_test_precision', label='Test precision', ax=ax[i*3+0])
            sns.lineplot(cv_results_df, x='param_' + param, y='mean_train_precision', label='Train precision', ax=ax[i*3+1])
            sns.lineplot(cv_results_df, x='param_' + param, y='train_test_diff_precision', label='Train-Test precision Difference', ax=ax[i*3+2])

        plt.legend()
        plt.show()
    
    return random_search

# %% [markdown]
# ### XGBoost
#
# a. balanced sampling

# %%
counter = Counter(df[target])
scale_pos_weight = counter[0] / counter[1]
scale_pos_weight
# Out:
# 117.14516129032258

# %%
classifier = XGBClassifier(n_jobs=None, scale_pos_weight=scale_pos_weight, eval_metric='aucpr')
pipeline = Pipeline([
        ('custom_preprocessor', CustomPreprocessor()),
        ('classifier', classifier)
    ])
eval_set = [(X_train, y_train), (X_test, y_test)]
pipeline.fit(X_train, y_train)
y_pred = pipeline.predict(X_test)
cm = confusion_matrix(y_test, y_pred)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=pipeline.classes_)
disp.plot()
print(precision_score(y_test, y_pred))
PrecisionRecallDisplay.from_estimator(pipeline, X_test, y_test)
plt.show()
# Out:
# 0.0

# %% [markdown]
# b. SMOTE

# %%
classifier = XGBClassifier(n_jobs=None, eval_metric='aucpr')
pipeline = Pipeline([
        ('custom_preprocessor', CustomPreprocessor()),
        ('over', SMOTE(sampling_strategy='not majority')),        
        ('classifier', classifier)
    ])
pipeline.fit(X_train, y_train)
y_pred = pipeline.predict(X_test)
cm = confusion_matrix(y_test, y_pred)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=pipeline.classes_)
disp.plot()
print(precision_score(y_test, y_pred))
PrecisionRecallDisplay.from_estimator(pipeline, X_test, y_test)
plt.show()
# Out:
# 0.0

# %% [markdown]
# balanced sampling works better than SMOTE

# %% [markdown]
# hyperparameter tuning
#
# 1. max_depth and min_child_weight

# %%
param_distributions = {
        "classifier__max_depth": [np.int64(i) for i in np.linspace(2, 1000, 50)],
        "classifier__min_child_weight": [i for i in np.linspace(0, 100, 30)]
    }
classifier = XGBClassifier(n_jobs=None, scale_pos_weight=scale_pos_weight, eval_metric='aucpr')
pipeline = Pipeline([
        ('custom_preprocessor', CustomPreprocessor()),
        ('over', SMOTE(sampling_strategy='not majority')),
        ('classifier', classifier)
    ])
random_search = run_experiment(features, param_distributions, pipeline, 
                               n_iter=50, n_splits=4, 
                               classifier=classifier)
# Out:
# Fitting 4 folds for each of 50 candidates, totalling 200 fits
# [CV 1/4; 1/50] START classifier__max_depth=755, classifier__min_child_weight=20.689655172413794
# [CV 1/4; 1/50] END classifier__max_depth=755, classifier__min_child_weight=20.689655172413794; precision: (train=0.545, test=0.094) total time=   0.5s
# [CV 2/4; 1/50] START classifier__max_depth=755, classifier__min_child_weight=20.689655172413794
# [CV 2/4; 1/50] END classifier__max_depth=755, classifier__min_child_weight=20.689655172413794; precision: (train=0.547, test=0.160) total time=   0.4s
# [CV 3/4; 1/50] START classifier__max_depth=755, classifier__min_child_weight=20.689655172413794
# [CV 3/4; 1/50] END classifier__max_depth=755, classifier__min_child_weight=20.689655172413794; precision: (train=0.569, test=0.105) total time=   0.4s
# [CV 4/4; 1/50] START classifier__max_depth=755, classifier__min_child_weight=20.689655172413794
# [CV 4/4; 1/50] END classifier__max_depth=755, classifier__min_child_weight=20.689655172413794; precision: (train=0.562, test=0.083) total time=   0.4s
# [CV 1/4; 2/50] START classifier__max_depth=918, classifier__min_child_weight=62.068965517241374
# [CV 1/4; 2/50] END classifier__max_depth=918, classifier__min_child_weight=62.068965517241374; precision: (train=0.247, test=0.077) total time=   0.4s
# [CV 2/4; 2/50] START classifier__max_depth=918, classifier__min_child_weight=62.068965517241374
# [CV 2/4; 2/50] END classifier__max_depth=918, classifier__min_child_weight=62.068965517241374; precision: (train=0.281, test=0.080) total time=   0.5s
# [CV 3/4; 2/50] START classifier__max_depth=918, classifier__min_child_weight=62.068965517241374
# [CV 3/4; 2/50] END classifier__max_depth=918, classifier__min_child_weight=62.068965517241374; precision: (train=0.241, test=0.088) total time=   0.5s
# [CV 4/4; 2/50] START classifier__max_depth=918, classifier__min_child_weight=62.068965517241374
# [CV 4/4; 2/50] END classifier__max_depth=918, classifier__min_child_weight=62.068965517241374; precision: (train=0.244, test=0.102) total time=   0.5s
# [CV 1/4; 3/50] START classifier__max_depth=287, classifier__min_child_weight=6.896551724137931
# [CV 1/4; 3/50] END classifier__max_depth=287, classifier__min_child_weight=6.896551724137931; precision: (train=0.913, test=0.143) total time=   0.5s
# [CV 2/4; 3/50] START classifier__max_depth=287, classifier__min_child_weight=6.896551724137931
# [CV 2/4; 3/50] END classifier__max_depth=287, classifier__min_child_weight=6.896551724137931; precision: (train=0.837, test=0.222) total time=   0.6s
# [CV 3/4; 3/50] START classifier__max_depth=287, classifier__min_child_weight=6.896551724137931
# [CV 3/4; 3/50] END classifier__max_depth=287, classifier__min_child_weight=6.896551724137931; precision: (train=0.911, test=0.143) total time=   0.7s
# [CV 4/4; 3/50] START classifier__max_depth=287, classifier__min_child_weight=6.896551724137931
# [CV 4/4; 3/50] END classifier__max_depth=287, classifier__min_child_weight=6.896551724137931; precision: (train=0.976, test=0.133) total time=   0.6s
# [CV 1/4; 4/50] START classifier__max_depth=266, classifier__min_child_weight=79.3103448275862
# [CV 1/4; 4/50] END classifier__max_depth=266, classifier__min_child_weight=79.3103448275862; precision: (train=0.202, test=0.064) total time=   0.5s
# [CV 2/4; 4/50] START classifier__max_depth=266, classifier__min_child_weight=79.3103448275862
# [CV 2/4; 4/50] END classifier__max_depth=266, classifier__min_child_weight=79.3103448275862; precision: (train=0.240, test=0.086) total time=   0.5s
# [CV 3/4; 4/50] START classifier__max_depth=266, classifier__min_child_weight=79.3103448275862
# [CV 3/4; 4/50] END classifier__max_depth=266, classifier__min_child_weight=79.3103448275862; precision: (train=0.199, test=0.078) total time=   0.4s
# [CV 4/4; 4/50] START classifier__max_depth=266, classifier__min_child_weight=79.3103448275862
# [CV 4/4; 4/50] END classifier__max_depth=266, classifier__min_child_weight=79.3103448275862; precision: (train=0.198, test=0.062) total time=   0.4s
# [CV 1/4; 5/50] START classifier__max_depth=307, classifier__min_child_weight=3.4482758620689653
# [CV 1/4; 5/50] END classifier__max_depth=307, classifier__min_child_weight=3.4482758620689653; precision: (train=1.000, test=0.143) total time=   0.5s
# [CV 2/4; 5/50] START classifier__max_depth=307, classifier__min_child_weight=3.4482758620689653
# [CV 2/4; 5/50] END classifier__max_depth=307, classifier__min_child_weight=3.4482758620689653; precision: (train=1.000, test=0.176) total time=   0.5s
# [CV 3/4; 5/50] START classifier__max_depth=307, classifier__min_child_weight=3.4482758620689653
# [CV 3/4; 5/50] END classifier__max_depth=307, classifier__min_child_weight=3.4482758620689653; precision: (train=0.976, test=0.222) total time=   0.5s
# [CV 4/4; 5/50] START classifier__max_depth=307, classifier__min_child_weight=3.4482758620689653
# [CV 4/4; 5/50] END classifier__max_depth=307, classifier__min_child_weight=3.4482758620689653; precision: (train=1.000, test=0.182) total time=   0.5s
# [CV 1/4; 6/50] START classifier__max_depth=572, classifier__min_child_weight=72.41379310344827
# [CV 1/4; 6/50] END classifier__max_depth=572, classifier__min_child_weight=72.41379310344827; precision: (train=0.228, test=0.070) total time=   0.4s
# [CV 2/4; 6/50] START classifier__max_depth=572, classifier__min_child_weight=72.41379310344827
# [CV 2/4; 6/50] END classifier__max_depth=572, classifier__min_child_weight=72.41379310344827; precision: (train=0.253, test=0.080) total time=   0.4s
# [CV 3/4; 6/50] START classifier__max_depth=572, classifier__min_child_weight=72.41379310344827
# [CV 3/4; 6/50] END classifier__max_depth=572, classifier__min_child_weight=72.41379310344827; precision: (train=0.202, test=0.082) total time=   0.4s
# [CV 4/4; 6/50] START classifier__max_depth=572, classifier__min_child_weight=72.41379310344827
# [CV 4/4; 6/50] END classifier__max_depth=572, classifier__min_child_weight=72.41379310344827; precision: (train=0.215, test=0.066) total time=   0.4s
# [CV 1/4; 7/50] START classifier__max_depth=714, classifier__min_child_weight=44.82758620689655
# [CV 1/4; 7/50] END classifier__max_depth=714, classifier__min_child_weight=44.82758620689655; precision: (train=0.333, test=0.088) total time=   0.4s
# [CV 2/4; 7/50] START classifier__max_depth=714, classifier__min_child_weight=44.82758620689655
# [CV 2/4; 7/50] END classifier__max_depth=714, classifier__min_child_weight=44.82758620689655; precision: (train=0.366, test=0.098) total time=   0.4s
# [CV 3/4; 7/50] START classifier__max_depth=714, classifier__min_child_weight=44.82758620689655
# [CV 3/4; 7/50] END classifier__max_depth=714, classifier__min_child_weight=44.82758620689655; precision: (train=0.295, test=0.085) total time=   0.4s
# [CV 4/4; 7/50] START classifier__max_depth=714, classifier__min_child_weight=44.82758620689655
# [CV 4/4; 7/50] END classifier__max_depth=714, classifier__min_child_weight=44.82758620689655; precision: (train=0.304, test=0.098) total time=   0.4s
# [CV 1/4; 8/50] START classifier__max_depth=490, classifier__min_child_weight=72.41379310344827
# [CV 1/4; 8/50] END classifier__max_depth=490, classifier__min_child_weight=72.41379310344827; precision: (train=0.214, test=0.066) total time=   0.4s
# [CV 2/4; 8/50] START classifier__max_depth=490, classifier__min_child_weight=72.41379310344827
# [CV 2/4; 8/50] END classifier__max_depth=490, classifier__min_child_weight=72.41379310344827; precision: (train=0.261, test=0.094) total time=   0.4s
# [CV 3/4; 8/50] START classifier__max_depth=490, classifier__min_child_weight=72.41379310344827
# [CV 3/4; 8/50] END classifier__max_depth=490, classifier__min_child_weight=72.41379310344827; precision: (train=0.237, test=0.079) total time=   0.4s
# [CV 4/4; 8/50] START classifier__max_depth=490, classifier__min_child_weight=72.41379310344827
# [CV 4/4; 8/50] END classifier__max_depth=490, classifier__min_child_weight=72.41379310344827; precision: (train=0.225, test=0.050) total time=   0.4s
# [CV 1/4; 9/50] START classifier__max_depth=857, classifier__min_child_weight=41.37931034482759
# [CV 1/4; 9/50] END classifier__max_depth=857, classifier__min_child_weight=41.37931034482759; precision: (train=0.368, test=0.098) total time=   0.4s
# [CV 2/4; 9/50] START classifier__max_depth=857, classifier__min_child_weight=41.37931034482759
# [CV 2/4; 9/50] END classifier__max_depth=857, classifier__min_child_weight=41.37931034482759; precision: (train=0.387, test=0.114) total time=   0.4s
# [CV 3/4; 9/50] START classifier__max_depth=857, classifier__min_child_weight=41.37931034482759
# [CV 3/4; 9/50] END classifier__max_depth=857, classifier__min_child_weight=41.37931034482759; precision: (train=0.328, test=0.109) total time=   0.4s
# [CV 4/4; 9/50] START classifier__max_depth=857, classifier__min_child_weight=41.37931034482759
# [CV 4/4; 9/50] END classifier__max_depth=857, classifier__min_child_weight=41.37931034482759; precision: (train=0.331, test=0.105) total time=   0.4s
# [CV 1/4; 10/50] START classifier__max_depth=164, classifier__min_child_weight=65.51724137931033
# [CV 1/4; 10/50] END classifier__max_depth=164, classifier__min_child_weight=65.51724137931033; precision: (train=0.241, test=0.069) total time=   0.4s
# [CV 2/4; 10/50] START classifier__max_depth=164, classifier__min_child_weight=65.51724137931033
# [CV 2/4; 10/50] END classifier__max_depth=164, classifier__min_child_weight=65.51724137931033; precision: (train=0.277, test=0.082) total time=   0.4s
# [CV 3/4; 10/50] START classifier__max_depth=164, classifier__min_child_weight=65.51724137931033
# [CV 3/4; 10/50] END classifier__max_depth=164, classifier__min_child_weight=65.51724137931033; precision: (train=0.230, test=0.094) total time=   0.4s
# [CV 4/4; 10/50] START classifier__max_depth=164, classifier__min_child_weight=65.51724137931033
# [CV 4/4; 10/50] END classifier__max_depth=164, classifier__min_child_weight=65.51724137931033; precision: (train=0.241, test=0.073) total time=   0.4s
# [CV 1/4; 11/50] START classifier__max_depth=592, classifier__min_child_weight=62.068965517241374
# [CV 1/4; 11/50] END classifier__max_depth=592, classifier__min_child_weight=62.068965517241374; precision: (train=0.251, test=0.076) total time=   0.4s
# [CV 2/4; 11/50] START classifier__max_depth=592, classifier__min_child_weight=62.068965517241374
# [CV 2/4; 11/50] END classifier__max_depth=592, classifier__min_child_weight=62.068965517241374; precision: (train=0.311, test=0.077) total time=   0.4s
# [CV 3/4; 11/50] START classifier__max_depth=592, classifier__min_child_weight=62.068965517241374
# [CV 3/4; 11/50] END classifier__max_depth=592, classifier__min_child_weight=62.068965517241374; precision: (train=0.234, test=0.074) total time=   0.4s
# [CV 4/4; 11/50] START classifier__max_depth=592, classifier__min_child_weight=62.068965517241374
# [CV 4/4; 11/50] END classifier__max_depth=592, classifier__min_child_weight=62.068965517241374; precision: (train=0.244, test=0.073) total time=   0.4s
# [CV 1/4; 12/50] START classifier__max_depth=959, classifier__min_child_weight=75.86206896551724
# [CV 1/4; 12/50] END classifier__max_depth=959, classifier__min_child_weight=75.86206896551724; precision: (train=0.227, test=0.077) total time=   0.4s
# [CV 2/4; 12/50] START classifier__max_depth=959, classifier__min_child_weight=75.86206896551724
# [CV 2/4; 12/50] END classifier__max_depth=959, classifier__min_child_weight=75.86206896551724; precision: (train=0.243, test=0.086) total time=   0.4s
# [CV 3/4; 12/50] START classifier__max_depth=959, classifier__min_child_weight=75.86206896551724
# [CV 3/4; 12/50] END classifier__max_depth=959, classifier__min_child_weight=75.86206896551724; precision: (train=0.220, test=0.072) total time=   0.5s
# [CV 4/4; 12/50] START classifier__max_depth=959, classifier__min_child_weight=75.86206896551724
# [CV 4/4; 12/50] END classifier__max_depth=959, classifier__min_child_weight=75.86206896551724; precision: (train=0.214, test=0.065) total time=   0.5s
# [CV 1/4; 13/50] START classifier__max_depth=470, classifier__min_child_weight=75.86206896551724
# [CV 1/4; 13/50] END classifier__max_depth=470, classifier__min_child_weight=75.86206896551724; precision: (train=0.226, test=0.078) total time=   0.5s
# [CV 2/4; 13/50] START classifier__max_depth=470, classifier__min_child_weight=75.86206896551724
# [CV 2/4; 13/50] END classifier__max_depth=470, classifier__min_child_weight=75.86206896551724; precision: (train=0.244, test=0.085) total time=   0.4s
# [CV 3/4; 13/50] START classifier__max_depth=470, classifier__min_child_weight=75.86206896551724
# [CV 3/4; 13/50] END classifier__max_depth=470, classifier__min_child_weight=75.86206896551724; precision: (train=0.212, test=0.087) total time=   0.4s
# [CV 4/4; 13/50] START classifier__max_depth=470, classifier__min_child_weight=75.86206896551724
# [CV 4/4; 13/50] END classifier__max_depth=470, classifier__min_child_weight=75.86206896551724; precision: (train=0.203, test=0.070) total time=   0.5s
# [CV 1/4; 14/50] START classifier__max_depth=938, classifier__min_child_weight=6.896551724137931
# [CV 1/4; 14/50] END classifier__max_depth=938, classifier__min_child_weight=6.896551724137931; precision: (train=0.933, test=0.143) total time=   0.5s
# [CV 2/4; 14/50] START classifier__max_depth=938, classifier__min_child_weight=6.896551724137931
# [CV 2/4; 14/50] END classifier__max_depth=938, classifier__min_child_weight=6.896551724137931; precision: (train=0.872, test=0.158) total time=   0.5s
# [CV 3/4; 14/50] START classifier__max_depth=938, classifier__min_child_weight=6.896551724137931
# [CV 3/4; 14/50] END classifier__max_depth=938, classifier__min_child_weight=6.896551724137931; precision: (train=0.953, test=0.136) total time=   0.5s
# [CV 4/4; 14/50] START classifier__max_depth=938, classifier__min_child_weight=6.896551724137931
# [CV 4/4; 14/50] END classifier__max_depth=938, classifier__min_child_weight=6.896551724137931; precision: (train=0.953, test=0.150) total time=   0.6s
# [CV 1/4; 15/50] START classifier__max_depth=42, classifier__min_child_weight=34.48275862068965
# [CV 1/4; 15/50] END classifier__max_depth=42, classifier__min_child_weight=34.48275862068965; precision: (train=0.442, test=0.111) total time=   0.5s
# [CV 2/4; 15/50] START classifier__max_depth=42, classifier__min_child_weight=34.48275862068965
# [CV 2/4; 15/50] END classifier__max_depth=42, classifier__min_child_weight=34.48275862068965; precision: (train=0.446, test=0.103) total time=   0.4s
# [CV 3/4; 15/50] START classifier__max_depth=42, classifier__min_child_weight=34.48275862068965
# [CV 3/4; 15/50] END classifier__max_depth=42, classifier__min_child_weight=34.48275862068965; precision: (train=0.366, test=0.087) total time=   0.5s
# [CV 4/4; 15/50] START classifier__max_depth=42, classifier__min_child_weight=34.48275862068965
# [CV 4/4; 15/50] END classifier__max_depth=42, classifier__min_child_weight=34.48275862068965; precision: (train=0.363, test=0.125) total time=   0.5s
# [CV 1/4; 16/50] START classifier__max_depth=857, classifier__min_child_weight=27.586206896551722
# [CV 1/4; 16/50] END classifier__max_depth=857, classifier__min_child_weight=27.586206896551722; precision: (train=0.500, test=0.135) total time=   0.5s
# [CV 2/4; 16/50] START classifier__max_depth=857, classifier__min_child_weight=27.586206896551722
# [CV 2/4; 16/50] END classifier__max_depth=857, classifier__min_child_weight=27.586206896551722; precision: (train=0.482, test=0.148) total time=   0.5s
# [CV 3/4; 16/50] START classifier__max_depth=857, classifier__min_child_weight=27.586206896551722
# [CV 3/4; 16/50] END classifier__max_depth=857, classifier__min_child_weight=27.586206896551722; precision: (train=0.436, test=0.056) total time=   0.5s
# [CV 4/4; 16/50] START classifier__max_depth=857, classifier__min_child_weight=27.586206896551722
# [CV 4/4; 16/50] END classifier__max_depth=857, classifier__min_child_weight=27.586206896551722; precision: (train=0.471, test=0.148) total time=   0.5s
# [CV 1/4; 17/50] START classifier__max_depth=1000, classifier__min_child_weight=72.41379310344827
# [CV 1/4; 17/50] END classifier__max_depth=1000, classifier__min_child_weight=72.41379310344827; precision: (train=0.230, test=0.072) total time=   0.4s
# [CV 2/4; 17/50] START classifier__max_depth=1000, classifier__min_child_weight=72.41379310344827
# [CV 2/4; 17/50] END classifier__max_depth=1000, classifier__min_child_weight=72.41379310344827; precision: (train=0.248, test=0.094) total time=   0.4s
# [CV 3/4; 17/50] START classifier__max_depth=1000, classifier__min_child_weight=72.41379310344827
# [CV 3/4; 17/50] END classifier__max_depth=1000, classifier__min_child_weight=72.41379310344827; precision: (train=0.216, test=0.082) total time=   0.5s
# [CV 4/4; 17/50] START classifier__max_depth=1000, classifier__min_child_weight=72.41379310344827
# [CV 4/4; 17/50] END classifier__max_depth=1000, classifier__min_child_weight=72.41379310344827; precision: (train=0.244, test=0.059) total time=   0.4s
# [CV 1/4; 18/50] START classifier__max_depth=409, classifier__min_child_weight=24.137931034482758
# [CV 1/4; 18/50] END classifier__max_depth=409, classifier__min_child_weight=24.137931034482758; precision: (train=0.545, test=0.079) total time=   0.5s
# [CV 2/4; 18/50] START classifier__max_depth=409, classifier__min_child_weight=24.137931034482758
# [CV 2/4; 18/50] END classifier__max_depth=409, classifier__min_child_weight=24.137931034482758; precision: (train=0.519, test=0.125) total time=   0.4s
# [CV 3/4; 18/50] START classifier__max_depth=409, classifier__min_child_weight=24.137931034482758
# [CV 3/4; 18/50] END classifier__max_depth=409, classifier__min_child_weight=24.137931034482758; precision: (train=0.423, test=0.114) total time=   0.5s
# [CV 4/4; 18/50] START classifier__max_depth=409, classifier__min_child_weight=24.137931034482758
# [CV 4/4; 18/50] END classifier__max_depth=409, classifier__min_child_weight=24.137931034482758; precision: (train=0.471, test=0.111) total time=   0.5s
# [CV 1/4; 19/50] START classifier__max_depth=287, classifier__min_child_weight=44.82758620689655
# [CV 1/4; 19/50] END classifier__max_depth=287, classifier__min_child_weight=44.82758620689655; precision: (train=0.328, test=0.109) total time=   0.5s
# [CV 2/4; 19/50] START classifier__max_depth=287, classifier__min_child_weight=44.82758620689655
# [CV 2/4; 19/50] END classifier__max_depth=287, classifier__min_child_weight=44.82758620689655; precision: (train=0.376, test=0.098) total time=   0.4s
# [CV 3/4; 19/50] START classifier__max_depth=287, classifier__min_child_weight=44.82758620689655
# [CV 3/4; 19/50] END classifier__max_depth=287, classifier__min_child_weight=44.82758620689655; precision: (train=0.297, test=0.122) total time=   0.4s
# [CV 4/4; 19/50] START classifier__max_depth=287, classifier__min_child_weight=44.82758620689655
# [CV 4/4; 19/50] END classifier__max_depth=287, classifier__min_child_weight=44.82758620689655; precision: (train=0.325, test=0.098) total time=   0.4s
# [CV 1/4; 20/50] START classifier__max_depth=22, classifier__min_child_weight=72.41379310344827
# [CV 1/4; 20/50] END classifier__max_depth=22, classifier__min_child_weight=72.41379310344827; precision: (train=0.233, test=0.080) total time=   0.4s
# [CV 2/4; 20/50] START classifier__max_depth=22, classifier__min_child_weight=72.41379310344827
# [CV 2/4; 20/50] END classifier__max_depth=22, classifier__min_child_weight=72.41379310344827; precision: (train=0.258, test=0.074) total time=   0.4s
# [CV 3/4; 20/50] START classifier__max_depth=22, classifier__min_child_weight=72.41379310344827
# [CV 3/4; 20/50] END classifier__max_depth=22, classifier__min_child_weight=72.41379310344827; precision: (train=0.224, test=0.077) total time=   0.5s
# [CV 4/4; 20/50] START classifier__max_depth=22, classifier__min_child_weight=72.41379310344827
# [CV 4/4; 20/50] END classifier__max_depth=22, classifier__min_child_weight=72.41379310344827; precision: (train=0.223, test=0.053) total time=   0.5s
# [CV 1/4; 21/50] START classifier__max_depth=796, classifier__min_child_weight=100.0
# [CV 1/4; 21/50] END classifier__max_depth=796, classifier__min_child_weight=100.0; precision: (train=0.174, test=0.065) total time=   0.4s
# [CV 2/4; 21/50] START classifier__max_depth=796, classifier__min_child_weight=100.0
# [CV 2/4; 21/50] END classifier__max_depth=796, classifier__min_child_weight=100.0; precision: (train=0.197, test=0.066) total time=   0.4s
# [CV 3/4; 21/50] START classifier__max_depth=796, classifier__min_child_weight=100.0
# [CV 3/4; 21/50] END classifier__max_depth=796, classifier__min_child_weight=100.0; precision: (train=0.177, test=0.061) total time=   0.4s
# [CV 4/4; 21/50] START classifier__max_depth=796, classifier__min_child_weight=100.0
# [CV 4/4; 21/50] END classifier__max_depth=796, classifier__min_child_weight=100.0; precision: (train=0.168, test=0.040) total time=   0.4s
# [CV 1/4; 22/50] START classifier__max_depth=755, classifier__min_child_weight=62.068965517241374
# [CV 1/4; 22/50] END classifier__max_depth=755, classifier__min_child_weight=62.068965517241374; precision: (train=0.273, test=0.062) total time=   0.5s
# [CV 2/4; 22/50] START classifier__max_depth=755, classifier__min_child_weight=62.068965517241374
# [CV 2/4; 22/50] END classifier__max_depth=755, classifier__min_child_weight=62.068965517241374; precision: (train=0.285, test=0.091) total time=   0.4s
# [CV 3/4; 22/50] START classifier__max_depth=755, classifier__min_child_weight=62.068965517241374
# [CV 3/4; 22/50] END classifier__max_depth=755, classifier__min_child_weight=62.068965517241374; precision: (train=0.238, test=0.082) total time=   0.4s
# [CV 4/4; 22/50] START classifier__max_depth=755, classifier__min_child_weight=62.068965517241374
# [CV 4/4; 22/50] END classifier__max_depth=755, classifier__min_child_weight=62.068965517241374; precision: (train=0.248, test=0.078) total time=   0.4s
# [CV 1/4; 23/50] START classifier__max_depth=796, classifier__min_child_weight=68.9655172413793
# [CV 1/4; 23/50] END classifier__max_depth=796, classifier__min_child_weight=68.9655172413793; precision: (train=0.237, test=0.072) total time=   0.4s
# [CV 2/4; 23/50] START classifier__max_depth=796, classifier__min_child_weight=68.9655172413793
# [CV 2/4; 23/50] END classifier__max_depth=796, classifier__min_child_weight=68.9655172413793; precision: (train=0.272, test=0.080) total time=   0.4s
# [CV 3/4; 23/50] START classifier__max_depth=796, classifier__min_child_weight=68.9655172413793
# [CV 3/4; 23/50] END classifier__max_depth=796, classifier__min_child_weight=68.9655172413793; precision: (train=0.224, test=0.082) total time=   0.4s
# [CV 4/4; 23/50] START classifier__max_depth=796, classifier__min_child_weight=68.9655172413793
# [CV 4/4; 23/50] END classifier__max_depth=796, classifier__min_child_weight=68.9655172413793; precision: (train=0.223, test=0.075) total time=   0.4s
# [CV 1/4; 24/50] START classifier__max_depth=837, classifier__min_child_weight=65.51724137931033
# [CV 1/4; 24/50] END classifier__max_depth=837, classifier__min_child_weight=65.51724137931033; precision: (train=0.250, test=0.072) total time=   0.4s
# [CV 2/4; 24/50] START classifier__max_depth=837, classifier__min_child_weight=65.51724137931033
# [CV 2/4; 24/50] END classifier__max_depth=837, classifier__min_child_weight=65.51724137931033; precision: (train=0.265, test=0.078) total time=   0.4s
# [CV 3/4; 24/50] START classifier__max_depth=837, classifier__min_child_weight=65.51724137931033
# [CV 3/4; 24/50] END classifier__max_depth=837, classifier__min_child_weight=65.51724137931033; precision: (train=0.234, test=0.060) total time=   0.4s
# [CV 4/4; 24/50] START classifier__max_depth=837, classifier__min_child_weight=65.51724137931033
# [CV 4/4; 24/50] END classifier__max_depth=837, classifier__min_child_weight=65.51724137931033; precision: (train=0.233, test=0.077) total time=   0.5s
# [CV 1/4; 25/50] START classifier__max_depth=959, classifier__min_child_weight=31.034482758620687
# [CV 1/4; 25/50] END classifier__max_depth=959, classifier__min_child_weight=31.034482758620687; precision: (train=0.477, test=0.098) total time=   0.5s
# [CV 2/4; 25/50] START classifier__max_depth=959, classifier__min_child_weight=31.034482758620687
# [CV 2/4; 25/50] END classifier__max_depth=959, classifier__min_child_weight=31.034482758620687; precision: (train=0.461, test=0.111) total time=   0.5s
# [CV 3/4; 25/50] START classifier__max_depth=959, classifier__min_child_weight=31.034482758620687
# [CV 3/4; 25/50] END classifier__max_depth=959, classifier__min_child_weight=31.034482758620687; precision: (train=0.380, test=0.103) total time=   0.5s
# [CV 4/4; 25/50] START classifier__max_depth=959, classifier__min_child_weight=31.034482758620687
# [CV 4/4; 25/50] END classifier__max_depth=959, classifier__min_child_weight=31.034482758620687; precision: (train=0.414, test=0.111) total time=   0.5s
# [CV 1/4; 26/50] START classifier__max_depth=287, classifier__min_child_weight=41.37931034482759
# [CV 1/4; 26/50] END classifier__max_depth=287, classifier__min_child_weight=41.37931034482759; precision: (train=0.362, test=0.102) total time=   0.5s
# [CV 2/4; 26/50] START classifier__max_depth=287, classifier__min_child_weight=41.37931034482759
# [CV 2/4; 26/50] END classifier__max_depth=287, classifier__min_child_weight=41.37931034482759; precision: (train=0.366, test=0.114) total time=   0.4s
# [CV 3/4; 26/50] START classifier__max_depth=287, classifier__min_child_weight=41.37931034482759
# [CV 3/4; 26/50] END classifier__max_depth=287, classifier__min_child_weight=41.37931034482759; precision: (train=0.331, test=0.074) total time=   0.5s
# [CV 4/4; 26/50] START classifier__max_depth=287, classifier__min_child_weight=41.37931034482759
# [CV 4/4; 26/50] END classifier__max_depth=287, classifier__min_child_weight=41.37931034482759; precision: (train=0.323, test=0.108) total time=   0.4s
# [CV 1/4; 27/50] START classifier__max_depth=979, classifier__min_child_weight=41.37931034482759
# [CV 1/4; 27/50] END classifier__max_depth=979, classifier__min_child_weight=41.37931034482759; precision: (train=0.344, test=0.080) total time=   0.5s
# [CV 2/4; 27/50] START classifier__max_depth=979, classifier__min_child_weight=41.37931034482759
# [CV 2/4; 27/50] END classifier__max_depth=979, classifier__min_child_weight=41.37931034482759; precision: (train=0.398, test=0.129) total time=   0.5s
# [CV 3/4; 27/50] START classifier__max_depth=979, classifier__min_child_weight=41.37931034482759
# [CV 3/4; 27/50] END classifier__max_depth=979, classifier__min_child_weight=41.37931034482759; precision: (train=0.325, test=0.104) total time=   0.5s
# [CV 4/4; 27/50] START classifier__max_depth=979, classifier__min_child_weight=41.37931034482759
# [CV 4/4; 27/50] END classifier__max_depth=979, classifier__min_child_weight=41.37931034482759; precision: (train=0.333, test=0.079) total time=   0.4s
# [CV 1/4; 28/50] START classifier__max_depth=1000, classifier__min_child_weight=0.0
# [CV 1/4; 28/50] END classifier__max_depth=1000, classifier__min_child_weight=0.0; precision: (train=1.000, test=0.077) total time=   1.4s
# [CV 2/4; 28/50] START classifier__max_depth=1000, classifier__min_child_weight=0.0
# [CV 2/4; 28/50] END classifier__max_depth=1000, classifier__min_child_weight=0.0; precision: (train=1.000, test=0.133) total time=   1.3s
# [CV 3/4; 28/50] START classifier__max_depth=1000, classifier__min_child_weight=0.0
# [CV 3/4; 28/50] END classifier__max_depth=1000, classifier__min_child_weight=0.0; precision: (train=1.000, test=0.182) total time=   1.4s
# [CV 4/4; 28/50] START classifier__max_depth=1000, classifier__min_child_weight=0.0
# [CV 4/4; 28/50] END classifier__max_depth=1000, classifier__min_child_weight=0.0; precision: (train=1.000, test=0.250) total time=   1.4s
# [CV 1/4; 29/50] START classifier__max_depth=837, classifier__min_child_weight=13.793103448275861
# [CV 1/4; 29/50] END classifier__max_depth=837, classifier__min_child_weight=13.793103448275861; precision: (train=0.764, test=0.115) total time=   0.5s
# [CV 2/4; 29/50] START classifier__max_depth=837, classifier__min_child_weight=13.793103448275861
# [CV 2/4; 29/50] END classifier__max_depth=837, classifier__min_child_weight=13.793103448275861; precision: (train=0.672, test=0.174) total time=   0.5s
# [CV 3/4; 29/50] START classifier__max_depth=837, classifier__min_child_weight=13.793103448275861
# [CV 3/4; 29/50] END classifier__max_depth=837, classifier__min_child_weight=13.793103448275861; precision: (train=0.641, test=0.154) total time=   0.5s
# [CV 4/4; 29/50] START classifier__max_depth=837, classifier__min_child_weight=13.793103448275861
# [CV 4/4; 29/50] END classifier__max_depth=837, classifier__min_child_weight=13.793103448275861; precision: (train=0.759, test=0.150) total time=   0.5s
# [CV 1/4; 30/50] START classifier__max_depth=857, classifier__min_child_weight=72.41379310344827
# [CV 1/4; 30/50] END classifier__max_depth=857, classifier__min_child_weight=72.41379310344827; precision: (train=0.230, test=0.076) total time=   0.5s
# [CV 2/4; 30/50] START classifier__max_depth=857, classifier__min_child_weight=72.41379310344827
# [CV 2/4; 30/50] END classifier__max_depth=857, classifier__min_child_weight=72.41379310344827; precision: (train=0.258, test=0.080) total time=   0.4s
# [CV 3/4; 30/50] START classifier__max_depth=857, classifier__min_child_weight=72.41379310344827
# [CV 3/4; 30/50] END classifier__max_depth=857, classifier__min_child_weight=72.41379310344827; precision: (train=0.218, test=0.071) total time=   0.4s
# [CV 4/4; 30/50] START classifier__max_depth=857, classifier__min_child_weight=72.41379310344827
# [CV 4/4; 30/50] END classifier__max_depth=857, classifier__min_child_weight=72.41379310344827; precision: (train=0.214, test=0.081) total time=   0.4s
# [CV 1/4; 31/50] START classifier__max_depth=735, classifier__min_child_weight=17.241379310344826
# [CV 1/4; 31/50] END classifier__max_depth=735, classifier__min_child_weight=17.241379310344826; precision: (train=0.646, test=0.074) total time=   0.5s
# [CV 2/4; 31/50] START classifier__max_depth=735, classifier__min_child_weight=17.241379310344826
# [CV 2/4; 31/50] END classifier__max_depth=735, classifier__min_child_weight=17.241379310344826; precision: (train=0.683, test=0.167) total time=   0.5s
# [CV 3/4; 31/50] START classifier__max_depth=735, classifier__min_child_weight=17.241379310344826
# [CV 3/4; 31/50] END classifier__max_depth=735, classifier__min_child_weight=17.241379310344826; precision: (train=0.554, test=0.100) total time=   0.5s
# [CV 4/4; 31/50] START classifier__max_depth=735, classifier__min_child_weight=17.241379310344826
# [CV 4/4; 31/50] END classifier__max_depth=735, classifier__min_child_weight=17.241379310344826; precision: (train=0.651, test=0.167) total time=   0.5s
# [CV 1/4; 32/50] START classifier__max_depth=409, classifier__min_child_weight=34.48275862068965
# [CV 1/4; 32/50] END classifier__max_depth=409, classifier__min_child_weight=34.48275862068965; precision: (train=0.389, test=0.114) total time=   0.5s
# [CV 2/4; 32/50] START classifier__max_depth=409, classifier__min_child_weight=34.48275862068965
# [CV 2/4; 32/50] END classifier__max_depth=409, classifier__min_child_weight=34.48275862068965; precision: (train=0.427, test=0.114) total time=   0.4s
# [CV 3/4; 32/50] START classifier__max_depth=409, classifier__min_child_weight=34.48275862068965
# [CV 3/4; 32/50] END classifier__max_depth=409, classifier__min_child_weight=34.48275862068965; precision: (train=0.363, test=0.080) total time=   0.5s
# [CV 4/4; 32/50] START classifier__max_depth=409, classifier__min_child_weight=34.48275862068965
# [CV 4/4; 32/50] END classifier__max_depth=409, classifier__min_child_weight=34.48275862068965; precision: (train=0.350, test=0.061) total time=   0.4s
# [CV 1/4; 33/50] START classifier__max_depth=857, classifier__min_child_weight=82.75862068965517
# [CV 1/4; 33/50] END classifier__max_depth=857, classifier__min_child_weight=82.75862068965517; precision: (train=0.210, test=0.080) total time=   0.4s
# [CV 2/4; 33/50] START classifier__max_depth=857, classifier__min_child_weight=82.75862068965517
# [CV 2/4; 33/50] END classifier__max_depth=857, classifier__min_child_weight=82.75862068965517; precision: (train=0.228, test=0.068) total time=   0.4s
# [CV 3/4; 33/50] START classifier__max_depth=857, classifier__min_child_weight=82.75862068965517
# [CV 3/4; 33/50] END classifier__max_depth=857, classifier__min_child_weight=82.75862068965517; precision: (train=0.194, test=0.066) total time=   0.4s
# [CV 4/4; 33/50] START classifier__max_depth=857, classifier__min_child_weight=82.75862068965517
# [CV 4/4; 33/50] END classifier__max_depth=857, classifier__min_child_weight=82.75862068965517; precision: (train=0.207, test=0.063) total time=   0.4s
# [CV 1/4; 34/50] START classifier__max_depth=694, classifier__min_child_weight=72.41379310344827
# [CV 1/4; 34/50] END classifier__max_depth=694, classifier__min_child_weight=72.41379310344827; precision: (train=0.233, test=0.070) total time=   0.4s
# [CV 2/4; 34/50] START classifier__max_depth=694, classifier__min_child_weight=72.41379310344827
# [CV 2/4; 34/50] END classifier__max_depth=694, classifier__min_child_weight=72.41379310344827; precision: (train=0.240, test=0.088) total time=   0.4s
# [CV 3/4; 34/50] START classifier__max_depth=694, classifier__min_child_weight=72.41379310344827
# [CV 3/4; 34/50] END classifier__max_depth=694, classifier__min_child_weight=72.41379310344827; precision: (train=0.219, test=0.080) total time=   0.4s
# [CV 4/4; 34/50] START classifier__max_depth=694, classifier__min_child_weight=72.41379310344827
# [CV 4/4; 34/50] END classifier__max_depth=694, classifier__min_child_weight=72.41379310344827; precision: (train=0.216, test=0.089) total time=   0.4s
# [CV 1/4; 35/50] START classifier__max_depth=144, classifier__min_child_weight=34.48275862068965
# [CV 1/4; 35/50] END classifier__max_depth=144, classifier__min_child_weight=34.48275862068965; precision: (train=0.396, test=0.104) total time=   0.5s
# [CV 2/4; 35/50] START classifier__max_depth=144, classifier__min_child_weight=34.48275862068965
# [CV 2/4; 35/50] END classifier__max_depth=144, classifier__min_child_weight=34.48275862068965; precision: (train=0.394, test=0.091) total time=   0.4s
# [CV 3/4; 35/50] START classifier__max_depth=144, classifier__min_child_weight=34.48275862068965
# [CV 3/4; 35/50] END classifier__max_depth=144, classifier__min_child_weight=34.48275862068965; precision: (train=0.373, test=0.077) total time=   0.5s
# [CV 4/4; 35/50] START classifier__max_depth=144, classifier__min_child_weight=34.48275862068965
# [CV 4/4; 35/50] END classifier__max_depth=144, classifier__min_child_weight=34.48275862068965; precision: (train=0.353, test=0.100) total time=   0.5s
# [CV 1/4; 36/50] START classifier__max_depth=226, classifier__min_child_weight=31.034482758620687
# [CV 1/4; 36/50] END classifier__max_depth=226, classifier__min_child_weight=31.034482758620687; precision: (train=0.438, test=0.100) total time=   0.5s
# [CV 2/4; 36/50] START classifier__max_depth=226, classifier__min_child_weight=31.034482758620687
# [CV 2/4; 36/50] END classifier__max_depth=226, classifier__min_child_weight=31.034482758620687; precision: (train=0.451, test=0.129) total time=   0.4s
# [CV 3/4; 36/50] START classifier__max_depth=226, classifier__min_child_weight=31.034482758620687
# [CV 3/4; 36/50] END classifier__max_depth=226, classifier__min_child_weight=31.034482758620687; precision: (train=0.398, test=0.119) total time=   0.5s
# [CV 4/4; 36/50] START classifier__max_depth=226, classifier__min_child_weight=31.034482758620687
# [CV 4/4; 36/50] END classifier__max_depth=226, classifier__min_child_weight=31.034482758620687; precision: (train=0.427, test=0.083) total time=   0.5s
# [CV 1/4; 37/50] START classifier__max_depth=287, classifier__min_child_weight=10.344827586206897
# [CV 1/4; 37/50] END classifier__max_depth=287, classifier__min_child_weight=10.344827586206897; precision: (train=0.894, test=0.091) total time=   0.5s
# [CV 2/4; 37/50] START classifier__max_depth=287, classifier__min_child_weight=10.344827586206897
# [CV 2/4; 37/50] END classifier__max_depth=287, classifier__min_child_weight=10.344827586206897; precision: (train=0.774, test=0.174) total time=   0.5s
# [CV 3/4; 37/50] START classifier__max_depth=287, classifier__min_child_weight=10.344827586206897
# [CV 3/4; 37/50] END classifier__max_depth=287, classifier__min_child_weight=10.344827586206897; precision: (train=0.820, test=0.083) total time=   0.5s
# [CV 4/4; 37/50] START classifier__max_depth=287, classifier__min_child_weight=10.344827586206897
# [CV 4/4; 37/50] END classifier__max_depth=287, classifier__min_child_weight=10.344827586206897; precision: (train=0.837, test=0.118) total time=   0.5s
# [CV 1/4; 38/50] START classifier__max_depth=287, classifier__min_child_weight=27.586206896551722
# [CV 1/4; 38/50] END classifier__max_depth=287, classifier__min_child_weight=27.586206896551722; precision: (train=0.483, test=0.111) total time=   0.5s
# [CV 2/4; 38/50] START classifier__max_depth=287, classifier__min_child_weight=27.586206896551722
# [CV 2/4; 38/50] END classifier__max_depth=287, classifier__min_child_weight=27.586206896551722; precision: (train=0.494, test=0.138) total time=   0.5s
# [CV 3/4; 38/50] START classifier__max_depth=287, classifier__min_child_weight=27.586206896551722
# [CV 3/4; 38/50] END classifier__max_depth=287, classifier__min_child_weight=27.586206896551722; precision: (train=0.398, test=0.091) total time=   0.5s
# [CV 4/4; 38/50] START classifier__max_depth=287, classifier__min_child_weight=27.586206896551722
# [CV 4/4; 38/50] END classifier__max_depth=287, classifier__min_child_weight=27.586206896551722; precision: (train=0.441, test=0.115) total time=   0.5s
# [CV 1/4; 39/50] START classifier__max_depth=735, classifier__min_child_weight=86.20689655172413
# [CV 1/4; 39/50] END classifier__max_depth=735, classifier__min_child_weight=86.20689655172413; precision: (train=0.192, test=0.063) total time=   0.4s
# [CV 2/4; 39/50] START classifier__max_depth=735, classifier__min_child_weight=86.20689655172413
# [CV 2/4; 39/50] END classifier__max_depth=735, classifier__min_child_weight=86.20689655172413; precision: (train=0.228, test=0.091) total time=   0.4s
# [CV 3/4; 39/50] START classifier__max_depth=735, classifier__min_child_weight=86.20689655172413
# [CV 3/4; 39/50] END classifier__max_depth=735, classifier__min_child_weight=86.20689655172413; precision: (train=0.194, test=0.075) total time=   0.4s
# [CV 4/4; 39/50] START classifier__max_depth=735, classifier__min_child_weight=86.20689655172413
# [CV 4/4; 39/50] END classifier__max_depth=735, classifier__min_child_weight=86.20689655172413; precision: (train=0.182, test=0.063) total time=   0.4s
# [CV 1/4; 40/50] START classifier__max_depth=42, classifier__min_child_weight=55.172413793103445
# [CV 1/4; 40/50] END classifier__max_depth=42, classifier__min_child_weight=55.172413793103445; precision: (train=0.300, test=0.091) total time=   0.5s
# [CV 2/4; 40/50] START classifier__max_depth=42, classifier__min_child_weight=55.172413793103445
# [CV 2/4; 40/50] END classifier__max_depth=42, classifier__min_child_weight=55.172413793103445; precision: (train=0.323, test=0.098) total time=   0.4s
# [CV 3/4; 40/50] START classifier__max_depth=42, classifier__min_child_weight=55.172413793103445
# [CV 3/4; 40/50] END classifier__max_depth=42, classifier__min_child_weight=55.172413793103445; precision: (train=0.266, test=0.091) total time=   0.5s
# [CV 4/4; 40/50] START classifier__max_depth=42, classifier__min_child_weight=55.172413793103445
# [CV 4/4; 40/50] END classifier__max_depth=42, classifier__min_child_weight=55.172413793103445; precision: (train=0.270, test=0.068) total time=   0.5s
# [CV 1/4; 41/50] START classifier__max_depth=938, classifier__min_child_weight=37.93103448275862
# [CV 1/4; 41/50] END classifier__max_depth=938, classifier__min_child_weight=37.93103448275862; precision: (train=0.389, test=0.094) total time=   0.5s
# [CV 2/4; 41/50] START classifier__max_depth=938, classifier__min_child_weight=37.93103448275862
# [CV 2/4; 41/50] END classifier__max_depth=938, classifier__min_child_weight=37.93103448275862; precision: (train=0.436, test=0.091) total time=   0.5s
# [CV 3/4; 41/50] START classifier__max_depth=938, classifier__min_child_weight=37.93103448275862
# [CV 3/4; 41/50] END classifier__max_depth=938, classifier__min_child_weight=37.93103448275862; precision: (train=0.339, test=0.104) total time=   0.5s
# [CV 4/4; 41/50] START classifier__max_depth=938, classifier__min_child_weight=37.93103448275862
# [CV 4/4; 41/50] END classifier__max_depth=938, classifier__min_child_weight=37.93103448275862; precision: (train=0.336, test=0.114) total time=   0.5s
# [CV 1/4; 42/50] START classifier__max_depth=287, classifier__min_child_weight=65.51724137931033
# [CV 1/4; 42/50] END classifier__max_depth=287, classifier__min_child_weight=65.51724137931033; precision: (train=0.259, test=0.072) total time=   0.5s
# [CV 2/4; 42/50] START classifier__max_depth=287, classifier__min_child_weight=65.51724137931033
# [CV 2/4; 42/50] END classifier__max_depth=287, classifier__min_child_weight=65.51724137931033; precision: (train=0.270, test=0.082) total time=   0.5s
# [CV 3/4; 42/50] START classifier__max_depth=287, classifier__min_child_weight=65.51724137931033
# [CV 3/4; 42/50] END classifier__max_depth=287, classifier__min_child_weight=65.51724137931033; precision: (train=0.217, test=0.070) total time=   0.4s
# [CV 4/4; 42/50] START classifier__max_depth=287, classifier__min_child_weight=65.51724137931033
# [CV 4/4; 42/50] END classifier__max_depth=287, classifier__min_child_weight=65.51724137931033; precision: (train=0.232, test=0.081) total time=   0.4s
# [CV 1/4; 43/50] START classifier__max_depth=898, classifier__min_child_weight=55.172413793103445
# [CV 1/4; 43/50] END classifier__max_depth=898, classifier__min_child_weight=55.172413793103445; precision: (train=0.278, test=0.082) total time=   0.5s
# [CV 2/4; 43/50] START classifier__max_depth=898, classifier__min_child_weight=55.172413793103445
# [CV 2/4; 43/50] END classifier__max_depth=898, classifier__min_child_weight=55.172413793103445; precision: (train=0.293, test=0.095) total time=   0.4s
# [CV 3/4; 43/50] START classifier__max_depth=898, classifier__min_child_weight=55.172413793103445
# [CV 3/4; 43/50] END classifier__max_depth=898, classifier__min_child_weight=55.172413793103445; precision: (train=0.253, test=0.103) total time=   0.5s
# [CV 4/4; 43/50] START classifier__max_depth=898, classifier__min_child_weight=55.172413793103445
# [CV 4/4; 43/50] END classifier__max_depth=898, classifier__min_child_weight=55.172413793103445; precision: (train=0.287, test=0.068) total time=   0.4s
# [CV 1/4; 44/50] START classifier__max_depth=572, classifier__min_child_weight=82.75862068965517
# [CV 1/4; 44/50] END classifier__max_depth=572, classifier__min_child_weight=82.75862068965517; precision: (train=0.200, test=0.079) total time=   0.5s
# [CV 2/4; 44/50] START classifier__max_depth=572, classifier__min_child_weight=82.75862068965517
# [CV 2/4; 44/50] END classifier__max_depth=572, classifier__min_child_weight=82.75862068965517; precision: (train=0.219, test=0.082) total time=   0.4s
# [CV 3/4; 44/50] START classifier__max_depth=572, classifier__min_child_weight=82.75862068965517
# [CV 3/4; 44/50] END classifier__max_depth=572, classifier__min_child_weight=82.75862068965517; precision: (train=0.195, test=0.066) total time=   0.4s
# [CV 4/4; 44/50] START classifier__max_depth=572, classifier__min_child_weight=82.75862068965517
# [CV 4/4; 44/50] END classifier__max_depth=572, classifier__min_child_weight=82.75862068965517; precision: (train=0.193, test=0.057) total time=   0.4s
# [CV 1/4; 45/50] START classifier__max_depth=735, classifier__min_child_weight=0.0
# [CV 1/4; 45/50] END classifier__max_depth=735, classifier__min_child_weight=0.0; precision: (train=1.000, test=0.154) total time=   1.4s
# [CV 2/4; 45/50] START classifier__max_depth=735, classifier__min_child_weight=0.0
# [CV 2/4; 45/50] END classifier__max_depth=735, classifier__min_child_weight=0.0; precision: (train=1.000, test=0.200) total time=   1.2s
# [CV 3/4; 45/50] START classifier__max_depth=735, classifier__min_child_weight=0.0
# [CV 3/4; 45/50] END classifier__max_depth=735, classifier__min_child_weight=0.0; precision: (train=1.000, test=0.111) total time=   1.4s
# [CV 4/4; 45/50] START classifier__max_depth=735, classifier__min_child_weight=0.0
# [CV 4/4; 45/50] END classifier__max_depth=735, classifier__min_child_weight=0.0; precision: (train=1.000, test=0.500) total time=   1.4s
# [CV 1/4; 46/50] START classifier__max_depth=226, classifier__min_child_weight=82.75862068965517
# [CV 1/4; 46/50] END classifier__max_depth=226, classifier__min_child_weight=82.75862068965517; precision: (train=0.205, test=0.074) total time=   0.4s
# [CV 2/4; 46/50] START classifier__max_depth=226, classifier__min_child_weight=82.75862068965517
# [CV 2/4; 46/50] END classifier__max_depth=226, classifier__min_child_weight=82.75862068965517; precision: (train=0.215, test=0.070) total time=   0.4s
# [CV 3/4; 46/50] START classifier__max_depth=226, classifier__min_child_weight=82.75862068965517
# [CV 3/4; 46/50] END classifier__max_depth=226, classifier__min_child_weight=82.75862068965517; precision: (train=0.194, test=0.073) total time=   0.4s
# [CV 4/4; 46/50] START classifier__max_depth=226, classifier__min_child_weight=82.75862068965517
# [CV 4/4; 46/50] END classifier__max_depth=226, classifier__min_child_weight=82.75862068965517; precision: (train=0.183, test=0.062) total time=   0.4s
# [CV 1/4; 47/50] START classifier__max_depth=246, classifier__min_child_weight=17.241379310344826
# [CV 1/4; 47/50] END classifier__max_depth=246, classifier__min_child_weight=17.241379310344826; precision: (train=0.656, test=0.100) total time=   0.5s
# [CV 2/4; 47/50] START classifier__max_depth=246, classifier__min_child_weight=17.241379310344826
# [CV 2/4; 47/50] END classifier__max_depth=246, classifier__min_child_weight=17.241379310344826; precision: (train=0.621, test=0.120) total time=   0.6s
# [CV 3/4; 47/50] START classifier__max_depth=246, classifier__min_child_weight=17.241379310344826
# [CV 3/4; 47/50] END classifier__max_depth=246, classifier__min_child_weight=17.241379310344826; precision: (train=0.586, test=0.103) total time=   0.5s
# [CV 4/4; 47/50] START classifier__max_depth=246, classifier__min_child_weight=17.241379310344826
# [CV 4/4; 47/50] END classifier__max_depth=246, classifier__min_child_weight=17.241379310344826; precision: (train=0.612, test=0.158) total time=   0.5s
# [CV 1/4; 48/50] START classifier__max_depth=205, classifier__min_child_weight=31.034482758620687
# [CV 1/4; 48/50] END classifier__max_depth=205, classifier__min_child_weight=31.034482758620687; precision: (train=0.452, test=0.125) total time=   0.5s
# [CV 2/4; 48/50] START classifier__max_depth=205, classifier__min_child_weight=31.034482758620687
# [CV 2/4; 48/50] END classifier__max_depth=205, classifier__min_child_weight=31.034482758620687; precision: (train=0.446, test=0.125) total time=   0.5s
# [CV 3/4; 48/50] START classifier__max_depth=205, classifier__min_child_weight=31.034482758620687
# [CV 3/4; 48/50] END classifier__max_depth=205, classifier__min_child_weight=31.034482758620687; precision: (train=0.394, test=0.122) total time=   0.5s
# [CV 4/4; 48/50] START classifier__max_depth=205, classifier__min_child_weight=31.034482758620687
# [CV 4/4; 48/50] END classifier__max_depth=205, classifier__min_child_weight=31.034482758620687; precision: (train=0.418, test=0.129) total time=   0.5s
# [CV 1/4; 49/50] START classifier__max_depth=490, classifier__min_child_weight=55.172413793103445
# [CV 1/4; 49/50] END classifier__max_depth=490, classifier__min_child_weight=55.172413793103445; precision: (train=0.266, test=0.078) total time=   0.4s
# [CV 2/4; 49/50] START classifier__max_depth=490, classifier__min_child_weight=55.172413793103445
# [CV 2/4; 49/50] END classifier__max_depth=490, classifier__min_child_weight=55.172413793103445; precision: (train=0.320, test=0.083) total time=   0.4s
# [CV 3/4; 49/50] START classifier__max_depth=490, classifier__min_child_weight=55.172413793103445
# [CV 3/4; 49/50] END classifier__max_depth=490, classifier__min_child_weight=55.172413793103445; precision: (train=0.275, test=0.092) total time=   0.5s
# [CV 4/4; 49/50] START classifier__max_depth=490, classifier__min_child_weight=55.172413793103445
# [CV 4/4; 49/50] END classifier__max_depth=490, classifier__min_child_weight=55.172413793103445; precision: (train=0.266, test=0.083) total time=   0.5s
# [CV 1/4; 50/50] START classifier__max_depth=674, classifier__min_child_weight=27.586206896551722
# [CV 1/4; 50/50] END classifier__max_depth=674, classifier__min_child_weight=27.586206896551722; precision: (train=0.483, test=0.094) total time=   0.5s
# [CV 2/4; 50/50] START classifier__max_depth=674, classifier__min_child_weight=27.586206896551722
# [CV 2/4; 50/50] END classifier__max_depth=674, classifier__min_child_weight=27.586206896551722; precision: (train=0.488, test=0.103) total time=   0.5s
# [CV 3/4; 50/50] START classifier__max_depth=674, classifier__min_child_weight=27.586206896551722
# [CV 3/4; 50/50] END classifier__max_depth=674, classifier__min_child_weight=27.586206896551722; precision: (train=0.410, test=0.081) total time=   0.5s
# [CV 4/4; 50/50] START classifier__max_depth=674, classifier__min_child_weight=27.586206896551722
# [CV 4/4; 50/50] END classifier__max_depth=674, classifier__min_child_weight=27.586206896551722; precision: (train=0.414, test=0.071) total time=   0.5s
# 0.24123931623931624 {'classifier__min_child_weight': 0.0, 'classifier__max_depth': 735}
# 0.0

# %% [markdown]
# 2. subsample and colsample_bytree

# %%
max_depth, min_child_weight = 735, 0.0

param_distributions = {
        "classifier__colsample_bytree": [i for i in np.linspace(0.1, 1, 50)]
        #,"classifier__subsample": [i for i in np.linspace(0.1, 1, 20)]
    }
classifier = XGBClassifier(n_jobs=None, scale_pos_weight=scale_pos_weight, eval_metric='aucpr', max_depth=max_depth, min_child_weight=min_child_weight)
pipeline = Pipeline([
        ('custom_preprocessor', CustomPreprocessor()),
        ('classifier', classifier)
    ])
random_search = run_experiment(features, param_distributions, pipeline, 
                               n_iter=50, n_splits=4, 
                               classifier=classifier)
# Out:
# Fitting 4 folds for each of 50 candidates, totalling 200 fits
# [CV 1/4; 1/50] START classifier__colsample_bytree=0.1...........................
# [CV 1/4; 1/50] END classifier__colsample_bytree=0.1; precision: (train=0.840, test=0.143) total time=   0.3s
# [CV 2/4; 1/50] START classifier__colsample_bytree=0.1...........................
# [CV 2/4; 1/50] END classifier__colsample_bytree=0.1; precision: (train=0.911, test=0.333) total time=   0.3s
# [CV 3/4; 1/50] START classifier__colsample_bytree=0.1...........................
# [CV 3/4; 1/50] END classifier__colsample_bytree=0.1; precision: (train=0.804, test=0.000) total time=   0.3s
# [CV 4/4; 1/50] START classifier__colsample_bytree=0.1...........................
# [CV 4/4; 1/50] END classifier__colsample_bytree=0.1; precision: (train=0.804, test=0.000) total time=   0.3s
# [CV 1/4; 2/50] START classifier__colsample_bytree=0.11836734693877551...........
# [CV 1/4; 2/50] END classifier__colsample_bytree=0.11836734693877551; precision: (train=0.840, test=0.143) total time=   0.3s
# [CV 2/4; 2/50] START classifier__colsample_bytree=0.11836734693877551...........
# [CV 2/4; 2/50] END classifier__colsample_bytree=0.11836734693877551; precision: (train=0.911, test=0.333) total time=   0.3s
# [CV 3/4; 2/50] START classifier__colsample_bytree=0.11836734693877551...........
# [CV 3/4; 2/50] END classifier__colsample_bytree=0.11836734693877551; precision: (train=0.804, test=0.000) total time=   0.4s
# [CV 4/4; 2/50] START classifier__colsample_bytree=0.11836734693877551...........
# [CV 4/4; 2/50] END classifier__colsample_bytree=0.11836734693877551; precision: (train=0.804, test=0.000) total time=   0.4s
# [CV 1/4; 3/50] START classifier__colsample_bytree=0.13673469387755102...........
# [CV 1/4; 3/50] END classifier__colsample_bytree=0.13673469387755102; precision: (train=1.000, test=0.000) total time=   0.4s
# [CV 2/4; 3/50] START classifier__colsample_bytree=0.13673469387755102...........
# [CV 2/4; 3/50] END classifier__colsample_bytree=0.13673469387755102; precision: (train=1.000, test=0.167) total time=   0.4s
# [CV 3/4; 3/50] START classifier__colsample_bytree=0.13673469387755102...........
# [CV 3/4; 3/50] END classifier__colsample_bytree=0.13673469387755102; precision: (train=1.000, test=0.000) total time=   0.5s
# [CV 4/4; 3/50] START classifier__colsample_bytree=0.13673469387755102...........
# [CV 4/4; 3/50] END classifier__colsample_bytree=0.13673469387755102; precision: (train=1.000, test=0.000) total time=   0.3s
# [CV 1/4; 4/50] START classifier__colsample_bytree=0.15510204081632656...........
# [CV 1/4; 4/50] END classifier__colsample_bytree=0.15510204081632656; precision: (train=1.000, test=0.000) total time=   0.3s
# [CV 2/4; 4/50] START classifier__colsample_bytree=0.15510204081632656...........
# [CV 2/4; 4/50] END classifier__colsample_bytree=0.15510204081632656; precision: (train=1.000, test=0.167) total time=   0.3s
# [CV 3/4; 4/50] START classifier__colsample_bytree=0.15510204081632656...........
# [CV 3/4; 4/50] END classifier__colsample_bytree=0.15510204081632656; precision: (train=1.000, test=0.000) total time=   0.3s
# [CV 4/4; 4/50] START classifier__colsample_bytree=0.15510204081632656...........
# [CV 4/4; 4/50] END classifier__colsample_bytree=0.15510204081632656; precision: (train=1.000, test=0.000) total time=   0.3s
# [CV 1/4; 5/50] START classifier__colsample_bytree=0.17346938775510207...........
# [CV 1/4; 5/50] END classifier__colsample_bytree=0.17346938775510207; precision: (train=1.000, test=0.000) total time=   0.3s
# [CV 2/4; 5/50] START classifier__colsample_bytree=0.17346938775510207...........
# [CV 2/4; 5/50] END classifier__colsample_bytree=0.17346938775510207; precision: (train=1.000, test=0.250) total time=   0.5s
# [CV 3/4; 5/50] START classifier__colsample_bytree=0.17346938775510207...........
# [CV 3/4; 5/50] END classifier__colsample_bytree=0.17346938775510207; precision: (train=1.000, test=0.000) total time=   0.5s
# [CV 4/4; 5/50] START classifier__colsample_bytree=0.17346938775510207...........
# [CV 4/4; 5/50] END classifier__colsample_bytree=0.17346938775510207; precision: (train=1.000, test=0.000) total time=   0.4s
# [CV 1/4; 6/50] START classifier__colsample_bytree=0.19183673469387758...........
# [CV 1/4; 6/50] END classifier__colsample_bytree=0.19183673469387758; precision: (train=1.000, test=0.000) total time=   0.3s
# [CV 2/4; 6/50] START classifier__colsample_bytree=0.19183673469387758...........
# [CV 2/4; 6/50] END classifier__colsample_bytree=0.19183673469387758; precision: (train=1.000, test=0.250) total time=   0.3s
# [CV 3/4; 6/50] START classifier__colsample_bytree=0.19183673469387758...........
# [CV 3/4; 6/50] END classifier__colsample_bytree=0.19183673469387758; precision: (train=1.000, test=0.000) total time=   0.3s
# [CV 4/4; 6/50] START classifier__colsample_bytree=0.19183673469387758...........
# [CV 4/4; 6/50] END classifier__colsample_bytree=0.19183673469387758; precision: (train=1.000, test=0.000) total time=   0.4s
# [CV 1/4; 7/50] START classifier__colsample_bytree=0.21020408163265308...........
# [CV 1/4; 7/50] END classifier__colsample_bytree=0.21020408163265308; precision: (train=1.000, test=0.000) total time=   0.4s
# [CV 2/4; 7/50] START classifier__colsample_bytree=0.21020408163265308...........
# [CV 2/4; 7/50] END classifier__colsample_bytree=0.21020408163265308; precision: (train=1.000, test=0.500) total time=   0.3s
# [CV 3/4; 7/50] START classifier__colsample_bytree=0.21020408163265308...........
# [CV 3/4; 7/50] END classifier__colsample_bytree=0.21020408163265308; precision: (train=1.000, test=0.000) total time=   0.3s
# [CV 4/4; 7/50] START classifier__colsample_bytree=0.21020408163265308...........
# c:\Users\danjr\anaconda3\envs\cycleCollisions\lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# [CV 4/4; 7/50] END classifier__colsample_bytree=0.21020408163265308; precision: (train=1.000, test=0.000) total time=   0.3s
# [CV 1/4; 8/50] START classifier__colsample_bytree=0.2285714285714286............
# [CV 1/4; 8/50] END classifier__colsample_bytree=0.2285714285714286; precision: (train=1.000, test=0.000) total time=   0.4s
# [CV 2/4; 8/50] START classifier__colsample_bytree=0.2285714285714286............
# [CV 2/4; 8/50] END classifier__colsample_bytree=0.2285714285714286; precision: (train=1.000, test=0.500) total time=   0.3s
# [CV 3/4; 8/50] START classifier__colsample_bytree=0.2285714285714286............
# [CV 3/4; 8/50] END classifier__colsample_bytree=0.2285714285714286; precision: (train=1.000, test=0.000) total time=   0.4s
# [CV 4/4; 8/50] START classifier__colsample_bytree=0.2285714285714286............
# c:\Users\danjr\anaconda3\envs\cycleCollisions\lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# [CV 4/4; 8/50] END classifier__colsample_bytree=0.2285714285714286; precision: (train=1.000, test=0.000) total time=   0.4s
# [CV 1/4; 9/50] START classifier__colsample_bytree=0.2469387755102041............
# [CV 1/4; 9/50] END classifier__colsample_bytree=0.2469387755102041; precision: (train=1.000, test=0.000) total time=   0.4s
# [CV 2/4; 9/50] START classifier__colsample_bytree=0.2469387755102041............
# [CV 2/4; 9/50] END classifier__colsample_bytree=0.2469387755102041; precision: (train=1.000, test=0.333) total time=   0.4s
# [CV 3/4; 9/50] START classifier__colsample_bytree=0.2469387755102041............
# [CV 3/4; 9/50] END classifier__colsample_bytree=0.2469387755102041; precision: (train=1.000, test=0.000) total time=   0.5s
# [CV 4/4; 9/50] START classifier__colsample_bytree=0.2469387755102041............
# [CV 4/4; 9/50] END classifier__colsample_bytree=0.2469387755102041; precision: (train=1.000, test=0.000) total time=   0.5s
# [CV 1/4; 10/50] START classifier__colsample_bytree=0.2653061224489796...........
# [CV 1/4; 10/50] END classifier__colsample_bytree=0.2653061224489796; precision: (train=1.000, test=0.000) total time=   0.5s
# [CV 2/4; 10/50] START classifier__colsample_bytree=0.2653061224489796...........
# [CV 2/4; 10/50] END classifier__colsample_bytree=0.2653061224489796; precision: (train=1.000, test=0.333) total time=   0.4s
# [CV 3/4; 10/50] START classifier__colsample_bytree=0.2653061224489796...........
# [CV 3/4; 10/50] END classifier__colsample_bytree=0.2653061224489796; precision: (train=1.000, test=0.000) total time=   0.4s
# [CV 4/4; 10/50] START classifier__colsample_bytree=0.2653061224489796...........
# [CV 4/4; 10/50] END classifier__colsample_bytree=0.2653061224489796; precision: (train=1.000, test=0.000) total time=   0.4s
# [CV 1/4; 11/50] START classifier__colsample_bytree=0.2836734693877551...........
# [CV 1/4; 11/50] END classifier__colsample_bytree=0.2836734693877551; precision: (train=1.000, test=0.000) total time=   0.4s
# [CV 2/4; 11/50] START classifier__colsample_bytree=0.2836734693877551...........
# [CV 2/4; 11/50] END classifier__colsample_bytree=0.2836734693877551; precision: (train=1.000, test=0.500) total time=   0.4s
# [CV 3/4; 11/50] START classifier__colsample_bytree=0.2836734693877551...........
# [CV 3/4; 11/50] END classifier__colsample_bytree=0.2836734693877551; precision: (train=1.000, test=0.000) total time=   0.4s
# [CV 4/4; 11/50] START classifier__colsample_bytree=0.2836734693877551...........
# c:\Users\danjr\anaconda3\envs\cycleCollisions\lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# [CV 4/4; 11/50] END classifier__colsample_bytree=0.2836734693877551; precision: (train=1.000, test=0.000) total time=   0.5s
# [CV 1/4; 12/50] START classifier__colsample_bytree=0.3020408163265306...........
# [CV 1/4; 12/50] END classifier__colsample_bytree=0.3020408163265306; precision: (train=1.000, test=0.000) total time=   0.6s
# [CV 2/4; 12/50] START classifier__colsample_bytree=0.3020408163265306...........
# [CV 2/4; 12/50] END classifier__colsample_bytree=0.3020408163265306; precision: (train=1.000, test=0.500) total time=   0.5s
# [CV 3/4; 12/50] START classifier__colsample_bytree=0.3020408163265306...........
# [CV 3/4; 12/50] END classifier__colsample_bytree=0.3020408163265306; precision: (train=1.000, test=0.000) total time=   0.7s
# [CV 4/4; 12/50] START classifier__colsample_bytree=0.3020408163265306...........
# c:\Users\danjr\anaconda3\envs\cycleCollisions\lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# [CV 4/4; 12/50] END classifier__colsample_bytree=0.3020408163265306; precision: (train=1.000, test=0.000) total time=   0.6s
# [CV 1/4; 13/50] START classifier__colsample_bytree=0.3204081632653062...........
# [CV 1/4; 13/50] END classifier__colsample_bytree=0.3204081632653062; precision: (train=1.000, test=0.000) total time=   0.5s
# [CV 2/4; 13/50] START classifier__colsample_bytree=0.3204081632653062...........
# [CV 2/4; 13/50] END classifier__colsample_bytree=0.3204081632653062; precision: (train=1.000, test=0.000) total time=   0.7s
# [CV 3/4; 13/50] START classifier__colsample_bytree=0.3204081632653062...........
# [CV 3/4; 13/50] END classifier__colsample_bytree=0.3204081632653062; precision: (train=1.000, test=0.500) total time=   0.7s
# [CV 4/4; 13/50] START classifier__colsample_bytree=0.3204081632653062...........
# c:\Users\danjr\anaconda3\envs\cycleCollisions\lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# [CV 4/4; 13/50] END classifier__colsample_bytree=0.3204081632653062; precision: (train=1.000, test=0.000) total time=   0.5s
# [CV 1/4; 14/50] START classifier__colsample_bytree=0.3387755102040817...........
# [CV 1/4; 14/50] END classifier__colsample_bytree=0.3387755102040817; precision: (train=1.000, test=0.000) total time=   0.7s
# [CV 2/4; 14/50] START classifier__colsample_bytree=0.3387755102040817...........
# [CV 2/4; 14/50] END classifier__colsample_bytree=0.3387755102040817; precision: (train=1.000, test=0.000) total time=   0.9s
# [CV 3/4; 14/50] START classifier__colsample_bytree=0.3387755102040817...........
# [CV 3/4; 14/50] END classifier__colsample_bytree=0.3387755102040817; precision: (train=1.000, test=0.500) total time=   0.6s
# [CV 4/4; 14/50] START classifier__colsample_bytree=0.3387755102040817...........
# c:\Users\danjr\anaconda3\envs\cycleCollisions\lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# [CV 4/4; 14/50] END classifier__colsample_bytree=0.3387755102040817; precision: (train=1.000, test=0.000) total time=   0.4s
# [CV 1/4; 15/50] START classifier__colsample_bytree=0.3571428571428572...........
# [CV 1/4; 15/50] END classifier__colsample_bytree=0.3571428571428572; precision: (train=1.000, test=0.000) total time=   0.5s
# [CV 2/4; 15/50] START classifier__colsample_bytree=0.3571428571428572...........
# [CV 2/4; 15/50] END classifier__colsample_bytree=0.3571428571428572; precision: (train=1.000, test=0.000) total time=   0.4s
# [CV 3/4; 15/50] START classifier__colsample_bytree=0.3571428571428572...........
# [CV 3/4; 15/50] END classifier__colsample_bytree=0.3571428571428572; precision: (train=1.000, test=0.500) total time=   0.4s
# [CV 4/4; 15/50] START classifier__colsample_bytree=0.3571428571428572...........
# c:\Users\danjr\anaconda3\envs\cycleCollisions\lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# [CV 4/4; 15/50] END classifier__colsample_bytree=0.3571428571428572; precision: (train=1.000, test=0.000) total time=   0.4s
# [CV 1/4; 16/50] START classifier__colsample_bytree=0.3755102040816327...........
# [CV 1/4; 16/50] END classifier__colsample_bytree=0.3755102040816327; precision: (train=1.000, test=0.000) total time=   0.5s
# [CV 2/4; 16/50] START classifier__colsample_bytree=0.3755102040816327...........
# [CV 2/4; 16/50] END classifier__colsample_bytree=0.3755102040816327; precision: (train=1.000, test=0.000) total time=   0.4s
# [CV 3/4; 16/50] START classifier__colsample_bytree=0.3755102040816327...........
# [CV 3/4; 16/50] END classifier__colsample_bytree=0.3755102040816327; precision: (train=1.000, test=0.500) total time=   0.5s
# [CV 4/4; 16/50] START classifier__colsample_bytree=0.3755102040816327...........
# c:\Users\danjr\anaconda3\envs\cycleCollisions\lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# [CV 4/4; 16/50] END classifier__colsample_bytree=0.3755102040816327; precision: (train=1.000, test=0.000) total time=   0.4s
# [CV 1/4; 17/50] START classifier__colsample_bytree=0.3938775510204082...........
# [CV 1/4; 17/50] END classifier__colsample_bytree=0.3938775510204082; precision: (train=1.000, test=0.000) total time=   0.4s
# [CV 2/4; 17/50] START classifier__colsample_bytree=0.3938775510204082...........
# [CV 2/4; 17/50] END classifier__colsample_bytree=0.3938775510204082; precision: (train=1.000, test=0.000) total time=   0.4s
# [CV 3/4; 17/50] START classifier__colsample_bytree=0.3938775510204082...........
# [CV 3/4; 17/50] END classifier__colsample_bytree=0.3938775510204082; precision: (train=1.000, test=0.500) total time=   0.6s
# [CV 4/4; 17/50] START classifier__colsample_bytree=0.3938775510204082...........
# c:\Users\danjr\anaconda3\envs\cycleCollisions\lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# [CV 4/4; 17/50] END classifier__colsample_bytree=0.3938775510204082; precision: (train=1.000, test=0.000) total time=   0.6s
# [CV 1/4; 18/50] START classifier__colsample_bytree=0.41224489795918373..........
# [CV 1/4; 18/50] END classifier__colsample_bytree=0.41224489795918373; precision: (train=1.000, test=0.000) total time=   0.6s
# [CV 2/4; 18/50] START classifier__colsample_bytree=0.41224489795918373..........
# [CV 2/4; 18/50] END classifier__colsample_bytree=0.41224489795918373; precision: (train=1.000, test=0.333) total time=   0.5s
# [CV 3/4; 18/50] START classifier__colsample_bytree=0.41224489795918373..........
# [CV 3/4; 18/50] END classifier__colsample_bytree=0.41224489795918373; precision: (train=1.000, test=0.000) total time=   0.4s
# [CV 4/4; 18/50] START classifier__colsample_bytree=0.41224489795918373..........
# c:\Users\danjr\anaconda3\envs\cycleCollisions\lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# [CV 4/4; 18/50] END classifier__colsample_bytree=0.41224489795918373; precision: (train=1.000, test=0.000) total time=   0.4s
# [CV 1/4; 19/50] START classifier__colsample_bytree=0.43061224489795924..........
# [CV 1/4; 19/50] END classifier__colsample_bytree=0.43061224489795924; precision: (train=1.000, test=0.000) total time=   0.5s
# [CV 2/4; 19/50] START classifier__colsample_bytree=0.43061224489795924..........
# [CV 2/4; 19/50] END classifier__colsample_bytree=0.43061224489795924; precision: (train=1.000, test=0.333) total time=   0.6s
# [CV 3/4; 19/50] START classifier__colsample_bytree=0.43061224489795924..........
# [CV 3/4; 19/50] END classifier__colsample_bytree=0.43061224489795924; precision: (train=1.000, test=0.000) total time=   0.6s
# [CV 4/4; 19/50] START classifier__colsample_bytree=0.43061224489795924..........
# c:\Users\danjr\anaconda3\envs\cycleCollisions\lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# [CV 4/4; 19/50] END classifier__colsample_bytree=0.43061224489795924; precision: (train=1.000, test=0.000) total time=   0.5s
# [CV 1/4; 20/50] START classifier__colsample_bytree=0.44897959183673475..........
# [CV 1/4; 20/50] END classifier__colsample_bytree=0.44897959183673475; precision: (train=1.000, test=0.000) total time=   0.5s
# [CV 2/4; 20/50] START classifier__colsample_bytree=0.44897959183673475..........
# [CV 2/4; 20/50] END classifier__colsample_bytree=0.44897959183673475; precision: (train=1.000, test=0.333) total time=   0.6s
# [CV 3/4; 20/50] START classifier__colsample_bytree=0.44897959183673475..........
# [CV 3/4; 20/50] END classifier__colsample_bytree=0.44897959183673475; precision: (train=1.000, test=0.000) total time=   0.6s
# [CV 4/4; 20/50] START classifier__colsample_bytree=0.44897959183673475..........
# [CV 4/4; 20/50] END classifier__colsample_bytree=0.44897959183673475; precision: (train=1.000, test=0.000) total time=   0.5s
# [CV 1/4; 21/50] START classifier__colsample_bytree=0.46734693877551026..........
# [CV 1/4; 21/50] END classifier__colsample_bytree=0.46734693877551026; precision: (train=1.000, test=0.000) total time=   0.4s
# [CV 2/4; 21/50] START classifier__colsample_bytree=0.46734693877551026..........
# [CV 2/4; 21/50] END classifier__colsample_bytree=0.46734693877551026; precision: (train=1.000, test=0.333) total time=   0.4s
# [CV 3/4; 21/50] START classifier__colsample_bytree=0.46734693877551026..........
# [CV 3/4; 21/50] END classifier__colsample_bytree=0.46734693877551026; precision: (train=1.000, test=0.000) total time=   0.5s
# [CV 4/4; 21/50] START classifier__colsample_bytree=0.46734693877551026..........
# [CV 4/4; 21/50] END classifier__colsample_bytree=0.46734693877551026; precision: (train=1.000, test=0.000) total time=   0.5s
# [CV 1/4; 22/50] START classifier__colsample_bytree=0.48571428571428577..........
# [CV 1/4; 22/50] END classifier__colsample_bytree=0.48571428571428577; precision: (train=1.000, test=0.000) total time=   0.6s
# [CV 2/4; 22/50] START classifier__colsample_bytree=0.48571428571428577..........
# [CV 2/4; 22/50] END classifier__colsample_bytree=0.48571428571428577; precision: (train=1.000, test=0.000) total time=   0.6s
# [CV 3/4; 22/50] START classifier__colsample_bytree=0.48571428571428577..........
# [CV 3/4; 22/50] END classifier__colsample_bytree=0.48571428571428577; precision: (train=1.000, test=0.500) total time=   0.6s
# [CV 4/4; 22/50] START classifier__colsample_bytree=0.48571428571428577..........
# [CV 4/4; 22/50] END classifier__colsample_bytree=0.48571428571428577; precision: (train=1.000, test=0.000) total time=   0.4s
# [CV 1/4; 23/50] START classifier__colsample_bytree=0.5040816326530613...........
# [CV 1/4; 23/50] END classifier__colsample_bytree=0.5040816326530613; precision: (train=1.000, test=0.000) total time=   0.5s
# [CV 2/4; 23/50] START classifier__colsample_bytree=0.5040816326530613...........
# [CV 2/4; 23/50] END classifier__colsample_bytree=0.5040816326530613; precision: (train=1.000, test=0.000) total time=   0.5s
# [CV 3/4; 23/50] START classifier__colsample_bytree=0.5040816326530613...........
# [CV 3/4; 23/50] END classifier__colsample_bytree=0.5040816326530613; precision: (train=1.000, test=0.500) total time=   0.6s
# [CV 4/4; 23/50] START classifier__colsample_bytree=0.5040816326530613...........
# [CV 4/4; 23/50] END classifier__colsample_bytree=0.5040816326530613; precision: (train=1.000, test=0.000) total time=   0.5s
# [CV 1/4; 24/50] START classifier__colsample_bytree=0.5224489795918368...........
# [CV 1/4; 24/50] END classifier__colsample_bytree=0.5224489795918368; precision: (train=1.000, test=0.000) total time=   0.6s
# [CV 2/4; 24/50] START classifier__colsample_bytree=0.5224489795918368...........
# [CV 2/4; 24/50] END classifier__colsample_bytree=0.5224489795918368; precision: (train=1.000, test=0.000) total time=   0.4s
# [CV 3/4; 24/50] START classifier__colsample_bytree=0.5224489795918368...........
# [CV 3/4; 24/50] END classifier__colsample_bytree=0.5224489795918368; precision: (train=1.000, test=0.500) total time=   0.4s
# [CV 4/4; 24/50] START classifier__colsample_bytree=0.5224489795918368...........
# [CV 4/4; 24/50] END classifier__colsample_bytree=0.5224489795918368; precision: (train=1.000, test=0.000) total time=   0.4s
# [CV 1/4; 25/50] START classifier__colsample_bytree=0.5408163265306123...........
# [CV 1/4; 25/50] END classifier__colsample_bytree=0.5408163265306123; precision: (train=1.000, test=0.000) total time=   0.4s
# [CV 2/4; 25/50] START classifier__colsample_bytree=0.5408163265306123...........
# [CV 2/4; 25/50] END classifier__colsample_bytree=0.5408163265306123; precision: (train=1.000, test=0.000) total time=   0.5s
# [CV 3/4; 25/50] START classifier__colsample_bytree=0.5408163265306123...........
# [CV 3/4; 25/50] END classifier__colsample_bytree=0.5408163265306123; precision: (train=1.000, test=0.500) total time=   0.5s
# [CV 4/4; 25/50] START classifier__colsample_bytree=0.5408163265306123...........
# [CV 4/4; 25/50] END classifier__colsample_bytree=0.5408163265306123; precision: (train=1.000, test=0.000) total time=   0.5s
# [CV 1/4; 26/50] START classifier__colsample_bytree=0.5591836734693878...........
# [CV 1/4; 26/50] END classifier__colsample_bytree=0.5591836734693878; precision: (train=1.000, test=0.000) total time=   0.4s
# [CV 2/4; 26/50] START classifier__colsample_bytree=0.5591836734693878...........
# [CV 2/4; 26/50] END classifier__colsample_bytree=0.5591836734693878; precision: (train=1.000, test=0.000) total time=   0.4s
# [CV 3/4; 26/50] START classifier__colsample_bytree=0.5591836734693878...........
# [CV 3/4; 26/50] END classifier__colsample_bytree=0.5591836734693878; precision: (train=1.000, test=0.500) total time=   0.4s
# [CV 4/4; 26/50] START classifier__colsample_bytree=0.5591836734693878...........
# [CV 4/4; 26/50] END classifier__colsample_bytree=0.5591836734693878; precision: (train=1.000, test=0.000) total time=   0.4s
# [CV 1/4; 27/50] START classifier__colsample_bytree=0.5775510204081633...........
# [CV 1/4; 27/50] END classifier__colsample_bytree=0.5775510204081633; precision: (train=1.000, test=0.000) total time=   0.4s
# [CV 2/4; 27/50] START classifier__colsample_bytree=0.5775510204081633...........
# [CV 2/4; 27/50] END classifier__colsample_bytree=0.5775510204081633; precision: (train=1.000, test=0.000) total time=   0.4s
# [CV 3/4; 27/50] START classifier__colsample_bytree=0.5775510204081633...........
# [CV 3/4; 27/50] END classifier__colsample_bytree=0.5775510204081633; precision: (train=1.000, test=0.000) total time=   0.5s
# [CV 4/4; 27/50] START classifier__colsample_bytree=0.5775510204081633...........
# [CV 4/4; 27/50] END classifier__colsample_bytree=0.5775510204081633; precision: (train=1.000, test=0.000) total time=   0.5s
# [CV 1/4; 28/50] START classifier__colsample_bytree=0.5959183673469388...........
# [CV 1/4; 28/50] END classifier__colsample_bytree=0.5959183673469388; precision: (train=1.000, test=0.000) total time=   0.4s
# [CV 2/4; 28/50] START classifier__colsample_bytree=0.5959183673469388...........
# [CV 2/4; 28/50] END classifier__colsample_bytree=0.5959183673469388; precision: (train=1.000, test=0.000) total time=   0.4s
# [CV 3/4; 28/50] START classifier__colsample_bytree=0.5959183673469388...........
# [CV 3/4; 28/50] END classifier__colsample_bytree=0.5959183673469388; precision: (train=1.000, test=0.000) total time=   0.5s
# [CV 4/4; 28/50] START classifier__colsample_bytree=0.5959183673469388...........
# [CV 4/4; 28/50] END classifier__colsample_bytree=0.5959183673469388; precision: (train=1.000, test=0.000) total time=   0.4s
# [CV 1/4; 29/50] START classifier__colsample_bytree=0.6142857142857143...........
# [CV 1/4; 29/50] END classifier__colsample_bytree=0.6142857142857143; precision: (train=1.000, test=0.000) total time=   0.5s
# [CV 2/4; 29/50] START classifier__colsample_bytree=0.6142857142857143...........
# [CV 2/4; 29/50] END classifier__colsample_bytree=0.6142857142857143; precision: (train=1.000, test=0.000) total time=   0.4s
# [CV 3/4; 29/50] START classifier__colsample_bytree=0.6142857142857143...........
# [CV 3/4; 29/50] END classifier__colsample_bytree=0.6142857142857143; precision: (train=1.000, test=0.500) total time=   0.4s
# [CV 4/4; 29/50] START classifier__colsample_bytree=0.6142857142857143...........
# [CV 4/4; 29/50] END classifier__colsample_bytree=0.6142857142857143; precision: (train=1.000, test=0.000) total time=   0.4s
# [CV 1/4; 30/50] START classifier__colsample_bytree=0.6326530612244898...........
# [CV 1/4; 30/50] END classifier__colsample_bytree=0.6326530612244898; precision: (train=1.000, test=0.000) total time=   0.6s
# [CV 2/4; 30/50] START classifier__colsample_bytree=0.6326530612244898...........
# [CV 2/4; 30/50] END classifier__colsample_bytree=0.6326530612244898; precision: (train=1.000, test=0.000) total time=   0.4s
# [CV 3/4; 30/50] START classifier__colsample_bytree=0.6326530612244898...........
# [CV 3/4; 30/50] END classifier__colsample_bytree=0.6326530612244898; precision: (train=1.000, test=0.500) total time=   0.4s
# [CV 4/4; 30/50] START classifier__colsample_bytree=0.6326530612244898...........
# [CV 4/4; 30/50] END classifier__colsample_bytree=0.6326530612244898; precision: (train=1.000, test=0.000) total time=   0.5s
# [CV 1/4; 31/50] START classifier__colsample_bytree=0.6510204081632653...........
# [CV 1/4; 31/50] END classifier__colsample_bytree=0.6510204081632653; precision: (train=1.000, test=0.000) total time=   0.5s
# [CV 2/4; 31/50] START classifier__colsample_bytree=0.6510204081632653...........
# [CV 2/4; 31/50] END classifier__colsample_bytree=0.6510204081632653; precision: (train=1.000, test=0.000) total time=   0.5s
# [CV 3/4; 31/50] START classifier__colsample_bytree=0.6510204081632653...........
# [CV 3/4; 31/50] END classifier__colsample_bytree=0.6510204081632653; precision: (train=1.000, test=0.667) total time=   0.6s
# [CV 4/4; 31/50] START classifier__colsample_bytree=0.6510204081632653...........
# [CV 4/4; 31/50] END classifier__colsample_bytree=0.6510204081632653; precision: (train=1.000, test=0.000) total time=   0.4s
# [CV 1/4; 32/50] START classifier__colsample_bytree=0.6693877551020408...........
# [CV 1/4; 32/50] END classifier__colsample_bytree=0.6693877551020408; precision: (train=1.000, test=0.000) total time=   0.4s
# [CV 2/4; 32/50] START classifier__colsample_bytree=0.6693877551020408...........
# [CV 2/4; 32/50] END classifier__colsample_bytree=0.6693877551020408; precision: (train=1.000, test=0.000) total time=   0.4s
# [CV 3/4; 32/50] START classifier__colsample_bytree=0.6693877551020408...........
# [CV 3/4; 32/50] END classifier__colsample_bytree=0.6693877551020408; precision: (train=1.000, test=0.667) total time=   0.4s
# [CV 4/4; 32/50] START classifier__colsample_bytree=0.6693877551020408...........
# [CV 4/4; 32/50] END classifier__colsample_bytree=0.6693877551020408; precision: (train=1.000, test=0.000) total time=   0.5s
# [CV 1/4; 33/50] START classifier__colsample_bytree=0.6877551020408164...........
# [CV 1/4; 33/50] END classifier__colsample_bytree=0.6877551020408164; precision: (train=1.000, test=0.000) total time=   0.4s
# [CV 2/4; 33/50] START classifier__colsample_bytree=0.6877551020408164...........
# [CV 2/4; 33/50] END classifier__colsample_bytree=0.6877551020408164; precision: (train=1.000, test=0.200) total time=   0.4s
# [CV 3/4; 33/50] START classifier__colsample_bytree=0.6877551020408164...........
# [CV 3/4; 33/50] END classifier__colsample_bytree=0.6877551020408164; precision: (train=1.000, test=0.333) total time=   0.5s
# [CV 4/4; 33/50] START classifier__colsample_bytree=0.6877551020408164...........
# [CV 4/4; 33/50] END classifier__colsample_bytree=0.6877551020408164; precision: (train=1.000, test=0.000) total time=   0.5s
# [CV 1/4; 34/50] START classifier__colsample_bytree=0.7061224489795919...........
# [CV 1/4; 34/50] END classifier__colsample_bytree=0.7061224489795919; precision: (train=1.000, test=0.000) total time=   0.4s
# [CV 2/4; 34/50] START classifier__colsample_bytree=0.7061224489795919...........
# [CV 2/4; 34/50] END classifier__colsample_bytree=0.7061224489795919; precision: (train=1.000, test=0.200) total time=   0.4s
# [CV 3/4; 34/50] START classifier__colsample_bytree=0.7061224489795919...........
# [CV 3/4; 34/50] END classifier__colsample_bytree=0.7061224489795919; precision: (train=1.000, test=0.333) total time=   0.4s
# [CV 4/4; 34/50] START classifier__colsample_bytree=0.7061224489795919...........
# [CV 4/4; 34/50] END classifier__colsample_bytree=0.7061224489795919; precision: (train=1.000, test=0.000) total time=   0.4s
# [CV 1/4; 35/50] START classifier__colsample_bytree=0.7244897959183674...........
# [CV 1/4; 35/50] END classifier__colsample_bytree=0.7244897959183674; precision: (train=1.000, test=0.000) total time=   0.4s
# [CV 2/4; 35/50] START classifier__colsample_bytree=0.7244897959183674...........
# [CV 2/4; 35/50] END classifier__colsample_bytree=0.7244897959183674; precision: (train=1.000, test=0.000) total time=   0.4s
# [CV 3/4; 35/50] START classifier__colsample_bytree=0.7244897959183674...........
# [CV 3/4; 35/50] END classifier__colsample_bytree=0.7244897959183674; precision: (train=1.000, test=0.333) total time=   0.4s
# [CV 4/4; 35/50] START classifier__colsample_bytree=0.7244897959183674...........
# [CV 4/4; 35/50] END classifier__colsample_bytree=0.7244897959183674; precision: (train=1.000, test=0.000) total time=   0.4s
# [CV 1/4; 36/50] START classifier__colsample_bytree=0.7428571428571429...........
# [CV 1/4; 36/50] END classifier__colsample_bytree=0.7428571428571429; precision: (train=1.000, test=0.000) total time=   0.4s
# [CV 2/4; 36/50] START classifier__colsample_bytree=0.7428571428571429...........
# [CV 2/4; 36/50] END classifier__colsample_bytree=0.7428571428571429; precision: (train=1.000, test=0.000) total time=   0.4s
# [CV 3/4; 36/50] START classifier__colsample_bytree=0.7428571428571429...........
# [CV 3/4; 36/50] END classifier__colsample_bytree=0.7428571428571429; precision: (train=1.000, test=0.333) total time=   0.4s
# [CV 4/4; 36/50] START classifier__colsample_bytree=0.7428571428571429...........
# [CV 4/4; 36/50] END classifier__colsample_bytree=0.7428571428571429; precision: (train=1.000, test=0.000) total time=   0.4s
# [CV 1/4; 37/50] START classifier__colsample_bytree=0.7612244897959184...........
# [CV 1/4; 37/50] END classifier__colsample_bytree=0.7612244897959184; precision: (train=1.000, test=0.000) total time=   0.4s
# [CV 2/4; 37/50] START classifier__colsample_bytree=0.7612244897959184...........
# [CV 2/4; 37/50] END classifier__colsample_bytree=0.7612244897959184; precision: (train=1.000, test=0.250) total time=   0.4s
# [CV 3/4; 37/50] START classifier__colsample_bytree=0.7612244897959184...........
# [CV 3/4; 37/50] END classifier__colsample_bytree=0.7612244897959184; precision: (train=1.000, test=0.500) total time=   0.4s
# [CV 4/4; 37/50] START classifier__colsample_bytree=0.7612244897959184...........
# [CV 4/4; 37/50] END classifier__colsample_bytree=0.7612244897959184; precision: (train=1.000, test=0.000) total time=   0.5s
# [CV 1/4; 38/50] START classifier__colsample_bytree=0.7795918367346939...........
# [CV 1/4; 38/50] END classifier__colsample_bytree=0.7795918367346939; precision: (train=1.000, test=0.000) total time=   0.4s
# [CV 2/4; 38/50] START classifier__colsample_bytree=0.7795918367346939...........
# [CV 2/4; 38/50] END classifier__colsample_bytree=0.7795918367346939; precision: (train=1.000, test=0.250) total time=   0.4s
# [CV 3/4; 38/50] START classifier__colsample_bytree=0.7795918367346939...........
# [CV 3/4; 38/50] END classifier__colsample_bytree=0.7795918367346939; precision: (train=1.000, test=0.500) total time=   0.4s
# [CV 4/4; 38/50] START classifier__colsample_bytree=0.7795918367346939...........
# [CV 4/4; 38/50] END classifier__colsample_bytree=0.7795918367346939; precision: (train=1.000, test=0.000) total time=   0.5s
# [CV 1/4; 39/50] START classifier__colsample_bytree=0.7979591836734694...........
# [CV 1/4; 39/50] END classifier__colsample_bytree=0.7979591836734694; precision: (train=1.000, test=0.000) total time=   0.4s
# [CV 2/4; 39/50] START classifier__colsample_bytree=0.7979591836734694...........
# [CV 2/4; 39/50] END classifier__colsample_bytree=0.7979591836734694; precision: (train=1.000, test=0.250) total time=   0.4s
# [CV 3/4; 39/50] START classifier__colsample_bytree=0.7979591836734694...........
# [CV 3/4; 39/50] END classifier__colsample_bytree=0.7979591836734694; precision: (train=1.000, test=0.500) total time=   0.4s
# [CV 4/4; 39/50] START classifier__colsample_bytree=0.7979591836734694...........
# [CV 4/4; 39/50] END classifier__colsample_bytree=0.7979591836734694; precision: (train=1.000, test=0.000) total time=   0.4s
# [CV 1/4; 40/50] START classifier__colsample_bytree=0.8163265306122449...........
# [CV 1/4; 40/50] END classifier__colsample_bytree=0.8163265306122449; precision: (train=1.000, test=0.000) total time=   0.4s
# [CV 2/4; 40/50] START classifier__colsample_bytree=0.8163265306122449...........
# [CV 2/4; 40/50] END classifier__colsample_bytree=0.8163265306122449; precision: (train=1.000, test=0.250) total time=   0.4s
# [CV 3/4; 40/50] START classifier__colsample_bytree=0.8163265306122449...........
# [CV 3/4; 40/50] END classifier__colsample_bytree=0.8163265306122449; precision: (train=1.000, test=0.500) total time=   0.5s
# [CV 4/4; 40/50] START classifier__colsample_bytree=0.8163265306122449...........
# [CV 4/4; 40/50] END classifier__colsample_bytree=0.8163265306122449; precision: (train=1.000, test=0.000) total time=   0.4s
# [CV 1/4; 41/50] START classifier__colsample_bytree=0.8346938775510204...........
# [CV 1/4; 41/50] END classifier__colsample_bytree=0.8346938775510204; precision: (train=1.000, test=0.000) total time=   0.4s
# [CV 2/4; 41/50] START classifier__colsample_bytree=0.8346938775510204...........
# [CV 2/4; 41/50] END classifier__colsample_bytree=0.8346938775510204; precision: (train=1.000, test=0.250) total time=   0.4s
# [CV 3/4; 41/50] START classifier__colsample_bytree=0.8346938775510204...........
# [CV 3/4; 41/50] END classifier__colsample_bytree=0.8346938775510204; precision: (train=1.000, test=0.500) total time=   0.5s
# [CV 4/4; 41/50] START classifier__colsample_bytree=0.8346938775510204...........
# [CV 4/4; 41/50] END classifier__colsample_bytree=0.8346938775510204; precision: (train=1.000, test=0.000) total time=   0.5s
# [CV 1/4; 42/50] START classifier__colsample_bytree=0.8530612244897959...........
# [CV 1/4; 42/50] END classifier__colsample_bytree=0.8530612244897959; precision: (train=1.000, test=0.000) total time=   0.4s
# [CV 2/4; 42/50] START classifier__colsample_bytree=0.8530612244897959...........
# [CV 2/4; 42/50] END classifier__colsample_bytree=0.8530612244897959; precision: (train=1.000, test=0.250) total time=   0.5s
# [CV 3/4; 42/50] START classifier__colsample_bytree=0.8530612244897959...........
# [CV 3/4; 42/50] END classifier__colsample_bytree=0.8530612244897959; precision: (train=1.000, test=0.600) total time=   0.5s
# [CV 4/4; 42/50] START classifier__colsample_bytree=0.8530612244897959...........
# [CV 4/4; 42/50] END classifier__colsample_bytree=0.8530612244897959; precision: (train=1.000, test=0.000) total time=   0.5s
# [CV 1/4; 43/50] START classifier__colsample_bytree=0.8714285714285714...........
# [CV 1/4; 43/50] END classifier__colsample_bytree=0.8714285714285714; precision: (train=1.000, test=0.000) total time=   0.5s
# [CV 2/4; 43/50] START classifier__colsample_bytree=0.8714285714285714...........
# [CV 2/4; 43/50] END classifier__colsample_bytree=0.8714285714285714; precision: (train=1.000, test=0.250) total time=   0.4s
# [CV 3/4; 43/50] START classifier__colsample_bytree=0.8714285714285714...........
# [CV 3/4; 43/50] END classifier__colsample_bytree=0.8714285714285714; precision: (train=1.000, test=0.600) total time=   0.5s
# [CV 4/4; 43/50] START classifier__colsample_bytree=0.8714285714285714...........
# [CV 4/4; 43/50] END classifier__colsample_bytree=0.8714285714285714; precision: (train=1.000, test=0.000) total time=   0.4s
# [CV 1/4; 44/50] START classifier__colsample_bytree=0.889795918367347............
# [CV 1/4; 44/50] END classifier__colsample_bytree=0.889795918367347; precision: (train=1.000, test=0.000) total time=   0.5s
# [CV 2/4; 44/50] START classifier__colsample_bytree=0.889795918367347............
# [CV 2/4; 44/50] END classifier__colsample_bytree=0.889795918367347; precision: (train=1.000, test=0.200) total time=   0.4s
# [CV 3/4; 44/50] START classifier__colsample_bytree=0.889795918367347............
# [CV 3/4; 44/50] END classifier__colsample_bytree=0.889795918367347; precision: (train=1.000, test=0.400) total time=   0.5s
# [CV 4/4; 44/50] START classifier__colsample_bytree=0.889795918367347............
# [CV 4/4; 44/50] END classifier__colsample_bytree=0.889795918367347; precision: (train=1.000, test=0.000) total time=   0.5s
# [CV 1/4; 45/50] START classifier__colsample_bytree=0.9081632653061225...........
# [CV 1/4; 45/50] END classifier__colsample_bytree=0.9081632653061225; precision: (train=1.000, test=0.000) total time=   0.5s
# [CV 2/4; 45/50] START classifier__colsample_bytree=0.9081632653061225...........
# [CV 2/4; 45/50] END classifier__colsample_bytree=0.9081632653061225; precision: (train=1.000, test=0.200) total time=   0.4s
# [CV 3/4; 45/50] START classifier__colsample_bytree=0.9081632653061225...........
# [CV 3/4; 45/50] END classifier__colsample_bytree=0.9081632653061225; precision: (train=1.000, test=0.400) total time=   0.4s
# [CV 4/4; 45/50] START classifier__colsample_bytree=0.9081632653061225...........
# [CV 4/4; 45/50] END classifier__colsample_bytree=0.9081632653061225; precision: (train=1.000, test=0.000) total time=   0.4s
# [CV 1/4; 46/50] START classifier__colsample_bytree=0.926530612244898............
# [CV 1/4; 46/50] END classifier__colsample_bytree=0.926530612244898; precision: (train=1.000, test=0.167) total time=   0.4s
# [CV 2/4; 46/50] START classifier__colsample_bytree=0.926530612244898............
# [CV 2/4; 46/50] END classifier__colsample_bytree=0.926530612244898; precision: (train=1.000, test=0.333) total time=   0.4s
# [CV 3/4; 46/50] START classifier__colsample_bytree=0.926530612244898............
# [CV 3/4; 46/50] END classifier__colsample_bytree=0.926530612244898; precision: (train=1.000, test=0.500) total time=   0.4s
# [CV 4/4; 46/50] START classifier__colsample_bytree=0.926530612244898............
# [CV 4/4; 46/50] END classifier__colsample_bytree=0.926530612244898; precision: (train=1.000, test=0.000) total time=   0.4s
# [CV 1/4; 47/50] START classifier__colsample_bytree=0.9448979591836735...........
# [CV 1/4; 47/50] END classifier__colsample_bytree=0.9448979591836735; precision: (train=1.000, test=0.167) total time=   0.5s
# [CV 2/4; 47/50] START classifier__colsample_bytree=0.9448979591836735...........
# [CV 2/4; 47/50] END classifier__colsample_bytree=0.9448979591836735; precision: (train=1.000, test=0.333) total time=   0.4s
# [CV 3/4; 47/50] START classifier__colsample_bytree=0.9448979591836735...........
# [CV 3/4; 47/50] END classifier__colsample_bytree=0.9448979591836735; precision: (train=1.000, test=0.500) total time=   0.4s
# [CV 4/4; 47/50] START classifier__colsample_bytree=0.9448979591836735...........
# [CV 4/4; 47/50] END classifier__colsample_bytree=0.9448979591836735; precision: (train=1.000, test=0.000) total time=   0.5s
# [CV 1/4; 48/50] START classifier__colsample_bytree=0.963265306122449............
# [CV 1/4; 48/50] END classifier__colsample_bytree=0.963265306122449; precision: (train=1.000, test=0.125) total time=   0.4s
# [CV 2/4; 48/50] START classifier__colsample_bytree=0.963265306122449............
# [CV 2/4; 48/50] END classifier__colsample_bytree=0.963265306122449; precision: (train=1.000, test=0.000) total time=   0.4s
# [CV 3/4; 48/50] START classifier__colsample_bytree=0.963265306122449............
# [CV 3/4; 48/50] END classifier__colsample_bytree=0.963265306122449; precision: (train=1.000, test=0.600) total time=   0.5s
# [CV 4/4; 48/50] START classifier__colsample_bytree=0.963265306122449............
# [CV 4/4; 48/50] END classifier__colsample_bytree=0.963265306122449; precision: (train=1.000, test=0.000) total time=   0.4s
# [CV 1/4; 49/50] START classifier__colsample_bytree=0.9816326530612246...........
# [CV 1/4; 49/50] END classifier__colsample_bytree=0.9816326530612246; precision: (train=1.000, test=0.125) total time=   0.4s
# [CV 2/4; 49/50] START classifier__colsample_bytree=0.9816326530612246...........
# [CV 2/4; 49/50] END classifier__colsample_bytree=0.9816326530612246; precision: (train=1.000, test=0.000) total time=   0.4s
# [CV 3/4; 49/50] START classifier__colsample_bytree=0.9816326530612246...........
# [CV 3/4; 49/50] END classifier__colsample_bytree=0.9816326530612246; precision: (train=1.000, test=0.600) total time=   0.5s
# [CV 4/4; 49/50] START classifier__colsample_bytree=0.9816326530612246...........
# [CV 4/4; 49/50] END classifier__colsample_bytree=0.9816326530612246; precision: (train=1.000, test=0.000) total time=   0.5s
# [CV 1/4; 50/50] START classifier__colsample_bytree=1.0..........................
# [CV 1/4; 50/50] END classifier__colsample_bytree=1.0; precision: (train=1.000, test=0.143) total time=   0.5s
# [CV 2/4; 50/50] START classifier__colsample_bytree=1.0..........................
# [CV 2/4; 50/50] END classifier__colsample_bytree=1.0; precision: (train=1.000, test=0.000) total time=   0.4s
# [CV 3/4; 50/50] START classifier__colsample_bytree=1.0..........................
# [CV 3/4; 50/50] END classifier__colsample_bytree=1.0; precision: (train=1.000, test=0.600) total time=   0.5s
# [CV 4/4; 50/50] START classifier__colsample_bytree=1.0..........................
# [CV 4/4; 50/50] END classifier__colsample_bytree=1.0; precision: (train=1.000, test=0.000) total time=   0.5s
# 0.25 {'classifier__colsample_bytree': 0.926530612244898}
# 0.0

# %% [markdown]
# 3. eta

# %%
colsample_bytree = 0.926530612244898

param_distributions = {
        "classifier__eta": [i for i in np.linspace(0.01, 0.4, 50)]
    }
classifier = XGBClassifier(n_jobs=None, scale_pos_weight=scale_pos_weight, eval_metric='aucpr'
                           , max_depth=max_depth, min_child_weight=min_child_weight
                           , colsample_bytree=colsample_bytree)
pipeline = Pipeline([
        ('custom_preprocessor', CustomPreprocessor()),
        ('classifier', classifier)
    ])
random_search = run_experiment(features, param_distributions, pipeline, 
                               n_iter=50, n_splits=4, 
                               classifier=classifier)
# Out:
# Fitting 4 folds for each of 50 candidates, totalling 200 fits
# [CV 1/4; 1/50] START classifier__eta=0.01.......................................
# [CV 1/4; 1/50] END classifier__eta=0.01; precision: (train=0.677, test=0.188) total time=   0.4s
# [CV 2/4; 1/50] START classifier__eta=0.01.......................................
# [CV 2/4; 1/50] END classifier__eta=0.01; precision: (train=0.603, test=0.111) total time=   0.4s
# [CV 3/4; 1/50] START classifier__eta=0.01.......................................
# [CV 3/4; 1/50] END classifier__eta=0.01; precision: (train=0.519, test=0.100) total time=   0.4s
# [CV 4/4; 1/50] START classifier__eta=0.01.......................................
# [CV 4/4; 1/50] END classifier__eta=0.01; precision: (train=0.554, test=0.095) total time=   0.4s
# [CV 1/4; 2/50] START classifier__eta=0.017959183673469388.......................
# [CV 1/4; 2/50] END classifier__eta=0.017959183673469388; precision: (train=0.737, test=0.133) total time=   0.4s
# [CV 2/4; 2/50] START classifier__eta=0.017959183673469388.......................
# [CV 2/4; 2/50] END classifier__eta=0.017959183673469388; precision: (train=0.695, test=0.105) total time=   0.4s
# [CV 3/4; 2/50] START classifier__eta=0.017959183673469388.......................
# [CV 3/4; 2/50] END classifier__eta=0.017959183673469388; precision: (train=0.577, test=0.120) total time=   0.4s
# [CV 4/4; 2/50] START classifier__eta=0.017959183673469388.......................
# [CV 4/4; 2/50] END classifier__eta=0.017959183673469388; precision: (train=0.651, test=0.133) total time=   0.4s
# [CV 1/4; 3/50] START classifier__eta=0.025918367346938774.......................
# [CV 1/4; 3/50] END classifier__eta=0.025918367346938774; precision: (train=0.840, test=0.154) total time=   0.4s
# [CV 2/4; 3/50] START classifier__eta=0.025918367346938774.......................
# [CV 2/4; 3/50] END classifier__eta=0.025918367346938774; precision: (train=0.837, test=0.077) total time=   0.4s
# [CV 3/4; 3/50] START classifier__eta=0.025918367346938774.......................
# [CV 3/4; 3/50] END classifier__eta=0.025918367346938774; precision: (train=0.732, test=0.158) total time=   0.4s
# [CV 4/4; 3/50] START classifier__eta=0.025918367346938774.......................
# [CV 4/4; 3/50] END classifier__eta=0.025918367346938774; precision: (train=0.759, test=0.000) total time=   0.4s
# [CV 1/4; 4/50] START classifier__eta=0.03387755102040817........................
# [CV 1/4; 4/50] END classifier__eta=0.03387755102040817; precision: (train=0.857, test=0.091) total time=   0.4s
# [CV 2/4; 4/50] START classifier__eta=0.03387755102040817........................
# [CV 2/4; 4/50] END classifier__eta=0.03387755102040817; precision: (train=0.872, test=0.091) total time=   0.4s
# [CV 3/4; 4/50] START classifier__eta=0.03387755102040817........................
# [CV 3/4; 4/50] END classifier__eta=0.03387755102040817; precision: (train=0.837, test=0.167) total time=   0.4s
# [CV 4/4; 4/50] START classifier__eta=0.03387755102040817........................
# [CV 4/4; 4/50] END classifier__eta=0.03387755102040817; precision: (train=0.854, test=0.000) total time=   0.4s
# [CV 1/4; 5/50] START classifier__eta=0.04183673469387755........................
# [CV 1/4; 5/50] END classifier__eta=0.04183673469387755; precision: (train=0.875, test=0.083) total time=   0.4s
# [CV 2/4; 5/50] START classifier__eta=0.04183673469387755........................
# [CV 2/4; 5/50] END classifier__eta=0.04183673469387755; precision: (train=0.932, test=0.100) total time=   0.4s
# [CV 3/4; 5/50] START classifier__eta=0.04183673469387755........................
# [CV 3/4; 5/50] END classifier__eta=0.04183673469387755; precision: (train=0.891, test=0.200) total time=   0.4s
# [CV 4/4; 5/50] START classifier__eta=0.04183673469387755........................
# [CV 4/4; 5/50] END classifier__eta=0.04183673469387755; precision: (train=0.872, test=0.000) total time=   0.4s
# [CV 1/4; 6/50] START classifier__eta=0.04979591836734694........................
# [CV 1/4; 6/50] END classifier__eta=0.04979591836734694; precision: (train=0.955, test=0.111) total time=   0.4s
# [CV 2/4; 6/50] START classifier__eta=0.04979591836734694........................
# [CV 2/4; 6/50] END classifier__eta=0.04979591836734694; precision: (train=0.932, test=0.111) total time=   0.4s
# [CV 3/4; 6/50] START classifier__eta=0.04979591836734694........................
# [CV 3/4; 6/50] END classifier__eta=0.04979591836734694; precision: (train=0.953, test=0.214) total time=   0.4s
# [CV 4/4; 6/50] START classifier__eta=0.04979591836734694........................
# [CV 4/4; 6/50] END classifier__eta=0.04979591836734694; precision: (train=0.872, test=0.000) total time=   0.4s
# [CV 1/4; 7/50] START classifier__eta=0.05775510204081633........................
# [CV 1/4; 7/50] END classifier__eta=0.05775510204081633; precision: (train=0.977, test=0.111) total time=   0.4s
# [CV 2/4; 7/50] START classifier__eta=0.05775510204081633........................
# [CV 2/4; 7/50] END classifier__eta=0.05775510204081633; precision: (train=0.953, test=0.222) total time=   0.4s
# [CV 3/4; 7/50] START classifier__eta=0.05775510204081633........................
# [CV 3/4; 7/50] END classifier__eta=0.05775510204081633; precision: (train=0.976, test=0.333) total time=   0.4s
# [CV 4/4; 7/50] START classifier__eta=0.05775510204081633........................
# [CV 4/4; 7/50] END classifier__eta=0.05775510204081633; precision: (train=0.911, test=0.000) total time=   0.4s
# [CV 1/4; 8/50] START classifier__eta=0.06571428571428571........................
# [CV 1/4; 8/50] END classifier__eta=0.06571428571428571; precision: (train=1.000, test=0.111) total time=   0.4s
# [CV 2/4; 8/50] START classifier__eta=0.06571428571428571........................
# [CV 2/4; 8/50] END classifier__eta=0.06571428571428571; precision: (train=0.976, test=0.125) total time=   0.4s
# [CV 3/4; 8/50] START classifier__eta=0.06571428571428571........................
# [CV 3/4; 8/50] END classifier__eta=0.06571428571428571; precision: (train=1.000, test=0.333) total time=   0.4s
# [CV 4/4; 8/50] START classifier__eta=0.06571428571428571........................
# [CV 4/4; 8/50] END classifier__eta=0.06571428571428571; precision: (train=1.000, test=0.000) total time=   0.4s
# [CV 1/4; 9/50] START classifier__eta=0.0736734693877551.........................
# [CV 1/4; 9/50] END classifier__eta=0.0736734693877551; precision: (train=1.000, test=0.111) total time=   0.4s
# [CV 2/4; 9/50] START classifier__eta=0.0736734693877551.........................
# [CV 2/4; 9/50] END classifier__eta=0.0736734693877551; precision: (train=1.000, test=0.143) total time=   0.4s
# [CV 3/4; 9/50] START classifier__eta=0.0736734693877551.........................
# [CV 3/4; 9/50] END classifier__eta=0.0736734693877551; precision: (train=1.000, test=0.286) total time=   0.4s
# [CV 4/4; 9/50] START classifier__eta=0.0736734693877551.........................
# [CV 4/4; 9/50] END classifier__eta=0.0736734693877551; precision: (train=1.000, test=0.000) total time=   0.4s
# [CV 1/4; 10/50] START classifier__eta=0.08163265306122448.......................
# [CV 1/4; 10/50] END classifier__eta=0.08163265306122448; precision: (train=1.000, test=0.125) total time=   0.4s
# [CV 2/4; 10/50] START classifier__eta=0.08163265306122448.......................
# [CV 2/4; 10/50] END classifier__eta=0.08163265306122448; precision: (train=1.000, test=0.143) total time=   0.4s
# [CV 3/4; 10/50] START classifier__eta=0.08163265306122448.......................
# [CV 3/4; 10/50] END classifier__eta=0.08163265306122448; precision: (train=1.000, test=0.286) total time=   0.4s
# [CV 4/4; 10/50] START classifier__eta=0.08163265306122448.......................
# [CV 4/4; 10/50] END classifier__eta=0.08163265306122448; precision: (train=1.000, test=0.000) total time=   0.4s
# [CV 1/4; 11/50] START classifier__eta=0.08959183673469387.......................
# [CV 1/4; 11/50] END classifier__eta=0.08959183673469387; precision: (train=1.000, test=0.100) total time=   0.4s
# [CV 2/4; 11/50] START classifier__eta=0.08959183673469387.......................
# [CV 2/4; 11/50] END classifier__eta=0.08959183673469387; precision: (train=1.000, test=0.167) total time=   0.4s
# [CV 3/4; 11/50] START classifier__eta=0.08959183673469387.......................
# [CV 3/4; 11/50] END classifier__eta=0.08959183673469387; precision: (train=1.000, test=0.375) total time=   0.4s
# [CV 4/4; 11/50] START classifier__eta=0.08959183673469387.......................
# [CV 4/4; 11/50] END classifier__eta=0.08959183673469387; precision: (train=1.000, test=0.000) total time=   0.4s
# [CV 1/4; 12/50] START classifier__eta=0.09755102040816326.......................
# [CV 1/4; 12/50] END classifier__eta=0.09755102040816326; precision: (train=1.000, test=0.125) total time=   0.4s
# [CV 2/4; 12/50] START classifier__eta=0.09755102040816326.......................
# [CV 2/4; 12/50] END classifier__eta=0.09755102040816326; precision: (train=1.000, test=0.000) total time=   0.4s
# [CV 3/4; 12/50] START classifier__eta=0.09755102040816326.......................
# [CV 3/4; 12/50] END classifier__eta=0.09755102040816326; precision: (train=1.000, test=0.429) total time=   0.4s
# [CV 4/4; 12/50] START classifier__eta=0.09755102040816326.......................
# [CV 4/4; 12/50] END classifier__eta=0.09755102040816326; precision: (train=1.000, test=0.000) total time=   0.4s
# [CV 1/4; 13/50] START classifier__eta=0.10551020408163266.......................
# [CV 1/4; 13/50] END classifier__eta=0.10551020408163266; precision: (train=1.000, test=0.143) total time=   0.4s
# [CV 2/4; 13/50] START classifier__eta=0.10551020408163266.......................
# [CV 2/4; 13/50] END classifier__eta=0.10551020408163266; precision: (train=1.000, test=0.167) total time=   0.4s
# [CV 3/4; 13/50] START classifier__eta=0.10551020408163266.......................
# [CV 3/4; 13/50] END classifier__eta=0.10551020408163266; precision: (train=1.000, test=0.429) total time=   0.4s
# [CV 4/4; 13/50] START classifier__eta=0.10551020408163266.......................
# [CV 4/4; 13/50] END classifier__eta=0.10551020408163266; precision: (train=1.000, test=0.000) total time=   0.4s
# [CV 1/4; 14/50] START classifier__eta=0.11346938775510204.......................
# [CV 1/4; 14/50] END classifier__eta=0.11346938775510204; precision: (train=1.000, test=0.143) total time=   0.4s
# [CV 2/4; 14/50] START classifier__eta=0.11346938775510204.......................
# [CV 2/4; 14/50] END classifier__eta=0.11346938775510204; precision: (train=1.000, test=0.000) total time=   0.4s
# [CV 3/4; 14/50] START classifier__eta=0.11346938775510204.......................
# [CV 3/4; 14/50] END classifier__eta=0.11346938775510204; precision: (train=1.000, test=0.429) total time=   0.4s
# [CV 4/4; 14/50] START classifier__eta=0.11346938775510204.......................
# [CV 4/4; 14/50] END classifier__eta=0.11346938775510204; precision: (train=1.000, test=0.000) total time=   0.4s
# [CV 1/4; 15/50] START classifier__eta=0.12142857142857143.......................
# [CV 1/4; 15/50] END classifier__eta=0.12142857142857143; precision: (train=1.000, test=0.125) total time=   0.5s
# [CV 2/4; 15/50] START classifier__eta=0.12142857142857143.......................
# [CV 2/4; 15/50] END classifier__eta=0.12142857142857143; precision: (train=1.000, test=0.000) total time=   0.5s
# [CV 3/4; 15/50] START classifier__eta=0.12142857142857143.......................
# [CV 3/4; 15/50] END classifier__eta=0.12142857142857143; precision: (train=1.000, test=0.429) total time=   0.5s
# [CV 4/4; 15/50] START classifier__eta=0.12142857142857143.......................
# [CV 4/4; 15/50] END classifier__eta=0.12142857142857143; precision: (train=1.000, test=0.000) total time=   0.5s
# [CV 1/4; 16/50] START classifier__eta=0.1293877551020408........................
# [CV 1/4; 16/50] END classifier__eta=0.1293877551020408; precision: (train=1.000, test=0.111) total time=   0.5s
# [CV 2/4; 16/50] START classifier__eta=0.1293877551020408........................
# [CV 2/4; 16/50] END classifier__eta=0.1293877551020408; precision: (train=1.000, test=0.000) total time=   0.5s
# [CV 3/4; 16/50] START classifier__eta=0.1293877551020408........................
# [CV 3/4; 16/50] END classifier__eta=0.1293877551020408; precision: (train=1.000, test=0.429) total time=   0.5s
# [CV 4/4; 16/50] START classifier__eta=0.1293877551020408........................
# [CV 4/4; 16/50] END classifier__eta=0.1293877551020408; precision: (train=1.000, test=0.000) total time=   0.5s
# [CV 1/4; 17/50] START classifier__eta=0.1373469387755102........................
# [CV 1/4; 17/50] END classifier__eta=0.1373469387755102; precision: (train=1.000, test=0.143) total time=   0.5s
# [CV 2/4; 17/50] START classifier__eta=0.1373469387755102........................
# [CV 2/4; 17/50] END classifier__eta=0.1373469387755102; precision: (train=1.000, test=0.250) total time=   0.4s
# [CV 3/4; 17/50] START classifier__eta=0.1373469387755102........................
# [CV 3/4; 17/50] END classifier__eta=0.1373469387755102; precision: (train=1.000, test=0.600) total time=   0.5s
# [CV 4/4; 17/50] START classifier__eta=0.1373469387755102........................
# [CV 4/4; 17/50] END classifier__eta=0.1373469387755102; precision: (train=1.000, test=0.000) total time=   0.5s
# [CV 1/4; 18/50] START classifier__eta=0.1453061224489796........................
# [CV 1/4; 18/50] END classifier__eta=0.1453061224489796; precision: (train=1.000, test=0.167) total time=   0.5s
# [CV 2/4; 18/50] START classifier__eta=0.1453061224489796........................
# [CV 2/4; 18/50] END classifier__eta=0.1453061224489796; precision: (train=1.000, test=0.250) total time=   0.4s
# [CV 3/4; 18/50] START classifier__eta=0.1453061224489796........................
# [CV 3/4; 18/50] END classifier__eta=0.1453061224489796; precision: (train=1.000, test=0.600) total time=   0.5s
# [CV 4/4; 18/50] START classifier__eta=0.1453061224489796........................
# [CV 4/4; 18/50] END classifier__eta=0.1453061224489796; precision: (train=1.000, test=0.000) total time=   0.5s
# [CV 1/4; 19/50] START classifier__eta=0.15326530612244899.......................
# [CV 1/4; 19/50] END classifier__eta=0.15326530612244899; precision: (train=1.000, test=0.125) total time=   0.5s
# [CV 2/4; 19/50] START classifier__eta=0.15326530612244899.......................
# [CV 2/4; 19/50] END classifier__eta=0.15326530612244899; precision: (train=1.000, test=0.200) total time=   0.5s
# [CV 3/4; 19/50] START classifier__eta=0.15326530612244899.......................
# [CV 3/4; 19/50] END classifier__eta=0.15326530612244899; precision: (train=1.000, test=0.500) total time=   0.5s
# [CV 4/4; 19/50] START classifier__eta=0.15326530612244899.......................
# [CV 4/4; 19/50] END classifier__eta=0.15326530612244899; precision: (train=1.000, test=0.000) total time=   0.5s
# [CV 1/4; 20/50] START classifier__eta=0.16122448979591839.......................
# [CV 1/4; 20/50] END classifier__eta=0.16122448979591839; precision: (train=1.000, test=0.111) total time=   0.5s
# [CV 2/4; 20/50] START classifier__eta=0.16122448979591839.......................
# [CV 2/4; 20/50] END classifier__eta=0.16122448979591839; precision: (train=1.000, test=0.200) total time=   0.4s
# [CV 3/4; 20/50] START classifier__eta=0.16122448979591839.......................
# [CV 3/4; 20/50] END classifier__eta=0.16122448979591839; precision: (train=1.000, test=0.600) total time=   0.5s
# [CV 4/4; 20/50] START classifier__eta=0.16122448979591839.......................
# [CV 4/4; 20/50] END classifier__eta=0.16122448979591839; precision: (train=1.000, test=0.000) total time=   0.5s
# [CV 1/4; 21/50] START classifier__eta=0.16918367346938776.......................
# [CV 1/4; 21/50] END classifier__eta=0.16918367346938776; precision: (train=1.000, test=0.143) total time=   0.5s
# [CV 2/4; 21/50] START classifier__eta=0.16918367346938776.......................
# [CV 2/4; 21/50] END classifier__eta=0.16918367346938776; precision: (train=1.000, test=0.000) total time=   0.5s
# [CV 3/4; 21/50] START classifier__eta=0.16918367346938776.......................
# [CV 3/4; 21/50] END classifier__eta=0.16918367346938776; precision: (train=1.000, test=0.600) total time=   0.5s
# [CV 4/4; 21/50] START classifier__eta=0.16918367346938776.......................
# [CV 4/4; 21/50] END classifier__eta=0.16918367346938776; precision: (train=1.000, test=0.000) total time=   0.5s
# [CV 1/4; 22/50] START classifier__eta=0.17714285714285716.......................
# [CV 1/4; 22/50] END classifier__eta=0.17714285714285716; precision: (train=1.000, test=0.143) total time=   0.5s
# [CV 2/4; 22/50] START classifier__eta=0.17714285714285716.......................
# [CV 2/4; 22/50] END classifier__eta=0.17714285714285716; precision: (train=1.000, test=0.000) total time=   0.5s
# [CV 3/4; 22/50] START classifier__eta=0.17714285714285716.......................
# [CV 3/4; 22/50] END classifier__eta=0.17714285714285716; precision: (train=1.000, test=0.429) total time=   0.5s
# [CV 4/4; 22/50] START classifier__eta=0.17714285714285716.......................
# [CV 4/4; 22/50] END classifier__eta=0.17714285714285716; precision: (train=1.000, test=0.000) total time=   0.5s
# [CV 1/4; 23/50] START classifier__eta=0.18510204081632653.......................
# [CV 1/4; 23/50] END classifier__eta=0.18510204081632653; precision: (train=1.000, test=0.125) total time=   0.5s
# [CV 2/4; 23/50] START classifier__eta=0.18510204081632653.......................
# [CV 2/4; 23/50] END classifier__eta=0.18510204081632653; precision: (train=1.000, test=0.000) total time=   0.4s
# [CV 3/4; 23/50] START classifier__eta=0.18510204081632653.......................
# [CV 3/4; 23/50] END classifier__eta=0.18510204081632653; precision: (train=1.000, test=0.429) total time=   0.5s
# [CV 4/4; 23/50] START classifier__eta=0.18510204081632653.......................
# [CV 4/4; 23/50] END classifier__eta=0.18510204081632653; precision: (train=1.000, test=0.000) total time=   0.5s
# [CV 1/4; 24/50] START classifier__eta=0.19306122448979593.......................
# [CV 1/4; 24/50] END classifier__eta=0.19306122448979593; precision: (train=1.000, test=0.125) total time=   0.5s
# [CV 2/4; 24/50] START classifier__eta=0.19306122448979593.......................
# [CV 2/4; 24/50] END classifier__eta=0.19306122448979593; precision: (train=1.000, test=0.000) total time=   0.5s
# [CV 3/4; 24/50] START classifier__eta=0.19306122448979593.......................
# [CV 3/4; 24/50] END classifier__eta=0.19306122448979593; precision: (train=1.000, test=0.600) total time=   0.5s
# [CV 4/4; 24/50] START classifier__eta=0.19306122448979593.......................
# [CV 4/4; 24/50] END classifier__eta=0.19306122448979593; precision: (train=1.000, test=0.000) total time=   0.5s
# [CV 1/4; 25/50] START classifier__eta=0.20102040816326533.......................
# [CV 1/4; 25/50] END classifier__eta=0.20102040816326533; precision: (train=1.000, test=0.125) total time=   0.5s
# [CV 2/4; 25/50] START classifier__eta=0.20102040816326533.......................
# [CV 2/4; 25/50] END classifier__eta=0.20102040816326533; precision: (train=1.000, test=0.000) total time=   0.5s
# [CV 3/4; 25/50] START classifier__eta=0.20102040816326533.......................
# [CV 3/4; 25/50] END classifier__eta=0.20102040816326533; precision: (train=1.000, test=0.500) total time=   0.5s
# [CV 4/4; 25/50] START classifier__eta=0.20102040816326533.......................
# [CV 4/4; 25/50] END classifier__eta=0.20102040816326533; precision: (train=1.000, test=0.000) total time=   0.5s
# [CV 1/4; 26/50] START classifier__eta=0.2089795918367347........................
# [CV 1/4; 26/50] END classifier__eta=0.2089795918367347; precision: (train=1.000, test=0.167) total time=   0.5s
# [CV 2/4; 26/50] START classifier__eta=0.2089795918367347........................
# [CV 2/4; 26/50] END classifier__eta=0.2089795918367347; precision: (train=1.000, test=0.000) total time=   0.5s
# [CV 3/4; 26/50] START classifier__eta=0.2089795918367347........................
# [CV 3/4; 26/50] END classifier__eta=0.2089795918367347; precision: (train=1.000, test=0.600) total time=   0.5s
# [CV 4/4; 26/50] START classifier__eta=0.2089795918367347........................
# [CV 4/4; 26/50] END classifier__eta=0.2089795918367347; precision: (train=1.000, test=0.000) total time=   0.5s
# [CV 1/4; 27/50] START classifier__eta=0.2169387755102041........................
# [CV 1/4; 27/50] END classifier__eta=0.2169387755102041; precision: (train=1.000, test=0.143) total time=   0.5s
# [CV 2/4; 27/50] START classifier__eta=0.2169387755102041........................
# [CV 2/4; 27/50] END classifier__eta=0.2169387755102041; precision: (train=1.000, test=0.000) total time=   0.4s
# [CV 3/4; 27/50] START classifier__eta=0.2169387755102041........................
# [CV 3/4; 27/50] END classifier__eta=0.2169387755102041; precision: (train=1.000, test=0.500) total time=   0.5s
# [CV 4/4; 27/50] START classifier__eta=0.2169387755102041........................
# [CV 4/4; 27/50] END classifier__eta=0.2169387755102041; precision: (train=1.000, test=0.000) total time=   0.5s
# [CV 1/4; 28/50] START classifier__eta=0.22489795918367347.......................
# [CV 1/4; 28/50] END classifier__eta=0.22489795918367347; precision: (train=1.000, test=0.143) total time=   0.5s
# [CV 2/4; 28/50] START classifier__eta=0.22489795918367347.......................
# [CV 2/4; 28/50] END classifier__eta=0.22489795918367347; precision: (train=1.000, test=0.000) total time=   0.5s
# [CV 3/4; 28/50] START classifier__eta=0.22489795918367347.......................
# [CV 3/4; 28/50] END classifier__eta=0.22489795918367347; precision: (train=1.000, test=0.500) total time=   0.5s
# [CV 4/4; 28/50] START classifier__eta=0.22489795918367347.......................
# [CV 4/4; 28/50] END classifier__eta=0.22489795918367347; precision: (train=1.000, test=0.000) total time=   0.5s
# [CV 1/4; 29/50] START classifier__eta=0.23285714285714287.......................
# [CV 1/4; 29/50] END classifier__eta=0.23285714285714287; precision: (train=1.000, test=0.125) total time=   0.5s
# [CV 2/4; 29/50] START classifier__eta=0.23285714285714287.......................
# [CV 2/4; 29/50] END classifier__eta=0.23285714285714287; precision: (train=1.000, test=0.000) total time=   0.5s
# [CV 3/4; 29/50] START classifier__eta=0.23285714285714287.......................
# [CV 3/4; 29/50] END classifier__eta=0.23285714285714287; precision: (train=1.000, test=0.500) total time=   0.5s
# [CV 4/4; 29/50] START classifier__eta=0.23285714285714287.......................
# [CV 4/4; 29/50] END classifier__eta=0.23285714285714287; precision: (train=1.000, test=0.000) total time=   0.5s
# [CV 1/4; 30/50] START classifier__eta=0.24081632653061225.......................
# [CV 1/4; 30/50] END classifier__eta=0.24081632653061225; precision: (train=1.000, test=0.143) total time=   0.5s
# [CV 2/4; 30/50] START classifier__eta=0.24081632653061225.......................
# [CV 2/4; 30/50] END classifier__eta=0.24081632653061225; precision: (train=1.000, test=0.000) total time=   0.5s
# [CV 3/4; 30/50] START classifier__eta=0.24081632653061225.......................
# [CV 3/4; 30/50] END classifier__eta=0.24081632653061225; precision: (train=1.000, test=0.429) total time=   0.5s
# [CV 4/4; 30/50] START classifier__eta=0.24081632653061225.......................
# [CV 4/4; 30/50] END classifier__eta=0.24081632653061225; precision: (train=1.000, test=0.000) total time=   0.5s
# [CV 1/4; 31/50] START classifier__eta=0.24877551020408165.......................
# [CV 1/4; 31/50] END classifier__eta=0.24877551020408165; precision: (train=1.000, test=0.143) total time=   0.5s
# [CV 2/4; 31/50] START classifier__eta=0.24877551020408165.......................
# [CV 2/4; 31/50] END classifier__eta=0.24877551020408165; precision: (train=1.000, test=0.000) total time=   0.4s
# [CV 3/4; 31/50] START classifier__eta=0.24877551020408165.......................
# [CV 3/4; 31/50] END classifier__eta=0.24877551020408165; precision: (train=1.000, test=0.429) total time=   0.5s
# [CV 4/4; 31/50] START classifier__eta=0.24877551020408165.......................
# [CV 4/4; 31/50] END classifier__eta=0.24877551020408165; precision: (train=1.000, test=0.000) total time=   0.4s
# [CV 1/4; 32/50] START classifier__eta=0.256734693877551.........................
# [CV 1/4; 32/50] END classifier__eta=0.256734693877551; precision: (train=1.000, test=0.143) total time=   0.5s
# [CV 2/4; 32/50] START classifier__eta=0.256734693877551.........................
# [CV 2/4; 32/50] END classifier__eta=0.256734693877551; precision: (train=1.000, test=0.333) total time=   0.5s
# [CV 3/4; 32/50] START classifier__eta=0.256734693877551.........................
# [CV 3/4; 32/50] END classifier__eta=0.256734693877551; precision: (train=1.000, test=0.500) total time=   0.5s
# [CV 4/4; 32/50] START classifier__eta=0.256734693877551.........................
# [CV 4/4; 32/50] END classifier__eta=0.256734693877551; precision: (train=1.000, test=0.000) total time=   0.5s
# [CV 1/4; 33/50] START classifier__eta=0.2646938775510204........................
# [CV 1/4; 33/50] END classifier__eta=0.2646938775510204; precision: (train=1.000, test=0.143) total time=   0.5s
# [CV 2/4; 33/50] START classifier__eta=0.2646938775510204........................
# [CV 2/4; 33/50] END classifier__eta=0.2646938775510204; precision: (train=1.000, test=0.000) total time=   0.4s
# [CV 3/4; 33/50] START classifier__eta=0.2646938775510204........................
# [CV 3/4; 33/50] END classifier__eta=0.2646938775510204; precision: (train=1.000, test=0.500) total time=   0.5s
# [CV 4/4; 33/50] START classifier__eta=0.2646938775510204........................
# [CV 4/4; 33/50] END classifier__eta=0.2646938775510204; precision: (train=1.000, test=0.000) total time=   0.5s
# [CV 1/4; 34/50] START classifier__eta=0.2726530612244898........................
# [CV 1/4; 34/50] END classifier__eta=0.2726530612244898; precision: (train=1.000, test=0.143) total time=   0.5s
# [CV 2/4; 34/50] START classifier__eta=0.2726530612244898........................
# [CV 2/4; 34/50] END classifier__eta=0.2726530612244898; precision: (train=1.000, test=0.000) total time=   0.4s
# [CV 3/4; 34/50] START classifier__eta=0.2726530612244898........................
# [CV 3/4; 34/50] END classifier__eta=0.2726530612244898; precision: (train=1.000, test=0.500) total time=   0.5s
# [CV 4/4; 34/50] START classifier__eta=0.2726530612244898........................
# [CV 4/4; 34/50] END classifier__eta=0.2726530612244898; precision: (train=1.000, test=0.000) total time=   0.5s
# [CV 1/4; 35/50] START classifier__eta=0.2806122448979592........................
# [CV 1/4; 35/50] END classifier__eta=0.2806122448979592; precision: (train=1.000, test=0.167) total time=   0.5s
# [CV 2/4; 35/50] START classifier__eta=0.2806122448979592........................
# [CV 2/4; 35/50] END classifier__eta=0.2806122448979592; precision: (train=1.000, test=0.333) total time=   0.4s
# [CV 3/4; 35/50] START classifier__eta=0.2806122448979592........................
# [CV 3/4; 35/50] END classifier__eta=0.2806122448979592; precision: (train=1.000, test=0.429) total time=   0.5s
# [CV 4/4; 35/50] START classifier__eta=0.2806122448979592........................
# [CV 4/4; 35/50] END classifier__eta=0.2806122448979592; precision: (train=1.000, test=0.000) total time=   0.5s
# [CV 1/4; 36/50] START classifier__eta=0.2885714285714286........................
# [CV 1/4; 36/50] END classifier__eta=0.2885714285714286; precision: (train=1.000, test=0.000) total time=   0.5s
# [CV 2/4; 36/50] START classifier__eta=0.2885714285714286........................
# [CV 2/4; 36/50] END classifier__eta=0.2885714285714286; precision: (train=1.000, test=0.333) total time=   0.5s
# [CV 3/4; 36/50] START classifier__eta=0.2885714285714286........................
# [CV 3/4; 36/50] END classifier__eta=0.2885714285714286; precision: (train=1.000, test=0.286) total time=   0.5s
# [CV 4/4; 36/50] START classifier__eta=0.2885714285714286........................
# [CV 4/4; 36/50] END classifier__eta=0.2885714285714286; precision: (train=1.000, test=0.000) total time=   0.5s
# [CV 1/4; 37/50] START classifier__eta=0.29653061224489796.......................
# [CV 1/4; 37/50] END classifier__eta=0.29653061224489796; precision: (train=1.000, test=0.125) total time=   0.5s
# [CV 2/4; 37/50] START classifier__eta=0.29653061224489796.......................
# [CV 2/4; 37/50] END classifier__eta=0.29653061224489796; precision: (train=1.000, test=0.250) total time=   0.5s
# [CV 3/4; 37/50] START classifier__eta=0.29653061224489796.......................
# [CV 3/4; 37/50] END classifier__eta=0.29653061224489796; precision: (train=1.000, test=0.400) total time=   0.5s
# [CV 4/4; 37/50] START classifier__eta=0.29653061224489796.......................
# [CV 4/4; 37/50] END classifier__eta=0.29653061224489796; precision: (train=1.000, test=0.000) total time=   0.5s
# [CV 1/4; 38/50] START classifier__eta=0.30448979591836733.......................
# [CV 1/4; 38/50] END classifier__eta=0.30448979591836733; precision: (train=1.000, test=0.250) total time=   0.5s
# [CV 2/4; 38/50] START classifier__eta=0.30448979591836733.......................
# [CV 2/4; 38/50] END classifier__eta=0.30448979591836733; precision: (train=1.000, test=0.000) total time=   0.4s
# [CV 3/4; 38/50] START classifier__eta=0.30448979591836733.......................
# [CV 3/4; 38/50] END classifier__eta=0.30448979591836733; precision: (train=1.000, test=0.500) total time=   0.5s
# [CV 4/4; 38/50] START classifier__eta=0.30448979591836733.......................
# [CV 4/4; 38/50] END classifier__eta=0.30448979591836733; precision: (train=1.000, test=0.000) total time=   0.5s
# [CV 1/4; 39/50] START classifier__eta=0.31244897959183676.......................
# [CV 1/4; 39/50] END classifier__eta=0.31244897959183676; precision: (train=1.000, test=0.167) total time=   0.5s
# [CV 2/4; 39/50] START classifier__eta=0.31244897959183676.......................
# [CV 2/4; 39/50] END classifier__eta=0.31244897959183676; precision: (train=1.000, test=0.250) total time=   0.5s
# [CV 3/4; 39/50] START classifier__eta=0.31244897959183676.......................
# [CV 3/4; 39/50] END classifier__eta=0.31244897959183676; precision: (train=1.000, test=0.400) total time=   0.5s
# [CV 4/4; 39/50] START classifier__eta=0.31244897959183676.......................
# [CV 4/4; 39/50] END classifier__eta=0.31244897959183676; precision: (train=1.000, test=0.000) total time=   0.5s
# [CV 1/4; 40/50] START classifier__eta=0.32040816326530613.......................
# [CV 1/4; 40/50] END classifier__eta=0.32040816326530613; precision: (train=1.000, test=0.167) total time=   0.5s
# [CV 2/4; 40/50] START classifier__eta=0.32040816326530613.......................
# [CV 2/4; 40/50] END classifier__eta=0.32040816326530613; precision: (train=1.000, test=0.000) total time=   0.5s
# [CV 3/4; 40/50] START classifier__eta=0.32040816326530613.......................
# [CV 3/4; 40/50] END classifier__eta=0.32040816326530613; precision: (train=1.000, test=0.600) total time=   0.5s
# [CV 4/4; 40/50] START classifier__eta=0.32040816326530613.......................
# [CV 4/4; 40/50] END classifier__eta=0.32040816326530613; precision: (train=1.000, test=0.000) total time=   0.5s
# [CV 1/4; 41/50] START classifier__eta=0.3283673469387755........................
# [CV 1/4; 41/50] END classifier__eta=0.3283673469387755; precision: (train=1.000, test=0.125) total time=   0.5s
# [CV 2/4; 41/50] START classifier__eta=0.3283673469387755........................
# [CV 2/4; 41/50] END classifier__eta=0.3283673469387755; precision: (train=1.000, test=0.000) total time=   0.4s
# [CV 3/4; 41/50] START classifier__eta=0.3283673469387755........................
# [CV 3/4; 41/50] END classifier__eta=0.3283673469387755; precision: (train=1.000, test=0.333) total time=   0.5s
# [CV 4/4; 41/50] START classifier__eta=0.3283673469387755........................
# [CV 4/4; 41/50] END classifier__eta=0.3283673469387755; precision: (train=1.000, test=0.000) total time=   0.5s
# [CV 1/4; 42/50] START classifier__eta=0.33632653061224493.......................
# [CV 1/4; 42/50] END classifier__eta=0.33632653061224493; precision: (train=1.000, test=0.000) total time=   0.5s
# [CV 2/4; 42/50] START classifier__eta=0.33632653061224493.......................
# [CV 2/4; 42/50] END classifier__eta=0.33632653061224493; precision: (train=1.000, test=0.000) total time=   0.4s
# [CV 3/4; 42/50] START classifier__eta=0.33632653061224493.......................
# [CV 3/4; 42/50] END classifier__eta=0.33632653061224493; precision: (train=1.000, test=0.500) total time=   0.5s
# [CV 4/4; 42/50] START classifier__eta=0.33632653061224493.......................
# [CV 4/4; 42/50] END classifier__eta=0.33632653061224493; precision: (train=1.000, test=0.000) total time=   0.5s
# [CV 1/4; 43/50] START classifier__eta=0.3442857142857143........................
# [CV 1/4; 43/50] END classifier__eta=0.3442857142857143; precision: (train=1.000, test=0.000) total time=   0.5s
# [CV 2/4; 43/50] START classifier__eta=0.3442857142857143........................
# [CV 2/4; 43/50] END classifier__eta=0.3442857142857143; precision: (train=1.000, test=0.000) total time=   0.5s
# [CV 3/4; 43/50] START classifier__eta=0.3442857142857143........................
# [CV 3/4; 43/50] END classifier__eta=0.3442857142857143; precision: (train=1.000, test=0.500) total time=   0.5s
# [CV 4/4; 43/50] START classifier__eta=0.3442857142857143........................
# [CV 4/4; 43/50] END classifier__eta=0.3442857142857143; precision: (train=1.000, test=0.000) total time=   0.5s
# [CV 1/4; 44/50] START classifier__eta=0.3522448979591837........................
# [CV 1/4; 44/50] END classifier__eta=0.3522448979591837; precision: (train=1.000, test=0.200) total time=   0.5s
# [CV 2/4; 44/50] START classifier__eta=0.3522448979591837........................
# [CV 2/4; 44/50] END classifier__eta=0.3522448979591837; precision: (train=1.000, test=0.000) total time=   0.4s
# [CV 3/4; 44/50] START classifier__eta=0.3522448979591837........................
# [CV 3/4; 44/50] END classifier__eta=0.3522448979591837; precision: (train=1.000, test=0.500) total time=   0.5s
# [CV 4/4; 44/50] START classifier__eta=0.3522448979591837........................
# [CV 4/4; 44/50] END classifier__eta=0.3522448979591837; precision: (train=1.000, test=0.000) total time=   0.5s
# [CV 1/4; 45/50] START classifier__eta=0.36020408163265305.......................
# [CV 1/4; 45/50] END classifier__eta=0.36020408163265305; precision: (train=1.000, test=0.143) total time=   0.5s
# [CV 2/4; 45/50] START classifier__eta=0.36020408163265305.......................
# [CV 2/4; 45/50] END classifier__eta=0.36020408163265305; precision: (train=1.000, test=0.000) total time=   0.4s
# [CV 3/4; 45/50] START classifier__eta=0.36020408163265305.......................
# [CV 3/4; 45/50] END classifier__eta=0.36020408163265305; precision: (train=1.000, test=0.400) total time=   0.5s
# [CV 4/4; 45/50] START classifier__eta=0.36020408163265305.......................
# [CV 4/4; 45/50] END classifier__eta=0.36020408163265305; precision: (train=1.000, test=0.000) total time=   0.5s
# [CV 1/4; 46/50] START classifier__eta=0.3681632653061225........................
# [CV 1/4; 46/50] END classifier__eta=0.3681632653061225; precision: (train=1.000, test=0.143) total time=   0.5s
# [CV 2/4; 46/50] START classifier__eta=0.3681632653061225........................
# [CV 2/4; 46/50] END classifier__eta=0.3681632653061225; precision: (train=1.000, test=0.000) total time=   0.5s
# [CV 3/4; 46/50] START classifier__eta=0.3681632653061225........................
# [CV 3/4; 46/50] END classifier__eta=0.3681632653061225; precision: (train=1.000, test=0.400) total time=   0.5s
# [CV 4/4; 46/50] START classifier__eta=0.3681632653061225........................
# [CV 4/4; 46/50] END classifier__eta=0.3681632653061225; precision: (train=1.000, test=0.000) total time=   0.5s
# [CV 1/4; 47/50] START classifier__eta=0.37612244897959185.......................
# [CV 1/4; 47/50] END classifier__eta=0.37612244897959185; precision: (train=1.000, test=0.000) total time=   0.5s
# [CV 2/4; 47/50] START classifier__eta=0.37612244897959185.......................
# [CV 2/4; 47/50] END classifier__eta=0.37612244897959185; precision: (train=1.000, test=0.000) total time=   0.5s
# [CV 3/4; 47/50] START classifier__eta=0.37612244897959185.......................
# [CV 3/4; 47/50] END classifier__eta=0.37612244897959185; precision: (train=1.000, test=0.400) total time=   0.5s
# [CV 4/4; 47/50] START classifier__eta=0.37612244897959185.......................
# [CV 4/4; 47/50] END classifier__eta=0.37612244897959185; precision: (train=1.000, test=0.000) total time=   0.5s
# [CV 1/4; 48/50] START classifier__eta=0.3840816326530612........................
# [CV 1/4; 48/50] END classifier__eta=0.3840816326530612; precision: (train=1.000, test=0.000) total time=   0.5s
# [CV 2/4; 48/50] START classifier__eta=0.3840816326530612........................
# [CV 2/4; 48/50] END classifier__eta=0.3840816326530612; precision: (train=1.000, test=0.000) total time=   0.5s
# [CV 3/4; 48/50] START classifier__eta=0.3840816326530612........................
# [CV 3/4; 48/50] END classifier__eta=0.3840816326530612; precision: (train=1.000, test=0.400) total time=   0.5s
# [CV 4/4; 48/50] START classifier__eta=0.3840816326530612........................
# [CV 4/4; 48/50] END classifier__eta=0.3840816326530612; precision: (train=1.000, test=0.000) total time=   0.5s
# [CV 1/4; 49/50] START classifier__eta=0.39204081632653065.......................
# [CV 1/4; 49/50] END classifier__eta=0.39204081632653065; precision: (train=1.000, test=0.000) total time=   0.5s
# [CV 2/4; 49/50] START classifier__eta=0.39204081632653065.......................
# [CV 2/4; 49/50] END classifier__eta=0.39204081632653065; precision: (train=1.000, test=0.333) total time=   0.4s
# [CV 3/4; 49/50] START classifier__eta=0.39204081632653065.......................
# [CV 3/4; 49/50] END classifier__eta=0.39204081632653065; precision: (train=1.000, test=0.500) total time=   0.5s
# [CV 4/4; 49/50] START classifier__eta=0.39204081632653065.......................
# [CV 4/4; 49/50] END classifier__eta=0.39204081632653065; precision: (train=1.000, test=0.000) total time=   0.5s
# [CV 1/4; 50/50] START classifier__eta=0.4.......................................
# [CV 1/4; 50/50] END classifier__eta=0.4; precision: (train=1.000, test=0.125) total time=   0.5s
# [CV 2/4; 50/50] START classifier__eta=0.4.......................................
# [CV 2/4; 50/50] END classifier__eta=0.4; precision: (train=1.000, test=0.250) total time=   0.4s
# [CV 3/4; 50/50] START classifier__eta=0.4.......................................
# [CV 3/4; 50/50] END classifier__eta=0.4; precision: (train=1.000, test=0.500) total time=   0.4s
# [CV 4/4; 50/50] START classifier__eta=0.4.......................................
# [CV 4/4; 50/50] END classifier__eta=0.4; precision: (train=1.000, test=0.000) total time=   0.5s
# 0.25416666666666665 {'classifier__eta': 0.1453061224489796}
# 0.0

# %% [markdown]
# 4. final model

# %%
eta = 0.3

classifier = XGBClassifier(n_jobs=None, scale_pos_weight=scale_pos_weight, eval_metric='aucpr'
                           , max_depth=max_depth, min_child_weight=min_child_weight
                           , colsample_bytree=colsample_bytree
                           , eta=eta)
pipeline = Pipeline([
        ('custom_preprocessor', CustomPreprocessor()),
        ('classifier', classifier)
    ])
pipeline.fit(X_train, y_train)
y_pred = pipeline.predict(X_test)
cm = confusion_matrix(y_test, y_pred)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=pipeline.classes_)
disp.plot()
print(precision_score(y_test, y_pred))

PrecisionRecallDisplay.from_estimator(pipeline, X_test, y_test)
plt.show()
# Out:
# 0.0

# %%
threshold = 0.03
y_pred = pipeline.predict_proba(X_test)[:,1]
y_pred = np.where(y_pred > threshold, 1, 0)
cm = confusion_matrix(y_test, y_pred)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=pipeline.classes_)
disp.plot()
print(precision_score(y_test, y_pred))
# Out:
# 0.25

# %%
features = pipeline.named_steps["custom_preprocessor"].get_feature_names_out()
importances = pipeline.named_steps["classifier"].feature_importances_
feature_importances = sorted(
    [i for i in zip(features, importances)], 
    key=lambda x: x[1],
    reverse=True
)
feature_importances = feature_importances
labels, values = zip(*feature_importances)

plt.figure(figsize=(10, 6))
plt.bar(labels, values, color='skyblue')
plt.xticks(rotation=45, ha='right', fontsize=10)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Random Forest
#
# a. balanced sampling

# %%
classifier = RandomForestClassifier(class_weight='balanced')
pipeline = Pipeline([
        ('custom_preprocessor', CustomPreprocessor()),
        ('classifier', classifier)
    ])
pipeline.fit(X_train, y_train)
y_pred = pipeline.predict(X_test)
cm = confusion_matrix(y_test, y_pred)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=pipeline.classes_)
disp.plot()
print(precision_score(y_test, y_pred))
PrecisionRecallDisplay.from_estimator(pipeline, X_test, y_test)
plt.show()
# Out:
# c:\Users\danjr\anaconda3\envs\cycleCollisions\lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# 0.0

# %% [markdown]
# b. SMOTE

# %%
classifier = RandomForestClassifier()
pipeline = Pipeline([
        ('custom_preprocessor', CustomPreprocessor()),
        ('over', SMOTE(sampling_strategy='not majority')),
        ('classifier', classifier)
    ])
pipeline.fit(X_train, y_train)
y_pred = pipeline.predict(X_test)
cm = confusion_matrix(y_test, y_pred)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=pipeline.classes_)
disp.plot()
print(precision_score(y_test, y_pred))
PrecisionRecallDisplay.from_estimator(pipeline, X_test, y_test)
plt.show()
# Out:
# 0.0
# c:\Users\danjr\anaconda3\envs\cycleCollisions\lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %% [markdown]
# balanced sampling works better than SMOTE

# %% [markdown]
# hyperparameter tuning

# %%
param_distributions = {
        "classifier__min_samples_split": [int(i) for i in np.linspace(2, 100, 50)],
        "classifier__max_features": [i for i in np.linspace(0.1, 1, 5)],
        "classifier__max_depth": [int(i) for i in np.linspace(10, 750, 50)] + [None],
        "classifier__max_leaf_nodes": [int(i) for i in np.linspace(100, 1000, 10)] + [None]
    }

classifier = RandomForestClassifier(class_weight='balanced', n_estimators=250)
pipeline = Pipeline([
        ('custom_preprocessor', CustomPreprocessor()),
        ('classifier', classifier)
    ])
random_search = run_experiment(features, param_distributions, pipeline, 
                               n_iter=100, n_splits=4, 
                               classifier=classifier)
# Out:
# Fitting 4 folds for each of 100 candidates, totalling 400 fits
# [CV 1/4; 1/100] START classifier__max_depth=221, classifier__max_features=0.775, classifier__max_leaf_nodes=None, classifier__min_samples_split=6, classifier__n_estimators=750
# [CV 1/4; 1/100] END classifier__max_depth=221, classifier__max_features=0.775, classifier__max_leaf_nodes=None, classifier__min_samples_split=6, classifier__n_estimators=750; precision: (train=0.977, test=0.000) total time=   6.4s
# [CV 2/4; 1/100] START classifier__max_depth=221, classifier__max_features=0.775, classifier__max_leaf_nodes=None, classifier__min_samples_split=6, classifier__n_estimators=750
# [CV 2/4; 1/100] END classifier__max_depth=221, classifier__max_features=0.775, classifier__max_leaf_nodes=None, classifier__min_samples_split=6, classifier__n_estimators=750; precision: (train=0.976, test=0.000) total time=   6.0s
# [CV 3/4; 1/100] START classifier__max_depth=221, classifier__max_features=0.775, classifier__max_leaf_nodes=None, classifier__min_samples_split=6, classifier__n_estimators=750
# [CV 3/4; 1/100] END classifier__max_depth=221, classifier__max_features=0.775, classifier__max_leaf_nodes=None, classifier__min_samples_split=6, classifier__n_estimators=750; precision: (train=1.000, test=1.000) total time=  11.2s
# [CV 4/4; 1/100] START classifier__max_depth=221, classifier__max_features=0.775, classifier__max_leaf_nodes=None, classifier__min_samples_split=6, classifier__n_estimators=750
# c:\Users\danjr\anaconda3\envs\cycleCollisions\lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# [CV 4/4; 1/100] END classifier__max_depth=221, classifier__max_features=0.775, classifier__max_leaf_nodes=None, classifier__min_samples_split=6, classifier__n_estimators=750; precision: (train=1.000, test=0.000) total time=   6.7s
# [CV 1/4; 2/100] START classifier__max_depth=266, classifier__max_features=1.0, classifier__max_leaf_nodes=100, classifier__min_samples_split=12, classifier__n_estimators=750
# [CV 1/4; 2/100] END classifier__max_depth=266, classifier__max_features=1.0, classifier__max_leaf_nodes=100, classifier__min_samples_split=12, classifier__n_estimators=750; precision: (train=0.955, test=0.000) total time=   9.4s
# [CV 2/4; 2/100] START classifier__max_depth=266, classifier__max_features=1.0, classifier__max_leaf_nodes=100, classifier__min_samples_split=12, classifier__n_estimators=750
# [CV 2/4; 2/100] END classifier__max_depth=266, classifier__max_features=1.0, classifier__max_leaf_nodes=100, classifier__min_samples_split=12, classifier__n_estimators=750; precision: (train=0.891, test=0.200) total time=   7.0s
# [CV 3/4; 2/100] START classifier__max_depth=266, classifier__max_features=1.0, classifier__max_leaf_nodes=100, classifier__min_samples_split=12, classifier__n_estimators=750
# [CV 3/4; 2/100] END classifier__max_depth=266, classifier__max_features=1.0, classifier__max_leaf_nodes=100, classifier__min_samples_split=12, classifier__n_estimators=750; precision: (train=0.872, test=0.333) total time=   7.1s
# [CV 4/4; 2/100] START classifier__max_depth=266, classifier__max_features=1.0, classifier__max_leaf_nodes=100, classifier__min_samples_split=12, classifier__n_estimators=750
# c:\Users\danjr\anaconda3\envs\cycleCollisions\lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# [CV 4/4; 2/100] END classifier__max_depth=266, classifier__max_features=1.0, classifier__max_leaf_nodes=100, classifier__min_samples_split=12, classifier__n_estimators=750; precision: (train=0.891, test=0.000) total time=   6.6s
# [CV 1/4; 3/100] START classifier__max_depth=236, classifier__max_features=1.0, classifier__max_leaf_nodes=None, classifier__min_samples_split=56, classifier__n_estimators=250
# [CV 1/4; 3/100] END classifier__max_depth=236, classifier__max_features=1.0, classifier__max_leaf_nodes=None, classifier__min_samples_split=56, classifier__n_estimators=250; precision: (train=0.506, test=0.190) total time=   2.4s
# [CV 2/4; 3/100] START classifier__max_depth=236, classifier__max_features=1.0, classifier__max_leaf_nodes=None, classifier__min_samples_split=56, classifier__n_estimators=250
# [CV 2/4; 3/100] END classifier__max_depth=236, classifier__max_features=1.0, classifier__max_leaf_nodes=None, classifier__min_samples_split=56, classifier__n_estimators=250; precision: (train=0.380, test=0.147) total time=   2.1s
# [CV 3/4; 3/100] START classifier__max_depth=236, classifier__max_features=1.0, classifier__max_leaf_nodes=None, classifier__min_samples_split=56, classifier__n_estimators=250
# [CV 3/4; 3/100] END classifier__max_depth=236, classifier__max_features=1.0, classifier__max_leaf_nodes=None, classifier__min_samples_split=56, classifier__n_estimators=250; precision: (train=0.357, test=0.121) total time=   2.2s
# [CV 4/4; 3/100] START classifier__max_depth=236, classifier__max_features=1.0, classifier__max_leaf_nodes=None, classifier__min_samples_split=56, classifier__n_estimators=250
# [CV 4/4; 3/100] END classifier__max_depth=236, classifier__max_features=1.0, classifier__max_leaf_nodes=None, classifier__min_samples_split=56, classifier__n_estimators=250; precision: (train=0.360, test=0.125) total time=   2.1s
# [CV 1/4; 4/100] START classifier__max_depth=674, classifier__max_features=0.325, classifier__max_leaf_nodes=800, classifier__min_samples_split=94, classifier__n_estimators=100
# [CV 1/4; 4/100] END classifier__max_depth=674, classifier__max_features=0.325, classifier__max_leaf_nodes=800, classifier__min_samples_split=94, classifier__n_estimators=100; precision: (train=0.339, test=0.158) total time=   0.5s
# [CV 2/4; 4/100] START classifier__max_depth=674, classifier__max_features=0.325, classifier__max_leaf_nodes=800, classifier__min_samples_split=94, classifier__n_estimators=100
# [CV 2/4; 4/100] END classifier__max_depth=674, classifier__max_features=0.325, classifier__max_leaf_nodes=800, classifier__min_samples_split=94, classifier__n_estimators=100; precision: (train=0.333, test=0.105) total time=   0.5s
# [CV 3/4; 4/100] START classifier__max_depth=674, classifier__max_features=0.325, classifier__max_leaf_nodes=800, classifier__min_samples_split=94, classifier__n_estimators=100
# [CV 3/4; 4/100] END classifier__max_depth=674, classifier__max_features=0.325, classifier__max_leaf_nodes=800, classifier__min_samples_split=94, classifier__n_estimators=100; precision: (train=0.285, test=0.071) total time=   0.5s
# [CV 4/4; 4/100] START classifier__max_depth=674, classifier__max_features=0.325, classifier__max_leaf_nodes=800, classifier__min_samples_split=94, classifier__n_estimators=100
# [CV 4/4; 4/100] END classifier__max_depth=674, classifier__max_features=0.325, classifier__max_leaf_nodes=800, classifier__min_samples_split=94, classifier__n_estimators=100; precision: (train=0.281, test=0.103) total time=   0.6s
# [CV 1/4; 5/100] START classifier__max_depth=478, classifier__max_features=0.55, classifier__max_leaf_nodes=100, classifier__min_samples_split=86, classifier__n_estimators=750
# [CV 1/4; 5/100] END classifier__max_depth=478, classifier__max_features=0.55, classifier__max_leaf_nodes=100, classifier__min_samples_split=86, classifier__n_estimators=750; precision: (train=0.359, test=0.182) total time=   4.3s
# [CV 2/4; 5/100] START classifier__max_depth=478, classifier__max_features=0.55, classifier__max_leaf_nodes=100, classifier__min_samples_split=86, classifier__n_estimators=750
# [CV 2/4; 5/100] END classifier__max_depth=478, classifier__max_features=0.55, classifier__max_leaf_nodes=100, classifier__min_samples_split=86, classifier__n_estimators=750; precision: (train=0.339, test=0.116) total time=   3.7s
# [CV 3/4; 5/100] START classifier__max_depth=478, classifier__max_features=0.55, classifier__max_leaf_nodes=100, classifier__min_samples_split=86, classifier__n_estimators=750
# [CV 3/4; 5/100] END classifier__max_depth=478, classifier__max_features=0.55, classifier__max_leaf_nodes=100, classifier__min_samples_split=86, classifier__n_estimators=750; precision: (train=0.299, test=0.093) total time=   4.0s
# [CV 4/4; 5/100] START classifier__max_depth=478, classifier__max_features=0.55, classifier__max_leaf_nodes=100, classifier__min_samples_split=86, classifier__n_estimators=750
# [CV 4/4; 5/100] END classifier__max_depth=478, classifier__max_features=0.55, classifier__max_leaf_nodes=100, classifier__min_samples_split=86, classifier__n_estimators=750; precision: (train=0.299, test=0.094) total time=   3.7s
# [CV 1/4; 6/100] START classifier__max_depth=221, classifier__max_features=0.55, classifier__max_leaf_nodes=800, classifier__min_samples_split=20, classifier__n_estimators=750
# [CV 1/4; 6/100] END classifier__max_depth=221, classifier__max_features=0.55, classifier__max_leaf_nodes=800, classifier__min_samples_split=20, classifier__n_estimators=750; precision: (train=0.857, test=0.286) total time=   4.6s
# [CV 2/4; 6/100] START classifier__max_depth=221, classifier__max_features=0.55, classifier__max_leaf_nodes=800, classifier__min_samples_split=20, classifier__n_estimators=750
# [CV 2/4; 6/100] END classifier__max_depth=221, classifier__max_features=0.55, classifier__max_leaf_nodes=800, classifier__min_samples_split=20, classifier__n_estimators=750; precision: (train=0.837, test=0.250) total time=   4.1s
# [CV 3/4; 6/100] START classifier__max_depth=221, classifier__max_features=0.55, classifier__max_leaf_nodes=800, classifier__min_samples_split=20, classifier__n_estimators=750
# [CV 3/4; 6/100] END classifier__max_depth=221, classifier__max_features=0.55, classifier__max_leaf_nodes=800, classifier__min_samples_split=20, classifier__n_estimators=750; precision: (train=0.732, test=0.222) total time=   4.4s
# [CV 4/4; 6/100] START classifier__max_depth=221, classifier__max_features=0.55, classifier__max_leaf_nodes=800, classifier__min_samples_split=20, classifier__n_estimators=750
# [CV 4/4; 6/100] END classifier__max_depth=221, classifier__max_features=0.55, classifier__max_leaf_nodes=800, classifier__min_samples_split=20, classifier__n_estimators=750; precision: (train=0.774, test=0.000) total time=   4.2s
# [CV 1/4; 7/100] START classifier__max_depth=206, classifier__max_features=0.325, classifier__max_leaf_nodes=1000, classifier__min_samples_split=14, classifier__n_estimators=100
# [CV 1/4; 7/100] END classifier__max_depth=206, classifier__max_features=0.325, classifier__max_leaf_nodes=1000, classifier__min_samples_split=14, classifier__n_estimators=100; precision: (train=0.955, test=0.000) total time=   0.6s
# [CV 2/4; 7/100] START classifier__max_depth=206, classifier__max_features=0.325, classifier__max_leaf_nodes=1000, classifier__min_samples_split=14, classifier__n_estimators=100
# [CV 2/4; 7/100] END classifier__max_depth=206, classifier__max_features=0.325, classifier__max_leaf_nodes=1000, classifier__min_samples_split=14, classifier__n_estimators=100; precision: (train=0.911, test=0.250) total time=   0.5s
# [CV 3/4; 7/100] START classifier__max_depth=206, classifier__max_features=0.325, classifier__max_leaf_nodes=1000, classifier__min_samples_split=14, classifier__n_estimators=100
# [CV 3/4; 7/100] END classifier__max_depth=206, classifier__max_features=0.325, classifier__max_leaf_nodes=1000, classifier__min_samples_split=14, classifier__n_estimators=100; precision: (train=0.891, test=0.333) total time=   0.5s
# [CV 4/4; 7/100] START classifier__max_depth=206, classifier__max_features=0.325, classifier__max_leaf_nodes=1000, classifier__min_samples_split=14, classifier__n_estimators=100
# c:\Users\danjr\anaconda3\envs\cycleCollisions\lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# [CV 4/4; 7/100] END classifier__max_depth=206, classifier__max_features=0.325, classifier__max_leaf_nodes=1000, classifier__min_samples_split=14, classifier__n_estimators=100; precision: (train=0.872, test=0.000) total time=   0.5s
# [CV 1/4; 8/100] START classifier__max_depth=387, classifier__max_features=0.1, classifier__max_leaf_nodes=None, classifier__min_samples_split=96, classifier__n_estimators=250
# [CV 1/4; 8/100] END classifier__max_depth=387, classifier__max_features=0.1, classifier__max_leaf_nodes=None, classifier__min_samples_split=96, classifier__n_estimators=250; precision: (train=0.315, test=0.111) total time=   0.8s
# [CV 2/4; 8/100] START classifier__max_depth=387, classifier__max_features=0.1, classifier__max_leaf_nodes=None, classifier__min_samples_split=96, classifier__n_estimators=250
# [CV 2/4; 8/100] END classifier__max_depth=387, classifier__max_features=0.1, classifier__max_leaf_nodes=None, classifier__min_samples_split=96, classifier__n_estimators=250; precision: (train=0.383, test=0.121) total time=   0.8s
# [CV 3/4; 8/100] START classifier__max_depth=387, classifier__max_features=0.1, classifier__max_leaf_nodes=None, classifier__min_samples_split=96, classifier__n_estimators=250
# [CV 3/4; 8/100] END classifier__max_depth=387, classifier__max_features=0.1, classifier__max_leaf_nodes=None, classifier__min_samples_split=96, classifier__n_estimators=250; precision: (train=0.271, test=0.083) total time=   0.8s
# [CV 4/4; 8/100] START classifier__max_depth=387, classifier__max_features=0.1, classifier__max_leaf_nodes=None, classifier__min_samples_split=96, classifier__n_estimators=250
# [CV 4/4; 8/100] END classifier__max_depth=387, classifier__max_features=0.1, classifier__max_leaf_nodes=None, classifier__min_samples_split=96, classifier__n_estimators=250; precision: (train=0.339, test=0.150) total time=   0.8s
# [CV 1/4; 9/100] START classifier__max_depth=100, classifier__max_features=0.775, classifier__max_leaf_nodes=300, classifier__min_samples_split=92, classifier__n_estimators=250
# [CV 1/4; 9/100] END classifier__max_depth=100, classifier__max_features=0.775, classifier__max_leaf_nodes=300, classifier__min_samples_split=92, classifier__n_estimators=250; precision: (train=0.365, test=0.158) total time=   1.9s
# [CV 2/4; 9/100] START classifier__max_depth=100, classifier__max_features=0.775, classifier__max_leaf_nodes=300, classifier__min_samples_split=92, classifier__n_estimators=250
# [CV 2/4; 9/100] END classifier__max_depth=100, classifier__max_features=0.775, classifier__max_leaf_nodes=300, classifier__min_samples_split=92, classifier__n_estimators=250; precision: (train=0.280, test=0.100) total time=   1.7s
# [CV 3/4; 9/100] START classifier__max_depth=100, classifier__max_features=0.775, classifier__max_leaf_nodes=300, classifier__min_samples_split=92, classifier__n_estimators=250
# [CV 3/4; 9/100] END classifier__max_depth=100, classifier__max_features=0.775, classifier__max_leaf_nodes=300, classifier__min_samples_split=92, classifier__n_estimators=250; precision: (train=0.270, test=0.102) total time=   1.8s
# [CV 4/4; 9/100] START classifier__max_depth=100, classifier__max_features=0.775, classifier__max_leaf_nodes=300, classifier__min_samples_split=92, classifier__n_estimators=250
# [CV 4/4; 9/100] END classifier__max_depth=100, classifier__max_features=0.775, classifier__max_leaf_nodes=300, classifier__min_samples_split=92, classifier__n_estimators=250; precision: (train=0.256, test=0.081) total time=   1.6s
# [CV 1/4; 10/100] START classifier__max_depth=251, classifier__max_features=0.775, classifier__max_leaf_nodes=300, classifier__min_samples_split=60, classifier__n_estimators=100
# [CV 1/4; 10/100] END classifier__max_depth=251, classifier__max_features=0.775, classifier__max_leaf_nodes=300, classifier__min_samples_split=60, classifier__n_estimators=100; precision: (train=0.477, test=0.190) total time=   0.8s
# [CV 2/4; 10/100] START classifier__max_depth=251, classifier__max_features=0.775, classifier__max_leaf_nodes=300, classifier__min_samples_split=60, classifier__n_estimators=100
# [CV 2/4; 10/100] END classifier__max_depth=251, classifier__max_features=0.775, classifier__max_leaf_nodes=300, classifier__min_samples_split=60, classifier__n_estimators=100; precision: (train=0.336, test=0.135) total time=   0.8s
# [CV 3/4; 10/100] START classifier__max_depth=251, classifier__max_features=0.775, classifier__max_leaf_nodes=300, classifier__min_samples_split=60, classifier__n_estimators=100
# [CV 3/4; 10/100] END classifier__max_depth=251, classifier__max_features=0.775, classifier__max_leaf_nodes=300, classifier__min_samples_split=60, classifier__n_estimators=100; precision: (train=0.328, test=0.091) total time=   0.9s
# [CV 4/4; 10/100] START classifier__max_depth=251, classifier__max_features=0.775, classifier__max_leaf_nodes=300, classifier__min_samples_split=60, classifier__n_estimators=100
# [CV 4/4; 10/100] END classifier__max_depth=251, classifier__max_features=0.775, classifier__max_leaf_nodes=300, classifier__min_samples_split=60, classifier__n_estimators=100; precision: (train=0.376, test=0.120) total time=   0.9s
# [CV 1/4; 11/100] START classifier__max_depth=161, classifier__max_features=0.775, classifier__max_leaf_nodes=100, classifier__min_samples_split=34, classifier__n_estimators=100
# [CV 1/4; 11/100] END classifier__max_depth=161, classifier__max_features=0.775, classifier__max_leaf_nodes=100, classifier__min_samples_split=34, classifier__n_estimators=100; precision: (train=0.724, test=0.286) total time=   1.1s
# [CV 2/4; 11/100] START classifier__max_depth=161, classifier__max_features=0.775, classifier__max_leaf_nodes=100, classifier__min_samples_split=34, classifier__n_estimators=100
# [CV 2/4; 11/100] END classifier__max_depth=161, classifier__max_features=0.775, classifier__max_leaf_nodes=100, classifier__min_samples_split=34, classifier__n_estimators=100; precision: (train=0.519, test=0.150) total time=   1.1s
# [CV 3/4; 11/100] START classifier__max_depth=161, classifier__max_features=0.775, classifier__max_leaf_nodes=100, classifier__min_samples_split=34, classifier__n_estimators=100
# [CV 3/4; 11/100] END classifier__max_depth=161, classifier__max_features=0.775, classifier__max_leaf_nodes=100, classifier__min_samples_split=34, classifier__n_estimators=100; precision: (train=0.512, test=0.158) total time=   1.4s
# [CV 4/4; 11/100] START classifier__max_depth=161, classifier__max_features=0.775, classifier__max_leaf_nodes=100, classifier__min_samples_split=34, classifier__n_estimators=100
# [CV 4/4; 11/100] END classifier__max_depth=161, classifier__max_features=0.775, classifier__max_leaf_nodes=100, classifier__min_samples_split=34, classifier__n_estimators=100; precision: (train=0.506, test=0.167) total time=   1.3s
# [CV 1/4; 12/100] START classifier__max_depth=689, classifier__max_features=0.55, classifier__max_leaf_nodes=300, classifier__min_samples_split=16, classifier__n_estimators=100
# [CV 1/4; 12/100] END classifier__max_depth=689, classifier__max_features=0.55, classifier__max_leaf_nodes=300, classifier__min_samples_split=16, classifier__n_estimators=100; precision: (train=0.894, test=0.000) total time=   0.8s
# [CV 2/4; 12/100] START classifier__max_depth=689, classifier__max_features=0.55, classifier__max_leaf_nodes=300, classifier__min_samples_split=16, classifier__n_estimators=100
# [CV 2/4; 12/100] END classifier__max_depth=689, classifier__max_features=0.55, classifier__max_leaf_nodes=300, classifier__min_samples_split=16, classifier__n_estimators=100; precision: (train=0.872, test=0.167) total time=   0.8s
# [CV 3/4; 12/100] START classifier__max_depth=689, classifier__max_features=0.55, classifier__max_leaf_nodes=300, classifier__min_samples_split=16, classifier__n_estimators=100
# [CV 3/4; 12/100] END classifier__max_depth=689, classifier__max_features=0.55, classifier__max_leaf_nodes=300, classifier__min_samples_split=16, classifier__n_estimators=100; precision: (train=0.820, test=0.286) total time=   0.9s
# [CV 4/4; 12/100] START classifier__max_depth=689, classifier__max_features=0.55, classifier__max_leaf_nodes=300, classifier__min_samples_split=16, classifier__n_estimators=100
# [CV 4/4; 12/100] END classifier__max_depth=689, classifier__max_features=0.55, classifier__max_leaf_nodes=300, classifier__min_samples_split=16, classifier__n_estimators=100; precision: (train=0.837, test=0.333) total time=   0.7s
# [CV 1/4; 13/100] START classifier__max_depth=719, classifier__max_features=0.1, classifier__max_leaf_nodes=500, classifier__min_samples_split=80, classifier__n_estimators=250
# [CV 1/4; 13/100] END classifier__max_depth=719, classifier__max_features=0.1, classifier__max_leaf_nodes=500, classifier__min_samples_split=80, classifier__n_estimators=250; precision: (train=0.396, test=0.129) total time=   0.7s
# [CV 2/4; 13/100] START classifier__max_depth=719, classifier__max_features=0.1, classifier__max_leaf_nodes=500, classifier__min_samples_split=80, classifier__n_estimators=250
# [CV 2/4; 13/100] END classifier__max_depth=719, classifier__max_features=0.1, classifier__max_leaf_nodes=500, classifier__min_samples_split=80, classifier__n_estimators=250; precision: (train=0.455, test=0.148) total time=   0.8s
# [CV 3/4; 13/100] START classifier__max_depth=719, classifier__max_features=0.1, classifier__max_leaf_nodes=500, classifier__min_samples_split=80, classifier__n_estimators=250
# [CV 3/4; 13/100] END classifier__max_depth=719, classifier__max_features=0.1, classifier__max_leaf_nodes=500, classifier__min_samples_split=80, classifier__n_estimators=250; precision: (train=0.315, test=0.103) total time=   0.7s
# [CV 4/4; 13/100] START classifier__max_depth=719, classifier__max_features=0.1, classifier__max_leaf_nodes=500, classifier__min_samples_split=80, classifier__n_estimators=250
# [CV 4/4; 13/100] END classifier__max_depth=719, classifier__max_features=0.1, classifier__max_leaf_nodes=500, classifier__min_samples_split=80, classifier__n_estimators=250; precision: (train=0.406, test=0.118) total time=   1.4s
# [CV 1/4; 14/100] START classifier__max_depth=327, classifier__max_features=0.325, classifier__max_leaf_nodes=300, classifier__min_samples_split=4, classifier__n_estimators=100
# [CV 1/4; 14/100] END classifier__max_depth=327, classifier__max_features=0.325, classifier__max_leaf_nodes=300, classifier__min_samples_split=4, classifier__n_estimators=100; precision: (train=1.000, test=0.000) total time=   0.7s
# [CV 2/4; 14/100] START classifier__max_depth=327, classifier__max_features=0.325, classifier__max_leaf_nodes=300, classifier__min_samples_split=4, classifier__n_estimators=100
# c:\Users\danjr\anaconda3\envs\cycleCollisions\lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# [CV 2/4; 14/100] END classifier__max_depth=327, classifier__max_features=0.325, classifier__max_leaf_nodes=300, classifier__min_samples_split=4, classifier__n_estimators=100; precision: (train=1.000, test=0.000) total time=   0.8s
# [CV 3/4; 14/100] START classifier__max_depth=327, classifier__max_features=0.325, classifier__max_leaf_nodes=300, classifier__min_samples_split=4, classifier__n_estimators=100
# [CV 3/4; 14/100] END classifier__max_depth=327, classifier__max_features=0.325, classifier__max_leaf_nodes=300, classifier__min_samples_split=4, classifier__n_estimators=100; precision: (train=1.000, test=0.000) total time=   1.0s
# [CV 4/4; 14/100] START classifier__max_depth=327, classifier__max_features=0.325, classifier__max_leaf_nodes=300, classifier__min_samples_split=4, classifier__n_estimators=100
# c:\Users\danjr\anaconda3\envs\cycleCollisions\lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# [CV 4/4; 14/100] END classifier__max_depth=327, classifier__max_features=0.325, classifier__max_leaf_nodes=300, classifier__min_samples_split=4, classifier__n_estimators=100; precision: (train=1.000, test=0.000) total time=   0.8s
# [CV 1/4; 15/100] START classifier__max_depth=357, classifier__max_features=0.1, classifier__max_leaf_nodes=None, classifier__min_samples_split=58, classifier__n_estimators=250
# [CV 1/4; 15/100] END classifier__max_depth=357, classifier__max_features=0.1, classifier__max_leaf_nodes=None, classifier__min_samples_split=58, classifier__n_estimators=250; precision: (train=0.506, test=0.143) total time=   1.0s
# [CV 2/4; 15/100] START classifier__max_depth=357, classifier__max_features=0.1, classifier__max_leaf_nodes=None, classifier__min_samples_split=58, classifier__n_estimators=250
# [CV 2/4; 15/100] END classifier__max_depth=357, classifier__max_features=0.1, classifier__max_leaf_nodes=None, classifier__min_samples_split=58, classifier__n_estimators=250; precision: (train=0.621, test=0.176) total time=   0.9s
# [CV 3/4; 15/100] START classifier__max_depth=357, classifier__max_features=0.1, classifier__max_leaf_nodes=None, classifier__min_samples_split=58, classifier__n_estimators=250
# [CV 3/4; 15/100] END classifier__max_depth=357, classifier__max_features=0.1, classifier__max_leaf_nodes=None, classifier__min_samples_split=58, classifier__n_estimators=250; precision: (train=0.441, test=0.087) total time=   1.0s
# [CV 4/4; 15/100] START classifier__max_depth=357, classifier__max_features=0.1, classifier__max_leaf_nodes=None, classifier__min_samples_split=58, classifier__n_estimators=250
# [CV 4/4; 15/100] END classifier__max_depth=357, classifier__max_features=0.1, classifier__max_leaf_nodes=None, classifier__min_samples_split=58, classifier__n_estimators=250; precision: (train=0.494, test=0.250) total time=   1.5s
# [CV 1/4; 16/100] START classifier__max_depth=508, classifier__max_features=0.775, classifier__max_leaf_nodes=700, classifier__min_samples_split=46, classifier__n_estimators=250
# [CV 1/4; 16/100] END classifier__max_depth=508, classifier__max_features=0.775, classifier__max_leaf_nodes=700, classifier__min_samples_split=46, classifier__n_estimators=250; precision: (train=0.575, test=0.222) total time=   3.4s
# [CV 2/4; 16/100] START classifier__max_depth=508, classifier__max_features=0.775, classifier__max_leaf_nodes=700, classifier__min_samples_split=46, classifier__n_estimators=250
# [CV 2/4; 16/100] END classifier__max_depth=508, classifier__max_features=0.775, classifier__max_leaf_nodes=700, classifier__min_samples_split=46, classifier__n_estimators=250; precision: (train=0.436, test=0.154) total time=   2.2s
# [CV 3/4; 16/100] START classifier__max_depth=508, classifier__max_features=0.775, classifier__max_leaf_nodes=700, classifier__min_samples_split=46, classifier__n_estimators=250
# [CV 3/4; 16/100] END classifier__max_depth=508, classifier__max_features=0.775, classifier__max_leaf_nodes=700, classifier__min_samples_split=46, classifier__n_estimators=250; precision: (train=0.418, test=0.120) total time=   1.9s
# [CV 4/4; 16/100] START classifier__max_depth=508, classifier__max_features=0.775, classifier__max_leaf_nodes=700, classifier__min_samples_split=46, classifier__n_estimators=250
# [CV 4/4; 16/100] END classifier__max_depth=508, classifier__max_features=0.775, classifier__max_leaf_nodes=700, classifier__min_samples_split=46, classifier__n_estimators=250; precision: (train=0.414, test=0.143) total time=   1.9s
# [CV 1/4; 17/100] START classifier__max_depth=70, classifier__max_features=1.0, classifier__max_leaf_nodes=1000, classifier__min_samples_split=94, classifier__n_estimators=750
# [CV 1/4; 17/100] END classifier__max_depth=70, classifier__max_features=1.0, classifier__max_leaf_nodes=1000, classifier__min_samples_split=94, classifier__n_estimators=750; precision: (train=0.372, test=0.143) total time=   7.2s
# [CV 2/4; 17/100] START classifier__max_depth=70, classifier__max_features=1.0, classifier__max_leaf_nodes=1000, classifier__min_samples_split=94, classifier__n_estimators=750
# [CV 2/4; 17/100] END classifier__max_depth=70, classifier__max_features=1.0, classifier__max_leaf_nodes=1000, classifier__min_samples_split=94, classifier__n_estimators=750; precision: (train=0.265, test=0.096) total time=   6.4s
# [CV 3/4; 17/100] START classifier__max_depth=70, classifier__max_features=1.0, classifier__max_leaf_nodes=1000, classifier__min_samples_split=94, classifier__n_estimators=750
# [CV 3/4; 17/100] END classifier__max_depth=70, classifier__max_features=1.0, classifier__max_leaf_nodes=1000, classifier__min_samples_split=94, classifier__n_estimators=750; precision: (train=0.270, test=0.104) total time=   6.5s
# [CV 4/4; 17/100] START classifier__max_depth=70, classifier__max_features=1.0, classifier__max_leaf_nodes=1000, classifier__min_samples_split=94, classifier__n_estimators=750
# [CV 4/4; 17/100] END classifier__max_depth=70, classifier__max_features=1.0, classifier__max_leaf_nodes=1000, classifier__min_samples_split=94, classifier__n_estimators=750; precision: (train=0.253, test=0.073) total time=   6.4s
# [CV 1/4; 18/100] START classifier__max_depth=598, classifier__max_features=1.0, classifier__max_leaf_nodes=700, classifier__min_samples_split=78, classifier__n_estimators=250
# [CV 1/4; 18/100] END classifier__max_depth=598, classifier__max_features=1.0, classifier__max_leaf_nodes=700, classifier__min_samples_split=78, classifier__n_estimators=250; precision: (train=0.404, test=0.133) total time=   2.9s
# [CV 2/4; 18/100] START classifier__max_depth=598, classifier__max_features=1.0, classifier__max_leaf_nodes=700, classifier__min_samples_split=78, classifier__n_estimators=250
# [CV 2/4; 18/100] END classifier__max_depth=598, classifier__max_features=1.0, classifier__max_leaf_nodes=700, classifier__min_samples_split=78, classifier__n_estimators=250; precision: (train=0.306, test=0.116) total time=   2.2s
# [CV 3/4; 18/100] START classifier__max_depth=598, classifier__max_features=1.0, classifier__max_leaf_nodes=700, classifier__min_samples_split=78, classifier__n_estimators=250
# [CV 3/4; 18/100] END classifier__max_depth=598, classifier__max_features=1.0, classifier__max_leaf_nodes=700, classifier__min_samples_split=78, classifier__n_estimators=250; precision: (train=0.295, test=0.093) total time=   2.3s
# [CV 4/4; 18/100] START classifier__max_depth=598, classifier__max_features=1.0, classifier__max_leaf_nodes=700, classifier__min_samples_split=78, classifier__n_estimators=250
# [CV 4/4; 18/100] END classifier__max_depth=598, classifier__max_features=1.0, classifier__max_leaf_nodes=700, classifier__min_samples_split=78, classifier__n_estimators=250; precision: (train=0.297, test=0.091) total time=   2.0s
# [CV 1/4; 19/100] START classifier__max_depth=115, classifier__max_features=1.0, classifier__max_leaf_nodes=400, classifier__min_samples_split=14, classifier__n_estimators=750
# [CV 1/4; 19/100] END classifier__max_depth=115, classifier__max_features=1.0, classifier__max_leaf_nodes=400, classifier__min_samples_split=14, classifier__n_estimators=750; precision: (train=0.955, test=0.000) total time=   7.3s
# [CV 2/4; 19/100] START classifier__max_depth=115, classifier__max_features=1.0, classifier__max_leaf_nodes=400, classifier__min_samples_split=14, classifier__n_estimators=750
# [CV 2/4; 19/100] END classifier__max_depth=115, classifier__max_features=1.0, classifier__max_leaf_nodes=400, classifier__min_samples_split=14, classifier__n_estimators=750; precision: (train=0.891, test=0.200) total time=   6.8s
# [CV 3/4; 19/100] START classifier__max_depth=115, classifier__max_features=1.0, classifier__max_leaf_nodes=400, classifier__min_samples_split=14, classifier__n_estimators=750
# [CV 3/4; 19/100] END classifier__max_depth=115, classifier__max_features=1.0, classifier__max_leaf_nodes=400, classifier__min_samples_split=14, classifier__n_estimators=750; precision: (train=0.804, test=0.286) total time=   7.1s
# [CV 4/4; 19/100] START classifier__max_depth=115, classifier__max_features=1.0, classifier__max_leaf_nodes=400, classifier__min_samples_split=14, classifier__n_estimators=750
# [CV 4/4; 19/100] END classifier__max_depth=115, classifier__max_features=1.0, classifier__max_leaf_nodes=400, classifier__min_samples_split=14, classifier__n_estimators=750; precision: (train=0.854, test=0.000) total time=   6.7s
# [CV 1/4; 20/100] START classifier__max_depth=478, classifier__max_features=1.0, classifier__max_leaf_nodes=400, classifier__min_samples_split=76, classifier__n_estimators=750
# [CV 1/4; 20/100] END classifier__max_depth=478, classifier__max_features=1.0, classifier__max_leaf_nodes=400, classifier__min_samples_split=76, classifier__n_estimators=750; precision: (train=0.400, test=0.143) total time=   6.4s
# [CV 2/4; 20/100] START classifier__max_depth=478, classifier__max_features=1.0, classifier__max_leaf_nodes=400, classifier__min_samples_split=76, classifier__n_estimators=750
# [CV 2/4; 20/100] END classifier__max_depth=478, classifier__max_features=1.0, classifier__max_leaf_nodes=400, classifier__min_samples_split=76, classifier__n_estimators=750; precision: (train=0.304, test=0.114) total time=   6.1s
# [CV 3/4; 20/100] START classifier__max_depth=478, classifier__max_features=1.0, classifier__max_leaf_nodes=400, classifier__min_samples_split=76, classifier__n_estimators=750
# [CV 3/4; 20/100] END classifier__max_depth=478, classifier__max_features=1.0, classifier__max_leaf_nodes=400, classifier__min_samples_split=76, classifier__n_estimators=750; precision: (train=0.299, test=0.089) total time=   6.4s
# [CV 4/4; 20/100] START classifier__max_depth=478, classifier__max_features=1.0, classifier__max_leaf_nodes=400, classifier__min_samples_split=76, classifier__n_estimators=750
# [CV 4/4; 20/100] END classifier__max_depth=478, classifier__max_features=1.0, classifier__max_leaf_nodes=400, classifier__min_samples_split=76, classifier__n_estimators=750; precision: (train=0.306, test=0.091) total time=   6.1s
# [CV 1/4; 21/100] START classifier__max_depth=598, classifier__max_features=0.1, classifier__max_leaf_nodes=100, classifier__min_samples_split=88, classifier__n_estimators=100
# [CV 1/4; 21/100] END classifier__max_depth=598, classifier__max_features=0.1, classifier__max_leaf_nodes=100, classifier__min_samples_split=88, classifier__n_estimators=100; precision: (train=0.378, test=0.103) total time=   0.4s
# [CV 2/4; 21/100] START classifier__max_depth=598, classifier__max_features=0.1, classifier__max_leaf_nodes=100, classifier__min_samples_split=88, classifier__n_estimators=100
# [CV 2/4; 21/100] END classifier__max_depth=598, classifier__max_features=0.1, classifier__max_leaf_nodes=100, classifier__min_samples_split=88, classifier__n_estimators=100; precision: (train=0.417, test=0.125) total time=   0.4s
# [CV 3/4; 21/100] START classifier__max_depth=598, classifier__max_features=0.1, classifier__max_leaf_nodes=100, classifier__min_samples_split=88, classifier__n_estimators=100
# [CV 3/4; 21/100] END classifier__max_depth=598, classifier__max_features=0.1, classifier__max_leaf_nodes=100, classifier__min_samples_split=88, classifier__n_estimators=100; precision: (train=0.264, test=0.068) total time=   0.4s
# [CV 4/4; 21/100] START classifier__max_depth=598, classifier__max_features=0.1, classifier__max_leaf_nodes=100, classifier__min_samples_split=88, classifier__n_estimators=100
# [CV 4/4; 21/100] END classifier__max_depth=598, classifier__max_features=0.1, classifier__max_leaf_nodes=100, classifier__min_samples_split=88, classifier__n_estimators=100; precision: (train=0.374, test=0.143) total time=   0.4s
# [CV 1/4; 22/100] START classifier__max_depth=357, classifier__max_features=0.55, classifier__max_leaf_nodes=700, classifier__min_samples_split=52, classifier__n_estimators=750
# [CV 1/4; 22/100] END classifier__max_depth=357, classifier__max_features=0.55, classifier__max_leaf_nodes=700, classifier__min_samples_split=52, classifier__n_estimators=750; precision: (train=0.538, test=0.211) total time=   4.3s
# [CV 2/4; 22/100] START classifier__max_depth=357, classifier__max_features=0.55, classifier__max_leaf_nodes=700, classifier__min_samples_split=52, classifier__n_estimators=750
# [CV 2/4; 22/100] END classifier__max_depth=357, classifier__max_features=0.55, classifier__max_leaf_nodes=700, classifier__min_samples_split=52, classifier__n_estimators=750; precision: (train=0.488, test=0.167) total time=   4.0s
# [CV 3/4; 22/100] START classifier__max_depth=357, classifier__max_features=0.55, classifier__max_leaf_nodes=700, classifier__min_samples_split=52, classifier__n_estimators=750
# [CV 3/4; 22/100] END classifier__max_depth=357, classifier__max_features=0.55, classifier__max_leaf_nodes=700, classifier__min_samples_split=52, classifier__n_estimators=750; precision: (train=0.390, test=0.107) total time=   4.1s
# [CV 4/4; 22/100] START classifier__max_depth=357, classifier__max_features=0.55, classifier__max_leaf_nodes=700, classifier__min_samples_split=52, classifier__n_estimators=750
# [CV 4/4; 22/100] END classifier__max_depth=357, classifier__max_features=0.55, classifier__max_leaf_nodes=700, classifier__min_samples_split=52, classifier__n_estimators=750; precision: (train=0.418, test=0.167) total time=   3.9s
# [CV 1/4; 23/100] START classifier__max_depth=598, classifier__max_features=0.775, classifier__max_leaf_nodes=300, classifier__min_samples_split=48, classifier__n_estimators=100
# [CV 1/4; 23/100] END classifier__max_depth=598, classifier__max_features=0.775, classifier__max_leaf_nodes=300, classifier__min_samples_split=48, classifier__n_estimators=100; precision: (train=0.538, test=0.211) total time=   0.8s
# [CV 2/4; 23/100] START classifier__max_depth=598, classifier__max_features=0.775, classifier__max_leaf_nodes=300, classifier__min_samples_split=48, classifier__n_estimators=100
# [CV 2/4; 23/100] END classifier__max_depth=598, classifier__max_features=0.775, classifier__max_leaf_nodes=300, classifier__min_samples_split=48, classifier__n_estimators=100; precision: (train=0.460, test=0.154) total time=   0.8s
# [CV 3/4; 23/100] START classifier__max_depth=598, classifier__max_features=0.775, classifier__max_leaf_nodes=300, classifier__min_samples_split=48, classifier__n_estimators=100
# [CV 3/4; 23/100] END classifier__max_depth=598, classifier__max_features=0.775, classifier__max_leaf_nodes=300, classifier__min_samples_split=48, classifier__n_estimators=100; precision: (train=0.383, test=0.100) total time=   0.8s
# [CV 4/4; 23/100] START classifier__max_depth=598, classifier__max_features=0.775, classifier__max_leaf_nodes=300, classifier__min_samples_split=48, classifier__n_estimators=100
# [CV 4/4; 23/100] END classifier__max_depth=598, classifier__max_features=0.775, classifier__max_leaf_nodes=300, classifier__min_samples_split=48, classifier__n_estimators=100; precision: (train=0.404, test=0.167) total time=   0.8s
# [CV 1/4; 24/100] START classifier__max_depth=463, classifier__max_features=0.775, classifier__max_leaf_nodes=200, classifier__min_samples_split=74, classifier__n_estimators=250
# [CV 1/4; 24/100] END classifier__max_depth=463, classifier__max_features=0.775, classifier__max_leaf_nodes=200, classifier__min_samples_split=74, classifier__n_estimators=250; precision: (train=0.400, test=0.143) total time=   1.9s
# [CV 2/4; 24/100] START classifier__max_depth=463, classifier__max_features=0.775, classifier__max_leaf_nodes=200, classifier__min_samples_split=74, classifier__n_estimators=250
# [CV 2/4; 24/100] END classifier__max_depth=463, classifier__max_features=0.775, classifier__max_leaf_nodes=200, classifier__min_samples_split=74, classifier__n_estimators=250; precision: (train=0.328, test=0.132) total time=   1.8s
# [CV 3/4; 24/100] START classifier__max_depth=463, classifier__max_features=0.775, classifier__max_leaf_nodes=200, classifier__min_samples_split=74, classifier__n_estimators=250
# [CV 3/4; 24/100] END classifier__max_depth=463, classifier__max_features=0.775, classifier__max_leaf_nodes=200, classifier__min_samples_split=74, classifier__n_estimators=250; precision: (train=0.301, test=0.091) total time=   2.0s
# [CV 4/4; 24/100] START classifier__max_depth=463, classifier__max_features=0.775, classifier__max_leaf_nodes=200, classifier__min_samples_split=74, classifier__n_estimators=250
# [CV 4/4; 24/100] END classifier__max_depth=463, classifier__max_features=0.775, classifier__max_leaf_nodes=200, classifier__min_samples_split=74, classifier__n_estimators=250; precision: (train=0.325, test=0.100) total time=   1.7s
# [CV 1/4; 25/100] START classifier__max_depth=372, classifier__max_features=0.1, classifier__max_leaf_nodes=700, classifier__min_samples_split=96, classifier__n_estimators=100
# [CV 1/4; 25/100] END classifier__max_depth=372, classifier__max_features=0.1, classifier__max_leaf_nodes=700, classifier__min_samples_split=96, classifier__n_estimators=100; precision: (train=0.323, test=0.133) total time=   0.4s
# [CV 2/4; 25/100] START classifier__max_depth=372, classifier__max_features=0.1, classifier__max_leaf_nodes=700, classifier__min_samples_split=96, classifier__n_estimators=100
# [CV 2/4; 25/100] END classifier__max_depth=372, classifier__max_features=0.1, classifier__max_leaf_nodes=700, classifier__min_samples_split=96, classifier__n_estimators=100; precision: (train=0.366, test=0.118) total time=   0.4s
# [CV 3/4; 25/100] START classifier__max_depth=372, classifier__max_features=0.1, classifier__max_leaf_nodes=700, classifier__min_samples_split=96, classifier__n_estimators=100
# [CV 3/4; 25/100] END classifier__max_depth=372, classifier__max_features=0.1, classifier__max_leaf_nodes=700, classifier__min_samples_split=96, classifier__n_estimators=100; precision: (train=0.252, test=0.056) total time=   0.4s
# [CV 4/4; 25/100] START classifier__max_depth=372, classifier__max_features=0.1, classifier__max_leaf_nodes=700, classifier__min_samples_split=96, classifier__n_estimators=100
# [CV 4/4; 25/100] END classifier__max_depth=372, classifier__max_features=0.1, classifier__max_leaf_nodes=700, classifier__min_samples_split=96, classifier__n_estimators=100; precision: (train=0.315, test=0.182) total time=   0.4s
# [CV 1/4; 26/100] START classifier__max_depth=493, classifier__max_features=0.55, classifier__max_leaf_nodes=200, classifier__min_samples_split=4, classifier__n_estimators=750
# [CV 1/4; 26/100] END classifier__max_depth=493, classifier__max_features=0.55, classifier__max_leaf_nodes=200, classifier__min_samples_split=4, classifier__n_estimators=750; precision: (train=1.000, test=0.000) total time=   4.9s
# [CV 2/4; 26/100] START classifier__max_depth=493, classifier__max_features=0.55, classifier__max_leaf_nodes=200, classifier__min_samples_split=4, classifier__n_estimators=750
# c:\Users\danjr\anaconda3\envs\cycleCollisions\lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# [CV 2/4; 26/100] END classifier__max_depth=493, classifier__max_features=0.55, classifier__max_leaf_nodes=200, classifier__min_samples_split=4, classifier__n_estimators=750; precision: (train=1.000, test=0.000) total time=   4.4s
# [CV 3/4; 26/100] START classifier__max_depth=493, classifier__max_features=0.55, classifier__max_leaf_nodes=200, classifier__min_samples_split=4, classifier__n_estimators=750
# [CV 3/4; 26/100] END classifier__max_depth=493, classifier__max_features=0.55, classifier__max_leaf_nodes=200, classifier__min_samples_split=4, classifier__n_estimators=750; precision: (train=1.000, test=0.000) total time=   4.7s
# [CV 4/4; 26/100] START classifier__max_depth=493, classifier__max_features=0.55, classifier__max_leaf_nodes=200, classifier__min_samples_split=4, classifier__n_estimators=750
# c:\Users\danjr\anaconda3\envs\cycleCollisions\lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# [CV 4/4; 26/100] END classifier__max_depth=493, classifier__max_features=0.55, classifier__max_leaf_nodes=200, classifier__min_samples_split=4, classifier__n_estimators=750; precision: (train=1.000, test=0.000) total time=   4.5s
# [CV 1/4; 27/100] START classifier__max_depth=191, classifier__max_features=0.55, classifier__max_leaf_nodes=800, classifier__min_samples_split=4, classifier__n_estimators=750
# [CV 1/4; 27/100] END classifier__max_depth=191, classifier__max_features=0.55, classifier__max_leaf_nodes=800, classifier__min_samples_split=4, classifier__n_estimators=750; precision: (train=1.000, test=0.000) total time=   5.0s
# [CV 2/4; 27/100] START classifier__max_depth=191, classifier__max_features=0.55, classifier__max_leaf_nodes=800, classifier__min_samples_split=4, classifier__n_estimators=750
# c:\Users\danjr\anaconda3\envs\cycleCollisions\lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# [CV 2/4; 27/100] END classifier__max_depth=191, classifier__max_features=0.55, classifier__max_leaf_nodes=800, classifier__min_samples_split=4, classifier__n_estimators=750; precision: (train=1.000, test=0.000) total time=   4.5s
# [CV 3/4; 27/100] START classifier__max_depth=191, classifier__max_features=0.55, classifier__max_leaf_nodes=800, classifier__min_samples_split=4, classifier__n_estimators=750
# [CV 3/4; 27/100] END classifier__max_depth=191, classifier__max_features=0.55, classifier__max_leaf_nodes=800, classifier__min_samples_split=4, classifier__n_estimators=750; precision: (train=1.000, test=0.000) total time=   4.8s
# [CV 4/4; 27/100] START classifier__max_depth=191, classifier__max_features=0.55, classifier__max_leaf_nodes=800, classifier__min_samples_split=4, classifier__n_estimators=750
# c:\Users\danjr\anaconda3\envs\cycleCollisions\lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# [CV 4/4; 27/100] END classifier__max_depth=191, classifier__max_features=0.55, classifier__max_leaf_nodes=800, classifier__min_samples_split=4, classifier__n_estimators=750; precision: (train=1.000, test=0.000) total time=   4.5s
# [CV 1/4; 28/100] START classifier__max_depth=432, classifier__max_features=0.55, classifier__max_leaf_nodes=1000, classifier__min_samples_split=98, classifier__n_estimators=750
# [CV 1/4; 28/100] END classifier__max_depth=432, classifier__max_features=0.55, classifier__max_leaf_nodes=1000, classifier__min_samples_split=98, classifier__n_estimators=750; precision: (train=0.328, test=0.150) total time=   4.1s
# [CV 2/4; 28/100] START classifier__max_depth=432, classifier__max_features=0.55, classifier__max_leaf_nodes=1000, classifier__min_samples_split=98, classifier__n_estimators=750
# [CV 2/4; 28/100] END classifier__max_depth=432, classifier__max_features=0.55, classifier__max_leaf_nodes=1000, classifier__min_samples_split=98, classifier__n_estimators=750; precision: (train=0.285, test=0.106) total time=   3.8s
# [CV 3/4; 28/100] START classifier__max_depth=432, classifier__max_features=0.55, classifier__max_leaf_nodes=1000, classifier__min_samples_split=98, classifier__n_estimators=750
# ...
# [CV 4/4; 91/100] END classifier__max_depth=25, classifier__max_features=0.325, classifier__max_leaf_nodes=None, classifier__min_samples_split=90, classifier__n_estimators=750; precision: (train=0.318, test=0.100) total time=   3.0s
# [CV 1/4; 92/100] START classifier__max_depth=70, classifier__max_features=1.0, classifier__max_leaf_nodes=600, classifier__min_samples_split=32, classifier__n_estimators=750
# [CV 1/4; 92/100] END classifier__max_depth=70, classifier__max_features=1.0, classifier__max_leaf_nodes=600, classifier__min_samples_split=32, classifier__n_estimators=750; precision: (train=0.750, test=0.308) total time=   7.4s
# [CV 2/4; 92/100] START classifier__max_depth=70, classifier__max_features=1.0, classifier__max_leaf_nodes=600, classifier__min_samples_split=32, classifier__n_estimators=750
# [CV 2/4; 92/100] END classifier__max_depth=70, classifier__max_features=1.0, classifier__max_leaf_nodes=600, classifier__min_samples_split=32, classifier__n_estimators=750; precision: (train=0.603, test=0.250) total time=   6.5s
# [CV 3/4; 92/100] START classifier__max_depth=70, classifier__max_features=1.0, classifier__max_leaf_nodes=600, classifier__min_samples_split=32, classifier__n_estimators=750
# [CV 3/4; 92/100] END classifier__max_depth=70, classifier__max_features=1.0, classifier__max_leaf_nodes=600, classifier__min_samples_split=32, classifier__n_estimators=750; precision: (train=0.539, test=0.125) total time=   6.9s
# [CV 4/4; 92/100] START classifier__max_depth=70, classifier__max_features=1.0, classifier__max_leaf_nodes=600, classifier__min_samples_split=32, classifier__n_estimators=750
# [CV 4/4; 92/100] END classifier__max_depth=70, classifier__max_features=1.0, classifier__max_leaf_nodes=600, classifier__min_samples_split=32, classifier__n_estimators=750; precision: (train=0.506, test=0.143) total time=   6.3s
# [CV 1/4; 93/100] START classifier__max_depth=478, classifier__max_features=0.325, classifier__max_leaf_nodes=300, classifier__min_samples_split=34, classifier__n_estimators=750
# [CV 1/4; 93/100] END classifier__max_depth=478, classifier__max_features=0.325, classifier__max_leaf_nodes=300, classifier__min_samples_split=34, classifier__n_estimators=750; precision: (train=0.750, test=0.231) total time=   3.3s
# [CV 2/4; 93/100] START classifier__max_depth=478, classifier__max_features=0.325, classifier__max_leaf_nodes=300, classifier__min_samples_split=34, classifier__n_estimators=750
# [CV 2/4; 93/100] END classifier__max_depth=478, classifier__max_features=0.325, classifier__max_leaf_nodes=300, classifier__min_samples_split=34, classifier__n_estimators=750; precision: (train=0.707, test=0.231) total time=   3.2s
# [CV 3/4; 93/100] START classifier__max_depth=478, classifier__max_features=0.325, classifier__max_leaf_nodes=300, classifier__min_samples_split=34, classifier__n_estimators=750
# [CV 3/4; 93/100] END classifier__max_depth=478, classifier__max_features=0.325, classifier__max_leaf_nodes=300, classifier__min_samples_split=34, classifier__n_estimators=750; precision: (train=0.612, test=0.167) total time=   3.3s
# [CV 4/4; 93/100] START classifier__max_depth=478, classifier__max_features=0.325, classifier__max_leaf_nodes=300, classifier__min_samples_split=34, classifier__n_estimators=750
# [CV 4/4; 93/100] END classifier__max_depth=478, classifier__max_features=0.325, classifier__max_leaf_nodes=300, classifier__min_samples_split=34, classifier__n_estimators=750; precision: (train=0.603, test=0.250) total time=   3.2s
# [CV 1/4; 94/100] START classifier__max_depth=644, classifier__max_features=1.0, classifier__max_leaf_nodes=300, classifier__min_samples_split=88, classifier__n_estimators=750
# [CV 1/4; 94/100] END classifier__max_depth=644, classifier__max_features=1.0, classifier__max_leaf_nodes=300, classifier__min_samples_split=88, classifier__n_estimators=750; precision: (train=0.385, test=0.125) total time=   6.5s
# [CV 2/4; 94/100] START classifier__max_depth=644, classifier__max_features=1.0, classifier__max_leaf_nodes=300, classifier__min_samples_split=88, classifier__n_estimators=750
# [CV 2/4; 94/100] END classifier__max_depth=644, classifier__max_features=1.0, classifier__max_leaf_nodes=300, classifier__min_samples_split=88, classifier__n_estimators=750; precision: (train=0.273, test=0.098) total time=   5.9s
# [CV 3/4; 94/100] START classifier__max_depth=644, classifier__max_features=1.0, classifier__max_leaf_nodes=300, classifier__min_samples_split=88, classifier__n_estimators=750
# [CV 3/4; 94/100] END classifier__max_depth=644, classifier__max_features=1.0, classifier__max_leaf_nodes=300, classifier__min_samples_split=88, classifier__n_estimators=750; precision: (train=0.270, test=0.109) total time=   6.2s
# [CV 4/4; 94/100] START classifier__max_depth=644, classifier__max_features=1.0, classifier__max_leaf_nodes=300, classifier__min_samples_split=88, classifier__n_estimators=750
# [CV 4/4; 94/100] END classifier__max_depth=644, classifier__max_features=1.0, classifier__max_leaf_nodes=300, classifier__min_samples_split=88, classifier__n_estimators=750; precision: (train=0.281, test=0.088) total time=   5.7s
# [CV 1/4; 95/100] START classifier__max_depth=478, classifier__max_features=1.0, classifier__max_leaf_nodes=600, classifier__min_samples_split=42, classifier__n_estimators=100
# [CV 1/4; 95/100] END classifier__max_depth=478, classifier__max_features=1.0, classifier__max_leaf_nodes=600, classifier__min_samples_split=42, classifier__n_estimators=100; precision: (train=0.631, test=0.235) total time=   1.0s
# [CV 2/4; 95/100] START classifier__max_depth=478, classifier__max_features=1.0, classifier__max_leaf_nodes=600, classifier__min_samples_split=42, classifier__n_estimators=100
# [CV 2/4; 95/100] END classifier__max_depth=478, classifier__max_features=1.0, classifier__max_leaf_nodes=600, classifier__min_samples_split=42, classifier__n_estimators=100; precision: (train=0.432, test=0.179) total time=   1.0s
# [CV 3/4; 95/100] START classifier__max_depth=478, classifier__max_features=1.0, classifier__max_leaf_nodes=600, classifier__min_samples_split=42, classifier__n_estimators=100
# [CV 3/4; 95/100] END classifier__max_depth=478, classifier__max_features=1.0, classifier__max_leaf_nodes=600, classifier__min_samples_split=42, classifier__n_estimators=100; precision: (train=0.436, test=0.130) total time=   1.1s
# [CV 4/4; 95/100] START classifier__max_depth=478, classifier__max_features=1.0, classifier__max_leaf_nodes=600, classifier__min_samples_split=42, classifier__n_estimators=100
# [CV 4/4; 95/100] END classifier__max_depth=478, classifier__max_features=1.0, classifier__max_leaf_nodes=600, classifier__min_samples_split=42, classifier__n_estimators=100; precision: (train=0.427, test=0.158) total time=   1.0s
# [CV 1/4; 96/100] START classifier__max_depth=100, classifier__max_features=0.775, classifier__max_leaf_nodes=800, classifier__min_samples_split=62, classifier__n_estimators=250
# [CV 1/4; 96/100] END classifier__max_depth=100, classifier__max_features=0.775, classifier__max_leaf_nodes=800, classifier__min_samples_split=62, classifier__n_estimators=250; precision: (train=0.472, test=0.211) total time=   2.0s
# [CV 2/4; 96/100] START classifier__max_depth=100, classifier__max_features=0.775, classifier__max_leaf_nodes=800, classifier__min_samples_split=62, classifier__n_estimators=250
# [CV 2/4; 96/100] END classifier__max_depth=100, classifier__max_features=0.775, classifier__max_leaf_nodes=800, classifier__min_samples_split=62, classifier__n_estimators=250; precision: (train=0.406, test=0.147) total time=   1.7s
# [CV 3/4; 96/100] START classifier__max_depth=100, classifier__max_features=0.775, classifier__max_leaf_nodes=800, classifier__min_samples_split=62, classifier__n_estimators=250
# [CV 3/4; 96/100] END classifier__max_depth=100, classifier__max_features=0.775, classifier__max_leaf_nodes=800, classifier__min_samples_split=62, classifier__n_estimators=250; precision: (train=0.325, test=0.098) total time=   1.9s
# [CV 4/4; 96/100] START classifier__max_depth=100, classifier__max_features=0.775, classifier__max_leaf_nodes=800, classifier__min_samples_split=62, classifier__n_estimators=250
# [CV 4/4; 96/100] END classifier__max_depth=100, classifier__max_features=0.775, classifier__max_leaf_nodes=800, classifier__min_samples_split=62, classifier__n_estimators=250; precision: (train=0.350, test=0.125) total time=   1.7s
# [CV 1/4; 97/100] START classifier__max_depth=402, classifier__max_features=0.775, classifier__max_leaf_nodes=1000, classifier__min_samples_split=58, classifier__n_estimators=100
# [CV 1/4; 97/100] END classifier__max_depth=402, classifier__max_features=0.775, classifier__max_leaf_nodes=1000, classifier__min_samples_split=58, classifier__n_estimators=100; precision: (train=0.472, test=0.208) total time=   0.8s
# [CV 2/4; 97/100] START classifier__max_depth=402, classifier__max_features=0.775, classifier__max_leaf_nodes=1000, classifier__min_samples_split=58, classifier__n_estimators=100
# [CV 2/4; 97/100] END classifier__max_depth=402, classifier__max_features=0.775, classifier__max_leaf_nodes=1000, classifier__min_samples_split=58, classifier__n_estimators=100; precision: (train=0.398, test=0.172) total time=   0.8s
# [CV 3/4; 97/100] START classifier__max_depth=402, classifier__max_features=0.775, classifier__max_leaf_nodes=1000, classifier__min_samples_split=58, classifier__n_estimators=100
# [CV 3/4; 97/100] END classifier__max_depth=402, classifier__max_features=0.775, classifier__max_leaf_nodes=1000, classifier__min_samples_split=58, classifier__n_estimators=100; precision: (train=0.357, test=0.086) total time=   0.9s
# [CV 4/4; 97/100] START classifier__max_depth=402, classifier__max_features=0.775, classifier__max_leaf_nodes=1000, classifier__min_samples_split=58, classifier__n_estimators=100
# [CV 4/4; 97/100] END classifier__max_depth=402, classifier__max_features=0.775, classifier__max_leaf_nodes=1000, classifier__min_samples_split=58, classifier__n_estimators=100; precision: (train=0.323, test=0.094) total time=   0.8s
# [CV 1/4; 98/100] START classifier__max_depth=40, classifier__max_features=1.0, classifier__max_leaf_nodes=100, classifier__min_samples_split=100, classifier__n_estimators=100
# [CV 1/4; 98/100] END classifier__max_depth=40, classifier__max_features=1.0, classifier__max_leaf_nodes=100, classifier__min_samples_split=100, classifier__n_estimators=100; precision: (train=0.300, test=0.170) total time=   1.1s
# [CV 2/4; 98/100] START classifier__max_depth=40, classifier__max_features=1.0, classifier__max_leaf_nodes=100, classifier__min_samples_split=100, classifier__n_estimators=100
# [CV 2/4; 98/100] END classifier__max_depth=40, classifier__max_features=1.0, classifier__max_leaf_nodes=100, classifier__min_samples_split=100, classifier__n_estimators=100; precision: (train=0.242, test=0.093) total time=   0.9s
# [CV 3/4; 98/100] START classifier__max_depth=40, classifier__max_features=1.0, classifier__max_leaf_nodes=100, classifier__min_samples_split=100, classifier__n_estimators=100
# [CV 3/4; 98/100] END classifier__max_depth=40, classifier__max_features=1.0, classifier__max_leaf_nodes=100, classifier__min_samples_split=100, classifier__n_estimators=100; precision: (train=0.252, test=0.093) total time=   1.0s
# [CV 4/4; 98/100] START classifier__max_depth=40, classifier__max_features=1.0, classifier__max_leaf_nodes=100, classifier__min_samples_split=100, classifier__n_estimators=100
# [CV 4/4; 98/100] END classifier__max_depth=40, classifier__max_features=1.0, classifier__max_leaf_nodes=100, classifier__min_samples_split=100, classifier__n_estimators=100; precision: (train=0.247, test=0.075) total time=   0.9s
# [CV 1/4; 99/100] START classifier__max_depth=40, classifier__max_features=1.0, classifier__max_leaf_nodes=900, classifier__min_samples_split=2, classifier__n_estimators=100
# [CV 1/4; 99/100] END classifier__max_depth=40, classifier__max_features=1.0, classifier__max_leaf_nodes=900, classifier__min_samples_split=2, classifier__n_estimators=100; precision: (train=1.000, test=0.000) total time=   1.2s
# [CV 2/4; 99/100] START classifier__max_depth=40, classifier__max_features=1.0, classifier__max_leaf_nodes=900, classifier__min_samples_split=2, classifier__n_estimators=100
# c:\Users\danjr\anaconda3\envs\cycleCollisions\lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# [CV 2/4; 99/100] END classifier__max_depth=40, classifier__max_features=1.0, classifier__max_leaf_nodes=900, classifier__min_samples_split=2, classifier__n_estimators=100; precision: (train=1.000, test=0.000) total time=   1.1s
# [CV 3/4; 99/100] START classifier__max_depth=40, classifier__max_features=1.0, classifier__max_leaf_nodes=900, classifier__min_samples_split=2, classifier__n_estimators=100
# c:\Users\danjr\anaconda3\envs\cycleCollisions\lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# [CV 3/4; 99/100] END classifier__max_depth=40, classifier__max_features=1.0, classifier__max_leaf_nodes=900, classifier__min_samples_split=2, classifier__n_estimators=100; precision: (train=1.000, test=0.000) total time=   1.3s
# [CV 4/4; 99/100] START classifier__max_depth=40, classifier__max_features=1.0, classifier__max_leaf_nodes=900, classifier__min_samples_split=2, classifier__n_estimators=100
# c:\Users\danjr\anaconda3\envs\cycleCollisions\lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# [CV 4/4; 99/100] END classifier__max_depth=40, classifier__max_features=1.0, classifier__max_leaf_nodes=900, classifier__min_samples_split=2, classifier__n_estimators=100; precision: (train=1.000, test=0.000) total time=   1.1s
# [CV 1/4; 100/100] START classifier__max_depth=161, classifier__max_features=0.1, classifier__max_leaf_nodes=200, classifier__min_samples_split=100, classifier__n_estimators=250
# [CV 1/4; 100/100] END classifier__max_depth=161, classifier__max_features=0.1, classifier__max_leaf_nodes=200, classifier__min_samples_split=100, classifier__n_estimators=250; precision: (train=0.310, test=0.114) total time=   0.9s
# [CV 2/4; 100/100] START classifier__max_depth=161, classifier__max_features=0.1, classifier__max_leaf_nodes=200, classifier__min_samples_split=100, classifier__n_estimators=250
# [CV 2/4; 100/100] END classifier__max_depth=161, classifier__max_features=0.1, classifier__max_leaf_nodes=200, classifier__min_samples_split=100, classifier__n_estimators=250; precision: (train=0.374, test=0.108) total time=   1.0s
# [CV 3/4; 100/100] START classifier__max_depth=161, classifier__max_features=0.1, classifier__max_leaf_nodes=200, classifier__min_samples_split=100, classifier__n_estimators=250
# [CV 3/4; 100/100] END classifier__max_depth=161, classifier__max_features=0.1, classifier__max_leaf_nodes=200, classifier__min_samples_split=100, classifier__n_estimators=250; precision: (train=0.240, test=0.069) total time=   1.0s
# [CV 4/4; 100/100] START classifier__max_depth=161, classifier__max_features=0.1, classifier__max_leaf_nodes=200, classifier__min_samples_split=100, classifier__n_estimators=250
# [CV 4/4; 100/100] END classifier__max_depth=161, classifier__max_features=0.1, classifier__max_leaf_nodes=200, classifier__min_samples_split=100, classifier__n_estimators=250; precision: (train=0.308, test=0.095) total time=   1.0s
# 0.4458333333333333 {'classifier__n_estimators': 250, 'classifier__min_samples_split': 18, 'classifier__max_leaf_nodes': 1000, 'classifier__max_features': 1.0, 'classifier__max_depth': 115}
# 0.5

# %% [markdown]
# final model

# %%
min_samples_split = 18
max_features = 1.0
max_depth = 115
max_leaf_nodes = 1000
bootstrap = True
n_estimators = 250

classifier = RandomForestClassifier(n_estimators=n_estimators, min_samples_split=min_samples_split,
                                    max_features=max_features, max_depth=max_depth,
                                    max_leaf_nodes=max_leaf_nodes, bootstrap=bootstrap,
                                    class_weight='balanced')
pipeline = Pipeline([
        ('custom_preprocessor', CustomPreprocessor()),
        ('classifier', classifier)
    ])
pipeline.fit(X_train, y_train)
y_pred = pipeline.predict(X_test)
cm = confusion_matrix(y_test, y_pred)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=pipeline.classes_)
disp.plot()
print(precision_score(y_test, y_pred))

PrecisionRecallDisplay.from_estimator(pipeline, X_test, y_test)
plt.show()
# Out:
# 0.5

# %%
threshold = 0.5
y_pred = pipeline.predict_proba(X_test)[:,1]
y_pred = np.where(y_pred > threshold, 1, 0)
cm = confusion_matrix(y_test, y_pred)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=pipeline.classes_)
disp.plot()
print(precision_score(y_test, y_pred))
# Out:
# 0.5

# %%
features = pipeline.named_steps["custom_preprocessor"].get_feature_names_out()
importances = pipeline.named_steps["classifier"].feature_importances_
feature_importances = sorted(
    [i for i in zip(features, importances)], 
    key=lambda x: x[1],
    reverse=True
)
feature_importances = feature_importances
labels, values = zip(*feature_importances)

plt.figure(figsize=(10, 6))
plt.bar(labels, values, color='skyblue')
plt.xticks(rotation=45, ha='right', fontsize=10)
plt.tight_layout()
plt.show()
